# %% [markdown]
# ** 02805 Social graphs and interactions **
#
# # Basic Stats

# %%
# IPython global cell magic
# %reset
# %matplotlib inline

# import all necessary packages
import bs4 # HTML parser
from collections import Counter, OrderedDict # counting elements and ordering keys in dictionaries
import community # python-louvain package
from __future__ import division # all numbers are float
import datetime # handle date objects
import dateparser # parse any (also foreign) date format to object: https://pypi.python.org/pypi/dateparser
import itertools # iterators for efficient looping
import json # JSON parser
import math # math operations
from matplotlib import pyplot as plt # plotting figures
import mwparserfromhell # parse MediaWiki syntax: https://github.com/earwig/mwparserfromhell
from nameparser import HumanName # parse a human name
import networkx as nx # networks creation library
import nltk # natural language processing
import numpy as np # scientific computing
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
import operator # efficient operator functions
import os # operating system operations, e.g.: with files and folders
import pandas as pd # use easy-to-use data frames for data analysis
import pickle # python data structures as files
from pprint import pprint # print data structures prettier
import re # regex
import requests # request URL content
import urllib # handle special URL chars

# make working directory
directory = os.getcwd() + '/companies'
if not os.path.exists(directory):
    os.makedirs(directory)

# files
ex1_fdat = directory + '/extraction1_data.pkl'
ex2_fdat = directory + '/extraction2_data.pkl'
ex3_tmp_fdat = directory + '/tmp_extraction3_data.pkl'
ex3_fdat = directory + '/extraction3_data.pkl'
merged = directory + '/merged_data.pkl'
extraction_csv = directory + '/company_data.csv'
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## Load Dataset

# %%
# load data from all extractions
companies = dict()
if os.path.isfile(merged):
    with open(merged, 'rb') as f:
        companies = pickle.load(f)

# TODO: remove this
if os.path.isfile(ex1_fdat):
    with open(ex1_fdat, 'rb') as f:
        companies = pickle.load(f)

# %%
# convert from dict into dataframe
comp_df = pd.DataFrame.from_dict(companies, orient='index')
comp_df
# Out:
#                                                                 location_city  \
# &pizza                                                                    NaN
# +Beryll                                                                   NaN
# ...instore                                                                NaN
# 01 Communique                                                             NaN
# 01 Distribution                                                          Rome
# 07th Expansion                                                            NaN
# 0verflow                                               Kanda, Chiyoda , Tokyo
# 1-2-3 (fuel station)                                                      NaN
# 1-800 Contacts                                                            NaN
# 1-800-FREE-411                                                            NaN
# 1-800-Flowers                                                             NaN
# 1-800-GOT-JUNK?                                                           NaN
# 1-Page                                                                    NaN
# 1-UP Studio                                                             Tokyo
# 10 feet                                                                   NaN
# 10,000ft                                                  Seattle, Washington
# 100 Women in Hedge Funds                                                  NaN
# 100% Banco                                                                NaN
# 1000Bulbs.com                                                             NaN
# 1000Memories                                                              NaN
# 108 Shop                                                                  NaN
# 10Bet, LLC                                                                NaN
# 10th Legion Championship Fighting                Hull, London and New Zealand
# 10x (company)                                                             NaN
# 10x Genomics                                                              NaN
# 11 bit studios                                                            NaN
# 112dB                                                                     NaN
# 12 Yard                                                                London
# 12 bis                                                                    NaN
# 123 Money                                                              Dublin
# ...                                                                       ...
# Đuro Đaković (company)                                                    NaN
# Ērenpreiss Bicycles                                                       NaN
# İDO                                                                       NaN
# İZBAN A.Ş.                                                    Alsancak, İzmir
# İhlas Holding                                     Yenibosna, Istanbul, Turkey
# İlbank                                                  Ulus, Çankaya, Ankara
# İletişim Yayınları                                                        NaN
# İnterbank                                                                 NaN
# İsdemir                                                                   NaN
# İstanbul Plak                                                        Istanbul
# İzocam                                                                    NaN
# İş Yatırım                         Isbank Tower 2, Levent, Beşiktaş, Istanbul
# Łódzka Kolej Aglomeracyjna                                                NaN
# Ōigawa Railway                                                            NaN
# Şahinler Holding                                                          NaN
# Şekerbank                                                                 NaN
# Šipad                                                                     NaN
# Škoda Auto                                                                NaN
# Škoda Auto India Private Limited                      Aurangabad, Maharashtra
# Škoda Transportation                                                      NaN
# Škoda Works                                                             Plzeň
# Školska knjiga                                                            NaN
# Štark                                                                     NaN
# Ūkio bankas                                                            Kaunas
# ŽIA valda                                                                 NaN
# Železara Smederevo                                                  Smederevo
# Železničná spoločnosť Slovensko                                           NaN
# Željeznički prevoz Crne Gore                                        Podgorica
# Živnostenská banka                                                        NaN
# Țiriac Holdings                                                           NaN
#
#                                                                                links  \
# &pizza                                                                           NaN
# +Beryll                                {Henri Bendel, Fred Segal, Los Angeles Times}
# ...instore                         {Home Bargains, Heron Foods, Tesco, Shoprite (...
# 01 Communique                                                                     {}
# 01 Distribution                                                                {RAI}
# 07th Expansion                                                 {Alchemist (company)}
# 0verflow                                                                          {}
# 1-2-3 (fuel station)                                         {Statoil Fuel & Retail}
# 1-800 Contacts                                                                   NaN
# 1-800-FREE-411                     {Google, Liberty Media, Tellme Networks, March...
# 1-800-Flowers                      {CompuServe, AOL, Comtex, Martha Stewart Livin...
# 1-800-GOT-JUNK?                    {HSBC Bank Canada, Teradici, The Pantry (resta...
# 1-Page                                                                           NaN
# 1-UP Studio                        {Nintendo Network Service Database, Spike Chun...
# 10 feet                                                                          NaN
# 10,000ft                                                        {Artefact (company)}
# 100 Women in Hedge Funds                                                         NaN
# 100% Banco                                                                        {}
# 1000Bulbs.com                                                                    NaN
# 1000Memories                       {Wieden+Kennedy, McKinsey & Company, Greylock ...
# 108 Shop                           {Tom's Convenience Store, Delhaize Group, Mini...
# 10Bet, LLC                                                                       NaN
# 10th Legion Championship Fighting  {Battlecade Extreme Fighting, Shark Fights, Af...
# 10x (company)                                                                     {}
# 10x Genomics                                                                     NaN
# 11 bit studios                                     {CD Projekt, Metropolis Software}
# 112dB                                                                            NaN
# 12 Yard                            {ITV Studios, Wireless Group, STV Group (Scotl...
# 12 bis                                                                           NaN
# 123 Money                                                      {RSA Insurance Group}
# ...                                                                              ...
# Đuro Đaković (company)                                                           NaN
# Ērenpreiss Bicycles                                   {G. Ērenpreis Bicycle Factory}
# İDO                                                       {İDO, Damen Group, Austal}
# İZBAN A.Ş.                         {Hyundai Rotem, Turkish State Railways, Constr...
# İhlas Holding                      {Migros Türk, Akbank, Petrol Ofisi, Ülker, Coc...
# İlbank                                                                            {}
# İletişim Yayınları                                                                {}
# İnterbank                                                                        NaN
# İsdemir                                                                          NaN
# İstanbul Plak                                                                     {}
# İzocam                             {Migros Türk, Akbank, Petrol Ofisi, Ülker, Coc...
# İş Yatırım                         {DYO Boya Fabrikaları, Renaissance Capital (Ru...
# Łódzka Kolej Aglomeracyjna         {Arriva RP, PKP Polskie Linie Kolejowe, Lotos ...
# Ōigawa Railway                                                                   NaN
# Şahinler Holding                                                                  {}
# Şekerbank                          {Migros Türk, Akbank, Abank, Coca-Cola Içecek,...
# Šipad                                                                             {}
# Škoda Auto                                                                       NaN
# Škoda Auto India Private Limited   {DKW, Lamborghini, Honda, Ford Motor Company, ...
# Škoda Transportation               {Rīgas Satiksme, Transtech (Finnish company), ...
# Škoda Works                        {Ganz Works, České dráhy, Škoda Auto, Škoda Tr...
# Školska knjiga                                                                   NaN
# Štark                                                                            NaN
# Ūkio bankas                                        {Nasdaq Nordic, General Electric}
# ŽIA valda                                                                        NaN
# Železara Smederevo                                       {Hesteel Group, U.S. Steel}
# Železničná spoločnosť Slovensko                                                  NaN
# Željeznički prevoz Crne Gore       {Deutsche Bahn, Calea Ferată din Moldova, Iarn...
# Živnostenská banka                                                               NaN
# Țiriac Holdings                                                            {Allianz}
#
#                                                                             wiki_url  \
# &pizza                             https://en.wikipedia.org/w/index.php?title=%26...
# +Beryll                            https://en.wikipedia.org/w/index.php?title=%2B...
# ...instore                         https://en.wikipedia.org/w/index.php?title=......
# 01 Communique                      https://en.wikipedia.org/w/index.php?title=01+...
# 01 Distribution                    https://en.wikipedia.org/w/index.php?title=01+...
# 07th Expansion                     https://en.wikipedia.org/w/index.php?title=07t...
# 0verflow                           https://en.wikipedia.org/w/index.php?title=0ve...
# 1-2-3 (fuel station)               https://en.wikipedia.org/w/index.php?title=1-2...
# 1-800 Contacts                     https://en.wikipedia.org/w/index.php?title=1-8...
# 1-800-FREE-411                     https://en.wikipedia.org/w/index.php?title=1-8...
# 1-800-Flowers                      https://en.wikipedia.org/w/index.php?title=1-8...
# 1-800-GOT-JUNK?                    https://en.wikipedia.org/w/index.php?title=1-8...
# 1-Page                             https://en.wikipedia.org/w/index.php?title=1-Page
# 1-UP Studio                        https://en.wikipedia.org/w/index.php?title=1-U...
# 10 feet                            https://en.wikipedia.org/w/index.php?title=10+...
# 10,000ft                           https://en.wikipedia.org/w/index.php?title=10%...
# 100 Women in Hedge Funds           https://en.wikipedia.org/w/index.php?title=100...
# 100% Banco                         https://en.wikipedia.org/w/index.php?title=100...
# 1000Bulbs.com                      https://en.wikipedia.org/w/index.php?title=100...
# 1000Memories                       https://en.wikipedia.org/w/index.php?title=100...
# 108 Shop                           https://en.wikipedia.org/w/index.php?title=108...
# 10Bet, LLC                         https://en.wikipedia.org/w/index.php?title=10B...
# 10th Legion Championship Fighting  https://en.wikipedia.org/w/index.php?title=10t...
# 10x (company)                      https://en.wikipedia.org/w/index.php?title=10x...
# 10x Genomics                       https://en.wikipedia.org/w/index.php?title=10x...
# 11 bit studios                     https://en.wikipedia.org/w/index.php?title=11+...
# 112dB                               https://en.wikipedia.org/w/index.php?title=112dB
# 12 Yard                            https://en.wikipedia.org/w/index.php?title=12+...
# 12 bis                             https://en.wikipedia.org/w/index.php?title=12+bis
# 123 Money                          https://en.wikipedia.org/w/index.php?title=123...
# ...                                                                              ...
# Đuro Đaković (company)             https://en.wikipedia.org/w/index.php?title=%C4...
# Ērenpreiss Bicycles                https://en.wikipedia.org/w/index.php?title=%C4...
# İDO                                https://en.wikipedia.org/w/index.php?title=%C4...
# İZBAN A.Ş.                         https://en.wikipedia.org/w/index.php?title=%C4...
# İhlas Holding                      https://en.wikipedia.org/w/index.php?title=%C4...
# İlbank                             https://en.wikipedia.org/w/index.php?title=%C4...
# İletişim Yayınları                 https://en.wikipedia.org/w/index.php?title=%C4...
# İnterbank                          https://en.wikipedia.org/w/index.php?title=%C4...
# İsdemir                            https://en.wikipedia.org/w/index.php?title=%C4...
# İstanbul Plak                      https://en.wikipedia.org/w/index.php?title=%C4...
# İzocam                             https://en.wikipedia.org/w/index.php?title=%C4...
# İş Yatırım                         https://en.wikipedia.org/w/index.php?title=%C4...
# Łódzka Kolej Aglomeracyjna         https://en.wikipedia.org/w/index.php?title=%C5...
# Ōigawa Railway                     https://en.wikipedia.org/w/index.php?title=%C5...
# Şahinler Holding                   https://en.wikipedia.org/w/index.php?title=%C5...
# Şekerbank                          https://en.wikipedia.org/w/index.php?title=%C5...
# Šipad                              https://en.wikipedia.org/w/index.php?title=%C5...
# Škoda Auto                         https://en.wikipedia.org/w/index.php?title=%C5...
# Škoda Auto India Private Limited   https://en.wikipedia.org/w/index.php?title=%C5...
# Škoda Transportation               https://en.wikipedia.org/w/index.php?title=%C5...
# Škoda Works                        https://en.wikipedia.org/w/index.php?title=%C5...
# Školska knjiga                     https://en.wikipedia.org/w/index.php?title=%C5...
# Štark                              https://en.wikipedia.org/w/index.php?title=%C5...
# Ūkio bankas                        https://en.wikipedia.org/w/index.php?title=%C5...
# ŽIA valda                          https://en.wikipedia.org/w/index.php?title=%C5...
# Železara Smederevo                 https://en.wikipedia.org/w/index.php?title=%C5...
# Železničná spoločnosť Slovensko    https://en.wikipedia.org/w/index.php?title=%C5...
# Željeznički prevoz Crne Gore       https://en.wikipedia.org/w/index.php?title=%C5...
# Živnostenská banka                 https://en.wikipedia.org/w/index.php?title=%C5...
# Țiriac Holdings                    https://en.wikipedia.org/w/index.php?title=%C8...
#
#                                                                                 name  \
# &pizza                                                                           NaN
# +Beryll                                                                      +Beryll
# ...instore                                                                ...instore
# 01 Communique                                                          01 Communique
# 01 Distribution                                                '''01 Distribution'''
# 07th Expansion                                                        07th Expansion
# 0verflow                                                                    0verflow
# 1-2-3 (fuel station)                                                           1-2-3
# 1-800 Contacts                                                                   NaN
# 1-800-FREE-411                                                               Marchex
# 1-800-Flowers                                                1-800-Flowers.com, Inc.
# 1-800-GOT-JUNK?                                                      1-800-GOT-JUNK?
# 1-Page                                                                           NaN
# 1-UP Studio                                                         1-UP Studio Inc.
# 10 feet                                                                          NaN
# 10,000ft                                                                    10,000ft
# 100 Women in Hedge Funds                                                         NaN
# 100% Banco                                                                 100 Banco
# 1000Bulbs.com                                                                    NaN
# 1000Memories                                                            1000Memories
# 108 Shop                                                                    108 Shop
# 10Bet, LLC                                                                       NaN
# 10th Legion Championship Fighting                  10th Legion Championship Fighting
# 10x (company)                                                                    10x
# 10x Genomics                                                                     NaN
# 11 bit studios                                                   11 bit studios s.a.
# 112dB                                                                            NaN
# 12 Yard                                                                      12 Yard
# 12 bis                                                                           NaN
# 123 Money                                                                     123.ie
# ...                                                                              ...
# Đuro Đaković (company)                                                           NaN
# Ērenpreiss Bicycles                                              Ērenpreiss Bicycles
# İDO                                            [Istanbul Fast Ferries Co. Inc., İDO]
# İZBAN A.Ş.                                              İzmir Banliyö Anonim Şirketi
# İhlas Holding                                                     İhlas Holding A.Ş.
# İlbank                                                                   İlbank A.Ş.
# İletişim Yayınları                                                İletişim Yayınları
# İnterbank                                                                        NaN
# İsdemir                                                                          NaN
# İstanbul Plak                                                          İstanbul Plak
# İzocam                                                 İZOCAM TİCARET VE SANAYİ A.Ş.
# İş Yatırım                                                             IS Investment
# Łódzka Kolej Aglomeracyjna            [Łódzka Kolej Aglomeracyjna - ŁKA, Sp. z o.o.]
# Ōigawa Railway                                                                   NaN
# Şahinler Holding                                                    Şahinler Holding
# Şekerbank                                                           Şekerbank T.A.Ş.
# Šipad                                                                    Šipad, d.d.
# Škoda Auto                                                                       NaN
# Škoda Auto India Private Limited                           Škoda Auto India Pvt Ltd.
# Škoda Transportation                                       Škoda Transportation a.s.
# Škoda Works                                                              Škoda, a.s.
# Školska knjiga                                                                   NaN
# Štark                                                                            NaN
# Ūkio bankas                                                           AB Ūkio bankas
# ŽIA valda                                                                        NaN
# Železara Smederevo                                                Železara Smederevo
# Železničná spoločnosť Slovensko                                                  NaN
# Željeznički prevoz Crne Gore       [Railway transport of Montenegro, Željeznički ...
# Živnostenská banka                                                               NaN
# Țiriac Holdings                                                 Ţiriac Holdings Ltd.
#
#                                                            wiki_name  \
# &pizza                                                        &pizza
# +Beryll                                                      +Beryll
# ...instore                                                ...instore
# 01 Communique                                          01 Communique
# 01 Distribution                                      01 Distribution
# 07th Expansion                                        07th Expansion
# 0verflow                                                    0verflow
# 1-2-3 (fuel station)                            1-2-3 (fuel station)
# 1-800 Contacts                                        1-800 Contacts
# 1-800-FREE-411                                        1-800-FREE-411
# 1-800-Flowers                                          1-800-Flowers
# 1-800-GOT-JUNK?                                      1-800-GOT-JUNK?
# 1-Page                                                        1-Page
# 1-UP Studio                                              1-UP Studio
# 10 feet                                                      10 feet
# 10,000ft                                                    10,000ft
# 100 Women in Hedge Funds                    100 Women in Hedge Funds
# 100% Banco                                                100% Banco
# 1000Bulbs.com                                          1000Bulbs.com
# 1000Memories                                            1000Memories
# 108 Shop                                                    108 Shop
# 10Bet, LLC                                                10Bet, LLC
# 10th Legion Championship Fighting  10th Legion Championship Fighting
# 10x (company)                                          10x (company)
# 10x Genomics                                            10x Genomics
# 11 bit studios                                        11 bit studios
# 112dB                                                          112dB
# 12 Yard                                                      12 Yard
# 12 bis                                                        12 bis
# 123 Money                                                  123 Money
# ...                                                              ...
# Đuro Đaković (company)                        Đuro Đaković (company)
# Ērenpreiss Bicycles                              Ērenpreiss Bicycles
# İDO                                                              İDO
# İZBAN A.Ş.                                                İZBAN A.Ş.
# İhlas Holding                                          İhlas Holding
# İlbank                                                        İlbank
# İletişim Yayınları                                İletişim Yayınları
# İnterbank                                                  İnterbank
# İsdemir                                                      İsdemir
# İstanbul Plak                                          İstanbul Plak
# İzocam                                                        İzocam
# İş Yatırım                                                İş Yatırım
# Łódzka Kolej Aglomeracyjna                Łódzka Kolej Aglomeracyjna
# Ōigawa Railway                                        Ōigawa Railway
# Şahinler Holding                                    Şahinler Holding
# Şekerbank                                                  Şekerbank
# Šipad                                                          Šipad
# Škoda Auto                                                Škoda Auto
# Škoda Auto India Private Limited    Škoda Auto India Private Limited
# Škoda Transportation                            Škoda Transportation
# Škoda Works                                              Škoda Works
# Školska knjiga                                        Školska knjiga
# Štark                                                          Štark
# Ūkio bankas                                              Ūkio bankas
# ŽIA valda                                                  ŽIA valda
# Železara Smederevo                                Železara Smederevo
# Železničná spoločnosť Slovensko      Železničná spoločnosť Slovensko
# Željeznički prevoz Crne Gore            Željeznički prevoz Crne Gore
# Živnostenská banka                                Živnostenská banka
# Țiriac Holdings                                      Țiriac Holdings
#
#                                                                      name_url_quoted  \
# &pizza                                                                      %26pizza
# +Beryll                                                                    %2BBeryll
# ...instore                                                                ...instore
# 01 Communique                                                          01+Communique
# 01 Distribution                                                      01+Distribution
# 07th Expansion                                                        07th+Expansion
# 0verflow                                                                    0verflow
# 1-2-3 (fuel station)                                        1-2-3+%28fuel+station%29
# 1-800 Contacts                                                        1-800+Contacts
# 1-800-FREE-411                                                        1-800-FREE-411
# 1-800-Flowers                                                          1-800-Flowers
# 1-800-GOT-JUNK?                                                    1-800-GOT-JUNK%3F
# 1-Page                                                                        1-Page
# 1-UP Studio                                                              1-UP+Studio
# 10 feet                                                                      10+feet
# 10,000ft                                                                  10%2C000ft
# 100 Women in Hedge Funds                                    100+Women+in+Hedge+Funds
# 100% Banco                                                              100%25+Banco
# 1000Bulbs.com                                                          1000Bulbs.com
# 1000Memories                                                            1000Memories
# 108 Shop                                                                    108+Shop
# 10Bet, LLC                                                              10Bet%2C+LLC
# 10th Legion Championship Fighting                  10th+Legion+Championship+Fighting
# 10x (company)                                                      10x+%28company%29
# 10x Genomics                                                            10x+Genomics
# 11 bit studios                                                        11+bit+studios
# 112dB                                                                          112dB
# 12 Yard                                                                      12+Yard
# 12 bis                                                                        12+bis
# 123 Money                                                                  123+Money
# ...                                                                              ...
# Đuro Đaković (company)                     %C4%90uro+%C4%90akovi%C4%87+%28company%29
# Ērenpreiss Bicycles                                         %C4%92renpreiss+Bicycles
# İDO                                                                         %C4%B0DO
# İZBAN A.Ş.                                                      %C4%B0ZBAN+A.%C5%9E.
# İhlas Holding                                                     %C4%B0hlas+Holding
# İlbank                                                                   %C4%B0lbank
# İletişim Yayınları                            %C4%B0leti%C5%9Fim+Yay%C4%B1nlar%C4%B1
# İnterbank                                                             %C4%B0nterbank
# İsdemir                                                                 %C4%B0sdemir
# İstanbul Plak                                                     %C4%B0stanbul+Plak
# İzocam                                                                   %C4%B0zocam
# İş Yatırım                                            %C4%B0%C5%9F+Yat%C4%B1r%C4%B1m
# Łódzka Kolej Aglomeracyjna                      %C5%81%C3%B3dzka+Kolej+Aglomeracyjna
# Ōigawa Railway                                                   %C5%8Cigawa+Railway
# Şahinler Holding                                               %C5%9Eahinler+Holding
# Şekerbank                                                             %C5%9Eekerbank
# Šipad                                                                     %C5%A0ipad
# Škoda Auto                                                           %C5%A0koda+Auto
# Škoda Auto India Private Limited               %C5%A0koda+Auto+India+Private+Limited
# Škoda Transportation                                       %C5%A0koda+Transportation
# Škoda Works                                                         %C5%A0koda+Works
# Školska knjiga                                                   %C5%A0kolska+knjiga
# Štark                                                                     %C5%A0tark
# Ūkio bankas                                                         %C5%AAkio+bankas
# ŽIA valda                                                             %C5%BDIA+valda
# Železara Smederevo                                           %C5%BDelezara+Smederevo
# Železničná spoločnosť Slovensko    %C5%BDelezni%C4%8Dn%C3%A1+spolo%C4%8Dnos%C5%A5...
# Željeznički prevoz Crne Gore                  %C5%BDeljezni%C4%8Dki+prevoz+Crne+Gore
# Živnostenská banka                                      %C5%BDivnostensk%C3%A1+banka
# Țiriac Holdings                                                 %C8%9Airiac+Holdings
#
#                                                                         wiki_api_url  \
# &pizza                                                                           NaN
# +Beryll                            https://en.wikipedia.org/w/api.php?&action=par...
# ...instore                         https://en.wikipedia.org/w/api.php?&action=par...
# 01 Communique                      https://en.wikipedia.org/w/api.php?&action=par...
# 01 Distribution                    https://en.wikipedia.org/w/api.php?&action=par...
# 07th Expansion                     https://en.wikipedia.org/w/api.php?&action=par...
# 0verflow                           https://en.wikipedia.org/w/api.php?&action=par...
# 1-2-3 (fuel station)               https://en.wikipedia.org/w/api.php?&action=par...
# 1-800 Contacts                                                                   NaN
# 1-800-FREE-411                     https://en.wikipedia.org/w/api.php?&action=par...
# 1-800-Flowers                      https://en.wikipedia.org/w/api.php?&action=par...
# 1-800-GOT-JUNK?                    https://en.wikipedia.org/w/api.php?&action=par...
# 1-Page                                                                           NaN
# 1-UP Studio                        https://en.wikipedia.org/w/api.php?&action=par...
# 10 feet                                                                          NaN
# 10,000ft                           https://en.wikipedia.org/w/api.php?&action=par...
# 100 Women in Hedge Funds                                                         NaN
# 100% Banco                         https://en.wikipedia.org/w/api.php?&action=par...
# 1000Bulbs.com                                                                    NaN
# 1000Memories                       https://en.wikipedia.org/w/api.php?&action=par...
# 108 Shop                           https://en.wikipedia.org/w/api.php?&action=par...
# 10Bet, LLC                                                                       NaN
# 10th Legion Championship Fighting  https://en.wikipedia.org/w/api.php?&action=par...
# 10x (company)                      https://en.wikipedia.org/w/api.php?&action=par...
# 10x Genomics                                                                     NaN
# 11 bit studios                     https://en.wikipedia.org/w/api.php?&action=par...
# 112dB                                                                            NaN
# 12 Yard                            https://en.wikipedia.org/w/api.php?&action=par...
# 12 bis                                                                           NaN
# 123 Money                          https://en.wikipedia.org/w/api.php?&action=par...
# ...                                                                              ...
# Đuro Đaković (company)                                                           NaN
# Ērenpreiss Bicycles                https://en.wikipedia.org/w/api.php?&action=par...
# İDO                                https://en.wikipedia.org/w/api.php?&action=par...
# İZBAN A.Ş.                         https://en.wikipedia.org/w/api.php?&action=par...
# İhlas Holding                      https://en.wikipedia.org/w/api.php?&action=par...
# İlbank                             https://en.wikipedia.org/w/api.php?&action=par...
# İletişim Yayınları                 https://en.wikipedia.org/w/api.php?&action=par...
# İnterbank                                                                        NaN
# İsdemir                                                                          NaN
# İstanbul Plak                      https://en.wikipedia.org/w/api.php?&action=par...
# İzocam                             https://en.wikipedia.org/w/api.php?&action=par...
# İş Yatırım                         https://en.wikipedia.org/w/api.php?&action=par...
# Łódzka Kolej Aglomeracyjna         https://en.wikipedia.org/w/api.php?&action=par...
# Ōigawa Railway                                                                   NaN
# Şahinler Holding                   https://en.wikipedia.org/w/api.php?&action=par...
# Şekerbank                          https://en.wikipedia.org/w/api.php?&action=par...
# Šipad                              https://en.wikipedia.org/w/api.php?&action=par...
# Škoda Auto                                                                       NaN
# Škoda Auto India Private Limited   https://en.wikipedia.org/w/api.php?&action=par...
# Škoda Transportation               https://en.wikipedia.org/w/api.php?&action=par...
# Škoda Works                        https://en.wikipedia.org/w/api.php?&action=par...
# Školska knjiga                                                                   NaN
# Štark                                                                            NaN
# Ūkio bankas                        https://en.wikipedia.org/w/api.php?&action=par...
# ŽIA valda                                                                        NaN
# Železara Smederevo                 https://en.wikipedia.org/w/api.php?&action=par...
# Železničná spoločnosť Slovensko                                                  NaN
# Željeznički prevoz Crne Gore       https://en.wikipedia.org/w/api.php?&action=par...
# Živnostenská banka                                                               NaN
# Țiriac Holdings                    https://en.wikipedia.org/w/api.php?&action=par...
#
#                                   is_company  wiki_page_id   location_country  \
# &pizza                                   NaN      47858476                NaN
# +Beryll                                 True      13860681                NaN
# ...instore                              True       9291975                NaN
# 01 Communique                           True      15244876                NaN
# 01 Distribution                         True      46724099              Italy
# 07th Expansion                          True       5936289                NaN
# 0verflow                                True      10387049              Japan
# 1-2-3 (fuel station)                    True      14018485                NaN
# 1-800 Contacts                           NaN       4613366                NaN
# 1-800-FREE-411                          True      18480351                NaN
# 1-800-Flowers                           True       4048045                NaN
# 1-800-GOT-JUNK?                         True       5579899                NaN
# 1-Page                                   NaN      44914210                NaN
# 1-UP Studio                             True       1549290              Japan
# 10 feet                                  NaN       7481455                NaN
# 10,000ft                                True      37913068  The United States
# 100 Women in Hedge Funds                 NaN      33740186                NaN
# 100% Banco                              True      23958183                NaN
# 1000Bulbs.com                            NaN      48249798                NaN
# 1000Memories                            True      28493016                NaN
# 108 Shop                                True      23183503                NaN
# 10Bet, LLC                               NaN      40634514                NaN
# 10th Legion Championship Fighting       True      29825173        England, UK
# 10x (company)                           True      51084325                NaN
# 10x Genomics                             NaN      52236081                NaN
# 11 bit studios                          True      38544394                NaN
# 112dB                                    NaN      23239375                NaN
# 12 Yard                                 True       3052956                 UK
# 12 bis                                   NaN      29163465                NaN
# 123 Money                               True      35861728            Ireland
# ...                                      ...           ...                ...
# Đuro Đaković (company)                   NaN      10072143                NaN
# Ērenpreiss Bicycles                     True      49226907                NaN
# İDO                                     True       6286396                NaN
# İZBAN A.Ş.                              True      30483454             Turkey
# İhlas Holding                           True      39611864                NaN
# İlbank                                  True      42266068                NaN
# İletişim Yayınları                      True      39646855                NaN
# İnterbank                                NaN      40034174                NaN
# İsdemir                                  NaN       8722407                NaN
# İstanbul Plak                           True      12807361             Turkey
# İzocam                                  True      43380582             Turkey
# İş Yatırım                              True      34538340                NaN
# Łódzka Kolej Aglomeracyjna              True      47269370                NaN
# Ōigawa Railway                           NaN      10752196                NaN
# Şahinler Holding                        True      18393229                NaN
# Şekerbank                               True      27193229             Turkey
# Šipad                                   True      46874309                NaN
# Škoda Auto                               NaN         26970                NaN
# Škoda Auto India Private Limited        True      22342461              India
# Škoda Transportation                    True      42128619                NaN
# Škoda Works                             True        672117     Czech Republic
# Školska knjiga                           NaN       3125604                NaN
# Štark                                    NaN       5056670                NaN
# Ūkio bankas                             True       7165143          Lithuania
# ŽIA valda                                NaN      19022570                NaN
# Železara Smederevo                      True      40327203             Serbia
# Železničná spoločnosť Slovensko          NaN      17402318                NaN
# Željeznički prevoz Crne Gore            True      39357175         Montenegro
# Živnostenská banka                       NaN       7906982                NaN
# Țiriac Holdings                         True      10868077                NaN
#
#                                    ...                        type  \
# &pizza                             ...                         NaN
# +Beryll                            ...                     private
# ...instore                         ...                      Retail
# 01 Communique                      ...    Public Listed Company ()
# 01 Distribution                    ...              public company
# 07th Expansion                     ...                         NaN
# 0verflow                           ...          Private subsidiary
# 1-2-3 (fuel station)               ...                Fuel station
# 1-800 Contacts                     ...                         NaN
# 1-800-FREE-411                     ...                      Public
# 1-800-Flowers                      ...                      Public
# 1-800-GOT-JUNK?                    ...             Private Company
# 1-Page                             ...                         NaN
# 1-UP Studio                        ...                  Subsidiary
# 10 feet                            ...                         NaN
# 10,000ft                           ...      Privately held company
# 100 Women in Hedge Funds           ...                         NaN
# 100% Banco                         ...         Joint stock company
# 1000Bulbs.com                      ...                         NaN
# 1000Memories                       ...              Privately held
# 108 Shop                           ...                         NaN
# 10Bet, LLC                         ...                         NaN
# 10th Legion Championship Fighting  ...                     Private
# 10x (company)                      ...                     Private
# 10x Genomics                       ...                         NaN
# 11 bit studios                     ...                     Private
# 112dB                              ...                         NaN
# 12 Yard                            ...                         NaN
# 12 bis                             ...                         NaN
# 123 Money                          ...                         NaN
# ...                                ...                         ...
# Đuro Đaković (company)             ...                         NaN
# Ērenpreiss Bicycles                ...                         NaN
# İDO                                ...                      Public
# İZBAN A.Ş.                         ...                      Public
# İhlas Holding                      ...               Anonim şirket
# İlbank                             ...                        Bank
# İletişim Yayınları                 ...                     Private
# İnterbank                          ...                         NaN
# İsdemir                            ...                         NaN
# İstanbul Plak                      ...                     Private
# İzocam                             ...                         NaN
# İş Yatırım                         ...                         NaN
# Łódzka Kolej Aglomeracyjna         ...                        Ltd.
# Ōigawa Railway                     ...                         NaN
# Şahinler Holding                   ...      Public/Private company
# Şekerbank                          ...                         NaN
# Šipad                              ...                      Public
# Škoda Auto                         ...                         NaN
# Škoda Auto India Private Limited   ...                  Subsidiary
# Škoda Transportation               ...         Joint-stock company
# Škoda Works                        ...                     Private
# Školska knjiga                     ...                         NaN
# Štark                              ...                         NaN
# Ūkio bankas                        ...              public company
# ŽIA valda                          ...                         NaN
# Železara Smederevo                 ...                         LLC
# Železničná spoločnosť Slovensko    ...                         NaN
# Željeznički prevoz Crne Gore       ...            Government-owned
# Živnostenská banka                 ...                         NaN
# Țiriac Holdings                    ...                     Private
#
#                                                                             industry  \
# &pizza                                                                           NaN
# +Beryll                                                          Fashion accessories
# ...instore                                                                       NaN
# 01 Communique                                                               Software
# 01 Distribution                                                     films, animation
# 07th Expansion                     [Sound novels, Video game industry, Interactiv...
# 0verflow                                [Interactive entertainment, Brand novelties]
# 1-2-3 (fuel station)                                                             NaN
# 1-800 Contacts                                                                   NaN
# 1-800-FREE-411                                                    Telecommunications
# 1-800-Flowers                                                                 Retail
# 1-800-GOT-JUNK?                                                         Junk Removal
# 1-Page                                                                           NaN
# 1-UP Studio                                                              Video games
# 10 feet                                                                          NaN
# 10,000ft                                                                         NaN
# 100 Women in Hedge Funds                                                         NaN
# 100% Banco                                                     Finance and Insurance
# 1000Bulbs.com                                                                    NaN
# 1000Memories                                                                     NaN
# ...
# 1-800-Flowers                      {u'wiki_raw_code': u'1-800-flowers com.svg', u...
# 1-800-GOT-JUNK?                    {u'wiki_raw_code': u'1800GOTJUNK Logo.svg', u'...
# 1-Page                                                                           NaN
# 1-UP Studio                                                                      NaN
# 10 feet                                                                          NaN
# 10,000ft                           {u'wiki_raw_code': u'10,000ft logo.png', u'wik...
# 100 Women in Hedge Funds                                                         NaN
# 100% Banco                         {u'wiki_raw_code': u'[[File:100% Banco logo.pn...
# 1000Bulbs.com                                                                    NaN
# 1000Memories                       {u'wiki_raw_code': u'[[Image:1000memories.png]...
# 108 Shop                                                                         NaN
# 10Bet, LLC                                                                       NaN
# 10th Legion Championship Fighting  {u'wiki_raw_code': u'[[File:10thLegionLogo.jpg...
# 10x (company)                                                                    NaN
# 10x Genomics                                                                     NaN
# 11 bit studios                                                                   NaN
# 112dB                                                                            NaN
# 12 Yard                            {u'wiki_raw_code': u'File:12 Yard Productions ...
# 12 bis                                                                           NaN
# 123 Money                                                                        NaN
# ...                                                                              ...
# Đuro Đaković (company)                                                           NaN
# Ērenpreiss Bicycles                {u'wiki_raw_code': u'[[File:Erenpreiss logo.jp...
# İDO                                {u'wiki_raw_code': u'[[File:Istanbul Sea Buses...
# İZBAN A.Ş.                                                                       NaN
# İhlas Holding                                                                    NaN
# İlbank                                                                           NaN
# İletişim Yayınları                                                               NaN
# İnterbank                                                                        NaN
# İsdemir                                                                          NaN
# İstanbul Plak                                                                    NaN
# İzocam                                                                           NaN
# İş Yatırım                         {u'wiki_raw_code': u'Is Investment Logo.png', ...
# Łódzka Kolej Aglomeracyjna         {u'wiki_raw_code': u'[[File:Łódzka Kolej Aglom...
# Ōigawa Railway                                                                   NaN
# Şahinler Holding                                                                 NaN
# Şekerbank                          {u'wiki_raw_code': u'[[File:Şekerbank Logo.jpg...
# Šipad                              {u'wiki_raw_code': u'[[File:Šipad d.d.jpg|155p...
# Škoda Auto                                                                       NaN
# Škoda Auto India Private Limited   {u'wiki_raw_code': u'[[File:Skoda Auto logo (2...
# Škoda Transportation               {u'wiki_raw_code': u'Škoda Transportation logo...
# Škoda Works                        {u'wiki_raw_code': u'Škoda Works logo.png', u'...
# Školska knjiga                                                                   NaN
# Štark                                                                            NaN
# Ūkio bankas                        {u'wiki_raw_code': u'[[File:Ukio bankas logo.j...
# ŽIA valda                                                                        NaN
# Železara Smederevo                                                               NaN
# Železničná spoločnosť Slovensko                                                  NaN
# Željeznički prevoz Crne Gore       {u'wiki_raw_code': u'[[File:ZCGlogo.png]]', u'...
# Živnostenská banka                                                               NaN
# Țiriac Holdings                    {u'wiki_raw_code': u'[[Image:Tiriac-Holdings.p...
#
#                                                      defunct  \
# &pizza                                                   NaN
# +Beryll                                                  NaN
# ...instore                                              2009
# 01 Communique                                            NaN
# 01 Distribution                                          NaN
# 07th Expansion                                           NaN
# 0verflow                                                 NaN
# 1-2-3 (fuel station)                                     NaN
# 1-800 Contacts                                           NaN
# 1-800-FREE-411                                           NaN
# 1-800-Flowers                                            NaN
# 1-800-GOT-JUNK?                                          NaN
# 1-Page                                                   NaN
# 1-UP Studio                                              NaN
# 10 feet                                                  NaN
# 10,000ft                                                 NaN
# 100 Women in Hedge Funds                                 NaN
# 100% Banco                                               NaN
# 1000Bulbs.com                                            NaN
# 1000Memories                                             NaN
# 108 Shop                                                 NaN
# 10Bet, LLC                                               NaN
# 10th Legion Championship Fighting                        NaN
# 10x (company)                                            NaN
# 10x Genomics                                             NaN
# 11 bit studios                                           NaN
# 112dB                                                    NaN
# 12 Yard                                                  NaN
# 12 bis                                                   NaN
# 123 Money                                                NaN
# ...                                                      ...
# Đuro Đaković (company)                                   NaN
# Ērenpreiss Bicycles                                      NaN
# İDO                                                      NaN
# İZBAN A.Ş.                                               NaN
# İhlas Holding                                            NaN
# İlbank                                                   NaN
# İletişim Yayınları                                       NaN
# İnterbank                                                NaN
# İsdemir                                                  NaN
# İstanbul Plak                                            NaN
# İzocam                                                   NaN
# İş Yatırım                                               NaN
# Łódzka Kolej Aglomeracyjna                               NaN
# Ōigawa Railway                                           NaN
# Şahinler Holding                                         NaN
# Şekerbank                                                NaN
# Šipad                                                    NaN
# Škoda Auto                                               NaN
# Škoda Auto India Private Limited                         NaN
# Škoda Transportation                                     NaN
# Škoda Works                              1999-11-25 00:00:00
# Školska knjiga                                           NaN
# Štark                                                    NaN
# Ūkio bankas                        As of February 12th, 2013
# ŽIA valda                                                NaN
# Železara Smederevo                                       NaN
# Železničná spoločnosť Slovensko                          NaN
# Željeznički prevoz Crne Gore                             NaN
# Živnostenská banka                                       NaN
# Țiriac Holdings                                          NaN
#
#                                                                     parent  \
# &pizza                                                                 NaN
# +Beryll                                                                NaN
# ...instore                                                             NaN
# 01 Communique                                                          NaN
# 01 Distribution                                                        NaN
# 07th Expansion                                                         NaN
# 0verflow                                                        Stack Ltd.
# 1-2-3 (fuel station)                                                   NaN
# 1-800 Contacts                                                         NaN
# 1-800-FREE-411                                          Liberty Media (9%)
# 1-800-Flowers                                                          NaN
# 1-800-GOT-JUNK?                                                        NaN
# 1-Page                                                                 NaN
# 1-UP Studio                                                       Nintendo
# 10 feet                                                                NaN
# 10,000ft                                                               NaN
# 100 Women in Hedge Funds                                               NaN
# 100% Banco                                                        Beserfin
# 1000Bulbs.com                                                          NaN
# 1000Memories                                                           NaN
# 108 Shop                                                        Saha Group
# 10Bet, LLC                                                             NaN
# 10th Legion Championship Fighting                                      NaN
# 10x (company)                                                          NaN
# 10x Genomics                                                           NaN
# 11 bit studios                                                         NaN
# 112dB                                                                  NaN
# 12 Yard                                                        ITV Studios
# 12 bis                                                                 NaN
# 123 Money                                              RSA Insurance Group
# ...                                                                    ...
# Đuro Đaković (company)                                                 NaN
# Ērenpreiss Bicycles                                                    NaN
# İDO                                                                    NaN
# İZBAN A.Ş.                         [TCDD (50%),  İzmir Municipality (50%)]
# İhlas Holding                                                          NaN
# İlbank                                                                 NaN
# İletişim Yayınları                                                     NaN
# İnterbank                                                              NaN
# İsdemir                                                                NaN
# İstanbul Plak                                                          NaN
# İzocam                                                                 NaN
# İş Yatırım                                                             NaN
# Łódzka Kolej Aglomeracyjna                                             NaN
# Ōigawa Railway                                                         NaN
# Şahinler Holding                                                       NaN
# Şekerbank                                                              NaN
# Šipad                                                                  NaN
# Škoda Auto                                                             NaN
# Škoda Auto India Private Limited                                Škoda Auto
# Škoda Transportation                  CEIL (Central Europe Industries) LTD
# Škoda Works                                                            NaN
# Školska knjiga                                                         NaN
# Štark                                                                  NaN
# Ūkio bankas                                                            NaN
# ŽIA valda                                                              NaN
# Železara Smederevo                                           Hesteel Group
# Železničná spoločnosť Slovensko                                        NaN
# Željeznički prevoz Crne Gore                                           NaN
# Živnostenská banka                                                     NaN
# Țiriac Holdings                                                        NaN
#
#                                   subsid
# &pizza                               NaN
# +Beryll                              NaN
# ...instore                           NaN
# 01 Communique                        NaN
# 01 Distribution                      NaN
# 07th Expansion                       NaN
# 0verflow                             NaN
# 1-2-3 (fuel station)                 NaN
# 1-800 Contacts                       NaN
# 1-800-FREE-411                       NaN
# 1-800-Flowers                        NaN
# 1-800-GOT-JUNK?                      NaN
# 1-Page                               NaN
# 1-UP Studio                          NaN
# 10 feet                              NaN
# 10,000ft                             NaN
# 100 Women in Hedge Funds             NaN
# 100% Banco                           NaN
# 1000Bulbs.com                        NaN
# 1000Memories                         NaN
# 108 Shop                             NaN
# 10Bet, LLC                           NaN
# 10th Legion Championship Fighting    NaN
# 10x (company)                        NaN
# 10x Genomics                         NaN
# 11 bit studios                       NaN
# 112dB                                NaN
# 12 Yard                              NaN
# 12 bis                               NaN
# 123 Money                            NaN
# ...                                  ...
# Đuro Đaković (company)               NaN
# Ērenpreiss Bicycles                  NaN
# İDO                                  NaN
# İZBAN A.Ş.                           NaN
# İhlas Holding                        NaN
# İlbank                               NaN
# İletişim Yayınları                   NaN
# İnterbank                            NaN
# İsdemir                              NaN
# İstanbul Plak                        NaN
# İzocam                               NaN
# İş Yatırım                           NaN
# Łódzka Kolej Aglomeracyjna           NaN
# Ōigawa Railway                       NaN
# Şahinler Holding                     NaN
# Şekerbank                            NaN
# Šipad                                NaN
# Škoda Auto                           NaN
# Škoda Auto India Private Limited     NaN
# Škoda Transportation                 NaN
# Škoda Works                          NaN
# Školska knjiga                       NaN
# Štark                                NaN
# Ūkio bankas                          NaN
# ŽIA valda                            NaN
# Železara Smederevo                   NaN
# Železničná spoločnosť Slovensko      NaN
# Željeznički prevoz Crne Gore         NaN
# Živnostenská banka                   NaN
# Țiriac Holdings                      NaN
#
# [56807 rows x 24 columns]

# %% [markdown]
# ## Basic Cleaning
#
# ### Name Conversion from List
#
# For example Chinese companies the name is a list and also contains the Chinese name.

# %%
convert_names = comp_df['name'].tolist()
for idx, ele in enumerate(convert_names):
    if isinstance(ele, list):
        # some lists are empty, then replace name with wiki_name
        if not ele[0]:
            convert_names[idx] = comp_df.index[idx]
        else:
            convert_names[idx] = ele[0]
    else:
        convert_names[idx] = ele

comp_df['name'] = convert_names

# %% [markdown]
# ### Companies with missing name
#
# Name misses should not occur because the wikipedia link name is taken if it is missing in the company infobox.

# %%
c_w_name = comp_df.dropna(subset=['name'])
c_w_name
# Out:
#                                                                  location_city  \
# +Beryll                                                                    NaN
# ...instore                                                                 NaN
# 01 Communique                                                              NaN
# 01 Distribution                                                           Rome
# 07th Expansion                                                             NaN
# 0verflow                                                Kanda, Chiyoda , Tokyo
# 1-2-3 (fuel station)                                                       NaN
# 1-800-FREE-411                                                             NaN
# 1-800-Flowers                                                              NaN
# 1-800-GOT-JUNK?                                                            NaN
# 1-UP Studio                                                              Tokyo
# 10,000ft                                                   Seattle, Washington
# 100% Banco                                                                 NaN
# 1000Memories                                                               NaN
# 108 Shop                                                                   NaN
# 10th Legion Championship Fighting                 Hull, London and New Zealand
# 10x (company)                                                              NaN
# 11 bit studios                                                             NaN
# 12 Yard                                                                 London
# 123 Money                                                               Dublin
# 123Net                                                    Southfield, Michigan
# 12BET                                                                      NaN
# 13 Flames Empire                                                           NaN
# 13CABS                                                      Oakleigh, Victoria
# 13cm                                                                     Osaka
# 14 Reels Entertainment                              Hyderabad, Telangana India
# 140 Proof                          77 DeBoom Street, San Francisco, California
# 15Five                                               San Francisco, California
# 16 Handles                                                        New York, NY
# 180 Nutrition                                                              NaN
# ...                                                                        ...
# Ùr-sgeul                                                               Glasgow
# Üstra                                                                  Hanover
# ČEZ Group                                                               Prague
# ČKD (company)                                                              NaN
# Čačanska banka                                                           Čačak
# Československá obchodní banka                                              NaN
# Česká Rafinérská                                                           NaN
# Česká pošta                                                                NaN
# Česká zbrojovka Uherský Brod                             Uherský Brod, Moravia
# Čili                                                                       NaN
# Ērenpreiss Bicycles                                                        NaN
# İDO                                                                        NaN
# İZBAN A.Ş.                                                     Alsancak, İzmir
# İhlas Holding                                      Yenibosna, Istanbul, Turkey
# İlbank                                                   Ulus, Çankaya, Ankara
# İletişim Yayınları                                                         NaN
# İstanbul Plak                                                         Istanbul
# İzocam                                                                     NaN
# İş Yatırım                          Isbank Tower 2, Levent, Beşiktaş, Istanbul
# Łódzka Kolej Aglomeracyjna                                                 NaN
# Şahinler Holding                                                           NaN
# Şekerbank                                                                  NaN
# Šipad                                                                      NaN
# Škoda Auto India Private Limited                       Aurangabad, Maharashtra
# Škoda Transportation                                                       NaN
# Škoda Works                                                              Plzeň
# Ūkio bankas                                                             Kaunas
# Železara Smederevo                                                   Smederevo
# Željeznički prevoz Crne Gore                                         Podgorica
# Țiriac Holdings                                                            NaN
#
#                                                                                links  \
# +Beryll                                {Henri Bendel, Fred Segal, Los Angeles Times}
# ...instore                         {Home Bargains, Heron Foods, Tesco, Shoprite (...
# 01 Communique                                                                     {}
# 01 Distribution                                                                {RAI}
# 07th Expansion                                                 {Alchemist (company)}
# 0verflow                                                                          {}
# 1-2-3 (fuel station)                                         {Statoil Fuel & Retail}
# 1-800-FREE-411                     {Google, Liberty Media, Tellme Networks, March...
# 1-800-Flowers                      {CompuServe, AOL, Comtex, Martha Stewart Livin...
# 1-800-GOT-JUNK?                    {HSBC Bank Canada, Teradici, The Pantry (resta...
# 1-UP Studio                        {Nintendo Network Service Database, Spike Chun...
# 10,000ft                                                        {Artefact (company)}
# 100% Banco                                                                        {}
# 1000Memories                       {Wieden+Kennedy, McKinsey & Company, Greylock ...
# 108 Shop                           {Tom's Convenience Store, Delhaize Group, Mini...
# 10th Legion Championship Fighting  {Battlecade Extreme Fighting, Shark Fights, Af...
# 10x (company)                                                                     {}
# 11 bit studios                                     {CD Projekt, Metropolis Software}
# 12 Yard                            {ITV Studios, Wireless Group, STV Group (Scotl...
# 123 Money                                                      {RSA Insurance Group}
# 123Net                                                {AT&T, Verizon Communications}
# 12BET                                                                             {}
# 13 Flames Empire                                                                  {}
# 13CABS                                                                            {}
# 13cm                                                                   {VisualArt's}
# 14 Reels Entertainment                       {Telugu cinema, Varahi Chalana Chitram}
# 140 Proof                          {Chevrolet, Nike, Inc., General Motors, AT&T, ...
# 15Five                                                                            {}
# 16 Handles                                                                     {HBO}
# 180 Nutrition                                                                     {}
# ...                                                                              ...
# Ùr-sgeul                                                                      {CLÀR}
# Üstra                                                                             {}
# ČEZ Group                          {PPF (company), Polska Grupa Energetyczna, Tau...
# ČKD (company)                                         {Tatra (company), Škoda Works}
# Čačanska banka                     {Belgrade Stock Exchange, Sojaprotein, KBM Ban...
# Československá obchodní banka                    {Česká pošta, KBC Bank, Istrobanka}
# Česká Rafinérská                                                                  {}
# Česká pošta                        {PostNL, Österreichische Post, PIN Group, La P...
# Česká zbrojovka Uherský Brod                           {Dan Wesson Firearms, CZ-USA}
# Čili                               {Hot Lips Pizza, Jubilant FoodWorks, Mellow Mu...
# Ērenpreiss Bicycles                                   {G. Ērenpreis Bicycle Factory}
# İDO                                                       {İDO, Damen Group, Austal}
# İZBAN A.Ş.                         {Hyundai Rotem, Turkish State Railways, Constr...
# İhlas Holding                      {Migros Türk, Akbank, Petrol Ofisi, Ülker, Coc...
# İlbank                                                                            {}
# İletişim Yayınları                                                                {}
# İstanbul Plak                                                                     {}
# İzocam                             {Migros Türk, Akbank, Petrol Ofisi, Ülker, Coc...
# İş Yatırım                         {DYO Boya Fabrikaları, Renaissance Capital (Ru...
# Łódzka Kolej Aglomeracyjna         {Arriva RP, PKP Polskie Linie Kolejowe, Lotos ...
# Şahinler Holding                                                                  {}
# Şekerbank                          {Migros Türk, Akbank, Abank, Coca-Cola Içecek,...
# Šipad                                                                             {}
# Škoda Auto India Private Limited   {DKW, Lamborghini, Honda, Ford Motor Company, ...
# Škoda Transportation               {Rīgas Satiksme, Transtech (Finnish company), ...
# Škoda Works                        {Ganz Works, České dráhy, Škoda Auto, Škoda Tr...
# Ūkio bankas                                        {Nasdaq Nordic, General Electric}
# Železara Smederevo                                       {Hesteel Group, U.S. Steel}
# Željeznički prevoz Crne Gore       {Deutsche Bahn, Calea Ferată din Moldova, Iarn...
# Țiriac Holdings                                                            {Allianz}
#
#                                                                             wiki_url  \
# +Beryll                            https://en.wikipedia.org/w/index.php?title=%2B...
# ...instore                         https://en.wikipedia.org/w/index.php?title=......
# 01 Communique                      https://en.wikipedia.org/w/index.php?title=01+...
# 01 Distribution                    https://en.wikipedia.org/w/index.php?title=01+...
# 07th Expansion                     https://en.wikipedia.org/w/index.php?title=07t...
# 0verflow                           https://en.wikipedia.org/w/index.php?title=0ve...
# 1-2-3 (fuel station)               https://en.wikipedia.org/w/index.php?title=1-2...
# 1-800-FREE-411                     https://en.wikipedia.org/w/index.php?title=1-8...
# 1-800-Flowers                      https://en.wikipedia.org/w/index.php?title=1-8...
# 1-800-GOT-JUNK?                    https://en.wikipedia.org/w/index.php?title=1-8...
# 1-UP Studio                        https://en.wikipedia.org/w/index.php?title=1-U...
# 10,000ft                           https://en.wikipedia.org/w/index.php?title=10%...
# 100% Banco                         https://en.wikipedia.org/w/index.php?title=100...
# 1000Memories                       https://en.wikipedia.org/w/index.php?title=100...
# 108 Shop                           https://en.wikipedia.org/w/index.php?title=108...
# 10th Legion Championship Fighting  https://en.wikipedia.org/w/index.php?title=10t...
# 10x (company)                      https://en.wikipedia.org/w/index.php?title=10x...
# 11 bit studios                     https://en.wikipedia.org/w/index.php?title=11+...
# 12 Yard                            https://en.wikipedia.org/w/index.php?title=12+...
# 123 Money                          https://en.wikipedia.org/w/index.php?title=123...
# 123Net                             https://en.wikipedia.org/w/index.php?title=123Net
# 12BET                               https://en.wikipedia.org/w/index.php?title=12BET
# 13 Flames Empire                   https://en.wikipedia.org/w/index.php?title=13+...
# 13CABS                             https://en.wikipedia.org/w/index.php?title=13CABS
# 13cm                                 https://en.wikipedia.org/w/index.php?title=13cm
# 14 Reels Entertainment             https://en.wikipedia.org/w/index.php?title=14+...
# 140 Proof                          https://en.wikipedia.org/w/index.php?title=140...
# 15Five                             https://en.wikipedia.org/w/index.php?title=15Five
# 16 Handles                         https://en.wikipedia.org/w/index.php?title=16+...
# 180 Nutrition                      https://en.wikipedia.org/w/index.php?title=180...
# ...                                                                              ...
# Ùr-sgeul                           https://en.wikipedia.org/w/index.php?title=%C3...
# Üstra                              https://en.wikipedia.org/w/index.php?title=%C3...
# ČEZ Group                          https://en.wikipedia.org/w/index.php?title=%C4...
# ČKD (company)                      https://en.wikipedia.org/w/index.php?title=%C4...
# Čačanska banka                     https://en.wikipedia.org/w/index.php?title=%C4...
# Československá obchodní banka      https://en.wikipedia.org/w/index.php?title=%C4...
# Česká Rafinérská                   https://en.wikipedia.org/w/index.php?title=%C4...
# Česká pošta                        https://en.wikipedia.org/w/index.php?title=%C4...
# Česká zbrojovka Uherský Brod       https://en.wikipedia.org/w/index.php?title=%C4...
# Čili                               https://en.wikipedia.org/w/index.php?title=%C4...
# Ērenpreiss Bicycles                https://en.wikipedia.org/w/index.php?title=%C4...
# İDO                                https://en.wikipedia.org/w/index.php?title=%C4...
# İZBAN A.Ş.                         https://en.wikipedia.org/w/index.php?title=%C4...
# İhlas Holding                      https://en.wikipedia.org/w/index.php?title=%C4...
# İlbank                             https://en.wikipedia.org/w/index.php?title=%C4...
# İletişim Yayınları                 https://en.wikipedia.org/w/index.php?title=%C4...
# İstanbul Plak                      https://en.wikipedia.org/w/index.php?title=%C4...
# İzocam                             https://en.wikipedia.org/w/index.php?title=%C4...
# İş Yatırım                         https://en.wikipedia.org/w/index.php?title=%C4...
# Łódzka Kolej Aglomeracyjna         https://en.wikipedia.org/w/index.php?title=%C5...
# Şahinler Holding                   https://en.wikipedia.org/w/index.php?title=%C5...
# Şekerbank                          https://en.wikipedia.org/w/index.php?title=%C5...
# Šipad                              https://en.wikipedia.org/w/index.php?title=%C5...
# Škoda Auto India Private Limited   https://en.wikipedia.org/w/index.php?title=%C5...
# Škoda Transportation               https://en.wikipedia.org/w/index.php?title=%C5...
# Škoda Works                        https://en.wikipedia.org/w/index.php?title=%C5...
# Ūkio bankas                        https://en.wikipedia.org/w/index.php?title=%C5...
# Železara Smederevo                 https://en.wikipedia.org/w/index.php?title=%C5...
# Željeznički prevoz Crne Gore       https://en.wikipedia.org/w/index.php?title=%C5...
# Țiriac Holdings                    https://en.wikipedia.org/w/index.php?title=%C8...
#
#                                                                      name  \
# +Beryll                                                           +Beryll
# ...instore                                                     ...instore
# 01 Communique                                               01 Communique
# 01 Distribution                                     '''01 Distribution'''
# 07th Expansion                                             07th Expansion
# 0verflow                                                         0verflow
# 1-2-3 (fuel station)                                                1-2-3
# 1-800-FREE-411                                                    Marchex
# 1-800-Flowers                                     1-800-Flowers.com, Inc.
# 1-800-GOT-JUNK?                                           1-800-GOT-JUNK?
# 1-UP Studio                                              1-UP Studio Inc.
# 10,000ft                                                         10,000ft
# 100% Banco                                                      100 Banco
# 1000Memories                                                 1000Memories
# 108 Shop                                                         108 Shop
# 10th Legion Championship Fighting       10th Legion Championship Fighting
# 10x (company)                                                         10x
# 11 bit studios                                        11 bit studios s.a.
# 12 Yard                                                           12 Yard
# 123 Money                                                          123.ie
# 123Net                                                       123.Net Inc.
# 12BET                                                           12BET.com
# 13 Flames Empire                                         13 Flames Empire
# 13CABS                                                             13CABS
# 13cm                                                                 13cm
# 14 Reels Entertainment             14 Reels Entertainment Private Limited
# 140 Proof                                                       140 Proof
# 15Five                                                             15Five
# 16 Handles                                                     16 Handles
# 180 Nutrition                                               180 Nutrition
# ...                                                                   ...
# Ùr-sgeul                                                         Ùr-sgeul
# Üstra                              üstra Hannoversche Verkehrsbetriebe AG
# ČEZ Group                                                       ČEZ Group
# ČKD (company)                                  Českomoravská Kolben-Daněk
# Čačanska banka                                             Čačanska banka
# Československá obchodní banka         Československá obchodní banka, a.s.
# Česká Rafinérská                                         Česká Rafinérská
# Česká pošta                                                    Czech Post
# Česká zbrojovka Uherský Brod                 Česká zbrojovka Uherský Brod
# Čili                                                                 Čili
# Ērenpreiss Bicycles                                   Ērenpreiss Bicycles
# İDO                                        Istanbul Fast Ferries Co. Inc.
# İZBAN A.Ş.                                   İzmir Banliyö Anonim Şirketi
# İhlas Holding                                          İhlas Holding A.Ş.
# İlbank                                                        İlbank A.Ş.
# İletişim Yayınları                                     İletişim Yayınları
# İstanbul Plak                                               İstanbul Plak
# İzocam                                      İZOCAM TİCARET VE SANAYİ A.Ş.
# İş Yatırım                                                  IS Investment
# Łódzka Kolej Aglomeracyjna               Łódzka Kolej Aglomeracyjna - ŁKA
# Şahinler Holding                                         Şahinler Holding
# Şekerbank                                                Şekerbank T.A.Ş.
# Šipad                                                         Šipad, d.d.
# Škoda Auto India Private Limited                Škoda Auto India Pvt Ltd.
# Škoda Transportation                            Škoda Transportation a.s.
# Škoda Works                                                   Škoda, a.s.
# Ūkio bankas                                                AB Ūkio bankas
# Železara Smederevo                                     Železara Smederevo
# Željeznički prevoz Crne Gore              Railway transport of Montenegro
# Țiriac Holdings                                      Ţiriac Holdings Ltd.
#
#                                                            wiki_name  \
# +Beryll                                                      +Beryll
# ...instore                                                ...instore
# 01 Communique                                          01 Communique
# 01 Distribution                                      01 Distribution
# 07th Expansion                                        07th Expansion
# 0verflow                                                    0verflow
# 1-2-3 (fuel station)                            1-2-3 (fuel station)
# 1-800-FREE-411                                        1-800-FREE-411
# 1-800-Flowers                                          1-800-Flowers
# 1-800-GOT-JUNK?                                      1-800-GOT-JUNK?
# 1-UP Studio                                              1-UP Studio
# 10,000ft                                                    10,000ft
# 100% Banco                                                100% Banco
# 1000Memories                                            1000Memories
# 108 Shop                                                    108 Shop
# 10th Legion Championship Fighting  10th Legion Championship Fighting
# 10x (company)                                          10x (company)
# 11 bit studios                                        11 bit studios
# 12 Yard                                                      12 Yard
# 123 Money                                                  123 Money
# 123Net                                                        123Net
# 12BET                                                          12BET
# 13 Flames Empire                                    13 Flames Empire
# 13CABS                                                        13CABS
# 13cm                                                            13cm
# 14 Reels Entertainment                        14 Reels Entertainment
# 140 Proof                                                  140 Proof
# 15Five                                                        15Five
# 16 Handles                                                16 Handles
# 180 Nutrition                                          180 Nutrition
# ...                                                              ...
# Ùr-sgeul                                                    Ùr-sgeul
# Üstra                                                          Üstra
# ČEZ Group                                                  ČEZ Group
# ČKD (company)                                          ČKD (company)
# Čačanska banka                                        Čačanska banka
# Československá obchodní banka          Československá obchodní banka
# Česká Rafinérská                                    Česká Rafinérská
# Česká pošta                                              Česká pošta
# Česká zbrojovka Uherský Brod            Česká zbrojovka Uherský Brod
# Čili                                                            Čili
# Ērenpreiss Bicycles                              Ērenpreiss Bicycles
# İDO                                                              İDO
# İZBAN A.Ş.                                                İZBAN A.Ş.
# İhlas Holding                                          İhlas Holding
# İlbank                                                        İlbank
# İletişim Yayınları                                İletişim Yayınları
# İstanbul Plak                                          İstanbul Plak
# İzocam                                                        İzocam
# İş Yatırım                                                İş Yatırım
# Łódzka Kolej Aglomeracyjna                Łódzka Kolej Aglomeracyjna
# Şahinler Holding                                    Şahinler Holding
# Şekerbank                                                  Şekerbank
# Šipad                                                          Šipad
# Škoda Auto India Private Limited    Škoda Auto India Private Limited
# Škoda Transportation                            Škoda Transportation
# Škoda Works                                              Škoda Works
# Ūkio bankas                                              Ūkio bankas
# Železara Smederevo                                Železara Smederevo
# Željeznički prevoz Crne Gore            Željeznički prevoz Crne Gore
# Țiriac Holdings                                      Țiriac Holdings
#
#                                                                 name_url_quoted  \
# +Beryll                                                               %2BBeryll
# ...instore                                                           ...instore
# 01 Communique                                                     01+Communique
# 01 Distribution                                                 01+Distribution
# 07th Expansion                                                   07th+Expansion
# 0verflow                                                               0verflow
# 1-2-3 (fuel station)                                   1-2-3+%28fuel+station%29
# 1-800-FREE-411                                                   1-800-FREE-411
# 1-800-Flowers                                                     1-800-Flowers
# 1-800-GOT-JUNK?                                               1-800-GOT-JUNK%3F
# 1-UP Studio                                                         1-UP+Studio
# 10,000ft                                                             10%2C000ft
# 100% Banco                                                         100%25+Banco
# 1000Memories                                                       1000Memories
# 108 Shop                                                               108+Shop
# 10th Legion Championship Fighting             10th+Legion+Championship+Fighting
# 10x (company)                                                 10x+%28company%29
# 11 bit studios                                                   11+bit+studios
# 12 Yard                                                                 12+Yard
# 123 Money                                                             123+Money
# 123Net                                                                   123Net
# 12BET                                                                     12BET
# 13 Flames Empire                                               13+Flames+Empire
# 13CABS                                                                   13CABS
# 13cm                                                                       13cm
# 14 Reels Entertainment                                   14+Reels+Entertainment
# 140 Proof                                                             140+Proof
# 15Five                                                                   15Five
# 16 Handles                                                           16+Handles
# 180 Nutrition                                                     180+Nutrition
# ...                                                                         ...
# Ùr-sgeul                                                          %C3%99r-sgeul
# Üstra                                                                %C3%9Cstra
# ČEZ Group                                                        %C4%8CEZ+Group
# ČKD (company)                                            %C4%8CKD+%28company%29
# Čačanska banka                                         %C4%8Ca%C4%8Danska+banka
# Československá obchodní banka      %C4%8Ceskoslovensk%C3%A1+obchodn%C3%AD+banka
# Česká Rafinérská                           %C4%8Cesk%C3%A1+Rafin%C3%A9rsk%C3%A1
# Česká pošta                                          %C4%8Cesk%C3%A1+po%C5%A1ta
# Česká zbrojovka Uherský Brod        %C4%8Cesk%C3%A1+zbrojovka+Uhersk%C3%BD+Brod
# Čili                                                                  %C4%8Cili
# Ērenpreiss Bicycles                                    %C4%92renpreiss+Bicycles
# İDO                                                                    %C4%B0DO
# İZBAN A.Ş.                                                 %C4%B0ZBAN+A.%C5%9E.
# İhlas Holding                                                %C4%B0hlas+Holding
# İlbank                                                              %C4%B0lbank
# İletişim Yayınları                       %C4%B0leti%C5%9Fim+Yay%C4%B1nlar%C4%B1
# İstanbul Plak                                                %C4%B0stanbul+Plak
# İzocam                                                              %C4%B0zocam
# İş Yatırım                                       %C4%B0%C5%9F+Yat%C4%B1r%C4%B1m
# Łódzka Kolej Aglomeracyjna                 %C5%81%C3%B3dzka+Kolej+Aglomeracyjna
# Şahinler Holding                                          %C5%9Eahinler+Holding
# Şekerbank                                                        %C5%9Eekerbank
# Šipad                                                                %C5%A0ipad
# Škoda Auto India Private Limited          %C5%A0koda+Auto+India+Private+Limited
# Škoda Transportation                                  %C5%A0koda+Transportation
# Škoda Works                                                    %C5%A0koda+Works
# Ūkio bankas                                                    %C5%AAkio+bankas
# Železara Smederevo                                      %C5%BDelezara+Smederevo
# Željeznički prevoz Crne Gore             %C5%BDeljezni%C4%8Dki+prevoz+Crne+Gore
# Țiriac Holdings                                            %C8%9Airiac+Holdings
#
#                                                                         wiki_api_url  \
# +Beryll                            https://en.wikipedia.org/w/api.php?&action=par...
# ...instore                         https://en.wikipedia.org/w/api.php?&action=par...
# 01 Communique                      https://en.wikipedia.org/w/api.php?&action=par...
# 01 Distribution                    https://en.wikipedia.org/w/api.php?&action=par...
# 07th Expansion                     https://en.wikipedia.org/w/api.php?&action=par...
# 0verflow                           https://en.wikipedia.org/w/api.php?&action=par...
# 1-2-3 (fuel station)               https://en.wikipedia.org/w/api.php?&action=par...
# 1-800-FREE-411                     https://en.wikipedia.org/w/api.php?&action=par...
# 1-800-Flowers                      https://en.wikipedia.org/w/api.php?&action=par...
# 1-800-GOT-JUNK?                    https://en.wikipedia.org/w/api.php?&action=par...
# 1-UP Studio                        https://en.wikipedia.org/w/api.php?&action=par...
# 10,000ft                           https://en.wikipedia.org/w/api.php?&action=par...
# 100% Banco                         https://en.wikipedia.org/w/api.php?&action=par...
# 1000Memories                       https://en.wikipedia.org/w/api.php?&action=par...
# 108 Shop                           https://en.wikipedia.org/w/api.php?&action=par...
# 10th Legion Championship Fighting  https://en.wikipedia.org/w/api.php?&action=par...
# 10x (company)                      https://en.wikipedia.org/w/api.php?&action=par...
# 11 bit studios                     https://en.wikipedia.org/w/api.php?&action=par...
# 12 Yard                            https://en.wikipedia.org/w/api.php?&action=par...
# 123 Money                          https://en.wikipedia.org/w/api.php?&action=par...
# 123Net                             https://en.wikipedia.org/w/api.php?&action=par...
# 12BET                              https://en.wikipedia.org/w/api.php?&action=par...
# 13 Flames Empire                   https://en.wikipedia.org/w/api.php?&action=par...
# 13CABS                             https://en.wikipedia.org/w/api.php?&action=par...
# 13cm                               https://en.wikipedia.org/w/api.php?&action=par...
# 14 Reels Entertainment             https://en.wikipedia.org/w/api.php?&action=par...
# 140 Proof                          https://en.wikipedia.org/w/api.php?&action=par...
# 15Five                             https://en.wikipedia.org/w/api.php?&action=par...
# 16 Handles                         https://en.wikipedia.org/w/api.php?&action=par...
# 180 Nutrition                      https://en.wikipedia.org/w/api.php?&action=par...
# ...                                                                              ...
# Ùr-sgeul                           https://en.wikipedia.org/w/api.php?&action=par...
# Üstra                              https://en.wikipedia.org/w/api.php?&action=par...
# ČEZ Group                          https://en.wikipedia.org/w/api.php?&action=par...
# ČKD (company)                      https://en.wikipedia.org/w/api.php?&action=par...
# Čačanska banka                     https://en.wikipedia.org/w/api.php?&action=par...
# Československá obchodní banka      https://en.wikipedia.org/w/api.php?&action=par...
# Česká Rafinérská                   https://en.wikipedia.org/w/api.php?&action=par...
# Česká pošta                        https://en.wikipedia.org/w/api.php?&action=par...
# Česká zbrojovka Uherský Brod       https://en.wikipedia.org/w/api.php?&action=par...
# Čili                               https://en.wikipedia.org/w/api.php?&action=par...
# Ērenpreiss Bicycles                https://en.wikipedia.org/w/api.php?&action=par...
# İDO                                https://en.wikipedia.org/w/api.php?&action=par...
# İZBAN A.Ş.                         https://en.wikipedia.org/w/api.php?&action=par...
# İhlas Holding                      https://en.wikipedia.org/w/api.php?&action=par...
# İlbank                             https://en.wikipedia.org/w/api.php?&action=par...
# İletişim Yayınları                 https://en.wikipedia.org/w/api.php?&action=par...
# İstanbul Plak                      https://en.wikipedia.org/w/api.php?&action=par...
# İzocam                             https://en.wikipedia.org/w/api.php?&action=par...
# İş Yatırım                         https://en.wikipedia.org/w/api.php?&action=par...
# Łódzka Kolej Aglomeracyjna         https://en.wikipedia.org/w/api.php?&action=par...
# Şahinler Holding                   https://en.wikipedia.org/w/api.php?&action=par...
# Şekerbank                          https://en.wikipedia.org/w/api.php?&action=par...
# Šipad                              https://en.wikipedia.org/w/api.php?&action=par...
# Škoda Auto India Private Limited   https://en.wikipedia.org/w/api.php?&action=par...
# Škoda Transportation               https://en.wikipedia.org/w/api.php?&action=par...
# Škoda Works                        https://en.wikipedia.org/w/api.php?&action=par...
# Ūkio bankas                        https://en.wikipedia.org/w/api.php?&action=par...
# Železara Smederevo                 https://en.wikipedia.org/w/api.php?&action=par...
# Željeznički prevoz Crne Gore       https://en.wikipedia.org/w/api.php?&action=par...
# Țiriac Holdings                    https://en.wikipedia.org/w/api.php?&action=par...
#
#                                   is_company  wiki_page_id  \
# +Beryll                                 True      13860681
# ...instore                              True       9291975
# 01 Communique                           True      15244876
# 01 Distribution                         True      46724099
# 07th Expansion                          True       5936289
# 0verflow                                True      10387049
# 1-2-3 (fuel station)                    True      14018485
# 1-800-FREE-411                          True      18480351
# 1-800-Flowers                           True       4048045
# 1-800-GOT-JUNK?                         True       5579899
# 1-UP Studio                             True       1549290
# 10,000ft                                True      37913068
# 100% Banco                              True      23958183
# 1000Memories                            True      28493016
# 108 Shop                                True      23183503
# 10th Legion Championship Fighting       True      29825173
# 10x (company)                           True      51084325
# 11 bit studios                          True      38544394
# 12 Yard                                 True       3052956
# 123 Money                               True      35861728
# 123Net                                  True      36026273
# 12BET                                   True      47822380
# 13 Flames Empire                        True      31245524
# 13CABS                                  True      37435631
# 13cm                                    True      18553400
# 14 Reels Entertainment                  True      36359425
# 140 Proof                               True      38128692
# 15Five                                  True      39394639
# 16 Handles                              True      46181848
# 180 Nutrition                           True       1281372
# ...                                      ...           ...
# Ùr-sgeul                                True      20900978
# Üstra                                   True       4865090
# ČEZ Group                               True       9815974
# ČKD (company)                           True       2372673
# Čačanska banka                          True      42066456
# Československá obchodní banka           True       8967870
# Česká Rafinérská                        True      24271607
# Česká pošta                             True       2362929
# Česká zbrojovka Uherský Brod            True       1481009
# Čili                                    True      11525538
# Ērenpreiss Bicycles                     True      49226907
# İDO                                     True       6286396
# İZBAN A.Ş.                              True      30483454
# İhlas Holding                           True      39611864
# İlbank                                  True      42266068
# İletişim Yayınları                      True      39646855
# İstanbul Plak                           True      12807361
# İzocam                                  True      43380582
# İş Yatırım                              True      34538340
# Łódzka Kolej Aglomeracyjna              True      47269370
# Şahinler Holding                        True      18393229
# Şekerbank                               True      27193229
# Šipad                                   True      46874309
# Škoda Auto India Private Limited        True      22342461
# Škoda Transportation                    True      42128619
# Škoda Works                             True        672117
# Ūkio bankas                             True       7165143
# Železara Smederevo                      True      40327203
# Željeznički prevoz Crne Gore            True      39357175
# Țiriac Holdings                         True      10868077
#
#                                            location_country  \
# +Beryll                                                 NaN
# ...instore                                              NaN
# 01 Communique                                           NaN
# 01 Distribution                                       Italy
# 07th Expansion                                          NaN
# 0verflow                                              Japan
# 1-2-3 (fuel station)                                    NaN
# 1-800-FREE-411                                          NaN
# 1-800-Flowers                                           NaN
# 1-800-GOT-JUNK?                                         NaN
# 1-UP Studio                                           Japan
# 10,000ft                                  The United States
# 100% Banco                                              NaN
# 1000Memories                                            NaN
# 108 Shop                                                NaN
# 10th Legion Championship Fighting               England, UK
# 10x (company)                                           NaN
# 11 bit studios                                          NaN
# 12 Yard                                                  UK
# 123 Money                                           Ireland
# 123Net                                        United States
# 12BET                                                   NaN
# 13 Flames Empire                                        NaN
# 13CABS                                            Australia
# 13cm                                                  Japan
# 14 Reels Entertainment                                  NaN
# 140 Proof                                     United States
# 15Five                                                  NaN
# 16 Handles                                              NaN
# 180 Nutrition                               New South Wales
# ...                                                     ...
# Ùr-sgeul                           Scotland, United Kingdom
# Üstra                                               Germany
# ČEZ Group                                    Czech Republic
# ČKD (company)                                           NaN
# Čačanska banka                                       Serbia
# Československá obchodní banka                           NaN
# Česká Rafinérská                                        NaN
# Česká pošta                                             NaN
# Česká zbrojovka Uherský Brod                 Czech Republic
# Čili                                                    NaN
# Ērenpreiss Bicycles                                     NaN
# İDO                                                     NaN
# İZBAN A.Ş.                                           Turkey
# İhlas Holding                                           NaN
# İlbank                                                  NaN
# İletişim Yayınları                                      NaN
# İstanbul Plak                                        Turkey
# İzocam                                               Turkey
# İş Yatırım                                              NaN
# Łódzka Kolej Aglomeracyjna                              NaN
# Şahinler Holding                                        NaN
# Şekerbank                                            Turkey
# Šipad                                                   NaN
# Škoda Auto India Private Limited                      India
# Škoda Transportation                                    NaN
# Škoda Works                                  Czech Republic
# Ūkio bankas                                       Lithuania
# Železara Smederevo                                   Serbia
# Željeznički prevoz Crne Gore                     Montenegro
# Țiriac Holdings                                         NaN
#
#                                                          ...                          \
# +Beryll                                                  ...
# ...instore                                               ...
# 01 Communique                                            ...
# 01 Distribution                                          ...
# 07th Expansion                                           ...
# 0verflow                                                 ...
# 1-2-3 (fuel station)                                     ...
# 1-800-FREE-411                                           ...
# 1-800-Flowers                                            ...
# 1-800-GOT-JUNK?                                          ...
# 1-UP Studio                                              ...
# 10,000ft                                                 ...
# 100% Banco                                               ...
# 1000Memories                                             ...
# 108 Shop                                                 ...
# 10th Legion Championship Fighting                        ...
# 10x (company)                                            ...
# 11 bit studios                                           ...
# 12 Yard                                                  ...
# 123 Money                                                ...
# 123Net                                                   ...
# 12BET                                                    ...
# 13 Flames Empire                                         ...
# 13CABS                                                   ...
# 13cm                                                     ...
# 14 Reels Entertainment                                   ...
# 140 Proof                                                ...
# 15Five                                                   ...
# 16 Handles                                               ...
# 180 Nutrition                                            ...
# ...                                                      ...
# Ùr-sgeul                                                 ...
# Üstra                                                    ...
# ČEZ Group                                                ...
# ČKD (company)                                            ...
# Čačanska banka                                           ...
# Československá obchodní banka                            ...
# Česká Rafinérská                                         ...
# Česká pošta                                              ...
# Česká zbrojovka Uherský Brod                             ...
# Čili                                                     ...
# Ērenpreiss Bicycles                                      ...
# İDO                                                      ...
# İZBAN A.Ş.                                               ...
# İhlas Holding                                            ...
# İlbank                                                   ...
# İletişim Yayınları                                       ...
# İstanbul Plak                                            ...
# İzocam                                                   ...
# ...
# Ērenpreiss Bicycles                {u'wiki_raw_code': u'[[File:Erenpreiss logo.jp...
# İDO                                {u'wiki_raw_code': u'[[File:Istanbul Sea Buses...
# İZBAN A.Ş.                                                                       NaN
# İhlas Holding                                                                    NaN
# İlbank                                                                           NaN
# İletişim Yayınları                                                               NaN
# İstanbul Plak                                                                    NaN
# İzocam                                                                           NaN
# İş Yatırım                         {u'wiki_raw_code': u'Is Investment Logo.png', ...
# Łódzka Kolej Aglomeracyjna         {u'wiki_raw_code': u'[[File:Łódzka Kolej Aglom...
# Şahinler Holding                                                                 NaN
# Şekerbank                          {u'wiki_raw_code': u'[[File:Şekerbank Logo.jpg...
# Šipad                              {u'wiki_raw_code': u'[[File:Šipad d.d.jpg|155p...
# Škoda Auto India Private Limited   {u'wiki_raw_code': u'[[File:Skoda Auto logo (2...
# Škoda Transportation               {u'wiki_raw_code': u'Škoda Transportation logo...
# Škoda Works                        {u'wiki_raw_code': u'Škoda Works logo.png', u'...
# Ūkio bankas                        {u'wiki_raw_code': u'[[File:Ukio bankas logo.j...
# Železara Smederevo                                                               NaN
# Željeznički prevoz Crne Gore       {u'wiki_raw_code': u'[[File:ZCGlogo.png]]', u'...
# Țiriac Holdings                    {u'wiki_raw_code': u'[[Image:Tiriac-Holdings.p...
#
#                                                      defunct  \
# +Beryll                                                  NaN
# ...instore                                              2009
# 01 Communique                                            NaN
# 01 Distribution                                          NaN
# 07th Expansion                                           NaN
# 0verflow                                                 NaN
# 1-2-3 (fuel station)                                     NaN
# 1-800-FREE-411                                           NaN
# 1-800-Flowers                                            NaN
# 1-800-GOT-JUNK?                                          NaN
# 1-UP Studio                                              NaN
# 10,000ft                                                 NaN
# 100% Banco                                               NaN
# 1000Memories                                             NaN
# 108 Shop                                                 NaN
# 10th Legion Championship Fighting                        NaN
# 10x (company)                                            NaN
# 11 bit studios                                           NaN
# 12 Yard                                                  NaN
# 123 Money                                                NaN
# 123Net                                                   NaN
# 12BET                                                    NaN
# 13 Flames Empire                                         NaN
# 13CABS                                                   NaN
# 13cm                                                     NaN
# 14 Reels Entertainment                                   NaN
# 140 Proof                                                NaN
# 15Five                                                   NaN
# 16 Handles                                               NaN
# 180 Nutrition                                            NaN
# ...                                                      ...
# Ùr-sgeul                                                 NaN
# Üstra                                                    NaN
# ČEZ Group                                                NaN
# ČKD (company)                                            NaN
# Čačanska banka                                           NaN
# Československá obchodní banka                            NaN
# Česká Rafinérská                                         NaN
# Česká pošta                                              NaN
# Česká zbrojovka Uherský Brod                             NaN
# Čili                                                     NaN
# Ērenpreiss Bicycles                                      NaN
# İDO                                                      NaN
# İZBAN A.Ş.                                               NaN
# İhlas Holding                                            NaN
# İlbank                                                   NaN
# İletişim Yayınları                                       NaN
# İstanbul Plak                                            NaN
# İzocam                                                   NaN
# İş Yatırım                                               NaN
# Łódzka Kolej Aglomeracyjna                               NaN
# Şahinler Holding                                         NaN
# Şekerbank                                                NaN
# Šipad                                                    NaN
# Škoda Auto India Private Limited                         NaN
# Škoda Transportation                                     NaN
# Škoda Works                              1999-11-25 00:00:00
# Ūkio bankas                        As of February 12th, 2013
# Železara Smederevo                                       NaN
# Željeznički prevoz Crne Gore                             NaN
# Țiriac Holdings                                          NaN
#
#                                                                     parent  \
# +Beryll                                                                NaN
# ...instore                                                             NaN
# 01 Communique                                                          NaN
# 01 Distribution                                                        NaN
# 07th Expansion                                                         NaN
# 0verflow                                                        Stack Ltd.
# 1-2-3 (fuel station)                                                   NaN
# 1-800-FREE-411                                          Liberty Media (9%)
# 1-800-Flowers                                                          NaN
# 1-800-GOT-JUNK?                                                        NaN
# 1-UP Studio                                                       Nintendo
# 10,000ft                                                               NaN
# 100% Banco                                                        Beserfin
# 1000Memories                                                           NaN
# 108 Shop                                                        Saha Group
# 10th Legion Championship Fighting                                      NaN
# 10x (company)                                                          NaN
# 11 bit studios                                                         NaN
# 12 Yard                                                        ITV Studios
# 123 Money                                              RSA Insurance Group
# 123Net                                                                 NaN
# 12BET                                                                  NaN
# 13 Flames Empire                                                       NaN
# 13CABS                                                                 NaN
# 13cm                                                                   NaN
# 14 Reels Entertainment                                                 NaN
# 140 Proof                                                              NaN
# 15Five                                                                 NaN
# 16 Handles                                                             NaN
# 180 Nutrition                                                          NaN
# ...                                                                    ...
# Ùr-sgeul                                                               NaN
# Üstra                                                                  NaN
# ČEZ Group                                                              NaN
# ČKD (company)                                                          NaN
# Čačanska banka                                                         NaN
# Československá obchodní banka                                     KBC Bank
# Česká Rafinérská                                                       NaN
# Česká pošta                                                            NaN
# Česká zbrojovka Uherský Brod                                           NaN
# Čili                                                                   NaN
# Ērenpreiss Bicycles                                                    NaN
# İDO                                                                    NaN
# İZBAN A.Ş.                         [TCDD (50%),  İzmir Municipality (50%)]
# İhlas Holding                                                          NaN
# İlbank                                                                 NaN
# İletişim Yayınları                                                     NaN
# İstanbul Plak                                                          NaN
# İzocam                                                                 NaN
# İş Yatırım                                                             NaN
# Łódzka Kolej Aglomeracyjna                                             NaN
# Şahinler Holding                                                       NaN
# Şekerbank                                                              NaN
# Šipad                                                                  NaN
# Škoda Auto India Private Limited                                Škoda Auto
# Škoda Transportation                  CEIL (Central Europe Industries) LTD
# Škoda Works                                                            NaN
# Ūkio bankas                                                            NaN
# Železara Smederevo                                           Hesteel Group
# Željeznički prevoz Crne Gore                                           NaN
# Țiriac Holdings                                                        NaN
#
#                                                                               subsid
# +Beryll                                                                          NaN
# ...instore                                                                       NaN
# 01 Communique                                                                    NaN
# 01 Distribution                                                                  NaN
# 07th Expansion                                                                   NaN
# 0verflow                                                                         NaN
# 1-2-3 (fuel station)                                                             NaN
# 1-800-FREE-411                                                                   NaN
# 1-800-Flowers                                                                    NaN
# 1-800-GOT-JUNK?                                                                  NaN
# 1-UP Studio                                                                      NaN
# 10,000ft                                                                         NaN
# 100% Banco                                                                       NaN
# 1000Memories                                                                     NaN
# 108 Shop                                                                         NaN
# 10th Legion Championship Fighting                                                NaN
# 10x (company)                                                                    NaN
# 11 bit studios                                                                   NaN
# 12 Yard                                                                          NaN
# 123 Money                                                                        NaN
# 123Net                                                                           NaN
# 12BET                                                                            NaN
# 13 Flames Empire                                                                 NaN
# 13CABS                                                                           NaN
# 13cm                                                                             NaN
# 14 Reels Entertainment                                                           NaN
# 140 Proof                                                                        NaN
# 15Five                                                                           NaN
# 16 Handles                                                                       NaN
# 180 Nutrition                                                                    NaN
# ...                                                                              ...
# Ùr-sgeul                                                                         NaN
# Üstra                                                                            NaN
# ČEZ Group                                                                        NaN
# ČKD (company)                                                                    NaN
# Čačanska banka                                                                   NaN
# Československá obchodní banka                                                    NaN
# Česká Rafinérská                                                                 NaN
# Česká pošta                                                                      NaN
# Česká zbrojovka Uherský Brod       [CZ-USA, (1997, US market), Zbrojovka Brno, (2...
# Čili                                                                             NaN
# Ērenpreiss Bicycles                                                              NaN
# İDO                                                                              NaN
# İZBAN A.Ş.                                                                       NaN
# İhlas Holding                                                                    NaN
# İlbank                                                                           NaN
# İletişim Yayınları                                                               NaN
# İstanbul Plak                                                                    NaN
# İzocam                                                                           NaN
# İş Yatırım                                                                       NaN
# Łódzka Kolej Aglomeracyjna                                                       NaN
# Şahinler Holding                                                                 NaN
# Şekerbank                                                                        NaN
# Šipad                                                                            NaN
# Škoda Auto India Private Limited                                                 NaN
# Škoda Transportation                                                             NaN
# Škoda Works                                                                      NaN
# Ūkio bankas                                                                      NaN
# Železara Smederevo                                                               NaN
# Željeznički prevoz Crne Gore                                                     NaN
# Țiriac Holdings                                                                  NaN
#
# [37729 rows x 24 columns]

# %% [markdown]
# ### Companies with duplicate names
#
# Can come from users that put company profiles on their pages, compare:
# * https://en.wikipedia.org/wiki/Amgen
# * https://en.wikipedia.org/wiki/User:Gjanko/sandbox

# %%
# find duplicate company names
c_dupl = pd.concat(g for _, g in comp_df.groupby('name') if len(g) > 1)
print "Found", len(c_dupl['name']), "duplicates:"
print c_dupl['name']
# Out:
# Abrazo Scottsdale Campus                                       Abrazo Scottsdale Campus
# Abrazo Scottsdale Campus Arizona                               Abrazo Scottsdale Campus
# Al Marjan Island                                                       Al Marjan Island
# Al Marjan Island LLC                                                   Al Marjan Island
# Alchemy (company)                                                               Alchemy
# Alchemy Boulders                                                                Alchemy
# Amplify (company)                                                               Amplify
# Amplify (distributor)                                                           Amplify
# Andersen Tax                                                           Andersen Tax LLC
# Andersen Tax LLC                                                       Andersen Tax LLC
# Army and Air Force Exchange Service                 Army and Air Force Exchange Service
# Army and Air Force Motion Picture Service           Army and Air Force Exchange Service
# Atari, Inc.                                                                 Atari, Inc.
# Atari, Inc. (Atari, SA subsidiary)                                          Atari, Inc.
# Babes.com                                                                         Babes
# BabesPornographic                                                                 Babes
# Banca di Sassari                                               Banco di Sardegna S.p.A.
# Banco di Sardegna                                              Banco di Sardegna S.p.A.
# Bank of Melbourne (1989)                                              Bank of Melbourne
# Bank of Melbourne (2011)                                              Bank of Melbourne
# Birmingham Midshires                                               Bank of Scotland Plc
# Intelligent Finance                                                Bank of Scotland Plc
# Bengal and North Western Railway                       Bengal and North Western Railway
# Lucknow–Sitapur–Seramow Provincial State Railway       Bengal and North Western Railway
# Bevolo Gas and Electric Lights                             Bevolo Gas & Electric Lights
# Bevolo Luci a Gas ed Elettrici                             Bevolo Gas & Electric Lights
# Boundless (company)                                                           Boundless
# Boundless (production company)                                                Boundless
# Capital Bank (Botswana)                                                    Capital Bank
# Capital Bank (Ghana)                                                       Capital Bank
#                                                                    ...
# Shinola (shoe polish)                                                           Shinola
# Siemens                                                                         Siemens
# Siemens Saudi Arabia                                                            Siemens
# Statoil                                                                         Statoil
# Statoil (fuel station)                                                          Statoil
# Switch Communications, Inc.                                 Switch Communications, Inc.
# UberConference                                              Switch Communications, Inc.
# Petri AG                                                             Takata Corporation
# Takata Corporation                                                   Takata Corporation
# Child & Co.                                             The Royal Bank of Scotland Plc,
# Drummonds Bank                                          The Royal Bank of Scotland Plc,
# Pavilions (supermarket)                                        The Vons Companies, Inc.
# Vons                                                           The Vons Companies, Inc.
# Turner Broadcasting System                                   Turner Broadcasting System
# Turner Broadcasting System Latin America                     Turner Broadcasting System
# Casas Bahia                                                             Via Varejo S.A.
# Via Varejo                                                              Via Varejo S.A.
# VitrA (sanitaryware)                                                              Vitra
# Vitra (furniture)                                                                 Vitra
# Vétra                                                                             Vétra
# Vétra (workwear)                                                                  Vétra
# Walton (motorcycle)                                   Walton Hi-Tech Industries Limited
# Walton Hi-Tech Industries Limited                     Walton Hi-Tech Industries Limited
# Western Power (networks corporation)                                      Western Power
# Western Power Corporation                                                 Western Power
# List of Yamaha guitars                                               Yamaha Corporation
# Yamaha Corporation                                                   Yamaha Corporation
# Yamaha electric guitar models                                        Yamaha Corporation
# Wagamama                                                                       wagamama
# Wok to Walk                                                                    wagamama
# Name: name, dtype: object
# Found 155 duplicates.

# %%
# add extra column adding the length of the link set
s_list = [
    'Yamaha Corporation',
    'List of Yamaha guitars',
    'Yamaha electric guitar models'
]
for s in s_list:
    print s, len(comp_df.loc[s, 'links'])
# Out:
# Yamaha Corporation 332
# List of Yamaha guitars 1
# Yamaha electric guitar models 5

# %%
# sort after multiple values, sorts the columns with least NaN values to top
sort_cols = ['wiki_page_id', 'num_employees']
c_dupl.sort_values(by=sort_cols, ascending=True)
c_dupl[['wiki_page_id', 'name', 'num_employees']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-24f5599f6e77> in <module>()
#       1 # sort after multiple values, sorts the columns with least NaN values to top
#       2 sort_cols = ['wiki_page_id', 'num_employees', 'links']
# ----> 3 c_dupl.sort_values(by=sort_cols, ascending=True)
#       4 c_dupl[['wiki_page_id', 'name', 'num_employees']]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3204                 keys.append(trans(k))
#    3205             indexer = _lexsort_indexer(keys, orders=ascending,
# -> 3206                                        na_position=na_position)
#    3207             indexer = _ensure_platform_int(indexer)
#    3208         else:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/groupby.pyc in _lexsort_indexer(keys, orders, na_position)
#    4266         # create the Categorical
#    4267         else:
# -> 4268             c = Categorical(key, ordered=True)
#    4269
#    4270         if na_position not in ['last', 'first']:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/categorical.pyc in __init__(self, values, categories, ordered, name, fastpath)
#     288                 codes, categories = factorize(values, sort=True)
#     289             except TypeError:
# --> 290                 codes, categories = factorize(values, sort=False)
#     291                 if ordered:
#     292                     # raise, as we don't have a sortable data structure and so
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/algorithms.pyc in factorize(values, sort, order, na_sentinel, size_hint)
#     302     table = hash_klass(size_hint or len(vals))
#     303     uniques = vec_klass()
# --> 304     labels = table.get_labels(vals, uniques, 0, na_sentinel, True)
#     305
#     306     labels = _ensure_platform_int(labels)
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_labels (pandas/hashtable.c:14826)()
#
# TypeError: unhashable type: 'set'

# %%
# now drop the one's with duplcate names
c_dupl.drop_duplicates('name', inplace=True)
c_dupl
# Out:
#                                                           location_city  \
# Greka Energy                                                        NaN
# Nintendo Integrated Research & Development                        Kyoto
# Open Systems International                                          NaN
# Great Western Bank (1907–present)                                   NaN
# Meyer Turku                                                       Turku
# Nepal Telecom                               Bhadrakali Plaza, Kathmandu
# Yamaha Corporation                                  Hamamatsu, Shizuoka
# Turner Broadcasting System                                          NaN
# Peer 1                                                              NaN
# Mayfair Sporting Club                                               NaN
# Cybersoft                                                           NaN
# Amplify (company)                                                   NaN
# Boundless (company)                                                 NaN
#
#                                                                                         links  \
# Greka Energy                                                   {Occidental Petroleum, Conoco}
# Nintendo Integrated Research & Development  {Nintendo Network Service Database, Spike Chun...
# Open Systems International                                                                 {}
# Great Western Bank (1907–present)                                   {National Australia Bank}
# Meyer Turku                                 {United Shipbuilding Corporation, Meyer Werft,...
# Nepal Telecom                               {Chaudhary Group, Marvell Technology Group, LG...
# Yamaha Corporation                          {Showa Denko, DKW, Bank of Yokohama, JVC Kenwo...
# Turner Broadcasting System                  {HBO, Cartoon Network Studios, Flagship Entert...
# Peer 1                                                                        {Toronto Hydro}
# Mayfair Sporting Club                                                                      {}
# Cybersoft                                                       {Microsoft, Associated Press}
# Amplify (company)                                                           {Asus, News Corp}
# Boundless (company)                         {Valore (company), Kno, Inkling, BenchPrep, Fl...
#
#                                                                                      wiki_url  \
# Greka Energy                                https://en.wikipedia.org/w/index.php?title=Gre...
# Nintendo Integrated Research & Development  https://en.wikipedia.org/w/index.php?title=Nin...
# Open Systems International                  https://en.wikipedia.org/w/index.php?title=Ope...
# Great Western Bank (1907–present)           https://en.wikipedia.org/w/index.php?title=Gre...
# Meyer Turku                                 https://en.wikipedia.org/w/index.php?title=Mey...
# Nepal Telecom                               https://en.wikipedia.org/w/index.php?title=Nep...
# Yamaha Corporation                          https://en.wikipedia.org/w/index.php?title=Yam...
# Turner Broadcasting System                  https://en.wikipedia.org/w/index.php?title=Tur...
# Peer 1                                      https://en.wikipedia.org/w/index.php?title=Peer+1
# Mayfair Sporting Club                       https://en.wikipedia.org/w/index.php?title=May...
# Cybersoft                                   https://en.wikipedia.org/w/index.php?title=Cyb...
# Amplify (company)                           https://en.wikipedia.org/w/index.php?title=Amp...
# Boundless (company)                         https://en.wikipedia.org/w/index.php?title=Bou...
#
#                                                                                      wiki_raw  \
# Greka Energy                                {{Infobox company \n| name   = Greka \n| logo ...
# Nintendo Integrated Research & Development  {{Infobox company\n| name             = Ninten...
# Open Systems International                  {{Infobox company \n| name   = OSI\n| logo   =...
# Great Western Bank (1907–present)           {{Infobox company |\n| name   = Great Western ...
# Meyer Turku                                 {{Infobox company\n| name           = Meyer Tu...
# Nepal Telecom                               {{Infobox company\n| name             = {{lang...
# Yamaha Corporation                          {{Redirect|Yamaha}}\n{{Infobox company\n| name...
# Turner Broadcasting System                  {{about|the company|the channel owned by this ...
# Peer 1                                      <!-- Please do not remove or change this AfD m...
# Mayfair Sporting Club                       {{multiple issues|\n{{notability|date=February...
# Cybersoft                                   {{about|the software company|the magazine|Cybe...
# Amplify (company)                           {{Infobox company|name = Amplify|native_name_l...
# Boundless (company)                         {{Infobox company \n  |name   = Boundless\n  |...
#
#                                                                              wiki_name  \
# Greka Energy                                                              Greka Energy
# Nintendo Integrated Research & Development  Nintendo Integrated Research & Development
# Open Systems International                                  Open Systems International
# Great Western Bank (1907–present)                    Great Western Bank (1907–present)
# Meyer Turku                                                                Meyer Turku
# Nepal Telecom                                                            Nepal Telecom
# Yamaha Corporation                                                  Yamaha Corporation
# Turner Broadcasting System                                  Turner Broadcasting System
# Peer 1                                                                          Peer 1
# Mayfair Sporting Club                                            Mayfair Sporting Club
# Cybersoft                                                                    Cybersoft
# Amplify (company)                                                    Amplify (company)
# Boundless (company)                                                Boundless (company)
#
#                                                                           name_url_quoted  \
# Greka Energy                                                                 Greka+Energy
# Nintendo Integrated Research & Development   Nintendo+Integrated+Research+%26+Development
# Open Systems International                                     Open+Systems+International
# Great Western Bank (1907–present)           Great+Western+Bank+%281907%E2%80%93present%29
# Meyer Turku                                                                   Meyer+Turku
# Nepal Telecom                                                               Nepal+Telecom
# Yamaha Corporation                                                     Yamaha+Corporation
# Turner Broadcasting System                                     Turner+Broadcasting+System
# Peer 1                                                                             Peer+1
# Mayfair Sporting Club                                               Mayfair+Sporting+Club
# Cybersoft                                                                       Cybersoft
# Amplify (company)                                                   Amplify+%28company%29
# Boundless (company)                                               Boundless+%28company%29
#
#                                                                                  wiki_api_url  \
# Greka Energy                                https://en.wikipedia.org/w/api.php?&action=par...
# Nintendo Integrated Research & Development  https://en.wikipedia.org/w/api.php?&action=par...
# Open Systems International                  https://en.wikipedia.org/w/api.php?&action=par...
# Great Western Bank (1907–present)           https://en.wikipedia.org/w/api.php?&action=par...
# Meyer Turku                                 https://en.wikipedia.org/w/api.php?&action=par...
# Nepal Telecom                               https://en.wikipedia.org/w/api.php?&action=par...
# Yamaha Corporation                          https://en.wikipedia.org/w/api.php?&action=par...
# Turner Broadcasting System                  https://en.wikipedia.org/w/api.php?&action=par...
# Peer 1                                      https://en.wikipedia.org/w/api.php?&action=par...
# Mayfair Sporting Club                       https://en.wikipedia.org/w/api.php?&action=par...
# Cybersoft                                   https://en.wikipedia.org/w/api.php?&action=par...
# Amplify (company)                           https://en.wikipedia.org/w/api.php?&action=par...
# Boundless (company)                         https://en.wikipedia.org/w/api.php?&action=par...
#
#                                                                                     all_links  \
# Greka Energy                                [Aera Energy LLC, Asphalt, California, Canada,...
# Nintendo Integrated Research & Development  [1-UP Studio, Affiliate (commerce), Arm Wrestl...
# Open Systems International                  [Chief executive officer, Distribution managem...
# Great Western Bank (1907–present)           [Arizona, Asset, Colorado, Financial Services,...
# Meyer Turku                                 [Aker ASA, Aker Arctic, Aker Yards, Allan Staf...
# Nepal Telecom                               [3G, ADSL, AKM Semiconductor, Inc., ARM Holdin...
# Yamaha Corporation                          [Yamaha, Shan Xin, Japan, United Kingdom, Swed...
# Turner Broadcasting System                  [21st Century Fox, 91kt.com, AGCO, AT&T Mobili...
# Peer 1                                      [British Columbia, Canada, Cloud Computing, Cl...
# Mayfair Sporting Club                       [Black tie, Boxing, Cafe Royal, Corporate ente...
# Cybersoft                                   [Associated Press, Buffalo Public Schools, Com...
# Amplify (company)                           [Amplify Tablet, Android (operating system), A...
# Boundless (company)                         [BenchPrep, Boston, Cengage Learning, Chegg, C...
#
#                                             wiki_page_id location_country  \
# Greka Energy                                    23796429              NaN
# Nintendo Integrated Research & Development       5444899            Japan
# Open Systems International                      19411647              NaN
# Great Western Bank (1907–present)               10669154              NaN
# Meyer Turku                                     48975797          Finland
# Nepal Telecom                                    1690862            Nepal
# Yamaha Corporation                                308428            Japan
# Turner Broadcasting System                        332695              NaN
# Peer 1                                          21122519              NaN
# Mayfair Sporting Club                           28499959              NaN
# Cybersoft                                       31317906              NaN
# Amplify (company)                               38755162              NaN
# Boundless (company)                             39971610              NaN
#
#                                                                   ...                          \
# Greka Energy                                                      ...
# Nintendo Integrated Research & Development                        ...
# Open Systems International                                        ...
# Great Western Bank (1907–present)                                 ...
# Meyer Turku                                                       ...
# Nepal Telecom                                                     ...
# Yamaha Corporation                                                ...
# Turner Broadcasting System                                        ...
# Peer 1                                                            ...
# Mayfair Sporting Club                                             ...
# Cybersoft                                                         ...
# Amplify (company)                                                 ...
# Boundless (company)                                               ...
#
#                                                                                      industry  \
# Greka Energy                                [Oil and petroleum extraction and refining, Mi...
# Nintendo Integrated Research & Development                                        Video games
# Open Systems International                                                 Utility Automation
# Great Western Bank (1907–present)                                          Financial Services
# Meyer Turku                                                                      shipbuilding
# Nepal Telecom                                                              Telecommunications
# Yamaha Corporation                                                               Conglomerate
# Turner Broadcasting System                                                                NaN
# Peer 1                                                               Cloud Computing, Hosting
# Mayfair Sporting Club                                                 Corporate entertainment
# Cybersoft                                                                                 NaN
# Amplify (company)                                                                   Education
# Boundless (company)                                                                 Education
#
#                                                                                    key_people  \
# Greka Energy                                [{u'last': u'Grewal', u'suffix': u'', u'title'...
# Nintendo Integrated Research & Development  [{u'last': u'Takeda', u'suffix': u'', u'title'...
# Open Systems International                  [{u'last': u'Hoveida', u'suffix': u'', u'title...
# Great Western Bank (1907–present)                                 Ken Karels, President & CEO
# Meyer Turku                                                                         Jan Meyer
# Nepal Telecom                                                            Budhi Prasad Acharya
# Yamaha Corporation                          [{u'last': u'Torakusu Yamaha', u'suffix': u'',...
# Turner Broadcasting System                                                                NaN
# Peer 1                                      [{u'last': u'Philippe Jetté', u'suffix': u'Co-...
# Mayfair Sporting Club                       [{u'last': u'', u'suffix': u'', u'title': u'',...
# Cybersoft                                                                                 NaN
# Amplify (company)                           [{u'last': u'Klein', u'suffix': u'', u'title':...
# Boundless (company)                                                   Geoffrey Willison (CEO)
#
#                                                                         founded  \
# Greka Energy                                [1999, (Saba; Horizontal Ventures)]
# Nintendo Integrated Research & Development                  2003-09-30 00:00:00
# Open Systems International                                                 1992
# Great Western Bank (1907–present)                           1935-11-25 00:00:00
# Meyer Turku                                                 1989-11-07 00:00:00
# Nepal Telecom                                               1913-11-25 00:00:00
# Yamaha Corporation                                          1887-10-12 00:00:00
# Turner Broadcasting System                                                  NaN
# Peer 1                                                                     2015
# Mayfair Sporting Club                                     2003 (United Kingdom)
# Cybersoft                                                                   NaN
# Amplify (company)                                           2000-11-25 00:00:00
# Boundless (company)                                         2011-03-25 00:00:00
#
#                                                                                      products  \
# Greka Energy                                              [Oil, Petroleum, Asphalt, Emulsion]
# Nintendo Integrated Research & Development               Various Nintendo video game consoles
# Open Systems International                                                                NaN
# Great Western Bank (1907–present)                                          Financial Services
# Meyer Turku                                                      cruise ships, cruise ferries
# Nepal Telecom                                                                             NaN
# Yamaha Corporation                          Musical Instruments, Audio equipment, Electron...
# Turner Broadcasting System                                                                NaN
# Peer 1                                                                                    NaN
# Mayfair Sporting Club                                                                     NaN
# Cybersoft                                                                                 NaN
# Amplify (company)                           Amplify Tablet, digital curriculum, assessment...
# Boundless (company)                                                    Textbooks (as E-books)
#
#                                                                                      location  \
# Greka Energy                                                    Santa Maria, California, U.S.
# Nintendo Integrated Research & Development                                                NaN
# Open Systems International                                             Minneapolis, Minnesota
# Great Western Bank (1907–present)                    Sioux Falls, South Dakota, United States
# Meyer Turku                                                                             Perno
# Nepal Telecom                                                                             NaN
# Yamaha Corporation                                                                        NaN
# Turner Broadcasting System                                                                NaN
# Peer 1                                      [413 Horner Avenue ,  Etobicoke, ON, Canada   ...
# Mayfair Sporting Club                                                                  London
# Cybersoft                                                                                 NaN
# Amplify (company)                           55 Washington Street\nSuite 900\nBrooklyn, NY ...
# Boundless (company)                                               Boston, Massachusetts, U.S.
#
#                                                                                          logo  \
# Greka Energy                                {u'wiki_raw_code': u'Greka Logo Flag.jpg', u'w...
# Nintendo Integrated Research & Development  {u'wiki_raw_code': u'File:Nintendo IRD logo.pn...
# Open Systems International                  {u'wiki_raw_code': u'File:Open_Systems_Interna...
# Great Western Bank (1907–present)           {u'wiki_raw_code': u'Great Western Bank (moder...
# Meyer Turku                                 {u'wiki_raw_code': u'Meyer Turku logo.jpg', u'...
# Nepal Telecom                               {u'wiki_raw_code': u'Nepal Telecom.jpg', u'wik...
# Yamaha Corporation                          {u'wiki_raw_code': u'[[File:YamahaCorp.svg|200...
# Turner Broadcasting System                                                                NaN
# Peer 1                                                                                    NaN
# Mayfair Sporting Club                                                                     NaN
# Cybersoft                                                                                 NaN
# Amplify (company)                                                                         NaN
# Boundless (company)                         {u'wiki_raw_code': u'[[File:boundless-logo-cen...
#
#                                                      type  \
# Greka Energy                                      Private
# Nintendo Integrated Research & Development       Division
# Open Systems International                        Private
# Great Western Bank (1907–present)                  Public
# Meyer Turku                                    osakeyhtiö
# Nepal Telecom                                      Public
# Yamaha Corporation                          Public (K.K.)
# Turner Broadcasting System                            NaN
# Peer 1                                         Subsidiary
# Mayfair Sporting Club                                 NaN
# Cybersoft                                             NaN
# Amplify (company)                                 Private
# Boundless (company)                                   NaN
#
#                                                         defunct  \
# Greka Energy                                                NaN
# Nintendo Integrated Research & Development  2015-09-16 00:00:00
# Open Systems International                                  NaN
# Great Western Bank (1907–present)                           NaN
# Meyer Turku                                                 NaN
# Nepal Telecom                                               NaN
# Yamaha Corporation                                          NaN
# Turner Broadcasting System                                  NaN
# Peer 1                                                      NaN
# Mayfair Sporting Club                                       NaN
# Cybersoft                                                   NaN
# Amplify (company)                                           NaN
# Boundless (company)                                         NaN
#
#                                                                                        parent  \
# Greka Energy                                                                              NaN
# Nintendo Integrated Research & Development                                           Nintendo
# Open Systems International                                                                NaN
# Great Western Bank (1907–present)                                  Great Western Bancorp Inc.
# Meyer Turku                                                                  Meyer Werft GmbH
# Nepal Telecom                                                                             NaN
# Yamaha Corporation                                                                        NaN
# Turner Broadcasting System                                                                NaN
# Peer 1                                      [[[Cogeco Communications Inc. , Cogeco Communi...
# Mayfair Sporting Club                                                                     NaN
# Cybersoft                                                                                 NaN
# Amplify (company)                                                                         NaN
# Boundless (company)                                                                       NaN
#
#                                                                                        subsid
# Greka Energy                                Greka Oil & Gas, Alexi Realty, Santa Maria Ref...
# Nintendo Integrated Research & Development                                                NaN
# Open Systems International                                                                NaN
# Great Western Bank (1907–present)                                                         NaN
# Meyer Turku                                 *Piikkio Works Oy\nShipbuilding Completion Oy\...
# Nepal Telecom                                                                             NaN
# Yamaha Corporation                                                       Yamaha Motor Company
# Turner Broadcasting System                                                                NaN
# Peer 1                                                                                    NaN
# Mayfair Sporting Club                                                                     NaN
# Cybersoft                                                                                 NaN
# Amplify (company)                                                                         NaN
# Boundless (company)                                                                       NaN
#
# [13 rows x 24 columns]

# %% [markdown]
# ## Add geolocation Data
#
# [OpenStreetMap Nominatim](https://wiki.openstreetmap.org/wiki/Nominatim) or [Google Geocoding API (V3)](https://developers.google.com/maps/documentation/geocoding/start) is used to resolve GPS coordinates to places. Uses the Python library [geopy](https://pypi.python.org/pypi/geopy/1.11.0).

# %%
# show how many companies have an address
def get_location(row, geolocators, _type=None):
    
    # check from top to bottom for location
    loc_str = None
    row_to_check = ['location', 'location_city', 'location_country']
    for r in row_to_check:
        if not pd.isnull(row[r]):
            loc_str = r
    if not loc_str:
        return loc_str

    for g in geoloators:
        loc = g.geocode(loc_str, timeout=10)
        if loc and _type == 'location_gps':
            return (loc.latitude, loc.longitude)
        elif loc:
            return loc.address
    return None

# %%
#c_dat['location_gps'] = df.apply(lambda row: get_location(row), axis=1)
# initialize the different geolocator APIs
g_osm = geopy.geocoders.Nominatim()
g_google = geopy.geocoders.GoogleV3() # can also be with g_api_key
geolocators = [g_osm, g_google]

# applies gets location function for each row
c_dat.apply(lambda row: get_location(row, geolocators), axis=1)
# return the GPS coordinates instead
#c_dat[c_dat.apply(lambda row: get_location(row, geolocators, 'location_gps'), axis=1)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-101-6eb8bf584b78> in <module>()
#       6
#       7 # applies gets location function for each row
# ----> 8 c_dat.apply(lambda row: get_location(row, geolocators), axis=1)
#       9 # return the GPS coordinates instead
#      10 #c_dat[c_dat.apply(lambda row: get_location(row, geolocators, 'location_gps'), axis=1)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4131                     if reduce is None:
#    4132                         reduce = True
# -> 4133                     return self._apply_standard(f, axis, reduce=reduce)
#    4134             else:
#    4135                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4187                     labels = self._get_agg_axis(axis)
#    4188                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 4189                                         labels=labels)
#    4190                     return Series(result, index=labels)
#    4191                 except Exception:
#
# pandas/src/reduce.pyx in pandas.lib.reduce (pandas/lib.c:43127)()
#
# pandas/src/reduce.pyx in pandas.lib.Reducer.get_result (pandas/lib.c:33268)()
#
# <ipython-input-101-6eb8bf584b78> in <lambda>(row)
#       6
#       7 # applies gets location function for each row
# ----> 8 c_dat.apply(lambda row: get_location(row, geolocators), axis=1)
#       9 # return the GPS coordinates instead
#      10 #c_dat[c_dat.apply(lambda row: get_location(row, geolocators, 'location_gps'), axis=1)]
#
# <ipython-input-100-e9f8c2f5e47d> in get_location(row, geolocators, _type)
#      12
#      13     for g in geoloators:
# ---> 14         loc = g.geocode(loc_str, timeout=10)
#      15         if loc and _type == 'location_gps':
#      16             return (loc.latitude, loc.longitude)
#
# /usr/local/lib/python2.7/dist-packages/geopy/geocoders/osm.pyc in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     191         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     192         return self._parse_json(
# --> 193             self._call_geocoder(url, timeout=timeout), exactly_one
#     194         )
#     195
#
# /usr/local/lib/python2.7/dist-packages/geopy/geocoders/base.pyc in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     141
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#     145             message = (
#
# /usr/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /usr/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /usr/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /usr/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /usr/lib/python2.7/urllib2.pyc in https_open(self, req)
#    1239         def https_open(self, req):
#    1240             return self.do_open(httplib.HTTPSConnection, req,
# -> 1241                 context=self._context)
#    1242
#    1243         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# /usr/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1134
#    1135         try:
# -> 1136             response.begin()
#    1137             assert response.will_close != _UNKNOWN
#    1138             self.__state = _CS_IDLE
#
# /usr/lib/python2.7/httplib.pyc in begin(self)
#     451         # read until we get a non-100 response
#     452         while True:
# --> 453             version, status, reason = self._read_status()
#     454             if status != CONTINUE:
#     455                 break
#
# /usr/lib/python2.7/httplib.pyc in _read_status(self)
#     407     def _read_status(self):
#     408         # Initialize with Simple-Response defaults
# --> 409         line = self.fp.readline(_MAXLINE + 1)
#     410         if len(line) > _MAXLINE:
#     411             raise LineTooLong("header line")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /usr/lib/python2.7/ssl.pyc in recv(self, buflen, flags)
#     754                     "non-zero flags not allowed in calls to recv() on %s" %
#     755                     self.__class__)
# --> 756             return self.read(buflen)
#     757         else:
#     758             return self._sock.recv(buflen, flags)
#
# /usr/lib/python2.7/ssl.pyc in read(self, len, buffer)
#     641                 v = self._sslobj.read(len, buffer)
#     642             else:
# --> 643                 v = self._sslobj.read(len)
#     644             return v
#     645         except SSLError as x:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save Data

# %%
# specify the type for each field
# TODO: location_gps 
types = {
    # when first link is crawled
    'wiki_name': unicode,
    'wiki_url': str,
    'name_url_quoted': str,
    
    # when WIKI API is crawled
    'wiki_page_id': int,
    'wiki_api_url': str,
    'all_links': list,
    'links': set,
    'is_company': bool,
    'wiki_raw': unicode,
    
    # from extraction2
    'oc_api_url': str,
    'oc_api_network_url': str,
    
    # added only when Infobox company exists or fields from OpenCorporates
    # not all fields always exist, they are NaN in the resulting DataFrame
    'name': unicode, 
    'type': unicode, 
    'founded': datetime.datetime, 
    'defunct': datetime.datetime, 
    'location': unicode, # 
    'location_city': unicode, 
    'location_country': unicode,
    # following not in OC
    'countries': set, # added with extraction 3
    'logo': dict, 
    'key_people': list, # additonally processed with nameparser.HumanName (dict)
    'industry': list, 
    'subsid': list,
    'products': list, 
    'num_employees': int, 
    'parent': unicode, 
    'homepage': unicode
}

# save as CSV file
comp_df.to_csv(extraction_csv, encoding='utf-8', index_label='wiki_name')

# %%
c_dat = pd.read_csv(extraction_csv, index_col=0, dtype=types)

# %% [markdown]
# ## General Statistics in the Data
#
# * Company with most links.
# * Company with most employees.
# * Companies by country.
# * Companies by age of foundation (graph)
# * Most influential people's first name (top 10)
# * What is the most central company in Denmark and Europe?
# * Company listed in most countries.

# %%
cnt = Counter()
# iterate every row that represents a company
for index, row in c_dat.iterrows():
    if isinstance(row['links'], float):
        continue
    cnt[row['name']] = len(row['links'])

print "Companies with most links:"
pprint(cnt.most_common(10))

# Italian banks have a category section: Banking in Italy (e.g.: https://en.wikipedia.org/wiki/Crediop)
# Out:
# Companies with most links:
# [('Dexia Crediop', 2457),
#  ('Banca Centropadana', 2450),
#  ('Fidi Toscana', 2445),
#  ('Banca Finnat', 2445),
#  ('ChiantiBanca', 2445),
#  ('Caript', 2441),
#  ('Banca Popolare Pugliese', 2426),
#  ('CR Veneto', 2425),
#  ("Banca d'Alba", 2421),
#  ('Banca Esperia', 2420)]

# %%
c_dat['num_employees'] = pd.to_numeric(c_dat['num_employees'])
c_dat.nlargest(10, 'num_employees')['num_employees']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-176-6254f5b99875> in <module>()
# ----> 1 c_dat['num_employees'] = pd.to_numeric(c_dat['num_employees'])
#       2 c_dat.nlargest(10, 'num_employees')['num_employees']
#
# /usr/local/lib/python2.7/dist-packages/pandas/tools/util.pyc in to_numeric(arg, errors, downcast)
#     193             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     194             values = lib.maybe_convert_numeric(values, set(),
# --> 195                                                coerce_numeric=coerce_numeric)
#     196
#     197     except Exception:
#
# pandas/src/inference.pyx in pandas.lib.maybe_convert_numeric (pandas/lib.c:53754)()
#
# ValueError: Unable to parse string "[c. 100 paid staff,  1,404 volunteers]" at position 6459

# %%
cnt = Counter()
for index, row in c_dat.iterrows():
    if isinstance(row['num_employees'], int):
        cnt[row['name']] = int(row['num_employees'])

print "Most companies by country:"
pprint(cnt.most_common(10))
