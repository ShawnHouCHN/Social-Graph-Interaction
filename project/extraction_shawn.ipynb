# %%
# import all necessary packages
from bs4 import BeautifulSoup
from collections import Counter
from matplotlib import pyplot as plt
import networkx as nx
import numpy as np
import operator
import os
import pickle
import pprint
import re
import requests
import urllib, urllib2
from collections import defaultdict
from __future__ import division
from itertools import count
import community # python-louvain package
# IPython specifics
# %matplotlib inline

# %%
corps_link = [
    ('https://en.wikipedia.org/w/index.php?title=List_of_companies_of_the_United_States&action=edit', 'us_corps'),
]

# get all philosopher pages wiki text
all_matches = {
    'all': set()
}

for country in corps_link:
    r = requests.get(country[0])
    soup = BeautifulSoup(r.text, 'html.parser')
    wiki_text = soup.find('textarea').get_text()
    # lines of philosophers start with "*" or "*St."
    # this link in logicians '[[Categoriae decem]]'' wasn't counted
    matches = re.findall(r'(\*\s?|\*\s?St\.\s?)\[\[(.+?)\]\]', wiki_text)
    # only 2nd group with philosopher name
    # remove any lists that can occur in the == See also == section
    m = [x[1].split('|')[0].replace(' ', '_') for x in matches if not re.match(r'list of.*', x[1], re.IGNORECASE)]
    # put in dictonary
    all_matches[country[1]] = m
    all_matches['all'] |= set(m)

pprint.pprint(len(all_matches['us_corps']))
# Out:
# 1727

# %%
wiki_cat_url="https://en.wikipedia.org/wiki/Category:Lists_of_companies_by_country"
wiki_cat_page=urllib2.urlopen(wiki_cat_url)
wiki_cat_soup = BeautifulSoup(wiki_cat_page.read(), 'html.parser')

wiki_subcats = wiki_cat_soup.find("div", attrs={"id":"mw-subcategories"})
wiki_subcats_lists= wiki_subcats.find_all("div",attrs={"class":"mw-category-group"})

wiki_coutrys = wiki_cat_soup.find("div",attrs={"id":"mw-pages"})
wiki_coutrys_lists= wiki_coutrys.find_all("div",attrs={"class":"mw-category-group"})

country_list_subcat=list()
country_list_page=list()


for wiki_subcats_list in wiki_subcats_lists:
    cat_tag=wiki_subcats_list.find("h3").text
    if cat_tag.isalpha():
        coutry_names_alpha=wiki_subcats_list.find("ul").findAll('a')
        coutry_name_lists=[coutry_name_alpha.text.split('Lists of companies of ')[1] for coutry_name_alpha in coutry_names_alpha]
        country_list_subcat+=coutry_name_lists
        
print "Country list extracted from Subcategory section\n"
pprint.pprint(country_list_subcat)

for wiki_coutrys_list in wiki_coutrys_lists:
    cat_tag=wiki_coutrys_list.find("h3").text
    if cat_tag.isalpha():
        coutry_names_alpha=wiki_coutrys_list.find("ul").findAll('a')
        coutry_name_lists=[coutry_name_alpha.text.split('List of companies of ')[1] for coutry_name_alpha in coutry_names_alpha]
        country_list_page+=coutry_name_lists

print "Country list extracted from \"Lists of companies by country\" \n"
pprint.pprint(country_list_page)
# Out:
# Country list extracted from Subcategory section
#
# [u'Afghanistan',
#  u'Albania',
#  u'Algeria',
#  u'Andorra',
#  u'Angola',
#  u'Argentina',
#  u'Armenia',
#  u'Australia',
#  u'Austria',
#  u'Azerbaijan',
#  u'the Bahamas',
#  u'Bahrain',
#  u'Bangladesh',
#  u'Barbados',
#  u'Belarus',
#  u'Belgium',
#  u'Belize',
#  u'Benin',
#  u'Bermuda',
#  u'Bhutan',
#  u'Bolivia',
#  u'Bosnia and Herzegovina',
#  u'Botswana',
#  u'Brazil',
#  u'Brunei',
#  u'Bulgaria',
#  u'Burkina Faso',
#  u'Burundi',
#  u'Cambodia',
#  u'Cameroon',
#  u'Canada',
#  u'Cape Verde',
#  u'the Central African Republic',
#  u'Chad',
#  u'Chile',
#  u'China',
#  u'Colombia',
#  u'the Comoros',
#  u'the Democratic Republic of the Congo',
#  u'the Republic of the Congo',
#  u'Costa Rica',
#  u'Croatia',
#  u'Cuba',
#  u'Cyprus',
#  u'the Czech Republic',
#  u'Denmark',
#  u'Djibouti',
#  u'Dominica',
#  u'the Dominican Republic',
#  u'Ecuador',
#  u'Egypt',
#  u'El Salvador',
#  u'Equatorial Guinea',
#  u'Estonia',
#  u'Ethiopia',
#  u'the Faroe Islands',
#  u'Fiji',
#  u'Finland',
#  u'France',
#  u'Gabon',
#  u'the Gambia',
#  u'Georgia (country)',
#  u'Germany',
#  u'Ghana',
#  u'Greece',
#  u'Guatemala',
#  u'Guinea',
#  u'Guyana',
#  u'Haiti',
#  u'Honduras',
#  u'Hong Kong',
#  u'Hungary',
#  u'Iceland',
#  u'India',
#  u'Indonesia',
#  u'Iran',
#  u'Iraq',
#  u'Ireland',
#  u'Israel',
#  u'Italy',
#  u'Ivory Coast',
#  u'Jamaica',
#  u'Japan',
#  u'Jordan',
#  u'Kazakhstan',
#  u'Kenya',
#  u'North Korea',
#  u'South Korea',
#  u'Kuwait',
#  u'Kyrgyzstan',
#  u'Laos',
#  u'Latvia',
#  u'Lebanon',
#  u'Lesotho',
#  u'Liberia',
#  u'Libya',
#  u'Lithuania',
#  u'Luxembourg',
#  u'the Republic of Macedonia',
#  u'Madadascar',
#  u'Malawi',
#  u'Malaysia',
#  u'the Maldives',
#  u'Mali',
#  u'Malta',
#  u'Mauritania',
#  u'Mauritius',
#  u'Mexico',
#  u'Moldova',
#  u'Mongolia',
#  u'Montenegro',
#  u'Morocco',
#  u'Mozambique',
#  u'Myanmar',
#  u'Namibia',
#  u'Nepal',
#  u'the Netherlands',
#  u'New Zealand',
#  u'Nicaragua',
#  u'Niger',
#  u'Nigeria',
#  u'Norway',
#  u'Oman',
#  u'Pakistan',
#  u'Panama',
#  u'Paraguay',
#  u'Peru',
#  u'the Philippines',
#  u'Poland',
#  u'Portugal',
#  u'Qatar',
#  u'Romania',
#  u'Russia',
#  u'Rwanda',
#  u'Samoa',
#  u'S\xe3o Tom\xe9 and Pr\xedncipe',
#  u'Saudi Arabia',
#  u'Senegal',
#  u'Serbia',
#  u'Seychelles',
#  u'Sierra Leone',
#  u'Singapore',
#  u'Slovakia',
#  u'Slovenia',
#  u'the Solomon Islands',
#  u'Somalia',
#  u'South Africa',
#  u'South Sudan',
#  u'Spain',
#  u'Sri Lanka',
#  u'Sudan',
#  u'Suriname',
#  u'Swaziland',
#  u'Sweden',
#  u'Switzerland',
#  u'Syria',
#  u'Tajikistan',
#  u'Tanzania',
#  u'Thailand',
#  u'Togo',
#  u'Tonga',
#  u'Trinidad and Tobago',
#  u'Tunisia',
#  u'Turkey',
#  u'Uganda',
#  u'Ukraine',
#  u'the United Arab Emirates',
#  u'the United Kingdom',
#  u'the United States',
#  u'Uruguay',
#  u'Uzbekistan',
#  u'Venezuela',
#  u'Vietnam',
#  u'Yemen',
#  u'Zambia',
#  u'Zimbabwe']
# Country list extracted from "Lists of companies by country"
#
# [u'Abkhazia',
#  u'Afghanistan',
#  u'Albania',
#  u'Algeria',
#  u'Andorra',
#  u'Angola',
#  u'Anguilla',
#  u'Antigua and Barbuda',
#  u'Argentina',
#  u'Armenia',
#  u'Australia',
#  u'Austria',
#  u'Azerbaijan',
#  u'the Bahamas',
#  u'Bahrain',
#  u'Bangladesh',
#  u'Barbados',
#  u'Belarus',
#  u'Belgium',
#  u'Belize',
#  u'Benin',
#  u'Bermuda',
#  u'Bhutan',
#  u'Bosnia and Herzegovina',
#  u'Botswana',
#  u'Brazil',
#  u'Brunei',
#  u'Bulgaria',
#  u'Burkina Faso',
#  u'Burundi',
#  u'Cambodia',
#  u'Cameroon',
#  u'Canada',
#  u'Cape Verde',
#  u'the Central African Republic',
#  u'Chad',
#  u'Chile',
#  u'China',
#  u'Colombia',
#  u'the Comoros',
#  u'the Democratic Republic of the Congo',
#  u'the Republic of the Congo',
#  u'Costa Rica',
#  u'Croatia',
#  u'Cuba',
#  u'Cyprus',
#  u'the Czech Republic',
#  u'Denmark',
#  u'Djibouti',
#  u'Dominica',
#  u'the Dominican Republic',
#  u'Egypt',
#  u'El Salvador',
#  u'Equatorial Guinea',
#  u'Estonia',
#  u'Ethiopia',
#  u'the Faroe Islands',
#  u'Finland',
#  u'France',
#  u'Gabon',
#  u'Georgia (country)',
#  u'Germany',
#  u'Ghana',
#  u'Greece',
#  u'Greenland',
#  u'Guatemala',
#  u'Guinea',
#  u'Guinea-Bissau',
#  u'Guyana',
#  u'Haiti',
#  u'Honduras',
#  u'Hong Kong',
#  u'Hungary',
#  u'Iceland',
#  u'India',
#  u'Indonesia',
#  u'Iran',
#  u'Iraq',
#  u'Ireland',
#  u'the Isle of Man',
#  u'Israel',
#  u'Italy',
#  u'the Ivory Coast',
#  u'Jamaica',
#  u'Japan',
#  u'Jordan',
#  u'Kazakhstan',
#  u'Kenya',
#  u'North Korea',
#  u'South Korea',
#  u'Kuwait',
#  u'Laos',
#  u'Latvia',
#  u'Lebanon',
#  u'Lesotho',
#  u'Liberia',
#  u'Libya',
#  u'Lithuania',
#  u'Luxembourg',
#  u'Macau',
#  u'the Republic of Macedonia',
#  u'Madagascar',
#  u'Malawi',
#  u'Malaysia',
#  u'Mali',
#  u'Malta',
#  u'Mauritania',
#  u'Mauritius',
#  u'Mexico',
#  u'Mongolia',
#  u'Montenegro',
#  u'Morocco',
#  u'Mozambique',
#  u'Myanmar',
#  u'the Nagorno-Karabakh Republic',
#  u'Namibia',
#  u'Nepal',
#  u'the Netherlands',
#  u'New Zealand',
#  u'Nicaragua',
#  u'Niger',
#  u'Nigeria',
#  u'Norway',
#  u'Oman',
#  u'Pakistan',
#  u'Panama',
#  u'Peru',
#  u'the Philippines',
#  u'Poland',
#  u'Portugal',
#  u'Puerto Rico',
#  u'Qatar',
#  u'Romania',
#  u'Russia',
#  u'Rwanda',
#  u'Saint Kitts and Nevis',
#  u'Saint Lucia',
#  u'S\xe3o Tom\xe9 and Pr\xedncipe',
#  u'Saudi Arabia',
#  u'Scotland',
#  u'Senegal',
#  u'Serbia',
#  u'Seychelles',
#  u'Sierra Leone',
#  u'Singapore',
#  u'Slovakia',
#  u'Slovenia',
#  u'Somalia',
#  u'South Africa',
#  u'South Sudan',
#  u'Spain',
#  u'Sri Lanka',
#  u'Sudan',
#  u'Swaziland',
#  u'Sweden',
#  u'Switzerland',
#  u'Syria',
#  u'Taiwan',
#  u'Tanzania',
#  u'Thailand',
#  u'Togo',
#  u'Trinidad and Tobago',
#  u'Tunisia',
#  u'Turkey',
#  u'Uganda',
#  u'Ukraine',
#  u'the United Arab Emirates',
#  u'the United States',
#  u'Uzbekistan',
#  u'Venezuela',
#  u'Vietnam',
#  u'Wales',
#  u'Zambia',
#  u'Zimbabwe']

# %%
print "Countries that do not have a direct wiki pages of all registerd companies\n"
unwiki_country=list(set(country_list_subcat).union(set(country_list_page))-set(country_list_page))
print unwiki_country
# Out:
# Countries that do not have a direct wiki pages of all registerd companies
#
# [u'the Solomon Islands', u'Tonga', u'Yemen', u'Samoa', u'Ivory Coast', u'Uruguay', u'Fiji', u'the Maldives', u'Kyrgyzstan', u'Moldova', u'the Gambia', u'Suriname', u'the United Kingdom', u'Paraguay', u'Bolivia', u'Tajikistan', u'Ecuador', u'Madadascar']

# %%
coutry_extend_urls=list()
for wiki_coutrys_list in wiki_coutrys_lists:
    coutry_links=wiki_coutrys_list.find("ul").findAll('a')
    coutry_link_extend=[coutry_link.get("href").split("/wiki/")[1] for coutry_link in coutry_links]
    coutry_extend_urls+=coutry_link_extend
print "links to wiki pages of countries with all registerd noteable companies\n"
pprint.pprint(coutry_extend_urls)
pprint.pprint(len(coutry_extend_urls))
# Out:
# links to wiki pages of countries with all registerd noteable companies
#
# [u'List_of_companies_of_Abkhazia',
#  u'List_of_companies_of_Afghanistan',
#  u'List_of_companies_of_Albania',
#  u'List_of_companies_of_Algeria',
#  u'List_of_companies_of_Andorra',
#  u'List_of_companies_of_Angola',
#  u'List_of_companies_of_Anguilla',
#  u'List_of_companies_of_Antigua_and_Barbuda',
#  u'List_of_companies_of_Argentina',
#  u'List_of_companies_of_Armenia',
#  u'List_of_companies_of_Australia',
#  u'List_of_companies_of_Austria',
#  u'List_of_companies_of_Azerbaijan',
#  u'List_of_companies_of_the_Bahamas',
#  u'List_of_companies_of_Bahrain',
#  u'List_of_companies_of_Bangladesh',
#  u'List_of_companies_of_Barbados',
#  u'List_of_companies_of_Belarus',
#  u'List_of_companies_of_Belgium',
#  u'List_of_companies_of_Belize',
#  u'List_of_companies_of_Benin',
#  u'List_of_companies_of_Bermuda',
#  u'List_of_companies_of_Bhutan',
#  u'List_of_companies_of_Bosnia_and_Herzegovina',
#  u'List_of_companies_of_Botswana',
#  u'List_of_companies_of_Brazil',
#  u'List_of_companies_of_Brunei',
#  u'List_of_companies_of_Bulgaria',
#  u'List_of_companies_of_Burkina_Faso',
#  u'List_of_companies_of_Burundi',
#  u'List_of_companies_of_Cambodia',
#  u'List_of_companies_of_Cameroon',
#  u'List_of_companies_of_Canada',
#  u'List_of_companies_of_Cape_Verde',
#  u'List_of_companies_of_the_Central_African_Republic',
#  u'List_of_companies_of_Chad',
#  u'List_of_companies_of_Chile',
#  u'List_of_companies_of_China',
#  u'List_of_companies_of_Colombia',
#  u'List_of_companies_of_the_Comoros',
#  u'List_of_companies_of_the_Democratic_Republic_of_the_Congo',
#  u'List_of_companies_of_the_Republic_of_the_Congo',
#  u'List_of_companies_of_Costa_Rica',
#  u'List_of_companies_of_Croatia',
#  u'List_of_companies_of_Cuba',
#  u'List_of_companies_of_Cyprus',
#  u'List_of_companies_of_the_Czech_Republic',
#  u'List_of_companies_of_Denmark',
#  u'List_of_companies_of_Djibouti',
#  u'List_of_companies_of_Dominica',
#  u'List_of_companies_of_the_Dominican_Republic',
#  u'List_of_companies_of_Egypt',
#  u'List_of_companies_of_El_Salvador',
#  u'List_of_companies_of_Equatorial_Guinea',
#  u'List_of_companies_of_Estonia',
#  u'List_of_companies_of_Ethiopia',
#  u'List_of_companies_of_the_Faroe_Islands',
#  u'List_of_companies_of_Finland',
#  u'List_of_companies_of_France',
#  u'List_of_companies_of_Gabon',
#  u'List_of_companies_of_Georgia_(country)',
#  u'List_of_companies_of_Germany',
#  u'List_of_companies_of_Ghana',
#  u'List_of_companies_of_Greece',
#  u'List_of_companies_of_Greenland',
#  u'List_of_companies_of_Guatemala',
#  u'List_of_companies_of_Guinea',
#  u'List_of_companies_of_Guinea-Bissau',
#  u'List_of_companies_of_Guyana',
#  u'List_of_companies_of_Haiti',
#  u'List_of_companies_of_Honduras',
#  u'List_of_companies_of_Hong_Kong',
#  u'List_of_companies_of_Hungary',
#  u'List_of_companies_of_Iceland',
#  u'List_of_companies_of_India',
#  u'List_of_companies_of_Indonesia',
#  u'List_of_companies_of_Iran',
#  u'List_of_companies_of_Iraq',
#  u'List_of_companies_of_Ireland',
#  u'List_of_companies_of_the_Isle_of_Man',
#  u'List_of_companies_of_Israel',
#  u'List_of_companies_of_Italy',
#  u'List_of_companies_of_the_Ivory_Coast',
#  u'List_of_companies_of_Jamaica',
#  u'List_of_companies_of_Japan',
#  u'List_of_companies_of_Jordan',
#  u'List_of_companies_of_Kazakhstan',
#  u'List_of_companies_of_Kenya',
#  u'List_of_companies_of_North_Korea',
#  u'List_of_companies_of_South_Korea',
#  u'List_of_companies_of_Kuwait',
#  u'List_of_companies_of_Laos',
#  u'List_of_companies_of_Latvia',
#  u'List_of_companies_of_Lebanon',
#  u'List_of_companies_of_Lesotho',
#  u'List_of_companies_of_Liberia',
#  u'List_of_companies_of_Libya',
#  u'List_of_companies_of_Lithuania',
#  u'List_of_companies_of_Luxembourg',
#  u'List_of_companies_of_Macau',
#  u'List_of_companies_of_the_Republic_of_Macedonia',
#  u'List_of_companies_of_Madagascar',
#  u'List_of_companies_of_Malawi',
#  u'List_of_companies_of_Malaysia',
#  u'List_of_companies_of_Mali',
#  u'List_of_companies_of_Malta',
#  u'List_of_companies_of_Mauritania',
#  u'List_of_companies_of_Mauritius',
#  u'List_of_companies_of_Mexico',
#  u'List_of_companies_of_Mongolia',
#  u'List_of_companies_of_Montenegro',
#  u'List_of_companies_of_Morocco',
#  u'List_of_companies_of_Mozambique',
#  u'List_of_companies_of_Myanmar',
#  u'List_of_companies_of_the_Nagorno-Karabakh_Republic',
#  u'List_of_companies_of_Namibia',
#  u'List_of_companies_of_Nepal',
#  u'List_of_companies_of_the_Netherlands',
#  u'List_of_companies_of_New_Zealand',
#  u'List_of_companies_of_Nicaragua',
#  u'List_of_companies_of_Niger',
#  u'List_of_companies_of_Nigeria',
#  u'List_of_companies_of_Norway',
#  u'List_of_companies_of_Oman',
#  u'List_of_companies_of_Pakistan',
#  u'List_of_companies_of_Panama',
#  u'List_of_companies_of_Peru',
#  u'List_of_companies_of_the_Philippines',
#  u'List_of_companies_of_Poland',
#  u'List_of_companies_of_Portugal',
#  u'List_of_companies_of_Puerto_Rico',
#  u'List_of_companies_of_Qatar',
#  u'List_of_companies_of_Romania',
#  u'List_of_companies_of_Russia',
#  u'List_of_companies_of_Rwanda',
#  u'List_of_companies_of_Saint_Kitts_and_Nevis',
#  u'List_of_companies_of_Saint_Lucia',
#  u'List_of_companies_of_S%C3%A3o_Tom%C3%A9_and_Pr%C3%ADncipe',
#  u'List_of_companies_of_Saudi_Arabia',
#  u'List_of_companies_of_Scotland',
#  u'List_of_companies_of_Senegal',
#  u'List_of_companies_of_Serbia',
#  u'List_of_companies_of_Seychelles',
#  u'List_of_companies_of_Sierra_Leone',
#  u'List_of_companies_of_Singapore',
#  u'List_of_companies_of_Slovakia',
#  u'List_of_companies_of_Slovenia',
#  u'List_of_companies_of_Somalia',
#  u'List_of_companies_of_South_Africa',
#  u'List_of_companies_of_South_Sudan',
#  u'List_of_companies_of_Spain',
#  u'List_of_companies_of_Sri_Lanka',
#  u'List_of_companies_of_Sudan',
#  u'List_of_companies_of_Swaziland',
#  u'List_of_companies_of_Sweden',
#  u'List_of_companies_of_Switzerland',
#  u'List_of_companies_of_Syria',
#  u'List_of_companies_of_Taiwan',
#  u'List_of_companies_of_Tanzania',
#  u'List_of_companies_of_Thailand',
#  u'List_of_companies_of_Togo',
#  u'List_of_companies_of_Trinidad_and_Tobago',
#  u'List_of_companies_of_Tunisia',
#  u'List_of_companies_of_Turkey',
#  u'List_of_companies_of_Uganda',
#  u'List_of_companies_of_Ukraine',
#  u'List_of_companies_of_the_United_Arab_Emirates',
#  u'List_of_companies_of_the_United_States',
#  u'List_of_companies_of_Uzbekistan',
#  u'List_of_companies_of_Venezuela',
#  u'List_of_companies_of_Vietnam',
#  u'List_of_companies_of_Wales',
#  u'List_of_companies_of_Zambia',
#  u'List_of_companies_of_Zimbabwe']
# 174

# %%
companies_dict = defaultdict(dict) #companies default dict...

wiki_base_edit_url="https://en.wikipedia.org/w/index.php?title="
wiki_base_page_url="https://en.wikipedia.org/wiki/"

com_col_dict=["name","registered name","company name","company","english"] #possible column names
for country_name, coutry_extend_url in zip(country_list_page,coutry_extend_urls):
    inds_list=list() #indust areas
    coms_list=list()
    
    full_edit_url = wiki_base_edit_url+coutry_extend_url+"&action=edit"
    full_page_url = wiki_base_page_url+coutry_extend_url

    r_edit = requests.get(full_edit_url)
    r_page = requests.get(full_page_url)
    
    soup_edit = BeautifulSoup(r_edit.text, 'html.parser')
    soup_page = BeautifulSoup(r_page.text, 'html.parser')
    
    com_tables=soup_page.find_all("table", attrs={"class":re.compile('wikitable.*')})
    com_div=soup_page.find("div", attrs={"id":"mw-content-text"})
           
    if len(com_tables): # countries that have company in table on their homepages
        print "\n EXCEPTION FORMAT PAGE:"+country_name+" has their companies saved in a table on home page"
        for com_table in com_tables:
            table_cols=com_table.find("tr").text.strip().lower().split('\n')
            com_col=(set(com_col_dict) & set(table_cols)).pop()
            com_col_index=table_cols.index(com_col)
            for row in com_table.find_all("tr")[1:]:
                if len(row.find_all('td'))<=com_col_index:
                    continue
                elif row.find_all('td')[com_col_index].find('a') and row.find_all('td')[com_col_index].find('a').parent.name!="sup": #there are none-link rows                   
                    com_td = row.find_all('td')[com_col_index].find('a')
                    com_name = com_td['title'].split("|")[0].replace(' ', '_')
                    companies_dict[com_name]['Country']=country_name
    
    else: #countries have company in list
        print "\n REGULAR FORMAT PAGE:"+country_name+" has their companies saved in a list on home page"
        wiki_text = soup_edit.find('textarea').get_text()
        matches = re.findall(r'(\*\s?)\[\[(.+?)\]\]', wiki_text)
        
        for x in matches:
            if "List of" not in x[1] and "Economy of" not in x[1] and "Companies of" not in x[1] and "Public limited" not in x[1]:
                com_name=x[1].split("|")[0].replace(' ', '_')
                companies_dict[com_name]['Country']=country_name

pprint.pprint(companies_dict)

    #else: #countries have company in list
        
    
    
    #wiki_text = soup_edit.find('textarea').get_text()
    #matches = re.findall(r'([\*\s\|]*)\[\[(.+?)\]\]', wiki_text)
    
    #break
    #matches = re.findall(r'(\*\s?|\*\s?St\.\s?)\[\[(.+?)\]\](.+?)', wiki_text)
    
    #m = [x[1].split('|')[0].replace(' ', '_') for x in matches]
    # put in dictonary
    #countries_dict[country_name]=m
    #countries_dict['all']|=set(m)
# Out:
#  REGULAR FORMAT PAGE:Abkhazia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Afghanistan has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Albania has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Algeria has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Andorra has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Angola has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Anguilla has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Antigua and Barbuda has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Argentina has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Armenia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Australia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Austria has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Azerbaijan has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Bahamas has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Bahrain has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Bangladesh has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Barbados has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Belarus has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Belgium has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Belize has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Benin has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Bermuda has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Bhutan has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Bosnia and Herzegovina has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Botswana has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Brazil has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Brunei has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Bulgaria has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Burkina Faso has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Burundi has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Cambodia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Cameroon has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Canada has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Cape Verde has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:the Central African Republic has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Chad has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Chile has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:China has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Colombia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Comoros has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Democratic Republic of the Congo has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Republic of the Congo has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Costa Rica has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Croatia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Cuba has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Cyprus has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:the Czech Republic has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Denmark has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Djibouti has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Dominica has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Dominican Republic has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Egypt has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:El Salvador has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Equatorial Guinea has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Estonia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Ethiopia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Faroe Islands has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Finland has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:France has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Gabon has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Georgia (country) has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Germany has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Ghana has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Greece has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Greenland has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Guatemala has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Guinea has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Guinea-Bissau has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Guyana has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Haiti has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Honduras has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Hong Kong has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Hungary has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Iceland has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:India has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Indonesia has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Iran has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Iraq has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Ireland has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Isle of Man has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Israel has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Italy has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Ivory Coast has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Jamaica has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Japan has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Jordan has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Kazakhstan has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Kenya has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:North Korea has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:South Korea has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Kuwait has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Laos has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Latvia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Lebanon has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Lesotho has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Liberia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Libya has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Lithuania has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Luxembourg has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Macau has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Republic of Macedonia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Madagascar has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Malawi has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Malaysia has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Mali has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Malta has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Mauritania has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Mauritius has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Mexico has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Mongolia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Montenegro has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Morocco has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Mozambique has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Myanmar has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Nagorno-Karabakh Republic has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Namibia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Nepal has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Netherlands has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:New Zealand has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Nicaragua has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Niger has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Nigeria has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Norway has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Oman has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Pakistan has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Panama has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Peru has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:the Philippines has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Poland has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Portugal has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Puerto Rico has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Qatar has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Romania has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Russia has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Rwanda has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Saint Kitts and Nevis has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Saint Lucia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:São Tomé and Príncipe has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Saudi Arabia has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Scotland has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Senegal has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Serbia has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Seychelles has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Sierra Leone has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Singapore has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Slovakia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Slovenia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Somalia has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:South Africa has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:South Sudan has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Spain has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Sri Lanka has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Sudan has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Swaziland has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Sweden has their companies saved in a list on home page
#
#  REGULAR FORMAT PAGE:Switzerland has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Syria has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Taiwan has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Tanzania has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Thailand has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Togo has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Trinidad and Tobago has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Tunisia has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Turkey has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Uganda has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Ukraine has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:the United Arab Emirates has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:the United States has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Uzbekistan has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Venezuela has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Vietnam has their companies saved in a table on home page
#
#  REGULAR FORMAT PAGE:Wales has their companies saved in a list on home page
#
#  EXCEPTION FORMAT PAGE:Zambia has their companies saved in a table on home page
#
#  EXCEPTION FORMAT PAGE:Zimbabwe has their companies saved in a table on home page
# defaultdict(<type 'dict'>, {u'Banco_Internacional_de_S\xe3o_Tom\xe9_e_Pr\xedncipe': {'Country': u'S\xe3o Tom\xe9 and Pr\xedncipe'}, u'Discount_Investment_Corporation_Ltd.': {'Country': u'Israel'}, u'Holmen_(company)': {'Country': u'Sweden'}, u'Laqtel': {'Country': u'Trinidad and Tobago'}, u'Cadillac_Fairview': {'Country': u'Canada'}, u'Columbia_Sussex': {'Country': u'the United States'}, u'Armenia_TV': {'Country': u'Armenia'}, u'Sonali_Bank': {'Country': u'Bangladesh'}, u'Cacique_Guaro': {'Country': u'Costa Rica'}, u'Recaro': {'Country': u'Germany'}, u'Carrozzeria_Castagna': {'Country': u'Italy'}, u'Imperia_(car)': {'Country': u'Belgium'}, u'Actelion': {'Country': u'Switzerland'}, u'Africa_World_Airlines': {'Country': u'Ghana'}, u'Dura_Automotive_Systems': {'Country': u'the United States'}, u'Appear': {'Country': u'Sweden'}, u'LM_Glasfiber': {'Country': u'Denmark'}, u'ATV_(Russia)': {'Country': u'Russia'}, u'Bure_Equity': {'Country': u'Sweden'}, u'Casio': {'Country': u'Japan'}, u'Lee_(jeans)': {'Country': u'the United States'}, u'CSX_Corporation': {'Country': u'the United States'}, u'Azerbaijan_International_Mineral_Resources_Operating_Company': {'Country': u'Azerbaijan'}, u'MacDonald_Dettwiler': {'Country': u'Canada'}, u'OPAP': {'Country': u'Greece'}, u'Fox_(clothing)': {'Country': u'Israel'}, u'Telecaribe': {'Country': u'Colombia'}, u'Meghna_Group': {'Country': u'Bangladesh'}, u'Luxor_AB': {'Country': u'Sweden'}, u'Tencent_Holdings_Ltd': {'Country': u'China'}, u'Quest_Global': {'Country': u'Singapore'}, u'Old_Mutual': {'Country': u'South Africa'}, u'Scottrade': {'Country': u'the United States'}, u'Bank_of_Kigali': {'Country': u'Rwanda'}, u'Progressive_Broadcasting_Corporation': {'Country': u'the Philippines'}, u'Nimero': {'Country': u'Bulgaria'}, u'Marsh_&_McLennan_Companies': {'Country': u'the United States'}, u'LG_Chem': {'Country': u'South Korea'}, u'Arkem': {'Country': u'Turkey'}, u'In_Win_Development': {'Country': u'Taiwan'}, u'Telefe': {'Country': u'Argentina'}, u'Etro': {'Country': u'Italy'}, u'BenQ': {'Country': u'Taiwan'}, u'Ufone': {'Country': u'Pakistan'}, u'LATAM_Cargo_Chile': {'Country': u'Chile'}, u'BlackBerry_(company)': {'Country': u'Canada'}, u'Suzlon_Energy': {'Country': u'India'}, u'AhnLab_Inc': {'Country': u'South Korea'}, u'Trijicon': {'Country': u'the United States'}, u'Westinghouse_Digital_LLC': {'Country': u'the United States'}, u'OKTA': {'Country': u'the Republic of Macedonia'}, u'Elektroprivreda_Republike_Srpske': {'Country': u'Bosnia and Herzegovina'}, u'SAMAA_TV': {'Country': u'Pakistan'}, u'Cumerio_Med': {'Country': u'Bulgaria'}, u'Venezolana': {'Country': u'Venezuela'}, u'Australian_airExpress': {'Country': u'Australia'}, u'K2_Telecom': {'Country': u'Uganda'}, u'Acando': {'Country': u'Sweden'}, u'Blackburn_Radio': {'Country': u'Canada'}, u'Pajhwok_Afghan_News': {'Country': u'Afghanistan'}, u'Shaw_Brothers_Studio': {'Country': u'Hong Kong'}, u'Macau_Jockey_Club': {'Country': u'Macau'}, u'Air_Dolomiti': {'Country': u'Italy'}, u'Sociedade_Independente_de_Comunica\xe7\xe3o': {'Country': u'Portugal'}, u'Air_Arabia_Maroc': {'Country': u'Morocco'}, u'Onvia': {'Country': u'the United States'}, u'Grace_Kennedy_and_Company_Limited': {'Country': u'Jamaica'}, u'Sanden_Corporation': {'Country': u'Japan'}, u'Semen_Indonesia': {'Country': u'Indonesia'}, u'Chantelle_(underwear)': {'Country': u'France'}, u'Dangote_Industries_Tanzania': {'Country': u'Tanzania'}, u'Tanfoglio': {'Country': u'Italy'}, u'Giant_Bicycles': {'Country': u'Taiwan'}, u'Uralita_Group': {'Country': u'Spain'}, u'Elekta': {'Country': u'Sweden'}, u'Eco-M\xe9dias': {'Country': u'Morocco'}, u'Junkers_(Aircraft)': {'Country': u'Germany'}, u'Kapital_Bank': {'Country': u'Azerbaijan'}, u'Alfonso_Bialetti': {'Country': u'Italy'}, u'AT&T': {'Country': u'the United States'}, u'Air_Tropiques': {'Country': u'the Democratic Republic of the Congo'}, u'Panda_Energy_International': {'Country': u'the United States'}, u'Avision': {'Country': u'Taiwan'}, u'Avian ...

# %%
dict_len= len(companies_dict.keys())
print "{0} noteable Companies in WIKI".format(dict_len)
# Out:
# 12606 noteable Companies in WIKI

# %% [markdown]
# ### 2. Save contents of each company page in another dict ###

# %%
#make working directory
directory = os.getcwd()+'/companies_dictionary'
if not os.path.exists(directory):
    os.makedirs(directory)

# %%
# wikipedia API parameters
baseurl = "https://en.wikipedia.org/w/api.php"
action = "action=query"
content = "prop=revisions&rvprop=content"
dataformat = "format=json"

# get content key: company name, value: json
for com_name in companies_dict.keys(): 
    # replace special cahrs in philosopher name with URL encoded
    title = 'titles={0}'.format(urllib.quote(com_name.encode('utf-8')))
    # concatenate wikipedia query
    url = '{0}?{1}&{2}&{3}&{4}'.format(baseurl, action, title, content, dataformat)
    r = requests.get(url)
    companies_dict[com_name]['Countent']=r.text

# store company data in one small binary file
with open('{0}/dat.pkl'.format(directory), 'wb') as f:
    pickle.dump(companies_dict, f)

# %% [markdown]
# ### 3. Construct the company network ###

# %%
# load data dictionary
directory = os.getcwd()+'/companies_dictionary'
with open('{0}/dat.pkl'.format(directory), 'rb') as f:
    com_dat_dict = pickle.load(f)

# create one node per company name (keys of data)
p_graph = nx.DiGraph()

# %%
# create node links
for p in com_dat_dict.keys():
    p_country = com_dat_dict[p]['Country']
    p_content = com_dat_dict[p]['Countent']
    # find all wiki links in the content
    p_links = re.findall(r'\[\[(.+?)\]\]', p_content)
    # list with all outgoing links for edges
    # decode unicode chars and clean the link for matching
    out_links = [l.decode('unicode-escape').split('|')[0].replace(' ', '_') for l in p_links]

    # add a node for the company
    p_graph.add_node(p,Country=p_country)
    # intersection between all companies and found links in article
    all_edges = set(com_dat_dict.keys()).intersection(out_links)
    # show example of related company
    if p == 'Apple_Inc.':
        print all_edges    
    # add an edge for the company
    for e in all_edges:
        p_graph.add_edge(p, e)
# Out:
# set([u'Nokia', u'IBM', u'Anobit', u'Foxconn', u'Ford_Motor_Company', u'Dell', u'Sun_Microsystems', u'John_Wiley_&_Sons', u'Tesla_Motors', u'CNET', u'PrimeSense', u'LG_Chem', u'AOL', u'Xerox', u'Toshiba', u'Maxim_Integrated', u'Inventec', u'Nike,_Inc.', u'Motorola', u'Intel', u'Netflix', u'Samsung_Electronics', u'FileMaker_Inc.', u'Johnson_Controls', u'Omnicom_Group', u'Microsoft', u'Google', u'Time_Warner', u'Twitter', u'Macromedia', u'Verizon_Wireless', u'The_Coca-Cola_Company', u'Uber_(company)', u'Panasonic'])

# %%
print "There are {0} nodes in the network".format(len(p_graph.nodes()))
print "There are {0} edges in the network".format(len(p_graph.edges()))
# Out:
# There are 12606 nodes in the network
# There are 27403 edges in the network

# %% [markdown]
# ### Draw the Company Network in directed graph

# %%
# draw countries with different colors
com_color_dict=dict()
print "Number of color used in the plot : {0}".format(len(country_list_page))


coutry_attr_list = set(nx.get_node_attributes(p_graph,'Country').values())
mapping = dict(zip(sorted(coutry_attr_list),count()))
nodes = p_graph.nodes()
colors = [mapping[p_graph.node[n]['Country']] for n in nodes]
# Out:
# Number of color used in the plot : 174

# %%
plt.figure(num=None, figsize=(20, 20), dpi=1200)
pos = nx.spring_layout(p_graph)
ec = nx.draw_networkx_edges(p_graph, pos, alpha=0.2)
nc = nx.draw_networkx_nodes(p_graph, pos, nodelist=nodes, node_color=colors, 
                            with_labels=False, node_size=5, width=0.1,cmap=plt.cm.jet)

plt.colorbar(nc)
plt.axis('off')
plt.show()

# %% [markdown]
# *** Compute the giant component of the network ***

# %%
p_weak = sorted(nx.weakly_connected_component_subgraphs(p_graph), key=len, reverse=True)[0]
print 'The size (number of nodes) of subgraph with largest weakly connected component is:', p_weak.size()
# Out:
# The size (number of nodes) of subgraph with largest weakly connected component is: 27022

# %% [markdown]
# *** Top 5 scored company nodes of in-out degree  ***

# %%
### degree centrality
# in-edges
node_in_degree = nx.in_degree_centrality(p_weak)
# out-edges
node_out_degree = nx.out_degree_centrality(p_weak)

print "5 most central companies according to in-edges degree centrality:"
pprint.pprint(Counter(node_in_degree).most_common(5))

print "\n5 most central companies according to out-edges degree centrality:"
pprint.pprint(Counter(node_out_degree).most_common(5))
# Out:
# 5 most central companies according to in-edges degree centrality:
# [(u'Microsoft', 0.019780773592037292),
#  (u'IBM', 0.017386922010835328),
#  (u'Google', 0.014867078241149047),
#  (u'General_Motors', 0.013859140733274537),
#  (u'Boeing', 0.013103187602368652)]
#
# 5 most central companies according to out-edges degree centrality:
# [(u'Amsterdam_Airport_Schiphol', 0.009575406324807861),
#  (u'Etihad_Airways', 0.00667758598966864),
#  (u'Copenhagen_Airport', 0.0062996094242156984),
#  (u'Samsung', 0.0062996094242156984),
#  (u'Dell', 0.005669648481794128)]

# %% [markdown]
# *** Top 5 scored company node based on betweeness centrality ***

# %%
# calculate betweenness centrality
node_dict = nx.betweenness_centrality(p_weak)

# use to print with betweenness_centrality
print "Top 5 most central company according to betweenness centrality:"
pprint.pprint(Counter(node_dict).most_common(5))
# Out:
# Top 5 most central company according to betweenness centrality:
# [(u'Samsung', 0.023595465098595916),
#  (u'General_Motors', 0.021575844789258395),
#  (u'IBM', 0.020557042779404636),
#  (u'General_Electric', 0.019917747961655467),
#  (u'American_Express', 0.019179581897363795)]

# %% [markdown]
# *** Top 5 scored company nodes based on eigenvector centrality ***

# %%
### eigenvector centrality
# in-edges
node_in_eigen = nx.eigenvector_centrality(p_weak)
# For out-edges eigenvector centrality first reverse the graph with G.reverse().
node_out_eigen = nx.eigenvector_centrality(p_weak.reverse())

print "5 most central companies according to in-edges eigenvector centrality:"
pprint.pprint(Counter(node_in_eigen).most_common(5))

print "\n5 most central companies according to out-edges eigenvector centrality:"
pprint.pprint(Counter(node_out_eigen).most_common(5))
# Out:
# 5 most central companies according to in-edges eigenvector centrality:
# [(u'Singapore_Airlines', 0.21431281646637113),
#  (u'Etihad_Airways', 0.20674713286604718),
#  (u'United_Airlines', 0.19759936988041266),
#  (u'Turkish_Airlines', 0.19507678728376882),
#  (u'Air_Canada', 0.189781602909256)]
#
# 5 most central companies according to out-edges eigenvector centrality:
# [(u'Amsterdam_Airport_Schiphol', 0.2424834967730799),
#  (u'Etihad_Airways', 0.2127981236870296),
#  (u'United_Airlines', 0.19530481399145527),
#  (u'Turkish_Airlines', 0.17011830666218938),
#  (u'Air_Canada', 0.1664732584478017)]

# %%
#for k,v in node_in_eigen.iteritems():
#    print k
print node_in_eigen['Lenovo']
# Out:
# 0.0029037104617

# %% [markdown]
# *** Top 5 scored company nodes based on in/out centrality ***

# %%
### degree centrality
# in-edges
node_in_degree = nx.in_degree_centrality(p_weak)
# out-edges
node_out_degree = nx.out_degree_centrality(p_weak)

print "5 most central companies according to in-edges degree centrality:"
pprint.pprint(Counter(node_in_degree).most_common(5))

print "\n5 most central companies according to out-edges degree centrality:"
pprint.pprint(Counter(node_out_degree).most_common(5))
# Out:
# 5 most central companies according to in-edges degree centrality:
# [(u'Microsoft', 0.019780773592037292),
#  (u'IBM', 0.017386922010835328),
#  (u'Google', 0.014867078241149047),
#  (u'General_Motors', 0.013859140733274537),
#  (u'Boeing', 0.013103187602368652)]
#
# 5 most central companies according to out-edges degree centrality:
# [(u'Amsterdam_Airport_Schiphol', 0.009575406324807861),
#  (u'Etihad_Airways', 0.00667758598966864),
#  (u'Copenhagen_Airport', 0.0062996094242156984),
#  (u'Samsung', 0.0062996094242156984),
#  (u'Dell', 0.005669648481794128)]

# %% [markdown]
# ** Draw the WIKI graph in undirected way **

# %%
p_undirect_graph = p_graph.to_undirected()

# %%
# draw countries with different colors
com_color_dict=dict()
print "Number of color used in the plot : {0}".format(len(country_list_page))


coutry_attr_list = set(nx.get_node_attributes(p_undirect_graph,'Country').values())
mapping = dict(zip(sorted(coutry_attr_list),count()))
nodes = p_undirect_graph.nodes()
colors = [mapping[p_undirect_graph.node[n]['Country']] for n in nodes]
# Out:
# Number of color used in the plot : 174

# %%
p_undirect_graph = p_graph.to_undirected()
#ec = nx.draw_networkx_edges(p_ungraph, pos, alpha=0.5)
#nc = nx.draw_networkx_nodes(p_ungraph, pos, nodelist=nodes_undirect, node_color=colors, 
#                            with_labels=False, node_size=5, width=0.1,cmap=plt.cm.jet)
pos = nx.spring_layout(p_undirect_graph)
nc=nx.draw_networkx(p_undirect_graph, pos, nodelist=nodes, node_color=colors, with_labels=False, node_size=5, width=0.1,cmap=plt.cm.jet)
#plt.colorbar(nc)
plt.axis('off')
plt.show()
