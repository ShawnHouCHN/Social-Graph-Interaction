# %% [markdown]
# ** 02805 Social graphs and interactions **
#
# # Data Extraction Part 1

# %%
# IPython global cell magic
# %reset
# %matplotlib inline

# import all necessary packages
import bs4 # HTML parser
from collections import Counter, OrderedDict # counting elements and ordering keys in dictionaries
import community # python-louvain package
from __future__ import division # all numbers are float
import geopy # get geo location according to addresses
from geopy.exc import GeocoderServiceError
import datetime # handle date objects
import dateparser # parse any (also foreign) date format to object: https://pypi.python.org/pypi/dateparser
import itertools # iterators for efficient looping
import json # JSON parser
import math # math operations
from matplotlib import pyplot as plt # plotting figures
import mwparserfromhell # parse MediaWiki syntax: https://github.com/earwig/mwparserfromhell
from nameparser import HumanName # parse a human name
import networkx as nx # networks creation library
import nltk # natural language processing
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
import operator # efficient operator functions
import os # operating system operations, e.g.: with files and folders
import pandas as pd # use easy-to-use data frames for data analysis
import pickle # python data structures as files
from pprint import pprint # print data structures prettier
import re # regex
import requests # request URL content
import time # sleep timer
from tqdm import tqdm_notebook # make a nice progressbar
import urllib # handle special URL chars

# make working directory
directory = os.getcwd() + '/companies'
if not os.path.exists(directory):
    os.makedirs(directory)

# files
ex1_fdat = directory + '/extraction1_data.pkl'
ex2_fdat = directory + '/extraction2_data.pkl'
ex3_tmp_fdat = directory + '/tmp_extraction3_data.pkl'
ex3_fdat = directory + '/extraction3_data.pkl'
merged = directory + '/merged_data.pkl'
extraction_csv = directory + '/company_data.csv'
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
def get_json_from_url(url):
    r = requests.get(url)
    
    # on HTML error codes
    if r.status_code != 200:
        return None

    # try converting into JSON
    try:
        sec = r.json()
        return sec
    except ValueError:  # includes simplejson.decoder.JSONDecodeError
        print 'WARN: Decoding JSON has failed on:', url
    return None

# %%
def get_comp_pages(api_url, extension=None):
    
    ext_api_url = api_url
    if extension:
        ext_api_url += extension
    
    # retrieve JSON
    sites_w_template = get_json_from_url(ext_api_url)

    # check for valid data
    if not sites_w_template or 'query' not in sites_w_template:
        print "WARN: query returned no data:", infobox_url + properties
    else:
        # iterate over list of companies that embed infobox and save to dict
        for page in sites_w_template['query']['embeddedin']:
            # unicode to str
            quoted_name = urllib.quote_plus(page['title'].encode('utf-8'))
            companies.update({
                page['title']: {
                    'wiki_page_id': int(page['pageid']),
                    'wiki_name': unicode(page['title']),
                    'wiki_url': u'{0}{1}?title={2}'.format(wiki_base, wiki_index, quoted_name),
                    'name_url_quoted': quoted_name
                }
            })

        # run the function recursively, when company found
        if 'continue' in sites_w_template:
            extension = '&eicontinue=' + sites_w_template['continue']['eicontinue']
            return get_comp_pages(api_url, extension)
    
    return companies

# %% [markdown]
# Example query for extraction of pages with "Infobox company" template:
# * https://en.wikipedia.org/w/api.php?&action=query&list=embeddedin&eititle=Template:Infobox+company&einamespace=0&eilimit=max
# * https://en.wikipedia.org/w/api.php?&action=query&list=embeddedin&eititle=Template:Infobox+company&einamespace=0&eilimit=max&eicontinue=0|167638

# %%
# specify wikipedia API URL parameters
wiki_base = u'https://en.wikipedia.org'
wiki_api = u'/w/api.php'
wiki_index = u'/w/index.php'
action = u'action=query'
dat_format = u'format=json'
# eititle=Template:Infobox+company - embedded pages with Template {{Infobox Company}}
# einamespace=0 only articles
# eilimit=max - maximum number before continuing to minimize requests
properties = u'list=embeddedin&eititle=Template:Infobox+company&einamespace=0&eilimit=max'

# concatenate URL
infobox_url = '{0}{1}?&{2}&{3}&'.format(
    wiki_base, wiki_api, action, dat_format)

# init and update with recursive function
companies = dict()
get_comp_pages(infobox_url + properties)

print len(companies), "companies were extracted."
# Out:
# 56843 companies were extracted.

# %%
print companies['AT&T']
# Out:
# {'name_url_quoted': 'AT%26T', 'wiki_page_id': 17555269, 'wiki_url': u'https://en.wikipedia.org/w/index.php?title=AT%26T', 'wiki_name': u'AT&T'}

# %%
def get_temp_val(temp, k):
    """Check if the parameter exists in the infobox template"""

    try:
        param = temp.get(k)
        return param
    except ValueError:
        # try alternative keys (template not always consistent)
        if k == 'founded':
            return get_temp_val(temp, 'foundation')
        if 'location' in k and 'hq_' not in k:
            return get_temp_val(temp, 'hq_' + k)
    # key not found in template
    return None

# %%
def parse_employee_nr(input_val, c_name):
    """
    Parse a proper number out of the various inputs
    Case possibilities tested:
    
    s_list = [
        '15-50',
        '~300+',
        'circa 40',
        '9,985(Dec 2011)',
        'over 10,000 in 10 countries',
        'Five',
        'over 1 million',
        '10.000',
        'Part of Popular, Inc., which has 8,000 employees'
    ]

    for s in s_list:
        print parse_employee_nr(s, 'test')
    """
    
    # match the first number, dot or comma separation optional
    m = re.search(r'[0-9]+([,\.][0-9]+)?', unicode(input_val))
    if m:
        try:
            # replace , and conert to int
            return int(m.group().replace(',', '').replace('.', ''))
        except ValueError:
            print "WARN: Failed conversion of:{0} (company: {1})".format(
                input_val, c_name)
    return None

# %%
def parse_people_name(names):
    """
    Tim Cook (CEO) becomes 
    {u'last': u'Cook', u'suffix': u'', u'title': u'', u'middle': u'', u'nickname': u'CEO', u'first': u'Tim'}
    """

    # if n makes sure no empty list value
    items = [HumanName(n).as_dict() for n in names if n]
    return items

# %%
def parse_date(date):
    if date: 
        # if only the year is given returns todays date in that year
        date_parsed = dateparser.parse(date, settings={
            'PREFER_DATES_FROM': 'past',
            'DATE_ORDER': 'YMD'})
        # try to extract the first number with 4 digits from 18XX-20XX
        if not date_parsed:
            m = re.search(r'(18|19|20\d{2})', date)
            if m:
                return dateparser.parse(m.group())
        else:
            return date_parsed
    # return null time: 00:00:00
    return datetime.time()

# %%
def parse_wiki_raw(param, k, c_name):
    """Extract the information on the raw value without notable wiki markup"""

    # strip_code does not work properly for [[File:: https://github.com/earwig/mwparserfromhell/issues/136
    if k == 'logo':
        split_val = unicode(param.value).strip().split('|')
        # first value always image link
        if split_val[0]:
            # avoid bs4 warning
            val = split_val[0]
            if not re.match(r'http://.*', val):
                val = bs4.BeautifulSoup(val, 'lxml').text
            val = val.replace('[[', '').replace(' ', '_')
            if val:
                # can be written without [[File: or [[Image:
                if 'File:' in val or 'Image:' in val:
                    pass
                else:
                    val = 'File:' + val
                # submit raw version too, also links can differ
                return {
                    'wiki_commons_link': 'https://commons.wikimedia.org/wiki/' + val,
                    'wiki_file_link': wiki_base + '/wiki/' + val,
                    'wiki_raw_code': param.value.strip()}
    
    # fields can contain break separations, e.g. Microsoft: 
    # [[John W. Thompson]] <small> ([[Chairman]]) </small> <br /> [[Satya Nadella]]
    if '<br' in param.value:
        # replace the HTML breaks with real newline
        param.value = re.sub(r'<br>|<br ?/>', '\n', unicode(param.value))
        # get rid of media wiki markup and split into parts
        val = unicode(param.value.strip_code())
        # strip code does not always remove HTML tags
        val = bs4.BeautifulSoup(val, 'lxml').text
        items = val.split('\n')
        if k == 'key_people':
            return parse_people_name(items)
        if k == 'num_employees':
            return parse_employee_nr(items[-1], c_name)
        return items

    # only assuming one value when no breaks, too vague to use other seperators than <br>
    val = param.value.strip_code()

    # avoid bs4 warning when parsing HTML link
    if k != 'homepage':
        # properly remove HTML remains
        val = bs4.BeautifulSoup(val, 'lxml').text
    if k == 'homepage':
        # there are cases like: [http://www.absn.tv/ ABS] for homepage/website that don't match URL template
        match_link = re.search(r'\[(.+)\]', unicode(param.value))
        if match_link:
            val = match_link.group(1)
        # if whitespaces, then still no valid link
        if ' ' in val:
            # HTML needs to be ignored, e.g.: <!-- {{URL|www.example.com}} --> (also strips text)
            rem_html = bs4.BeautifulSoup(val, 'lxml').text
            if rem_html:
                return param.value.strip().split(' ')[0].replace('[', '')
            else:
                return None
    if k == 'num_employees':
        return parse_employee_nr(val, c_name)

    # make sure string didn't just contain whitespaces
    if val:
        return unicode(val).strip()
    # it can be that the field exists but is empty
    return None

# %%
def parse_wiki_template(param, k, c_name):
    """Extract further information if templates in key value"""

    for tem in param.value.filter_templates():
        # handle dates, URL and list
        if k == 'founded' or k == 'defunct':
            if tem.name.matches(('start date and age', 'start date', 'end date')):
                # valid date: {{Start date and age|2003|January|5|df=1}}
                date = [unicode(p) for p in tem.params if '=' not in unicode(p)]
                # concatenate the date and give to dateparser
                if not date:
                    return datetime.time()
                return parse_date("/".join(date))
            else:
                return datetime.time()
        elif k == 'homepage' and tem.name.matches(('url', 'URL')):
            if tem.params:
                try:
                    url = tem.get(1)
                except ValueError:
                    print "WARN: Could not get first element in params:", tem.params
                    return unicode(tem.params[0]).strip()
                return unicode(url).strip()
        elif tem.name.matches('unbulleted list'):
            # replace wiki link markup and remove extra citations etc.
            items = [p.value.strip_code().strip() for p in tem.params]
            if k == 'key_people':
                return parse_people_name(items)
            if k == 'num_employees':
                # e.g.: {{unbulleted list|{{loss}}0 (7 February 2013)|850 (6 February 2013)}}
                # usually last value contains current number
                return parse_employee_nr(items[-1], c_name)
            return items
        elif tem.name.matches(('plainlist', 'flatlist')):
            if tem.params:
                items = tem.params[0].value.strip_code().strip().split('\n')
                if k == 'key_people':
                    # use nameparse to exclude titles, etc.
                    return parse_people_name(items)
                return items
        elif 'formatnum' in tem.name and k == 'num_employees':
            # {{formatnum:1234}}, colon not detected by mwparser
            m = re.search(r'formatnum:(.*)', unicode(tem.name))
            if m:
                return parse_employee_nr(m.group(1), c_name)

    # if the template didn't match anything parse raw text
    return parse_wiki_raw(param, k, c_name)

# %%
def parse_wiki_text(company):
    """Parse MediaWiki markup to extract detailed information"""

    # remove ref tags, bs4 adds unwanted body tags, thus regex better
    wiki_raw = re.sub(r'<ref.*?</ref>|<ref>.*?</ref>', '', company['wiki_raw'])

    comp_infobox = dict()
    # parse the wikimedia syntax
    # style can be ignored: https://github.com/earwig/mwparserfromhell/issues/115
    code = mwparserfromhell.parse(wiki_raw, skip_style_tags=True)
    # filter for the infobox
    # If matches is a regex, the flags passed to re.search() are re.IGNORECASE ...
    c_template = code.filter_templates(
        matches=r'infobox company|infobox_company|company infobox|company|infobox dot-com company')
    if not c_template:
        # try regex approach for any infobox, if nothing found above
        match = re.search(r'({{infobox.*\n(?:\|.*\n|\*.*\n)+}})', wiki_raw, re.IGNORECASE)
        if match:
            infobox_temp = mwparserfromhell.parse(
                match.group(1), skip_style_tags=True).filter_templates()
            if infobox_temp:
                infobox_temp = infobox_temp[0]
            else:
                print "WARN: No parsable company infobox template for:", company['wiki_name']
                return comp_infobox
        else:
            print "WARN: No company infobox found for:", company['wiki_name']
            return comp_infobox
    else:
        infobox_temp = c_template[0]

    # find values for each key
    key_list = ['name', 'logo', 'type', 'key_people', 'industry', 'founded', 'location', \
                'location_city', 'location_country', 'defunct', 'subsid', \
                'products', 'num_employees', 'parent', 'homepage']
    for k in key_list:
        param = get_temp_val(infobox_temp, k)
        if param:
            val = parse_wiki_template(param, k, company['wiki_name'])
            if val:
                comp_infobox[k] = val
    # if there was no name given, take name of company node
    if 'name' not in comp_infobox:
        comp_infobox['name'] = company['wiki_name']
    return comp_infobox

# %%
def get_c_info(company):
    """Get links and the wikitext which is used to extract key information about the company"""

    # reparse old text if text and links already there
    if 'wiki_raw' not in company or 'all_links' not in company:   
        # concatenate URL from previously set values
        link_url = '{0}{1}?&{2}&{3}&{4}&pageid={5}'.format(
            wiki_base, wiki_api, action, properties, dat_format, company['wiki_page_id'])

        # get JSON and check for validity
        c_content = get_json_from_url(link_url)
        if not c_content or 'parse' not in c_content:
            print 'WARN: No parsable content on: {0} under page {1} (id: {2})'.format(
                link_url, company['wiki_name'], company['wiki_page_id'])
            company['is_company'] = False
            return company

        # save new fields
        company['wiki_api_url'] = unicode(link_url)
        company['all_links'] = [x['*'] for x in c_content['parse']['links'] if x['ns'] == 0]

        # original wikitext to parse {{Infobox company
        company['wiki_raw'] = c_content['parse']['wikitext']['*']
    
    # extract company info from box, only on wiki text not HTML
    company_infobox = parse_wiki_text(company)
    company.update(company_infobox)
    company['is_company'] = True
    
    # keep non-company nodes but mark
    if not company_infobox:
        company['is_company'] = False
    return company

# %% [markdown]
# Example query to extract wikitext and links on a wiki page:
# * https://en.wikipedia.org/w/api.php?action=parse&page=Audi&prop=links|wikitext
# * https://en.wikipedia.org/w/api.php?action=parse&page=AT%26T&prop=links|wikitext
# * https://en.wikipedia.org/w/api.php?&action=parse&format=json&prop=links|wikitext&pageid=17555269

# %%
action = u'action=parse'
dat_format = u'format=json'
properties = u'prop=links|wikitext'

# other: 'Audi', 'Apple Inc.', 'Microsoft'
company = 'Audi'

print "Excerpt of", company, "dict structure:"
pprint(
    get_c_info(companies[company]))
# Out:
# Excerpt of Audi dict structure:
# {'all_links': [u'Germany',
#                u'United States',
#                u'United Kingdom',
#                u'Japan',
#                u'France',
#                u'Belgium',
#                u'Brazil',
#                u'Bahrain',
#                u'China',
#                u'Malaysia',
#                u'Uruguay',
#                u'Argentina',
#                u'Monaco',
#                u'Audi',
#                u'1,000,000,000 (number)',
#                u'1. FC Nuremberg',
#                u'1936 Summer Olympics',
#                u'1971 24 Hours of Le Mans',
#                u'1982 World Rally Championship season',
#                u'1983 World Rally Championship season',
#                u'1984 World Rally Championship season',
#                u'1985 World Rally Championship season',
#                u'1986 World Rally Championship season',
#                u'1999 24 Hours of Le Mans',
#                u'2000 24 Hours of Le Mans',
#                u'2000 American Le Mans Series season',
#                u'2001 24 Hours of Le Mans',
#                u'2001 American Le Mans Series season',
#                u'2002 24 Hours of Le Mans',
#                u'2002 American Le Mans Series season',
#                u'2003 1000km of Le Mans',
#                u'2003 24 Hours of Le Mans',
#                u'2003 American Le Mans Series season',
#                u'2004 24 Hours of Le Mans',
#                u'2004 American Le Mans Series season',
#                u'2005 24 Hours of Le Mans',
#                u'2005 American Le Mans Series season',
#                u'2006 12 Hours of Sebring',
#                u'2006 24 Hours of Le Mans',
#                u'2006 American Le Mans Series season',
#                u'2007 24 Hours of Le Mans',
#                u'2007 American Le Mans Series season',
#                u'2007 Rallye Deutschland',
#                u'2008 24 Hours of Le Mans',
#                u'2008 American Le Mans Series season',
#                u'2009 24 Hours of Le Mans',
#                u'2009 American Le Mans Series season',
#                u'2009\u20132010 Toyota vehicle recalls',
#                u'2010 24 Hours of Le Mans',
#                u'2010 American Le Mans Series season',
#                u'2011 24 Hours of Le Mans',
#                u'2012 12 Hours of Sebring',
#                u'2012 24 Hours of Le Mans',
#                u'2012 6 Hours of Bahrain',
#                u'2012 6 Hours of Fuji',
#                u'2012 6 Hours of Shanghai',
#                u'2012 6 Hours of Silverstone',
#                u'2012 6 Hours of Spa-Francorchamps',
#                u'2012 6 Hours of S\xe3o Paulo',
#                u'2012 American Le Mans Series season',
#                u'2012 FIA World Endurance Championship season',
#                u'2013 24 Hours of Le Mans',
#                u'2013 6 Hours of Bahrain',
#                u'2013 6 Hours of Circuit of the Americas',
#                u'2013 6 Hours of Fuji',
#                u'2013 6 Hours of Shanghai',
#                u'2013 6 Hours of Silverstone',
#                u'2013 6 Hours of Spa-Francorchamps',
#                u'2013 6 Hours of S\xe3o Paulo',
#                u'2013 American Le Mans Series season',
#                u'2013 FIA World Endurance Championship season',
#                u'2014-15 Formula E season',
#                u'2014 24 Hours of Le Mans',
#                u'2014 6 Hours of Bahrain',
#                u'2014 6 Hours of Circuit of the Americas',
#                u'2014 6 Hours of Fuji',
#                u'2014 6 Hours of Shanghai',
#                u'2014 6 Hours of Spa-Francorchamps',
#                u'2014 FIA World Endurance Championship season',
#                u'24 Hours of Le Mans',
#                u'60 Minutes',
#                u'AC Milan',
#                u'Abt Sportsline',
#                u'Ajax Amsterdam',
#                u'Aktiengesellschaft',
#                u'All-wheel drive',
#                u'American Le Mans Series',
#                u'Andr\xe9 Lotterer',
#                u'Assembly line',
#                u'Asset',
#                u'Association football',
#                u'Audi 100',
#                u'Audi 4000CS quattro',
#                u'Audi 50',
#                u'Audi 5000',
#                u'Audi 80',
#                u'Audi 90',
#                u'Audi 920',
#                u'Audi A1',
#                u'Audi A2',
#                u'Audi A3',
#                u'Audi A3 TDI clubsport quattro concept',
#                u'Audi A4',
#                u'Audi A4 B8',
#                u'Audi A4 DTM',
#                u'Audi A5',
#                u'Audi A5 DTM',
#                u'Audi A6',
#                u'Audi A6 allroad quattro',
#                u'Audi A7',
#                u'Audi A8',
#                u'Audi Avantissimo',
#                u'Audi Avus quattro',
#                u'Audi Brussels',
#                u'Audi Cabriolet',
#                u'Audi Channel',
#                u'Audi Coup\xe9',
#                u'Audi Coup\xe9 (B2)',
#                u'Audi Cup',
#                u'Audi Driving Experience',
#                u'Audi F103',
#                u'Audi Front',
#                u'Audi India',
#                u'Audi Le Mans quattro',
#                u'Audi Nuvolari quattro',
#                u'Audi Pikes Peak quattro',
#                u'Audi Prologue',
#                u'Audi Q2',
#                u'Audi Q3',
#                u'Audi Q5',
#                u'Audi Q7',
#                u'Audi Quattro',
#                u'Audi Quattro S1',
#                u'Audi R10',
#                u'Audi R10 TDI',
#                u'Audi R15',
#                u'Audi R15 TDI',
#                u'Audi R18',
#                u'Audi R18 TDI',
#                u'Audi R8',
#                u'Audi R8C',
#                u'Audi R8R',
#                u'Audi R8 (LMP)',
#                u'Audi R8 (road car)',
#                u'Audi R8 LMS Cup',
#                u'Audi R8 Le Mans Concept',
#                u'Audi R8 etron',
#                u'Audi RS2 Avant',
#                u'Audi RS4',
#                u'Audi RS6',
#                u'Audi RSQ',
#                u'Audi RS 2 Avant',
#                u'Audi RS 4',
#                u'Audi RS 6',
#                u'Audi Roadjet',
#                u'Audi Rosemeyer',
#                u'Audi S1',
#                u'Audi S2',
#                u'Audi S3',
#                u'Audi S4',
#                u'Audi S5',
#                u'Audi S6',
#                u'Audi S7',
#                u'Audi S8',
#                u'Audi S and RS models',
#                u'Audi S models',
#                u'Audi Shooting Brake',
#                u'Audi Sport TT Cup',
#                u'Audi Sport Team Joest',
#                u'Audi Sport WRC results',
#                u'Audi Sportback concept',
#                u'Audi Steppenwolf',
#                u'Audi TT',
#                u'Audi TTS',
#                u'Audi TT Mk3',
#                u'Audi TT Offroad',
#                u'Audi TT RS',
#                u'Audi Type A',
#                u'Audi Type B',
#                u'Audi Type P',
#                u'Audi Ur-S4 / Ur-S6',
#                u'Audi V8',
#                u'Audi allroad quattro',
#                u'Audi alteram partem',
#                u'Audi e-tron',
#                u'Audi hybrid vehicles',
#                u'Audi quattro concept',
#                u'Audi virtual cockpit',
#                u'Augmentative',
#                u'August Horch',
#                u'August Horch Museum Zwickau',
#                u'Aurangabad, Maharashtra',
#                u'Auto Union',
#                u'Auto racing',
#                u'Automatic transmission',
#                u'Automobile',
#                u'Automobile manufacturer',
#                u'Automobiles',
#                u'Automotive industry',
#                u'Autostadt',
#                u'BMW',
#                u'BMW M',
#                u'Bartle Bogle Hegarty',
#                u'Bavaria',
#                u'Beijing Olympic Green Circuit',
#                u'Beno\xeet Tr\xe9luyer',
#                u'Bentley',
#                u'Bentley Speed 8',
#                u'Berlin',
#                u'Berlin Tempelhof Airport',
#                u'Bernd Pischetsrieder',
#                u'Billboard',
#                u'BlueMotion',
#                u'Blur (Blur album)',
#                u'Bobby Unser',
#                u'Borussia M\xf6nchengladbach',
#                u'Brand',
#                u'Bratislava',
#                u'British Touring Car Championship',
#                u'Brussels',
#                u'Bugatti Automobiles',
#                u'Cabriolet (automobile)',
#                u'Capital Group Companies',
#                u'Carbon dioxide',
#                u'Carl Hahn',
#                u'Champion Racing',
#                u'Changchun',
#                u'Chelsea FC',
#                u'Chemnitz',
#                u'Christian Abt',
#                u'Circuit of the Americas',
#                u'Classic car',
#                u'Clutch',
#                u'Cologne',
#                u'Colorado',
#                u'Compact SUV',
#                u'Compact car',
#                u'Compact executive car',
#                u'Consumer Electronics Show',
#                u'Continuously variable transmission',
#                u'Corrosion',
#                u'Coup\xe9',
#                u'Crossover (automobile)',
#                u'DKW',
#                u'DKW F102',
#                u'DKW F89',
#                u'DKW Schnellaster',
#                u'Daimler-Benz',
#                u'Dampf-Kraft-Wagen',
#                u'Daniel Abt',
#                u'Daytime running light',
#                u'Detroit Motor Show',
#                u'Deutsche Tourenwagen Meisterschaft',
#                u'Diesel engine',
#                u'Differential (mechanical device)',
#                u'Digifant engine management system',
#                u'Direct-Shift Gearbox',
#                u'Direct-shift gearbox',
#                u'Direct fuel injection',
#                u'Division (business)',
#                u'Downtown Miami',
#                u'Dual clutch transmission',
#                u'Ducati',
#                u'D\xfcsseldorf',
#                u'ERC Ingolstadt',
#                u'ETKA',
#                u'Earnings before interest and taxes',
#                u'Ehra-Lessien',
#                u'Ehrenfeld, Cologne',
#                u'Electronic throttle control',
#                u'Elvis Presley',
#                u'Engine displacement',
#                u'Equity (finance)',
#                u'Everton F.C.',
#                u'FAW-Volkswagen',
#                u'FC Barcelona',
#                u'FC Bayern Munich',
#                u'FC Ingolstadt 04',
#                u'FIA Formula E Championship',
#                u'FIA Formula Two Championship',
#                u'FIA World Endurance Championship',
#                u'Facelift (automotive)',
#                u'Fastback',
#                u'Felix Wankel',
#                u'Ferdinand Pi\xebch',
#                u'Ferdinand Porsche',
#                u'Font',
#                u'Ford RS200',
#                u'Formula One',
#                u'Formula Palmer Audi',
#                u'Formula Volkswagen Germany',
#                u'Four-wheel drive',
#                u'Frankfurt Stock Exchange',
#                u'Frankfurt motor show',
#                u'French Supertouring Championship',
#                u'Friedrich Flick',
#                u'Front-engine design',
#                u'Front-wheel drive',
#                u'Full-size SUV',
#                u'Full-size car',
#                u'Fu\xdfball-Bundesliga',
#                u"F\xe9d\xe9ration Internationale de l'Automobile",
#                u'Galvanisation',
#                u'Gasoline direct injection',
#                u'Gear stick',
#                u'Geoffrey Palmer (actor)',
#                u'German (language)',
#                u'German Ski Association',
#                u'German automobile manufacturer',
#                u'Gesellschaft mit beschr\xe4nkter Haftung',
#                u'Gottlieb Daimler',
#                u'Gy\u0151r',
#                u'Haldex Traction',
#                u'Hamburger SV',
#                u'Hannu Mikkola',
#                u'Hatchback',
#                u'Heinrich Nordhoff',
#                u'Here (company)',
#                u'Hertha BSC',
#                u'Homologation',
#                u'Horch',
#                u'Hybrid vehicle',
#                u'IAV',
#                u'IDrive',
#                u'IFA F8',
#                u'IFA F9',
#                u'IMSA GT Championship',
#                u'Infotainment',
#                u'Ingolstadt',
#                u'Inline-four engine',
#                u'Interface standard',
#                u'Interlock',
#                u'International Motor Sports Association',
#                u'International Olympic Committee',
#                u'International Standard Book Number',
#                u'Italdesign Giugiaro',
#                u'Italian Superturismo Championship',
#                u'Ivan Hirst',
#                u'Jakarta',
#                u'Joest Racing',
#                u'Judd (engine)',
#                u'J\xf8rgen Skafte Rasmussen',
#                u'Karachi',
#                u'Klaus von Oertzen',
#                u'Korangi Creek Industrial Park',
#                u'Kurt Lotz',
#                u'LED headlamp',
#                u'LMP1',
#                u'Lamborghini',
#                u'Latin',
#                u'Laurent A\xefello',
#                u'Light-emitting diode',
#                u'List of Audi Sport Factory Race Cars',
#                u'List of Audi concept cars',
#                u'List of Audi vehicles',
#                u'List of North American Volkswagen engines',
#                u'List of PlayStation Home Game Spaces',
#                u'List of Volkswagen Group diesel engines',
#                u'List of Volkswagen Group engines',
#                u'List of Volkswagen Group factories',
#                u'List of Volkswagen Group petrol engines',
#                u'List of Volkswagen Group platforms',
#                u"List of World Rally Championship Constructors' Champions",
#                u"List of World Rally Championship Drivers' Champions",
#                u'List of discontinued Volkswagen Group diesel engines',
#                u'List of discontinued Volkswagen Group petrol engines',
#                u'Lock, Stock, and Two Smoking Barrels',
#                u'London',
#                u'Long Beach Street Circuit',
#                u'Longitudinal engine',
#                u'Lower Saxony',
#                u'Lucas di Grassi',
#                u'Lucian Bernhard',
#                u'Luna Rossa Challenge',
#                u'Luxury vehicle',
#                u'MAN SE',
#                u'Marcel F\xe4ssler (racing driver)',
#                u'Marque',
#                u'Marshall Plan',
#                u'Martin Winterkorn',
#                u'Martini Racing',
#                u'Martorell',
#                u'Megajoule',
#                u'Mercedes-AMG',
#                u'Mercedes-Benz',
#                u'Mercedes-Benz A-Class',
#                u'MetaDesign',
#                u'Mich\xe8le Mouton',
#                u'Mid-size SUV',
#                u'Mid-size car',
#                u'Monte Carlo Rally',
#                u'Multi Media Interface',
#                u'Multitronic',
#                u'Museum mobile',
#                u'NSU Motorenwerke',
#                u'NSU Motorenwerke AG',
#                u'NSU Prinz',
#                u'NSU Ro80',
#                u'NSU Ro 80',
#                u'National Highway Traffic Safety Administration',
#                u'Navistar International',
#                u'Neckarsulm',
#                u'Net income',
#                u'New York Yankees',
#                u'Only Fools and Horses',
#                u'Opel',
#                u'Open standard',
#                u'Oreca',
#                u'Overhead camshaft',
#                u'Pakistan',
#                u'Parent company',
#                u'Parklife (song)',
#                u'Peep Show (TV series)',
#                u'Perspolis F.C.',
#                u'Pescarolo Sport',
#                u'Peugeot',
#                u'Peugeot 908',
#                u'Peugeot 908 HDi FAP',
#                u'Pikes Peak',
#                u'Pikes Peak International Hill Climb',
#                u'PlayStation 3',
#                u'PlayStation Home',
#                u'Pole position',
#                u'Polo',
#                u'Porsche',
#                u'Porsche 917',
#                u'Porsche Boxster/Cayman',
#                u'Porsche SE',
#                u'Porsche family',
#                u'Procon-ten',
#                u'Proto-World language',
#                u'Prototypical',
#                u'Public company',
#                u'Puebla',
#                u'Puerto Madero Street Circuit',
#                u'Punta del Este Street Circuit',
#                u'Putrajaya Street Circuit',
#                u'Qatar Investment Authority',
#                u'Qi (standard)',
#                u'Quattro (four-wheel-drive system)',
#                u'Quattro (four-wheel drive system)',
#                u'Quattro GmbH',
#                u'Queens Park Rangers F.C.',
#                u'Rally Portugal',
#                u'Rally racing',
#                u'Rallying',
#                u'Real Madrid CF',
#                u'Rear-wheel drive',
#                u'Reichenbach im Vogtland',
#                u'Reichsgericht',
#                u'Rheinmetall',
#                u'Rickenbacker (car)',
#                u'Roadster (automobile)',
#                u'Rudolf Leiding',
#                u'Rupert Stadler',
#                u'SAIC Volkswagen',
#                u'SDI (engine)',
#                u'SEAT',
#                u'SPEED World Challenge',
#                u'Saloon (automobile)',
#                u'San Jos\xe9 Chiapa',
#                u'Sanyo',
#                u'Saxony',
#                u'Scania AB',
#                u'Scuderia Ferrari',
#                u'Semi-automatic transmission',
#                u'Silver Arrows',
#                u'Small family car',
#                u'Soviet Army',
#                u'Space frame',
#                u'Spark-Renault SRT 01E',
#                u'Sports car',
#                u'Sports car racing',
#                u'Stefano Domenicali',
#                u'Stig Blomqvist',
#                u'Straight-five engine',
#                u'Straight-four engine',
#                u'Straight-six engine',
#                u'Stuttgart',
#                u'Subsidiary',
#                u'Sudden unintended acceleration',
#                u'Super Tourenwagen Cup',
#                u'Super Touring',
#                u'Supercar',
#                u'Supermini',
#                u'Swedish Rally',
#                u'Synthetic diesel',
#                u'TBA',
#                u'Tagline',
#                u'Ticker symbol',
#                u'Toni Schm\xfccker',
#                u'Torque converter',
#                u'Torsen',
#                u'Toyota',
#                u'Trabant',
#                u'Trans-Am Series',
#                u'Turbo',
#                u'Turbocharged Direct Injection',
#                u'Turbocharger',
#                u'Twin-turbo',
#                u'Types of business entity',
#                u'U2',
#                u'Unit injector',
#                u'Univers',
#                u'V12 engine',
#                u'V6 engine',
#                u'V8 engine',
#                u'VAG-COM',
#                u'VR6 engine',
#                u'VW Electronics Research Laboratory',
#                u'VW K70',
#                u'Volkseigener Betrieb',
#                u'Volkswagen',
#                u'Volkswagen Commercial Vehicles',
#                u'Volkswagen Golf',
#                u'Volkswagen Golf Mk4',
#                u'Volkswagen Group',
#                u'Volkswagen Group China',
#                u'Volkswagen Group MLB platform',
#                u'Volkswagen Group Sales India',
#                u'Volkswagen Group of America',
#                u'Volkswagen Iltis',
#                u'Volkswagen Jetta TDI Cup',
#                u'Volkswagen Motorsport',
#                u'Volkswagen Passat',
#                u'Volkswagen Phaeton',
#                u'Volkswagen Polo',
#                u'Volkswagen Scirocco R-Cup',
#                u'Volkswagen Type 1',
#                u'Volkswagen do Brasil',
#                u'Volkswagen emissions testing scandal',
#                u'Volkswagen emissions violations',
#                u'Vorsprung durch Technik',
#                u'W12 engine',
#                u'Wackel-Elvis',
#                u'Walter R\xf6hrl',
#                u'Wanderer (car)',
#                u'Wankel rotary engine',
#                u'War reparations',
#                u'Warranty',
#                u'West Germany',
#                u'Wind tunnel',
#                u'Wireless Power Consortium',
#                u'Wolfsburg',
#                u'World-Wide Volkswagen Corp. v. Woodson',
#                u'World Rally Championship',
#                u'World War II',
#                u'Zetland, New South Wales',
#                u'Zinc',
#                u'Zooropa (song)',
#                u'Zwickau',
#                u'\u0160koda Auto',
#                u'Ulrich Hackenberg',
#                u'J\xf6rg Bensinger',
#                u'Joaquim Santos',
#                u'2004 European Le Mans Series',
#                u'2003 European Le Mans Series Season',
#                u'2004 European Le Mans Series Season',
#                u'2005 European Le Mans Series Season',
#                u'2008 Le Mans Endurance Series Season',
#                u'2010 Le Mans Endurance Series Season',
#                u'6hrs of Silverstone',
#                u'2014 12 Hours of Silverstone',
#                u'2014 6 Hours of Sau Paulo',
#                u'Bold Monday',
#                u'Audi Polo Awards',
#                u'Audi quattro e-tron',
#                u'Audi RS7 Concept',
#                u'Audi Nanuk',
#                u'Audi Urban Concept',
#                u'Audi Centre of Excellence',
#                u'AC Schnitzer',
#                u'ADAC',
#                u'ATR (company)',
#                u'Alpina',
#                u'Artega Automobile',
#                u'Association for Standardisation of Automation and Measuring Systems',
#                u'Audi Sport',
#                u'Auto Mobil International',
#                u'Autoblog.com',
#                u'Automotive industry in Germany',
#                u'BBC',
#                u'BBC News',
#                u'BBS Kraftfahrzeugtechnik',
#                u'BMW Motorrad',
#                u'BMW i',
#                u'Behr GmbH & Co. KG',
#                u'Berkshire Hathaway',
#                u'Bitter Cars',
#                u'Blaupunkt',
#                u'Borgward',
#                u'Brabus',
#                u'Business Wire',
#                u'B\xfchler Motor',
#                u'CNET',
#                u'Carlsson (car company)',
#                u'Continental AG',
#                u'Convertible (car)',
#                u'Daimler AG',
#                u'Daimler Financial Services',
#                u'Deutsche Tourenwagen Masters',
#                u'Dr\xe4xlmaier Group',
#                u'D\xfcrr AG',
#                u'ETAS Group',
#                u'Economy of Germany',
#                u'EvoBus',
#                u'Ford Germany',
#                u'Ford of Europe',
#                u'Frankfurt Motor Show',
#                u'Fuldamobil',
#                u'G-Power',
#                u'Gemballa',
#                u'Getrag',
#                u'Goggomobil',
#                u'Goliath (company)',
#                u'Gumpert',
#                u'Hansa (car)',
#                u'Hartge',
#                u'Hella (company)',
#                u'Hermann Peters',
#                u'Hyundai Motor Europe GmbH',
#                u'Integrated Authority File',
#                u'Je Design',
#                u'KSPG',
#                u'Koenig Specials',
#                u'Krauss-Maffei',
#                u'List of automobile manufacturers of Germany',
#                u'L\xf6we Automobil',
#                u'MAN Truck & Bus',
#                u'Magirus',
#                u'Mahle GmbH',
#                u'Mann+Hummel',
#                u'Mansory',
#                u'Marketing Week',
#                u'Maybach',
#                u'Mercedes-Benz Bank',
#                u'North German Automobile and Engine',
#                u'N\xfcrburgring',
#                u'Opel Performance Center',
#                u'PPI Automotive Design',
#                u'Petri AG',
#                u'Rheinmetall MAN Military Vehicles',
#                u'Rieger Tuning',
#                u'Robert Bosch GmbH',
#                u'Ruf Automobile',
#                u'Schaeffler Group',
#                u'Setra',
#                u'Sixt',
#                u'Smart (automobile)',
#                u'Steinmetz Opel Tuning',
#                u'Transport in Germany',
#                u'Verband der Automobilindustrie',
#                u'Voith',
#                u'Wayback Machine',
#                u'ZF Friedrichshafen',
#                u'ZF Sachs'],
#  'founded': datetime.datetime(1910, 4, 25, 0, 0),
#  'homepage': u'http://www.audi.com/index.html',
#  'industry': u'Automotive',
#  'is_company': True,
#  'key_people': [{u'first': u'Chairman of the Board of Management',
#                  u'last': u'Rupert Stadler',
#                  u'middle': u'',
#                  u'nickname': u'',
#                  u'suffix': u'',
#                  u'title': u''},
#                 {u'first': u'Head of Design',
#                  u'last': u'Marc Lichte',
#                  u'middle': u'',
#                  u'nickname': u'',
#                  u'suffix': u'',
#                  u'title': u''},
#                 {u'first': u'Head of Technical',
#                  u'last': u'Ulrich Hackenberg',
#                  u'middle': u'Development',
#                  u'nickname': u'',
#                  u'suffix': u'',
#                  u'title': u''}],
#  'location_city': u'Ingolstadt',
#  'location_country': u'Germany',
#  'location_geopy': u'Ingolstadt, OB, Bayern, Deutschland',
#  'location_gps': (48.7630165, 11.4250395),
#  'logo': {'wiki_commons_link': u'https://commons.wikimedia.org/wiki/File:Audi_AG_logo.png',
#           'wiki_file_link': u'https://en.wikipedia.org/wiki/File:Audi_AG_logo.png',
#           'wiki_raw_code': u'Audi AG logo.png'},
#  'name': u'Audi AG',
#  'name_url_quoted': u'Audi',
#  'num_employees': 84435,
#  'parent': u'Volkswagen Group',
#  'products': u'Luxury vehicles',
#  'subsid': [u'Audi Brussels',
#             u'Audi Hungaria Motor Kft.',
#             u'Ducati',
#             u'Italdesign Giugiaro',
#             u'Lamborghini',
#             u'quattro GmbH'],
#  'type': u'Public, Aktiengesellschaft',
#  'wiki_api_url': u'https://en.wikipedia.org/w/api.php?&action=parse&prop=links|wikitext&format=json&pageid=848',
#  'wiki_name': u'Audi',
#  'wiki_page_id': 848,
#  'wiki_raw': u'{{pp-vandalism|small=yes}}\n{{Use dmy dates|date=March 2013}}\n{{Infobox company\n| name             = Audi AG<ref name=artinc>{{cite web|url=http://www.audi.com/etc/medialib/ngw/company/investor_relations/pdf/corporate_governance.Par.0031.File.pdf/audi_ag_satzung_mai.pdf |title=Satzung und Statuten der AUDI AG |date=20 May 2010 |work=audi.com |publisher=AUDI AG |location=Ingolstadt, Germany |page=1 |language=German |trans_title=Articles of Incorporation and Bylaws of AUDI AG |format=PDF |archiveurl=http://www.webcitation.org/69wmn6sAX?url=http%3A%2F%2Fwww.audi.com%2Fetc%2Fmedialib%2Fngw%2Fcompany%2Finvestor_relations%2Fpdf%2Fcorporate_governance.Par.0031.File.pdf%2Faudi_ag_satzung_mai.pdf |archivedate=15 August 2012 |deadurl=no |accessdate=15 August 2012 |df=dmy }}</ref>\n| logo             = Audi AG logo.png\n| logo_size = 235\n| image            = Audi Ingolstadt.jpg\n| image_size = 265\n| image_caption    = Audi head office in [[Ingolstadt]]\n| type             = [[Public company|Public]], [[Aktiengesellschaft]]\n| traded_as        = {{FWB|NSU}}\n| predecessor      = [[Auto Union]] [[Gesellschaft mit beschr\xe4nkter Haftung|GmbH]]<br>[[NSU Motorenwerke|NSU Motorenwerke AG]]\n| successor        = \n| founder          = [[August Horch]]<ref name="Audi history"/>\n| defunct          = <!-- {{End date|df=yes|YYYY|MM|DD}} -->\n| fate             = \n| area_served      = Worldwide\n| key_people       = {{unbulleted list | [[Rupert Stadler]], Chairman of the Board of Management | Marc Lichte, Head of Design | [[Ulrich Hackenberg]], Head of Technical Development }}\n| industry         = [[Automotive industry|Automotive]]\n| products          = [[Luxury vehicle]]s\n| production       = {{increase}} 2,024,881&nbsp;units<ref name="Key figures worldwide">{{cite web|title=Key figures worldwide |url=http://www.audi.com/corporate/en/company/production-sites.html#fullwidthpar__ah_0}}</ref>\n| services         = \n| revenue          = {{increase}} \u20ac58.42&nbsp;[[1,000,000,000 (number)|billion]] (2015) <ref name="AUDIAG FY2015">{{cite web|title=Finances ar2015|url=http://www.audi-reports.com/ar2015/Finances.pdf}}</ref>\n| operating_income = {{increase}} \u20ac4.836&nbsp;[[1,000,000,000 (number)|billion]] (2015)<ref name="AUDIAG FY2015"/>\n| net_income       = {{increase}} \u20ac4.297&nbsp;[[1,000,000,000 (number)|billion]] (2015)<ref name="AUDIAG FY2015"/>\n| assets           = {{increase}} \u20ac16.832 [[1,000,000,000 (number)|billion]] (2009)\n| equity           = {{increase}} \u20ac3.451 [[1,000,000,000 (number)|billion]] (2009)\n| owner            = {{nowrap begin}}[[Volkswagen Group]] (99.55%){{nowrap end}}\n| num_employees    = 84,435 (2015) <ref name="Key figures worldwide">{{cite web|title=Key figures worldwide |url=http://www.audi.com/corporate/en/company/production-sites.html#fullwidthpar__ah_0}}</ref>\n| parent           = [[Volkswagen Group]]\n| divisions        = {{unbulleted list | [[Audi e-tron]] | [[Audi India]]}}\n| subsid           = {{unbulleted list | [[Audi Brussels]] | Audi Hungaria Motor Kft. | [[Ducati]] | [[Italdesign Giugiaro]] | [[Lamborghini]] | [[quattro GmbH]]}}\n| footnotes        = Audi History: Chronicle,<ref name=founded>{{cite web|url=http://www.audiusa.com/us/brand/en/about/main/history/Chronicle/Chronicle_1899-1914.html |title=Chronicle 1899\u20131914 |publisher=Audi of America, LLC |work=audiusa.com |year=2012 |accessdate=9 August 2012 |archiveurl=http://www.webcitation.org/69nfweGpM?url=http%3A%2F%2Fwww.audiusa.com%2Fus%2Fbrand%2Fen%2Fabout%2Fmain%2Fhistory%2FChronicle%2FChronicle_1899-1914.html |archivedate=9 August 2012 |ref={{SfnRef|AUDI AG|2012a}} |deadurl=no |df=dmy }}</ref> 2011 Annual Financial Report<ref name=aafr2011>{{cite web |url=http://www.audi.com/etc/medialib/ngw/company/investor_relations/pdf/finanzberichte/geschaeftsberichte5.Par.0015.File.pdf/jahresfinanzbericht.pdf |title=Audi 2011 Annual Financial Report |publisher=AUDI AG |format=PDF |date=17 February 2012 |acces ...
#  'wiki_url': u'https://en.wikipedia.org/w/index.php?title=Audi'}

# %%
def scrape_companies(companies):
    """Gets two dictionaries and parses those who don't have same content"""

    # scrape links and extra information of all companies, call with progress-bar
    for company in tqdm_notebook(companies, desc='Companies'):
        # don't repeat if pickle file already contains data
        if 'is_company' in companies[company] and \
            companies[company]['is_company']:
                continue
        # extract any company information
        companies[company] = get_c_info(companies[company])
    return companies

# %%
# get company file from extraction 1
com_dat_pickle = dict()
if os.path.isfile(ex1_fdat):
    with open(ex1_fdat, 'rb') as f:
        com_dat_pickle = pickle.load(f)
        # update previously fetched data to same keys
        companies.update(com_dat_pickle)

# %%
# %%time
# 500 companies take about 2-3 mins
# for 64k that is approx. 128 cykles which should total maximum 5 hours crawl time
# ((64000 / 500) * 2) / 60

# crawl for all companies that were not prcoessed yet and cotain no or a false 'is_company' flag
companies = scrape_companies(companies)
# Out:
# WARN: No company infobox found for: McDonald's legal cases
# WARN: No company infobox found for: History of Burger King
# WARN: No company infobox found for: KFC advertising
# WARN: No company infobox found for: Burger King products
# WARN: No company infobox found for: Protandim
# WARN: No company infobox found for: Burger King legal issues
# WARN: No company infobox found for: History of McDonald's
# WARN: No company infobox found for: History of KFC
# WARN: No company infobox found for: McDonald's advertising
# WARN: No company infobox found for: Burger King advertising
# WARN: No company infobox found for: Fondo Común
# WARN: No company infobox found for: List of Burger King ad programs
# WARN: No company infobox found for: List of McDonald's ad programs
# WARN: No company infobox found for: List of McDonald's products
#
# CPU times: user 1.36 s, sys: 112 ms, total: 1.48 s
# Wall time: 4.94 s

# %% [markdown]
# ## Add Geolocation Data

# %%
# show how many companies have an address
def get_location(comp, geolocators):
    
    # location variables
    loc_str = None
    loc_dict = {
        'location_geopy': loc_str,
        'location_gps': (None, None)}
    if 'location_geopy' in comp and 'location_gps' in comp:
        # if not None
        if comp['location_geopy'] and comp['location_gps']:
            return {
                'location_geopy': comp['location_geopy'],
                'location_gps': comp['location_gps']}
    
    # check from top to bottom for location
    fields_to_check = ['location', 'location_city', 'location_country']
    for f in fields_to_check:
        # continue if field not in company
        if f not in comp:
            continue
        # check if value unicode or list
        val = comp[f]
        if val:
            loc_str = val
            if isinstance(val, list):
                loc_str = " ".join(val)
            # fields are ordered, highest with value wins
            break
    # return if none of the fields set
    if not loc_str:
        return loc_dict
    
    # avoid request by looking into already processed
    if loc_str in all_locations:
        return all_locations[loc_str]

    # try to validate and get coordinates with geopy
    for g in geolocators:
        try:
            loc = g.geocode(loc_str, timeout=10)
        except GeocoderServiceError:
            print "HTML or API error on", comp['wiki_name']
            return loc_dict
        if loc:
            # max 1 request per second, http://wiki.openstreetmap.org/wiki/Nominatim_usage_policy
            time.sleep(1)
            loc_dict = {
                'location_geopy': loc.address,
                'location_gps': (loc.latitude, loc.longitude)}
            all_locations[loc_str] = loc_dict
            return loc_dict
    return loc_dict

# %%
# initialize the different geolocator APIs
g_osm = geopy.geocoders.Nominatim()
g_google = geopy.geocoders.GoogleV3() # can also be with g_api_key
#geolocators = [g_google, g_osm] # gives GeocoderQuotaExceeded without API key
geolocators = [g_osm]

# save looked up locations to not make API request
all_locations = dict()
for c in tqdm_notebook(companies, desc='Geolocation'):
    if not companies[c]['is_company']:
        continue
    processed_loc = get_location(companies[c], geolocators)
    companies[c].update(processed_loc)
# Out:
# HTML or API error on Ufone
# HTML or API error on Equity Group Holdings Limited
# HTML or API error on Grafotechna
# HTML or API error on First North Luzon Transit
# HTML or API error on Horex
# HTML or API error on Empire Today
# HTML or API error on United Copper
# HTML or API error on Kaplan Hawksmere
# HTML or API error on Trans-Asia Shipping Lines
# HTML or API error on MySQL AB
# HTML or API error on Marvelous USA
# HTML or API error on Miss Globe International
# HTML or API error on Madison Marquette
# HTML or API error on National Small Industries Corporation
# HTML or API error on Ectaco
# HTML or API error on Arvand Free Zone
# HTML or API error on Nortec Software
# HTML or API error on Jowett Cars
# HTML or API error on Nichicon
# HTML or API error on Petrocaribe
# HTML or API error on Bank Rakyat
# HTML or API error on Norwegian Cruise Line
# HTML or API error on Nippon Sheet Glass
# HTML or API error on Hesteel Group
# HTML or API error on Argus Media
# HTML or API error on Head (company)
# HTML or API error on Lixil Group
# HTML or API error on Reederei Zürich AG
# HTML or API error on North England Inward Investment Agency
# HTML or API error on Warid Telecom
# HTML or API error on P. C. Richard & Son
# HTML or API error on Mills Fleet Farm
# HTML or API error on ObjectRocket
# HTML or API error on Look Effects
# HTML or API error on Code Club AB
# HTML or API error on Suvudu
# HTML or API error on Aero Vodochody
# HTML or API error on Xangati
# HTML or API error on Telvent
# HTML or API error on BankIslami Pakistan
# HTML or API error on Redtail Telematics Corporation
# HTML or API error on Astellas Pharma
# HTML or API error on Polar Ice Cream
# HTML or API error on Tang Eng Iron Works
# HTML or API error on Banca Popolare di Puglia e Basilicata
# HTML or API error on Omron
# HTML or API error on RTÉ News and Current Affairs
# HTML or API error on London Tradition
# HTML or API error on Nomad Foods
# HTML or API error on Philippine Span Asia Carrier Corporation (PSACC)
# HTML or API error on Daewoo Bus
# HTML or API error on Advanced Technical Intelligence Center
# HTML or API error on Assam Tourism Development Corporation
# HTML or API error on Handley Page
# HTML or API error on Sweet Water Organics
# HTML or API error on British Motor Syndicate
# HTML or API error on The Singing Machine Company
# HTML or API error on Dabur
# HTML or API error on Wild & Bare Co.
# HTML or API error on TeleTalk
# HTML or API error on NGA Human Resources
# HTML or API error on Iris Capital
# HTML or API error on Independent Television Network
# HTML or API error on Krishak Bharati Cooperative
# HTML or API error on Seven & I Holdings Co.
# HTML or API error on Shalom Baranes Associates
# HTML or API error on Aiducation
# HTML or API error on American Plus Bank
# HTML or API error on Days Inn
# HTML or API error on Yamasaki & Associates
# HTML or API error on Lagos Court of Arbitration
# HTML or API error on AmMetLife
# HTML or API error on Goody's Burger House (restaurant)
# HTML or API error on Meridian Bank (Canada)
# HTML or API error on Blue Circle Industries
# HTML or API error on ServInt
# HTML or API error on IndusInd Bank
# HTML or API error on Carter Jonas
# HTML or API error on LM3LABS
# HTML or API error on TriStar Productions
# HTML or API error on Western Power Distribution
# HTML or API error on Incepta Pharmaceuticals
# HTML or API error on Cookie Jar (company)
# HTML or API error on United Press International
# HTML or API error on Diana Department Store
# HTML or API error on EliteHeads
# HTML or API error on Laurin & Klement
# HTML or API error on RFM Corporation
# HTML or API error on Marfin Investment Group
# HTML or API error on Kiddicare
# HTML or API error on Initium Media
# HTML or API error on The Society Management
# HTML or API error on Sanlam Kenya Plc
# HTML or API error on J&A Records
# HTML or API error on Fierce, Isakowitz and Blalock
# HTML or API error on QubicaAMF Worldwide
# HTML or API error on Wardrop Engineering Inc.
# HTML or API error on Travelzoo
# HTML or API error on HyperCity
# HTML or API error on AGV (helmet manufacturer)
# HTML or API error on Sopogy
# HTML or API error on Poptent
# HTML or API error on ABS-CBN Convergence
# HTML or API error on National Enterprise Corporation
# HTML or API error on Lemon Tree Hotels
# HTML or API error on Cricket Hill Brewery
# HTML or API error on SABB S.A.
# HTML or API error on Orange Marine
# HTML or API error on IndieBio
# HTML or API error on NLB Group
# HTML or API error on Kyushu Railway Company
# HTML or API error on Remke Markets
# HTML or API error on Pos Malaysia
# HTML or API error on Electro-Dynamic Company
# HTML or API error on Thomas Cook India
# HTML or API error on OpenSpirit Corporation
# HTML or API error on Shimadzu Corp.
# HTML or API error on Carpenter Body Company
# HTML or API error on Brodies
# HTML or API error on Detonics
# HTML or API error on Co.lab Xchange
# HTML or API error on BMARC
# HTML or API error on RPD International (company)
# HTML or API error on Odfjell Drilling
# HTML or API error on IdeaScale
# HTML or API error on MobiasBanca
# HTML or API error on Freedom Boat Club
# HTML or API error on Kuwait Financial Centre (Markaz)
# HTML or API error on Liberties Press
# HTML or API error on Mazda
# HTML or API error on Renault Classic
# HTML or API error on Superunie
# HTML or API error on Abu Dhabi National Insurance Company
# HTML or API error on Viva Hotels and Resorts
# HTML or API error on Deep Stealth Productions
# HTML or API error on Celgene
# HTML or API error on Mandom
# HTML or API error on Ishapore Rifle Factory
# HTML or API error on Gilroy’s Brewery
# HTML or API error on Alawar
# HTML or API error on SimiGon
# HTML or API error on Food Lion
# HTML or API error on Wercker
# HTML or API error on Kardan Investment Bank
# HTML or API error on Tavalon Tea
# HTML or API error on Pakistan Mercantile Exchange
# HTML or API error on The Bulfinch Companies
# HTML or API error on Zonamerica
# HTML or API error on Tie Rack
# HTML or API error on Onyx Pharmaceuticals
# HTML or API error on OneFamily
# HTML or API error on UltraStar Cinemas
# HTML or API error on First Milk (company)
# HTML or API error on Shwe Thanlwin
# HTML or API error on Budget Rent a Car
# HTML or API error on Paccar
# HTML or API error on AEG
# HTML or API error on Bioderma
# HTML or API error on NRG Engineering
# HTML or API error on Vortex Engineering
# HTML or API error on HiteJinro
# HTML or API error on Odisha State Road Transport Corporation
# HTML or API error on Right Stuff
# HTML or API error on Revol Wireless
# HTML or API error on Kwik Save
# HTML or API error on Cēsu Alus
# HTML or API error on AIM Media Texas
# HTML or API error on Harris Scarfe
# HTML or API error on Christopher Pratts
# HTML or API error on BKV Zrt.
# HTML or API error on BA Systems
# HTML or API error on Applause (toy company)
# HTML or API error on Byrne Construction Services
# HTML or API error on Rosetta Genomics
# HTML or API error on Chocolate City (music label)
# HTML or API error on Parco (retailer)
# HTML or API error on Vestax
# HTML or API error on Nanoleaf
# HTML or API error on SK Infosec
# HTML or API error on Terumo
# HTML or API error on Armstrong Whitworth Aircraft
# HTML or API error on Nippon Broadcasting System
# HTML or API error on Osaka Securities Exchange
# HTML or API error on Turner International India
# HTML or API error on Central Pattana
# HTML or API error on Anobit
# HTML or API error on Psygnosis
# HTML or API error on IGATE
# HTML or API error on Snaigė
# HTML or API error on Carmen Media
# HTML or API error on Belhaven Brewery
# HTML or API error on Nabil Bank
# HTML or API error on Brown Company
# HTML or API error on Quickbrowse
# HTML or API error on Groundswell (organization)
# HTML or API error on Robi
# HTML or API error on Spruce Finance
# HTML or API error on Next (Indian retailer)
# HTML or API error on PooPrints
# HTML or API error on Wałbrzych Special Economic Zone "INVEST-PARK"
# HTML or API error on Avis Rent a Car
# HTML or API error on Eizan Electric Railway
# HTML or API error on Institute for Information Industry
# HTML or API error on Telescreen (company)
# HTML or API error on Yazaki
# HTML or API error on Russian Post
# HTML or API error on Genco
# HTML or API error on Mitsubishi Fuso Truck and Bus Corporation
# HTML or API error on Futaba Corporation
# HTML or API error on Groundforce Portugal
# HTML or API error on LyondellBasell
# HTML or API error on Nurimedia
# HTML or API error on Ashley Furniture HomeStores
# HTML or API error on Doppelmayr Garaventa Group
# HTML or API error on Shaker Verlag
# HTML or API error on Tobu Railway
# HTML or API error on Albis (store)
# HTML or API error on Federal State Unitary Enterprise Research and Development Institute of Mechanical Engineering
# HTML or API error on Redstone American Grill
# HTML or API error on Santa Cruz AIDS Project
# HTML or API error on Lango (app)
# HTML or API error on Brockmore Classic Replicas
# HTML or API error on Beriev
# HTML or API error on Polson Iron Works Limited
# HTML or API error on Apptix
# HTML or API error on Mull & Fromer, Masons and Builders
# HTML or API error on ITV Digital
# HTML or API error on Public Union "Rivne Football Club Veres Rivne"
# HTML or API error on Junior ESSEC
# HTML or API error on Amperex Electronic
# HTML or API error on PC Club
# HTML or API error on Atlantis Diesel Engines
# HTML or API error on M3 Technology
# HTML or API error on Auto Union
# HTML or API error on Top Shelf Coffee
# HTML or API error on Wright Stephenson
# HTML or API error on CJ E&M Music Performance Division
# HTML or API error on Sango Bay Estates Limited
# HTML or API error on GEco Holdings
# HTML or API error on Filemobile
# HTML or API error on Teshkeel Comics
# HTML or API error on Oknoplast
# HTML or API error on DenTek
# HTML or API error on Lite Shipping Corporation
# HTML or API error on Endo International plc
# HTML or API error on Mellanox Technologies
# HTML or API error on Zebralution
# HTML or API error on 20th Century Fox Animation
# HTML or API error on Panda Express
# HTML or API error on Bone Clones
# HTML or API error on Rudy's Country Store and Bar-B-Q
# HTML or API error on Melendez Films
# HTML or API error on Altice USA
# HTML or API error on Al Madina Takaful
# HTML or API error on Global Investigations
# HTML or API error on Alfa Aesar
# HTML or API error on Diono
# HTML or API error on Martinolich Shipbuilding Company
# HTML or API error on Sennheiser
# HTML or API error on Ramly Group
# HTML or API error on Michael Rath Trombones
# HTML or API error on Verdant Power
# HTML or API error on Odakyu Electric Railway
# HTML or API error on Colantonio Incorporated
# HTML or API error on San Cristóbal mine (Bolivia)
# HTML or API error on Urney Chocolates
# HTML or API error on TeNeues
# HTML or API error on Penn West Exploration
# HTML or API error on FreeWave Technologies
# HTML or API error on Bremen Overseas Research and Development Association
# HTML or API error on Afterburner Inc
# HTML or API error on Futon Shop
# HTML or API error on DK'Tronics
# HTML or API error on Carbine Studios
# HTML or API error on Marine Stewardship Council
# HTML or API error on Hurley International
# HTML or API error on Daikin
# HTML or API error on Dainippon Screen
# HTML or API error on Indica Gallery
# HTML or API error on Nanex
# HTML or API error on Lithgow Small Arms Factory
# HTML or API error on Argela
# HTML or API error on Synthes
# HTML or API error on Nali Sauce
# HTML or API error on JS Bank
# HTML or API error on Hudson Soft
# HTML or API error on Canaan Fair Trade
# HTML or API error on JEX Co.,Ltd.
# HTML or API error on Crown Property Bureau
# HTML or API error on Vertex Venture Holdings
# HTML or API error on DataSage
# HTML or API error on Video Professor
# HTML or API error on Henkel Electronic Materials
# HTML or API error on Reallusion
# HTML or API error on STC DELTA
# HTML or API error on Travis Association for the Blind
# HTML or API error on JGC Corporation
# HTML or API error on Mehboob Studio
# HTML or API error on Bwin.Party Digital Entertainment
# HTML or API error on Schlumberger SEED
# HTML or API error on Temple Hotels
# HTML or API error on Shell Australia
# HTML or API error on Paper Plus Group
# HTML or API error on Belarc
# HTML or API error on Park Systems
# HTML or API error on MAYA Design
# HTML or API error on Oil and Natural Gas Corporation
# HTML or API error on Auto Windscreens
# HTML or API error on Up-Front Group
# HTML or API error on TmaxSoft
# HTML or API error on Kintetsu Group Holdings
# HTML or API error on H-E-B
# HTML or API error on Carmarthenshire Cheese Company
# HTML or API error on Odisha Industrial Infrastructure Development Corporation
# HTML or API error on Jeld-Wen
# HTML or API error on PACE Sports Management
# HTML or API error on Furuno
# HTML or API error on Travel Guard
# HTML or API error on Nissan Motor Philippines
# HTML or API error on WuXi PharmaTech
# HTML or API error on Celebrations Group
# HTML or API error on Bitwage
# HTML or API error on Zambian Breweries
# HTML or API error on IDE Technologies
# HTML or API error on Lucknow Metro Rail Corporation
# HTML or API error on White Cross Vets
# HTML or API error on Ausenco
# HTML or API error on Portland Energy Conservation
# HTML or API error on Manuloc
# HTML or API error on Nippon Cable
# HTML or API error on WhiteTie
# HTML or API error on JA Prestwich Industries
# HTML or API error on Yoshida & Co., Ltd.
# HTML or API error on Jacobs Engineering Group
# HTML or API error on Jingle Punks Music
# HTML or API error on Minolta
# HTML or API error on Wetson's
# HTML or API error on Sterilgarda
# HTML or API error on Almaz-Antey
# HTML or API error on Halifax International Airport Authority
# HTML or API error on MOS Burger
# HTML or API error on Bach Technology
# HTML or API error on Tata Interactive Systems
# HTML or API error on Camelot Ghana
# HTML or API error on Alrov Group
# HTML or API error on Kale Çelik Eşya
# HTML or API error on NorthLink Ferries
# HTML or API error on Shelikhov-Golikov Company
# HTML or API error on Infolink
# HTML or API error on Camelot Entertainment Group
# HTML or API error on Madhyanchal Gramin Bank
# HTML or API error on HelloWorld Inc
# HTML or API error on Roy's
# HTML or API error on China National Salt Industry Corporation
# HTML or API error on SOFEL
# HTML or API error on The Emirates Group
# HTML or API error on Day Software
# HTML or API error on Three Ireland
# HTML or API error on Sir Lindsay Parkinson
# HTML or API error on The Pheasant Aircraft Company
# HTML or API error on Financial Intelligence & Processing
# HTML or API error on Helaba
# HTML or API error on GlySens ICGM
# HTML or API error on Ebara Corporation
# HTML or API error on Dohwa
# HTML or API error on Kansai Super
# HTML or API error on Printvenue
# HTML or API error on Shin-Etsu Chemical
# HTML or API error on Star India
# HTML or API error on Fantasy Software
# HTML or API error on TSYS
# HTML or API error on Perspecsys
# HTML or API error on Nepal Bangladesh Bank
# HTML or API error on Indosolar
# HTML or API error on Spencer Stuart
# HTML or API error on BeeHex
# HTML or API error on Asda
# HTML or API error on Movistar+
# HTML or API error on Solar Entertainment Corporation
# HTML or API error on Tombola (bingo company)
# HTML or API error on Industrial Press
# HTML or API error on Fingerhut
# HTML or API error on Intimissimi
# HTML or API error on Yamaha electric guitar models
# HTML or API error on Great Wall Wine
# HTML or API error on Tecrea
# HTML or API error on Dolphin Music
# HTML or API error on DMCI Homes
# HTML or API error on Experian
# HTML or API error on Temenos Group
# HTML or API error on AmerisourceBergen
# HTML or API error on Vikram Solar
# HTML or API error on BIG Synergy
# HTML or API error on Big light productions
# HTML or API error on Steinberger
# HTML or API error on Simpson Gumpertz & Heger Inc.
# HTML or API error on TerminalFour
# HTML or API error on Center for the Development of Recycling
# HTML or API error on The Asian Banker
# HTML or API error on University of New Hampshire InterOperability Laboratory
# HTML or API error on Subaru of America
# HTML or API error on Camp Loughridge
# HTML or API error on The Home Depot
# HTML or API error on KeyEast
# HTML or API error on Golden Pages
# HTML or API error on Capstone Development
# HTML or API error on Sarao Motors
# HTML or API error on ViroPharma
# HTML or API error on Ansira
# HTML or API error on Precision Group
# HTML or API error on Airframes Unlimited
# HTML or API error on Brown & Brown
# HTML or API error on Tech For Good
# HTML or API error on International Association for Measurement and Evaluation of Communication
# HTML or API error on Mascot Pictures
# HTML or API error on Quality Markets
# HTML or API error on BDO International
# HTML or API error on WIMBIZ
# HTML or API error on Bank Saderat Iran
# HTML or API error on Schlecker
# HTML or API error on Sugino
# HTML or API error on Intact Media Group
# HTML or API error on Mitsuba Corporation
# HTML or API error on Online Trading Academy
# HTML or API error on Norske Skog Skogn
# HTML or API error on Bottecchia
# HTML or API error on Saskatchewan Government Insurance
# HTML or API error on Gogo Inflight Internet
# HTML or API error on Avision
# HTML or API error on Boomtown, Inc.
# HTML or API error on The Churchill Machine Tool Company
# HTML or API error on Schlitzer Destillerie
# HTML or API error on Grid Corporation of Odisha
# HTML or API error on Potbelly Sandwich Works
# HTML or API error on The Ralphs Group
# HTML or API error on Federation of International Trade Associations
# HTML or API error on Brunello Cucinelli (company)
# HTML or API error on Guidon Games
# HTML or API error on Bay Restaurant Group
# HTML or API error on UK-ASEAN Business Council
# HTML or API error on Fortunoff
# HTML or API error on Consolidated Media Associates
# HTML or API error on Big Blue Bubble
# HTML or API error on Technopark Zürich
# HTML or API error on Mosaic Inc.
# HTML or API error on Sanitas
# HTML or API error on Herzog Heine Geduld, Inc.
# HTML or API error on Deluxe Distribution
# HTML or API error on TrueVisions
# HTML or API error on Fresnillo plc
# HTML or API error on Janrain
# HTML or API error on Israel Railways
# HTML or API error on Dhanlaxmi Bank
# HTML or API error on Ullico
# HTML or API error on Norms Restaurants
# HTML or API error on Ushakiran Movies
# HTML or API error on Price Chopper Supermarkets
# HTML or API error on Kadokawa Pictures
# HTML or API error on Newcom Group
# HTML or API error on De Havilland Propellers
# HTML or API error on Circus (company)
# HTML or API error on Seaboard International
# HTML or API error on Montgomery Ward
# HTML or API error on Lavochkin
# HTML or API error on Atiak Sugar Factory
# HTML or API error on Greenwich Strategy
# HTML or API error on Abraham & Straus
# HTML or API error on Astro (television)
# HTML or API error on GEICO
# HTML or API error on Jordan Marsh
# HTML or API error on Clarify Op3nvoice
# HTML or API error on Mama Sita's Holding Company
# HTML or API error on Carlyle Works
# HTML or API error on Weatherford International
# HTML or API error on The JBG Companies
# HTML or API error on Korea Securities Depository
# HTML or API error on Johnston Press
# HTML or API error on Beltone
# HTML or API error on NewsBlur
# HTML or API error on St. Bernard Sports
# HTML or API error on Farra Design Center
# HTML or API error on Surya Group
# HTML or API error on Tamil Nadu Industrial Explosives Limited
# HTML or API error on Phoenix Venture Holdings
# HTML or API error on V-Star Creations
# HTML or API error on Yaskawa Electric Corporation
# HTML or API error on Logistics Management Institute
# HTML or API error on Holzindustrie Schweighofer
# HTML or API error on Pollo Campero
# HTML or API error on Hazama Ando
# HTML or API error on Aqua Net Hiroshima
# HTML or API error on Shimizu Corporation
# HTML or API error on Tata Salt
# HTML or API error on AG Vulcan Stettin
# HTML or API error on Long & Foster
# HTML or API error on CIBIL
# HTML or API error on Ya Kun Kaya Toast
# HTML or API error on Bengal Dooars Railway
# HTML or API error on Mary Brown's
# HTML or API error on Auzentech
# HTML or API error on IQor
# HTML or API error on Spirit Halloween
# HTML or API error on Clipper Group
# HTML or API error on Lincat
# HTML or API error on Wah Seong Corporation
# HTML or API error on Rudolph Technologies, Inc.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-0389f1db83fc> in <module>()
#      10     if not companies[c]['is_company']:
#      11         continue
# ---> 12     processed_loc = get_location(companies[c], geolocators)
#      13     companies[c].update(processed_loc)
#
# <ipython-input-21-3e9a5d5ddc3b> in get_location(comp, geolocators)
#      39     for g in geolocators:
#      40         try:
# ---> 41             loc = g.geocode(loc_str, timeout=10)
#      42         except GeocoderServiceError:
#      43             print "HTML or API error on", comp['wiki_name']
#
# /usr/local/lib/python2.7/dist-packages/geopy/geocoders/osm.pyc in geocode(self, query, exactly_one, timeout, addressdetails, language, geometry)
#     191         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     192         return self._parse_json(
# --> 193             self._call_geocoder(url, timeout=timeout), exactly_one
#     194         )
#     195
#
# /usr/local/lib/python2.7/dist-packages/geopy/geocoders/base.pyc in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     141
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#     145             message = (
#
# /usr/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /usr/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# /usr/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# /usr/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# /usr/lib/python2.7/urllib2.pyc in https_open(self, req)
#    1239         def https_open(self, req):
#    1240             return self.do_open(httplib.HTTPSConnection, req,
# -> 1241                 context=self._context)
#    1242
#    1243         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1193
#    1194         try:
# -> 1195             h.request(req.get_method(), req.get_selector(), req.data, headers)
#    1196         except socket.error, err: # XXX what error?
#    1197             h.close()
#
# /usr/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#    1055     def request(self, method, url, body=None, headers={}):
#    1056         """Send a complete request to the server."""
# -> 1057         self._send_request(method, url, body, headers)
#    1058
#    1059     def _set_content_length(self, body, method):
#
# /usr/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1095         for hdr, value in headers.iteritems():
#    1096             self.putheader(hdr, value)
# -> 1097         self.endheaders(body)
#    1098
#    1099     def getresponse(self, buffering=False):
#
# /usr/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#    1051         else:
#    1052             raise CannotSendHeader()
# -> 1053         self._send_output(message_body)
#    1054
#    1055     def request(self, method, url, body=None, headers={}):
#
# /usr/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     895             msg += message_body
#     896             message_body = None
# --> 897         self.send(msg)
#     898         if message_body is not None:
#     899             #message_body was not a string (i.e. it is a file) and
#
# /usr/lib/python2.7/httplib.pyc in send(self, data)
#     857         if self.sock is None:
#     858             if self.auto_open:
# --> 859                 self.connect()
#     860             else:
#     861                 raise NotConnected()
#
# /usr/lib/python2.7/httplib.pyc in connect(self)
#    1268             "Connect to a host on a given (SSL) port."
#    1269
# -> 1270             HTTPConnection.connect(self)
#    1271
#    1272             if self._tunnel_host:
#
# /usr/lib/python2.7/httplib.pyc in connect(self)
#     834         """Connect to the host and port specified in __init__."""
#     835         self.sock = self._create_connection((self.host,self.port),
# --> 836                                            self.timeout, self.source_address)
#     837
#     838         if self._tunnel_host:
#
# /usr/lib/python2.7/socket.pyc in create_connection(address, timeout, source_address)
#     564             if source_address:
#     565                 sock.bind(source_address)
# --> 566             sock.connect(sa)
#     567             return sock
#     568
#
# /usr/lib/python2.7/socket.pyc in meth(name, self, *args)
#     226
#     227 def meth(name,self,*args):
# --> 228     return getattr(self._sock,name)(*args)
#     229
#     230 for _m in _socketmethods:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Basic Data Cleaning

# %%
# specify the type for each field
types = {
    # when first link is crawled
    'wiki_name': unicode,
    'wiki_url': unicode,
    'name_url_quoted': unicode,
    
    # when WIKI API is crawled
    'wiki_page_id': int,
    'wiki_api_url': unicode,
    'all_links': list,
    'links': set,
    'is_company': bool,
    'wiki_raw': unicode,
    
    # from extraction2
    'wb_api_url': unicode,
    'wb_api_search_url': unicode,
    
    # added only when Infobox company exists or fields from OpenCorporates
    # not all fields always exist, they are NaN in the resulting DataFrame
    'name': unicode, 
    'type': unicode, 
    'founded': datetime.datetime, 
    'defunct': datetime.datetime, 
    'location': unicode,
    'location_city': unicode,
    'location_country': unicode,
    'location_geopy': unicode,
    'location_gps': tuple,
    # following not in OC
    'countries': set, # added with extraction 3
    'logo': dict,
    'key_people': list, # additonally processed with nameparser.HumanName (dict)
    'industry': list, 
    'subsid': list,
    'products': list, 
    'num_employees': int, 
    'parent': unicode, 
    'homepage': unicode
}

# %%
for c, comp in companies.iteritems():
    for k, val in comp.iteritems():
        if not val:
            continue
        # list values that are not supposed to be lists, to single value
        elif types[k] != list and isinstance(val, list):
            if k == 'num_employees':
                companies[c][k] = parse_employee_nr(val[0], c)
            elif types[k] == datetime.datetime:
                 companies[c][k] = parse_date(val[0])
            else:
                companies[c][k] = val[0]
        # string values to unicode
        elif types[k] == unicode and isinstance(val, str):
            companies[c][k] = unicode(val)
        # single values with one element or only one dict, e.g. in key_people, to list
        elif types[k] == list and not isinstance(val, list):
            companies[c][k] = [val]
        # single unicode values to datetime obj
        elif types[k] == datetime.datetime and isinstance(val, unicode):
                companies[c][k] = parse_date(val)

# %%
# reiterate to check conversion result
failed_types = dict()
for c, comp in companies.iteritems():
    for k, val in comp.iteritems():
        # show values that do not fit specified type
        if val and not isinstance(val, types[k]):
            # non extracted logos just deleted
            if k == 'logo':
                print val
                companies[c][k] = None
            if k not in failed_types:
                failed_types.update({
                    k: {
                        'is_type': type(val),
                        'should_be_type': types[k]}})

print failed_types
# Out:
# {}

# %%
# delete all None type objects
companies = { k: v for k, v in companies.iteritems() if v}

# %%
cnt = 0
for c in companies:
    # are there any unprocessed entries
    if 'is_company' not in companies[c]:
        print c
        continue
    if not companies[c]['is_company']:
        cnt += 1
print cnt, "companies were marked as no company.\nOthers look like:\n"

test_excerpt = 'Microsoft'
print "Excerpt of", test_excerpt, "dict structure:", companies[test_excerpt]
# Out:
# 14 companies were marked as no company.
# Others look like:
#
# Excerpt of Microsoft dict structure: {'num_employees': 114000, 'founded': datetime.datetime(1975, 4, 4, 0, 0), 'name_url_quoted': u'Microsoft', 'wiki_api_url': u'https://en.wikipedia.org/w/api.php?&action=parse&prop=links|wikitext&format=json&pageid=19001', 'location_geopy': u'Building 99 Parking Garage, Northeast 36th Street, Microsoft West Campus, Redmond, King County, Washington, 98052, United States of America', 'logo': {'wiki_raw_code': u'Microsoft logo and wordmark.svg', 'wiki_file_link': u'https://en.wikipedia.org/wiki/File:Microsoft_logo_and_wordmark.svg', 'wiki_commons_link': u'https://commons.wikimedia.org/wiki/File:Microsoft_logo_and_wordmark.svg'}, 'wiki_name': u'Microsoft', 'subsid': [u'List of Microsoft subsidiaries'], 'location_city': u'Microsoft Redmond campus, Redmond, Washington', 'name': u'Microsoft Corporation', 'wiki_url': u'https://en.wikipedia.org/w/index.php?title=Microsoft', 'industry': [u'Computer software', u'Computer hardware', u'Consumer electronics', u'Digital distribution'], 'key_people': [{u'last': u'Thompson', u'suffix': u'', u'title': u'', u'middle': u'W.', u'nickname': u'Chairman', u'first': u'John'}, {u'last': u'Nadella', u'suffix': u'', u'title': u'', u'middle': u'', u'nickname': u'CEO', u'first': u'Satya'}, {u'last': u'Gates', u'suffix': u'', u'title': u'', u'middle': u'', u'nickname': u'Founder & Technology advisor', u'first': u'Bill'}, {u'last': u'Smith', u'suffix': u'', u'title': u'', u'middle': u'', u'nickname': u'President', u'first': u'Brad'}], 'location_country': u'United States', 'products': [u'Windows', u' Office', u' Servers', u' Skype', u' Visual Studio', u' Dynamics', u' Azure', u' Xbox', u' Surface', u' Mobile', u' more...'], 'is_company': True, 'location_gps': (47.64166855, -122.140335782968), 'wiki_page_id': 19001, 'type': u'Public', 'all_links': [u'.NET Foundation', u'.NET framework', u'16-bit', u'2015 EuroBasket', u'21st Century Fox', u'24/7', u'32-bit', u'3M', u'86-DOS', u'ADATA', u'AOL', u'AQuantive', u'ASCII (company)', u'AT&T', u'Accenture', u'Acer Inc.', u'Activision Blizzard', u'Adobe Systems', u'Advanced Micro Devices', u'Advanced persistent threat', u'Age of Empires', u'Akamai Technologies', u'Albuquerque', u'Albuquerque, New Mexico', u'Alcatel-Lucent v. Microsoft Corp.', u'Alexion Pharmaceuticals', u'Alibaba Group', u'Alphabet Inc.', u'Altair 8800', u'Altair BASIC', u'Altamira Software', u'Amazon.com', u'Amazon Web Services', u'American Airlines Group', u'American Express', u'Amgen', u'Amy Hood', u'Am\xe9rica M\xf3vil', u'Analog Devices', u'Android (operating system)', u'Antitrust', u'Apple Computer, Inc. v. Microsoft Corp.', u'Apple Inc.', u'Application programming interface', u'Applied Materials', u'Asset', u'Asus', u'Atlanta Braves', u'Atos', u'Autodesk', u'Automatic Data Processing', u'Avaya', u'Azure Services Platform', u'B. Kevin Turner', u'BASIC', u'BBK Electronics', u'BIOS', u'BT Global Services', u'BT Group', u'Backdoor (computing)', u'Baidu', u'Bed Bath & Beyond', u'Bell Canada', u'Bellevue, Washington', u'Bharat Sanchar Nigam Limited', u'Bharti Airtel', u'Bill Gates', u'Bing', u'BioMarin Pharmaceutical', u'Biogen', u'BlackBerry Limited', u'Board of directors', u'Boeing', u'Booz Allen Hamilton', u'Broadcom Corporation', u'Broadcom Limited', u'Brominated flame retardant', u'Build (developer conference)', u'Bundling of Microsoft Windows', u'Bungie', u'Business', u'Business networking', u'Business process management', u'CACI', u'CA Technologies', u'CGI Group', u'CP/M', u'CSX Corporation', u'Calista Technologies', u'Canon Inc.', u'Capgemini', u'Casio', u'Caterpillar Inc.', u'Celestica', u'Celgene', u'CenturyLink', u'Cerner', u'Chairman', u'Channel 9 (Microsoft)', u'Charles Noski', u'Charles W. Scharf', u'Charter Communications', u'Check Point', u'Chevron Corporation', u'Chief executive officer', u'China Mobile', u'China Telecom', u'China Unicom', u'Cisco Systems', u'Citrix Systems', u'Climate change', u'Cloud computing', u'CodePlex', u'Cognizant', u'Collabor ...

# %%
# store company data in one binary file
with open(ex1_fdat, 'wb') as f:
    pickle.dump(companies, f)
