# %% [markdown]
# ** 02805 Social graphs and interactions **
#
# # Data Extraction Part 1

# %%
# IPython global cell magic
# %reset
# %matplotlib inline

# import all necessary packages
import bs4 # HTML parser
from collections import Counter, OrderedDict # counting elements and ordering keys in dictionaries
import community # python-louvain package
from __future__ import division # all numbers are float
import datetime # handle date objects
import dateparser # parse any (also foreign) date format to object: https://pypi.python.org/pypi/dateparser
import itertools # iterators for efficient looping
import json # JSON parser
import math # math operations
from matplotlib import pyplot as plt # plotting figures
import mwparserfromhell # parse MediaWiki syntax: https://github.com/earwig/mwparserfromhell
from nameparser import HumanName # parse a human name
import networkx as nx # networks creation library
import nltk # natural language processing
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
import operator # efficient operator functions
import os # operating system operations, e.g.: with files and folders
import pandas as pd # use easy-to-use data frames for data analysis
import pickle # python data structures as files
from pprint import pprint # print data structures prettier
import re # regex
import requests # request URL content
from tqdm import tqdm_notebook # make a nice progressbar
import urllib # handle special URL chars

# make working directory
directory = os.getcwd() + '/companies'
if not os.path.exists(directory):
    os.makedirs(directory)

# files
ex1_fdat = directory + '/extraction1_data.pkl'
ex2_fdat = directory + '/extraction2_data.pkl'
ex3_tmp_fdat = directory + '/tmp_extraction3_data.pkl'
ex3_fdat = directory + '/extraction3_data.pkl'
merged = directory + '/merged_data.pkl'
extraction_csv = directory + '/company_data.csv'
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
def get_json_from_url(url):
    r = requests.get(url)
    
    # on HTML error codes
    if r.status_code != 200:
        return None

    # try converting into JSON
    try:
        sec = r.json()
        return sec
    except ValueError:  # includes simplejson.decoder.JSONDecodeError
        print 'WARN: Decoding JSON has failed on:', url
    return None

# %%
def get_comp_pages(api_url, extension=None):
    
    ext_api_url = api_url
    if extension:
        ext_api_url += extension
    
    # retrieve JSON
    sites_w_template = get_json_from_url(ext_api_url)

    # check for valid data
    if not sites_w_template or 'query' not in sites_w_template:
        print "WARN: query returned no data:", infobox_url + properties
    else:
        # iterate over list of companies that embed infobox and save to dict
        for page in sites_w_template['query']['embeddedin']:
            # unicode to str
            quoted_name = urllib.quote_plus(page['title'].encode('utf-8'))
            companies.update({
                page['title']: {
                    'wiki_page_id': page['pageid'],
                    'wiki_name': page['title']),
                    'wiki_url': u'{0}{1}?title={2}'.format(wiki_base, wiki_index, quoted_name),
                    'name_url_quoted': quoted_name
                }
            })

        # run the function recursively, when company found
        if 'continue' in sites_w_template:
            extension = '&eicontinue=' + sites_w_template['continue']['eicontinue']
            return get_comp_pages(api_url, extension)
    
    return companies

# %% [markdown]
# Example query for extraction of pages with "Infobox company" template:
# * https://en.wikipedia.org/w/api.php?&action=query&list=embeddedin&eititle=Template:Infobox+company&einamespace=0&eilimit=max
# * https://en.wikipedia.org/w/api.php?&action=query&list=embeddedin&eititle=Template:Infobox+company&einamespace=0&eilimit=max&eicontinue=0|167638

# %%
# specify wikipedia API URL parameters
wiki_base = u'https://en.wikipedia.org'
wiki_api = u'/w/api.php'
wiki_index = u'/w/index.php'
action = u'action=query'
dat_format = u'format=json'
# eititle=Template:Infobox+company - embedded pages with Template {{Infobox Company}}
# einamespace=0 only articles
# eilimit=max - maximum number before continuing to minimize requests
properties = u'list=embeddedin&eititle=Template:Infobox+company&einamespace=0&eilimit=max'

# concatenate URL
infobox_url = '{0}{1}?&{2}&{3}&'.format(
    wiki_base, wiki_api, action, dat_format)

# init and update with recursive function
companies = dict()
get_comp_pages(infobox_url + properties)

print len(companies), "companies were extracted."
# Out:
# 0 companies were extracted.

# %%
print companies['AT&T']
# Out:
# {'links': set([u'Frontier Florida', u'T-Systems', u'AT&T Corporation', u'Cisco Systems', u'Verizon New England', u'Tata Teleservices', u'KDDI', u'Indiana Bell', u'Dell EMC', u'Northern New England Spinco', u'Huawei', u'BendBroadband', u'Applied Materials', u'Comcast', u'IBM Global Services', u'Deloitte', u'AT&T Broadband', u'Citigroup', u'EPB', u'Sanmina Corporation', u'Hughes Communications', u'NTT Docomo USA', u'Samsung Electronics', u'CenturyLink', u'Olympus Corporation', u'HP Inc.', u'Sony Mobile', u'Qwest', u'AOL', u'Xerox', u'AT&T Communications', u'Houston Cellular', u'AT&T Mobility', u'Hewlett Packard Enterprise', u'AT&T Wireless Services', u'Booz Allen Hamilton', u'Frontier Southwest', u'SK Hynix', u'Prodigy (online service)', u'BellSouth Long Distance', u'MediaTek', u'Verizon Virginia', u'Southern New England Telecommunications', u'CA Technologies', u'NTT DATA', u'Verizon New Jersey', u'China Unicom', u'Advanced Mobile Phone Service', u'Gogo Inflight Internet', u'Silicon Power', u'Yellowpages.com', u'Konica Minolta', u'AT&T U-verse', u'BellSouth Telecommunications', u'Leidos', u'Canon Inc.', u'Asus', u'KPMG', u'SanDisk', u'BT Group', u'Bharti Airtel', u'Ameritech', u'China Mobile', u'SAP SE', u'Centennial Communications', u'Am\xe9rica M\xf3vil', u'Plextor', u'BBK Electronics', u'Graham Holdings Company', u'ADATA', u'Micron Technology', u'Wistron Corporation', u'SBC Long Distance', u'DirecTV', u'Claro Puerto Rico', u'Airespring', u'Accenture', u'Cognizant', u'Apex Global Internet Services', u'Infosys', u'Semiconductor Manufacturing International Corporation', u'Cable One', u'Hewlett Packard Enterprise Services', u'STMicroelectronics', u'KT Corporation', u'Dell Technologies', u'Frontier West Virginia', u'LG Electronics', u'Nippon Telegraph and Telephone', u'Star Micronics', u'Dish Network', u'China Telecom', u'Orange Business Services', u'AT&T Intellectual Property I', u'Fujifilm', u'Inspur', u'Kingston Technology', u'Ricoh', u'BlackBerry Limited', u'Caribe.Net', u'Atlantic.Net', u'Northwestern Bell', u'Verizon New York', u'NYNEX', u'Pacific Northwest Bell', u'Unisys', u'TCL Corporation', u'Tyco International', u'ON Semiconductor', u'Hawaiian Telcom', u'Symantec', u'Wisconsin Bell', u'Ohio Bell', u'Lexmark', u'Intuit', u'LUSFiber', u'T-Mobile', u'Vodafone', u'MTS (network provider)', u'Centracom', u'Sony', u'Juniper Networks', u'Orange S.A.', u'Motorola Solutions', u'Telef\xf3nica', u'Lucent', u'Salesforce.com', u'Lenovo', u'Sprint Corporation', u'OneLink Communications', u'Pacific Bell', u'Alltel', u'MTN Group', u'HCL Technologies', u'Bell Labs', u'NCR Corporation', u'Southern New England Telephone', u'Capgemini', u'TPV Technology', u'Qwest Corporation', u'Rackspace', u'Verizon Communications', u'Microsoft', u'KPN', u'CGI Group', u'MediaOne', u'MSN Dial-up', u'Tech Mahindra', u'Flextronics', u'Hitachi Consulting', u'Qualcomm', u'Celestica', u'NetApp', u'Time Warner Cable', u'Computer Sciences Corporation', u'Infineon Technologies', u'Nortel', u'Western Electric', u'VimpelCom Ltd.', u'Fujitsu', u'Woodbury Telephone', u'Oracle Corporation', u'Idea Cellular', u'ConocoPhillips', u'SK Telecom', u'Ericsson', u'FairPoint Communications', u'Ameritech Cellular', u'Marvell Technology Group', u'Nokia', u'Motorola Mobility', u'@Home Network', u'NEC', u'EchoStar', u'Sony Interactive Entertainment', u'Hisense', u'Quickplay Media', u'Indra Sistemas', u'Microsoft Studios', u'Pacific Telesis', u'Southern Bell', u'Telcordia Technologies', u'Charter Communications', u'AT&T Labs', u'Mahanagar Telephone Nigam', u'C&P Telephone', u'South Central Bell', u'Teradata', u'Frontier California', u'Pure TalkUSA', u'Tokyo Electron', u'Western Digital', u'Take-Two Interactive', u'AT&T Mexico', u'Wincor Nixdorf', u'Avaya', u'Toshiba', u'Nikon', u'Casio', u'LenovoEMC', u'DEX One', u'VMware', u'United Microelectronics Corporation', u'Nintendo', u'Reliance Communications', u'True Corporation', u'Atlantic Broadband', u'Advanced Micro Devices', u'Unef\xf3 ...

# %%
def get_temp_val(temp, k):
    """Check if the parameter exists in the infobox template"""

    try:
        param = temp.get(k)
        return param
    except ValueError:
        # try alternative keys (template not always consistent)
        if k == 'founded':
            return get_temp_val(temp, 'foundation')
        if 'location' in k and 'hq_' not in k:
            return get_temp_val(temp, 'hq_' + k)
    # key not found in template
    return None

# %%
def parse_employee_nr(input_val, c_name):
    """
    Parse a proper number out of the various inputs
    Case possibilities tested:
    
    s_list = [
        '15-50',
        '~300+',
        'circa 40',
        '9,985(Dec 2011)',
        'over 10,000 in 10 countries',
        'Five',
        'over 1 million',
        '10.000',
        'Part of Popular, Inc., which has 8,000 employees'
    ]

    for s in s_list:
        print parse_employee_nr(s, 'test')
    """
    
    # match the first number, dot or comma separation optional
    m = re.search(r'[0-9]+([,\.][0-9]+)?', unicode(input_val))
    if m:
        try:
            # replace , and conert to int
            return int(m.group().replace(',', '').replace('.', ''))
        except ValueError:
            print "WARN: Failed conversion of:{0} (company: {1})".format(
                input_val, c_name)
    return None

# %%
def parse_people_name(names):
    """
    Tim Cook (CEO) becomes 
    {u'last': u'Cook', u'suffix': u'', u'title': u'', u'middle': u'', u'nickname': u'CEO', u'first': u'Tim'}
    """

    # if n makes sure no empty list value
    items = [HumanName(n).as_dict() for n in names if n]
    return items

# %%
def parse_wiki_raw(param, k, c_name):
    """Extract the information on the raw value without notable wiki markup"""

    # strip_code does not work properly for [[File:: https://github.com/earwig/mwparserfromhell/issues/136
    if k == 'logo':
        split_val = unicode(param.value).strip().split('|')
        # first value always image link
        if split_val[0]:
            # avoid bs4 warning
            val = split_val[0]
            if not re.match(r'http://.*', val):
                val = bs4.BeautifulSoup(val, 'lxml').text
            val = val.replace('[[', '').replace(' ', '_')
            if val:
                # can be written without [[File: or [[Image:
                if 'File:' in val or 'Image:' in val:
                    pass
                else:
                    val = 'File:' + val
                # submit raw version too, also links can differ
                return {
                    'wiki_commons_link': 'https://commons.wikimedia.org/wiki/' + val,
                    'wiki_file_link': wiki_base + '/wiki/' + val,
                    'wiki_raw_code': param.value.strip()}
    
    # fields can contain break separations, e.g. Microsoft: 
    # [[John W. Thompson]] <small> ([[Chairman]]) </small> <br /> [[Satya Nadella]]
    if '<br' in param.value:
        # replace the HTML breaks with real newline
        param.value = re.sub(r'<br>|<br ?/>', '\n', unicode(param.value))
        # get rid of media wiki markup and split into parts
        val = unicode(param.value.strip_code())
        # strip code does not always remove HTML tags
        val = bs4.BeautifulSoup(val, 'lxml').text
        items = val.split('\n')
        if k == 'key_people':
            return parse_people_name(items)
        if k == 'num_employees':
            return parse_employee_nr(items[-1], c_name)
        return items

    # only assuming one value when no breaks, too vague to use other seperators than <br>
    val = param.value.strip_code()

    # avoid bs4 warning when parsing HTML link
    if k != 'homepage':
        # properly remove HTML remains
        val = bs4.BeautifulSoup(val, 'lxml').text
    if k == 'homepage':
        # there are cases like: [http://www.absn.tv/ ABS] for homepage/website that don't match URL template
        match_link = re.search(r'\[(.+)\]', unicode(param.value))
        if match_link:
            val = match_link.group(1)
        # if whitespaces, then still no valid link
        if ' ' in val:
            # HTML needs to be ignored, e.g.: <!-- {{URL|www.example.com}} --> (also strips text)
            rem_html = bs4.BeautifulSoup(val, 'lxml').text
            if rem_html:
                return param.value.strip().split(' ')[0].replace('[', '')
            else:
                return None
    if k == 'num_employees':
        return parse_employee_nr(val, c_name)

    # make sure string didn't just contain whitespaces
    if val:
        return unicode(val).strip()
    # it can be that the field exists but is empty
    return None

# %%
def parse_wiki_template(param, k, c_name):
    """Extract further information if templates in key value"""

    for tem in param.value.filter_templates():
        # handle dates, URL and list
        if k == 'founded' or k == 'defunct':
            if tem.name.matches(('start date and age', 'start date', 'end date')):
                # valid date: {{Start date and age|2003|January|5|df=1}}
                date = [unicode(p) for p in tem.params if '=' not in unicode(p)]
                # concatenate the date and give to dateparser
                if not date:
                    return datetime.time()
                # if only the year is given returns todays date in that year
                return dateparser.parse("/".join(date), settings={
                        'PREFER_DATES_FROM': 'past',
                        'DATE_ORDER': 'YMD'})
            else:
                return datetime.time()
        elif k == 'homepage' and tem.name.matches(('url', 'URL')):
            if tem.params:
                try:
                    url = tem.get(1)
                except ValueError:
                    print "WARN: Could not get first element in params:", tem.params
                    return unicode(tem.params[0]).strip()
                return unicode(url).strip()
        elif tem.name.matches('unbulleted list'):
            # replace wiki link markup and remove extra citations etc.
            items = [p.value.strip_code().strip() for p in tem.params]
            if k == 'key_people':
                return parse_people_name(items)
            if k == 'num_employees':
                # e.g.: {{unbulleted list|{{loss}}0 (7 February 2013)|850 (6 February 2013)}}
                # usually last value contains current number
                return parse_employee_nr(items[-1], c_name)
            return items
        elif tem.name.matches(('plainlist', 'flatlist')):
            if tem.params:
                items = tem.params[0].value.strip_code().strip().split('\n')
                if k == 'key_people':
                    # use nameparse to exclude titles, etc.
                    return parse_people_name(items)
                return items
        elif 'formatnum' in tem.name and k == 'num_employees':
            # {{formatnum:1234}}, colon not detected by mwparser
            m = re.search(r'formatnum:(.*)', unicode(tem.name))
            if m:
                return parse_employee_nr(m.group(1), c_name)

    # if the template didn't match anything parse raw text
    return parse_wiki_raw(param, k, c_name)

# %%
def parse_wiki_text(company):
    """Parse MediaWiki markup to extract detailed information"""

    # remove ref tags, bs4 adds unwanted body tags, thus regex better
    wiki_raw = re.sub(r'<ref.*?</ref>|<ref>.*?</ref>', '', company['wiki_raw'])

    comp_infobox = dict()
    # parse the wikimedia syntax
    # style can be ignored: https://github.com/earwig/mwparserfromhell/issues/115
    code = mwparserfromhell.parse(wiki_raw, skip_style_tags=True)
    # filter for the infobox
    # If matches is a regex, the flags passed to re.search() are re.IGNORECASE ...
    c_template = code.filter_templates(
        matches=r'infobox company|infobox_company|company infobox|company|infobox dot-com company')
    if not c_template:
        # try regex approach for any infobox, if nothing found above
        match = re.search(r'({{infobox.*\n(?:\|.*\n|\*.*\n)+}})', wiki_raw, re.IGNORECASE)
        if match:
            infobox_temp = mwparserfromhell.parse(
                match.group(1), skip_style_tags=True).filter_templates()
            if infobox_temp:
                infobox_temp = infobox_temp[0]
            else:
                print "WARN: No parsable company infobox template for:", company['wiki_name']
                return comp_infobox
        else:
            print "WARN: No company infobox found for:", company['wiki_name']
            return comp_infobox
    else:
        infobox_temp = c_template[0]

    # find values for each key
    key_list = ['name', 'logo', 'type', 'key_people', 'industry', 'founded', 'location', \
                'location_city', 'location_country', 'defunct', 'subsid', \
                'products', 'num_employees', 'parent', 'homepage']
    for k in key_list:
        param = get_temp_val(infobox_temp, k)
        if param:
            val = parse_wiki_template(param, k, company['wiki_name'])
            if val:
                comp_infobox[k] = val
    # if there was no name given, take name of company node
    if 'name' not in comp_infobox:
        comp_infobox['name'] = company['wiki_name']
    return comp_infobox

# %%
def get_c_info(all_companies, company):
    """Get links and the wikitext which is used to extract key information about the company"""

    # concatenate URL from previously set values
    link_url = '{0}{1}?&{2}&{3}&{4}&pageid={5}'.format(
        wiki_base, wiki_api, action, properties, dat_format, company['wiki_page_id'])

    # get JSON and check for validity
    c_content = get_json_from_url(link_url)
    if not c_content or 'parse' not in c_content:
        print 'WARN: No parsable content on: {0} under page {1} (id: {2})'.format(
            link_url, company['wiki_name'], company['wiki_page_id'])
        company['is_company'] = False
        return company

    # save new fields
    company['wiki_api_url'] = link_url
    # list of links intersected with list containing all companies
    links = [x['*'] for x in c_content['parse']['links'] if x['ns'] == 0]
    company['all_links'] = links
    company['links'] = all_companies.intersection(links)

    # original wikitext to parse {{Infobox company
    company['wiki_raw'] = c_content['parse']['wikitext']['*']
    
    # extract company info from box, only on wiki text not HTML
    company_infobox = parse_wiki_text(company)
    company.update(company_infobox)
    company['is_company'] = True
    
    # keep non-company nodes but mark
    if not company_infobox:
        company['is_company'] = False
    return company

# %% [markdown]
# Example query to extract wikitext and links on a wiki page:
# * https://en.wikipedia.org/w/api.php?action=parse&page=Audi&prop=links|wikitext
# * https://en.wikipedia.org/w/api.php?action=parse&page=AT%26T&prop=links|wikitext
# * https://en.wikipedia.org/w/api.php?&action=parse&format=json&prop=links|wikitext&pageid=17555269

# %%
action = u'action=parse'
dat_format = u'format=json'
properties = u'prop=links|wikitext'

# other: 'Audi', 'Apple Inc.', 'Microsoft'
company = 'Groupe Casino'

# create unique set of all companies
all_companies = set(companies.keys())

print "Excerpt of", company, "dict structure:"
pprint(get_c_info(all_companies, companies[company]))
# Out:
# Excerpt of Groupe Casino dict structure:
# {'all_links': [u'France',
#                u'Air France-KLM',
#                u'Aldi',
#                u'Argentina',
#                u'Arkema',
#                u'Atac',
#                u'Auchan',
#                u'Brazil',
#                u'Bricomarch\xe9',
#                u'Bureau Veritas',
#                u'CAC Next 20',
#                u'CGG (company)',
#                u'Carrefour',
#                u'Carrefour City',
#                u'Carrefour Express',
#                u'Carrefour Market',
#                u'Cdiscount',
#                u'Champion (supermarket)',
#                u'Coccinelle',
#                u'Colombia',
#                u'Cora (hypermarket)',
#                u'Dassault Syst\xe8mes',
#                u'Dia (supermarket chain)',
#                u'Docks de France',
#                u'E.Leclerc',
#                u'Ed (supermarket)',
#                u'Edenred',
#                u'Equity (finance)',
#                u'Euromarch\xe9',
#                u'Euronext',
#                u'Eurotunnel',
#                u'Extra Hipermercados',
#                u'Franprix',
#                u'Galeries Lafayette',
#                u'Gemalto',
#                u'Grupo P\xe3o de A\xe7\xfacar',
#                u'G\xe9ant Casino',
#                u'Herm\xe8s',
#                u'Hypercacher',
#                u'Indian Ocean',
#                u'Inno',
#                u'Intermarch\xe9',
#                u'Jean-Charles Naouri',
#                u'Kl\xe9pierre',
#                u'Lagard\xe8re Group',
#                u'Le Relais des Mousquetaires',
#                u'Leader Price',
#                u'Les Mousquetaires',
#                u'Lidl',
#                u'List of supermarket chains in France',
#                u'Loire (department)',
#                u'Louis Delhaize Group',
#                u'March\xe9 Plus',
#                u'Market capitalisation',
#                u'Match (supermarket)',
#                u'Mercialys',
#                u'Monoprix',
#                u'NYSE Euronext Paris',
#                u'Natixis',
#                u'Net income',
#                u'Net sales',
#                u'Netto (Les Mousquetaires)',
#                u'Norma (supermarket)',
#                u'Paris Store',
#                u'Promod\xe8s',
#                u'P\xe3o de A\xe7\xfacar',
#                u'Restaumarch\xe9',
#                u'Roady (Mousquetaires)',
#                u'S.A. (corporation)',
#                u'SES S.A.',
#                u'SPAR',
#                u"Sainsbury's",
#                u'Saint-\xc9tienne',
#                u'Scor (company)',
#                u'Simply Market',
#                u'Sodexo',
#                u'South America',
#                u'Spar (retailer)',
#                u'Subsidiary',
#                u'Suez Environnement',
#                u'Syst\xe8me U',
#                u'Tesco',
#                u'Thales Group',
#                u'Ticker symbol',
#                u'Types of business entity',
#                u'Uruguay',
#                u'Valeo',
#                u'Vival (supermarket)',
#                u'V\xeati',
#                u'Wendel (group)',
#                u'\xc9comarch\xe9',
#                u'\u20ac',
#                u'Enseignes du groupe Casino',
#                u'Casino Restauration',
#                u'Naturalia',
#                u'P\xe3o de A\xe7\xfacar, Extra, Br\xe9sil',
#                u'Exito, Colombie',
#                u'Libertad, Mini Libertad, Argentine',
#                u'Devoto, Disco, Uruguay',
#                u'Jumbo, Oc\xe9an Indien',
#                u'Groupe \xc9xito',
#                u'Trading profit',
#                u'Shopi (supermarket)',
#                u'Utile'],
#  'founded': datetime.datetime(1898, 11, 25, 0, 0),
#  'homepage': u'http://mobile.casino.fr/',
#  'industry': u'Mass Retail',
#  'is_company': True,
#  'key_people': u'Jean-Charles Naouri',
#  'links': set([u'Aldi',
#                u'Arkema',
#                u'Atac',
#                u'Auchan',
#                u'Bricomarch\xe9',
#                u'Bureau Veritas',
#                u'CGG (company)',
#                u'Carrefour',
#                u'Carrefour City',
#                u'Carrefour Express',
#                u'Carrefour Market',
#                u'Champion (supermarket)',
#                u'Cora (hypermarket)',
#                u'Dassault Syst\xe8mes',
#                u'Dia (supermarket chain)',
#                u'E.Leclerc',
#                u'Ed (supermarket)',
#                u'Edenred',
#                u'Euromarch\xe9',
#                u'Eurotunnel',
#                u'Franprix',
#                u'Gemalto',
#                u'G\xe9ant Casino',
#                u'Herm\xe8s',
#                u'Intermarch\xe9',
#                u'Kl\xe9pierre',
#                u'Lagard\xe8re Group',
#                u'Le Relais des Mousquetaires',
#                u'Leader Price',
#                u'Les Mousquetaires',
#                u'Lidl',
#                u'Louis Delhaize Group',
#                u'Mercialys',
#                u'Natixis',
#                u'Netto (Les Mousquetaires)',
#                u'Norma (supermarket)',
#                u'Paris Store',
#                u'Promod\xe8s',
#                u'Restaumarch\xe9',
#                u'Roady (Mousquetaires)',
#                u'SES S.A.',
#                u"Sainsbury's",
#                u'Simply Market',
#                u'Sodexo',
#                u'Spar (retailer)',
#                u'Suez Environnement',
#                u'Syst\xe8me U',
#                u'Tesco',
#                u'Thales Group',
#                u'Valeo',
#                u'Vival (supermarket)',
#                u'V\xeati',
#                u'Wendel (group)']),
#  'location_city': u'Saint-\xc9tienne',
#  'location_country': u'France',
#  'logo': {'wiki_commons_link': u'https://commons.wikimedia.org/wiki/File:Groupe_Casino_logo.svg',
#           'wiki_file_link': u'https://en.wikipedia.org/wiki/File:Groupe_Casino_logo.svg',
#           'wiki_raw_code': u'Groupe Casino logo.svg'},
#  'name': u'Casino Guichard-Perrachon S.A.',
#  'name_url_quoted': 'Groupe+Casino',
#  'num_employees': 329600,
#  'subsid': u'G\xe9ant Casino; Casino Supermarch\xe9s; Hyper Casino; Petit Casino; Casino Shop; Casino Restauration; Monoprix; Naturalia; Franprix; Leader Price; Spar; Vival; Cdiscount; P\xe3o de A\xe7\xfacar, Extra, Br\xe9sil; Exito, Colombie; Libertad, Mini Libertad, Argentine; Devoto, Disco, Uruguay; Jumbo, Oc\xe9an Indien',
#  'type': u'Soci\xe9t\xe9 Anonyme with a Board of Directors',
#  'wiki_api_url': 'https://en.wikipedia.org/w/api.php?&action=parse&prop=links|wikitext&format=json&pageid=2511380',
#  'wiki_name': u'Groupe Casino',
#  'wiki_page_id': 2511380,
#  'wiki_raw': u'{{Infobox company\n| name             = Casino Guichard-Perrachon S.A.\n| logo             = Groupe Casino logo.svg\n| caption          = Groupe Casino, Feeding a world of diversity\n| foundation       = {{Start date and age|1898}}\n| image            = \n| image_caption    = Headquarters in [[Saint-\xc9tienne]]\n| founder          = Geoffroy Guichard\n| type\t\t   = [[S.A. (corporation)|Soci\xe9t\xe9 Anonyme with a Board of Directors]]\n| traded_as        = {{Euronext|CO|FR0000125585|XPAR}}\n| owner\t\t   = \n| ownership \t   = [[Rallye]](48.6%), [[CNP]](1.7%), [[Galeries Lafayette]](1.9%),Casino employee saving plan 2.1%)(December 2012)\n| industry         = Mass Retail\n| area_served      = \n| num_employees    = {{formatnum:329,600}} employees worldwide, of which {{formatnum:71,129}} in France (2013)\n| trading_name     = \n| native_name      = \n| native_name_lang =\n| romanized        =\n| former type      = \n| genre            = <!-- Only used with media and publishing companies -->\n| fate             = \n| predecessor      = \n| successor        = \n| defunct          = <!-- {{End date|YYYY|MM|DD}} -->\n| location_city    = [[Saint-\xc9tienne]]\n| location_country = [[France]]\n| locations        = \n| key_people       =  [[Jean-Charles Naouri]]\n| products         = \n| production       = \n| services         = \n| revenue          = {{unbulleted list|{{increase}}\u20ac48.645 billion (2014)}}\n| operating_income = \n| net_income       = {{unbulleted list|\u20ac556 million (2014)}}\n| aum              = <!-- Only used with financial services companies -->\n| assets           = \n| equity           = {{unbulleted list|{{increase}}\u20ac15,608 billion (2014)}}\n| parent           = \n| divisions        = \n| subsid           = [[Enseignes du groupe Casino#G\xe9ant Casino|G\xe9ant Casino]]; [[Enseignes du groupe Casino#Casino Supermarch\xe9s|Casino Supermarch\xe9s]]; [[Enseignes du groupe Casino#Hyper Casino|Hyper Casino]]; [[Enseignes du groupe Casino#Petit Casino|Petit Casino]]; [[Enseignes du groupe Casino#Casino Shopping et Casino Shop|Casino Shop]]; [[Casino Restauration]]; [[Monoprix]]; [[Naturalia]]; [[Franprix]]; [[Leader Price]]; [[Spar (retailer)|Spar]]; [[Enseignes du groupe Casino#Vival|Vival]]; [[Cdiscount]]; [[P\xe3o de A\xe7\xfacar, Extra, Br\xe9sil]]; [[Exito, Colombie]]; [[Libertad, Mini Libertad, Argentine]]; [[Devoto, Disco, Uruguay]]; [[Jumbo, Oc\xe9an Indien]]\n| homepage         = {{URL|http://mobile.casino.fr/}}<br />{{URL|http://www.groupe-casino.fr/}}\n| footnotes        = \n| intl             = yes\n| bodystyle        =\n}}\n\n\'\'\'Groupe Casino\'\'\' (or \'\'\'Casino Guichard-Perrachon\'\'\') is a [[France|French]] mass retailer with operations around the world. The company is listed on the [[NYSE Euronext Paris|NYSE Euronext Paris stock exchange]] and its majority shareholder is Rallye SA.\n\nThe company\'s head office is in [[Saint-\xc9tienne]].<ref>"[http://www.groupe-casino.fr/en/Contact.html Contact]." Groupe Casino. Retrieved on 24 June 2013. "Groupe Casino 1, Esplanade de France, BP 306 42008 Saint-Etienne Cedex 2 - FRANCE"</ref>\n\n== History ==\n\nIn 1892, Geoffroy Guichard became the sole proprietor of a grocery store located in the old Casino Lyrique cabaret in Saint-\xc9tienne, which remained the Group\u2019s flagship store for many years and is the origin of the group\u2019s current title.\n\nOn June 25, 1898 Geoffroy Guichard opened the first branch store in Veauche and, on August 2 of the same year, he set up the  \'\'Soci\xe9t\xe9 des Magasins du Casino et \xc9tablissements \xc9conomiques d\'Alimentation\'\', operating under the name "Guichard-Perrachon & Cie". Following the company\u2019s creation, the focus began to shift towards organisation with the construction of a warehouse in Saint-\xc9tienne.<ref>[http://www.fundinguniverse.com/company-histories/casino-guichard-perrachon-s-a-history/ Casino Guichard-Perrachon S.A. History], \'\'fundinguniverse.com\'\'</ ...
#  'wiki_url': 'https://en.wikipedia.org/w/index.php?title=Groupe+Casino'}

# %%
def scrape_companies(companies, com_dat):
    """Gets two dictionaries and parses those who don't have same content"""

    # scrape links and extra information of all companies, call with progress-bar
    for company in tqdm_notebook(companies, desc='Fetching companies'):
        # don't repeat if pickle file already contains data
        if com_dat and \
            company in com_dat and \
            'is_company' in com_dat[company] and \
            com_dat[company]['is_company']:
                continue
        # extract any company information
        companies[company] = get_c_info(all_companies, companies[company])
    return companies

# %%
# get company file from extraction 1, check for changes
com_dat_pickle = dict()
if os.path.isfile(ex1_fdat):
    with open(ex1_fdat, 'rb') as f:
        com_dat_pickle = pickle.load(f)

# %%
# %%time
# 500 companies take about 2-3 mins
# for 64k that is approx. 128 cykles which should total maximum 5 hours crawl time
# ((64000 / 500) * 2) / 60

# crawl for all companies that were not prcoessed yet and cotain no or a false 'is_company' flag
companies = scrape_companies(companies, com_dat_pickle)
# Out:
# WARN: No company infobox found for: McDonald's legal cases
# WARN: No company infobox found for: History of Burger King
# WARN: No company infobox found for: KFC advertising
# WARN: No company infobox found for: Albemarle Corporation
# WARN: No company infobox found for: UXC
# WARN: No company infobox found for: Burger King products
# WARN: No company infobox found for: Fondo Común
# WARN: Could not get first element in params: [u'sor.cz/site/index.php?lang=en']

# %%
test_excerpt = 'Microsoft'
print "Excerpt of", test_excerpt, "dict structure:", companies[test_excerpt]
# Out:
# Excerpt of Microsoft dict structure: {'location_city': u'Microsoft Redmond campus, Redmond, Washington', 'links': set([u'T-Systems', u'Toshiba', u'Tellme Networks', u'Norwegian Cruise Line', u'American Airlines Group', u'Big Fish Games', u'Visio Corporation', u'Rare (company)', u'Tata Teleservices', u'KDDI', u'Amgen', u'Huawei', u'Reuters', u'Applied Materials', u'Comcast', u'IBM Global Services', u'Pando Networks', u'Deloitte', u'Seagate Technology', u'Biogen', u'CBS Interactive', u'Powerset (company)', u'Vodafone', u'Thomson Reuters', u'Mylan', u'Sony', u'Olympus Corporation', u'HP Inc.', u'Sony Mobile', u'Quanta Computer', u'Revolution Analytics', u'AOL', u'Xerox', u'Agence France-Presse', u'American Express', u'Sysinternals', u'Booz Allen Hamilton', u'Time Inc.', u'SK Telecom', u'Alphabet Inc.', u'QFC', u'MediaTek', u'The Priceline Group', u'CA Technologies', u'NTT DATA', u'Samsung Electronics', u'Ctrip', u'Pfizer', u'Rackspace', u'Tata Consultancy Services', u'Jabil Circuit', u'Silicon Power', u'Havok (company)', u'Konica Minolta', u'Apple Inc.', u'International Data Group', u'Leidos', u'Canon Inc.', u'Asus', u'KPMG', u'SanDisk', u'Bharti Airtel', u'Adobe Systems', u'Plextor', u'Guardian Media Group', u'Fiserv', u'SAP SE', u'Orange S.A.', u'Am\xe9rica M\xf3vil', u'China Mobile', u'Liberty Interactive', u'Sony Interactive Entertainment', u'Xilinx', u'Dollar Tree', u'Endo International plc', u'DuPont', u'SBA Communications', u'Pegatron', u'REI', u'Sanmina Corporation', u'Accenture', u'Cognizant', u'The Travelers Companies', u'Infosys', u'Semiconductor Manufacturing International Corporation', u'Hewlett Packard Enterprise Services', u'Paccar', u'STMicroelectronics', u'KT Corporation', u'Dell Technologies', u'Wistron Corporation', u'LG Electronics', u'Nippon Telegraph and Telephone', u'Kingston Technology', u'Star Micronics', u'Perceptive Pixel', u'Dish Network', u'China Telecom', u'Orange Business Services', u'Ulta Beauty', u'Fujifilm', u'Inspur', u'Hitachi Consulting', u'Ricoh', u'BlackBerry Limited', u'Yankee Group', u'Meizu', u'3M', u'NetApp', u'Incyte', u'Kraft Heinz', u'Expeditors International', u'Unisys', u'TCL Corporation', u'ON Semiconductor', u'Cond\xe9 Nast', u'Symantec', u'Johnston Press', u'Liberty Media', u'AQuantive', u'Lexmark', u'Intuit', u'UnitedHealth Group', u'NBCUniversal', u'MTS (network provider)', u'Merck & Co.', u'AT&T', u'Juniper Networks', u'Costco', u'Motorola Solutions', u'Telef\xf3nica', u'Xamarin', u'Lenovo', u'Sprint Corporation', u'Sirius XM Holdings', u'United Technologies', u"O'Reilly Auto Parts", u'Procter & Gamble', u'MTN Group', u'Discovery Communications', u'HCL Technologies', u'Lam Research', u'NCR Corporation', u'Fujitsu', u'Capgemini', u'TPV Technology', u'Western Digital', u'Lionhead Studios', u'Linear Technology', u'Massive Incorporated', u'Compal Electronics', u'KPN', u'CGI Group', u'Mahanagar Telephone Nigam', u'Liberty Global', u'Tech Mahindra', u'Flextronics', u'Tokyo Electron', u'Autodesk', u'Qualcomm', u'Celestica', u'NXP Semiconductors', u'Telenor', u'Computer Sciences Corporation', u'Infineon Technologies', u'Twisted Pixel Games', u'GreenButton', u'United Microelectronics Corporation', u'Seattle Computer Products', u'Oracle Corporation', u'Expedia, Inc.', u'Idea Cellular', u'Panasonic', u'Ericsson', u'Vertex Pharmaceuticals', u'Marvell Technology Group', u'Nokia', u'Nike, Inc.', u'Nordstrom', u'Motorola Mobility', u'Express Scripts', u'NEC', u'Eddie Bauer', u'BT Group', u'BBK Electronics', u'Hisense', u'MileIQ', u'Indra Sistemas', u'SK Hynix', u'Dell EMC', u'Tesla Motors', u'Microsoft Mobile', u'Secure Islands', u'Verizon Communications', u'IBM', u'Nikon', u'Verisk Analytics', u'NTT DoCoMo', u'T-Mobile US', u'Weyerhaeuser', u'Take-Two Interactive', u'Wincor Nixdorf', u'Trusted Computing Group', u"McDonald's", u'Avaya', u'The Walt Disney Company', u'Caterpillar Inc.', u'Gilead Sciences', u'Puget Sound Energy', u'Casio', u'LenovoEMC', u'VMware', u'Nintendo', u'Novell', u'True ...

# %%
# store company data in one binary file
with open(ex1_fdat, 'wb') as f:
    pickle.dump(companies, f)
