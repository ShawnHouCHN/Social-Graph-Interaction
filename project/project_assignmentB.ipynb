# %% [markdown]
# ** DTU - 02805 Social graphs and interactions (2016) **
#
# # Project Assignment B
# ## Company Network
#
# A [video description](https://www.youtube.com/watch?v=HNrX5dCCrNw) gives a basic overview of the project.
#
#
# The main motivation was to get insights about the network of companies. Our dataset is extracted from articles about companies on [Wikipedia](https://www.wikipedia.org/). There is some coverage in part _1.2._ explaining how other data sources were incorporated to gather extra information that includes the type, industry, location and much more of a company.
#
# This particular dataset was chosen to build a network of the companies. Links between each company that represents a node are made according to the links in the Wikipedia article. Running several network analysis the goal is to find interesting facts like communities that are not only formed by type, industry or country. Maybe certain parent companies with their subsidiaries are found. Can it be that there are a few super companies that run the world? We hope to find some answers to this question.
#
# Furthermore, a sentiment analysis will help to gain insights into the general mood on companies on [Twitter](https://twitter.com/?lang=en). Who is the most hated company in Europe at the moment and does it play a very central row overall? Is Volkswagen still hit by the emission scandal or Samsung by the Galaxy Note 7 disaster? Is Twitter maybe dominated by the happy commercials of the companies?
#
# Following a general outline of the explainer notebook covering [required deliverables](https://github.com/suneman/socialgraphs2016/wiki/Assignments#more-on-the-explainer-notebook) surrounding basic stats, tools, theory and analysis:
#
# * 1\. Data Extraction
#     * 1.1\. API Data Gathering
#     * 1.2\. Additional Extraction
#     * 1.3\. Data Merging
#     * 1.4\. Adding Geo Location
#     * 1.5\. Data Cleaning
# * 2\. Preliminary Data Analysis
#     * 2.2\. Company Analysis
#     * 2.2\. Company Statistics
#     * 2.3\. Company Graphs
# * 3\. Network Construction
#     * 3.1\. Alternative Construction
# * 4\. Network Analysis
#     * 4.1\. Degree Distribution
#     * 4.2\. Power-laws and Friendship Paradox
#     * 4.3\. Centrality
#     * 4.4\. Assortativity
#     * 4.5\. Modularity
#     * 4.6\. Communities
#     * 4.7\. Network Visualizations and Statistics
# * 5\. Sentiment Analysis of Twitter Data
#     * 5.1\. API Data Gathering
#     * 5.2\. Happiness Averages of Companies
#     * 5.3\. Wordclouds
# * 6\. Discussion

# %% [markdown]
# ## 0. Load Modules
#
# Each needed module is loaded in order to keep the overview of already loaded modules. Also certain files and directories where data can be loaded from are specified. The reason is many that data crawling and some network analysis can take some time.

# %%
# IPython global cell magic
# %reset
# %matplotlib inline

# import all necessary packages
import bs4 # HTML parser
from collections import Counter, OrderedDict # counting elements and ordering keys in dictionaries
import community # python-louvain package
import datetime # handle date objects
import dateparser # parse any (also foreign) date format to object: https://pypi.python.org/pypi/dateparser
from __future__ import division # all numbers are float
import gc # garbage collector
import geoplotlib # plot points on tiled maps
from geoplotlib.utils import BoundingBox
import geopy # get geo location according to addresses
from geopy.exc import GeocoderServiceError
from infomap import infomap # python infomap algorithm, needs to be in same directory
import itertools # iterators for efficient looping
import json # JSON parser
import math # math operations
from matplotlib import pyplot as plt # plotting figures
import mwparserfromhell # parse MediaWiki syntax: https://github.com/earwig/mwparserfromhell
from nameparser import HumanName # parse a human name
import networkx as nx # networks creation library
import nltk # natural language processing
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
import operator # efficient operator functions
import os # operating system operations, e.g.: with files and folders
import pandas as pd # use easy-to-use data frames for data analysis
import pickle # python data structures as files
from pprint import pprint # print data structures prettier
import re # regex
import requests # request URL content
import sys # system operations
import time # sleep timer
from tqdm import tqdm_notebook # make a nice progressbar
import urllib # handle special URL chars

# make working directory
directory = os.getcwd() + '/companies'
if not os.path.exists(directory):
    os.makedirs(directory)

# files from data crawling
ex1_fdat = directory + '/extraction1_data.pkl'
ex2_fdat = directory + '/extraction2_data.pkl'
ex3_tmp_fdat = directory + '/tmp_extraction3_data.pkl'
ex3_fdat = directory + '/extraction3_data.pkl'
merged = directory + '/merged_data.pkl'
# network files
network_f = directory + '/network.pkl'
network_red_f = directory + '/reduced_network.pkl'
gephi_f = directory + 'gehpi.gexf'
# pandas data
extraction_csv = directory + '/company_data.csv'

# specify nltk data dir, otherwise LookupError
nltk.data.path.append(os.getcwd() + '/../nltk_data')
from nltk.corpus import names
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# ## 1. Data Extraction
# ### 1.1. API Data Gathering
#
# The first approach to detect companies on Wikipedia is by looking for a template called ["Infobox company"](https://en.wikipedia.org/wiki/Template:Infobox_company) that is embedded on the site. It contains certain fields that are also used as extra data that can be used for some data analysis later on, e.g.:
# * `key_people` - CEO and other important postitions in the company.
# * `founded` - The date when the company was founded.
# * `hq_location` - The address of the company.
# * etc.
#
# Example query for extraction of pages with "Infobox company" template:
#
# * https://en.wikipedia.org/w/api.php?&action=query&list=embeddedin&eititle=Template:Infobox+company&einamespace=0&eilimit=max
# * https://en.wikipedia.org/w/api.php?&action=query&list=embeddedin&eititle=Template:Infobox+company&einamespace=0&eilimit=max&eicontinue=0|167638
#
# Each query returns a maximum of 500 Wikipedia pages. Over a continue parameter the next results can be queried. That returned data is in JSON format and thus can be easily parsed into a Python dictionary.
#
# Some functions are defined and used throughout the notebook. Most of the functions have a description.

# %%
def get_json_from_url(url):
    """URL request that returns JSOn data if parsable."""

    r = requests.get(url)
    
    # on HTML error codes
    if r.status_code != 200:
        return None

    # try converting into JSON
    try:
        sec = r.json()
        return sec
    except ValueError:  # includes simplejson.decoder.JSONDecodeError
        print 'WARN: Decoding JSON has failed on:', url
    return None

# %%
def get_comp_pages(api_url, extension=None):
    """Query to get company wikipedia pages with embedded template."""
    
    # extend the input URL with continue parameter
    ext_api_url = api_url
    if extension:
        ext_api_url += extension
    
    # retrieve JSON
    sites_w_template = get_json_from_url(ext_api_url)

    # check for valid data
    if not sites_w_template or 'query' not in sites_w_template:
        print "WARN: query returned no data:", infobox_url + properties
    else:
        # iterate over list of companies that embed infobox and save to dict
        for page in sites_w_template['query']['embeddedin']:
            # unicode to str
            quoted_name = urllib.quote_plus(page['title'].encode('utf-8'))
            companies.update({
                page['title']: {
                    'wiki_page_id': int(page['pageid']),
                    'wiki_name': unicode(page['title']),
                    'wiki_url': u'{0}{1}?title={2}'.format(wiki_base, wiki_index, quoted_name),
                    'name_url_quoted': unicode(quoted_name)
                }
            })

        # run the function recursively, when company found
        if 'continue' in sites_w_template:
            extension = '&eicontinue=' + sites_w_template['continue']['eicontinue']
            return get_comp_pages(api_url, extension)
    
    return companies

# %% [markdown]
# All initial data will be stored in a dictonary. First the data necessary to crawl each company Wikipedia page individually is gathered.

# %%
# specify wikipedia API URL parameters
wiki_base = u'https://en.wikipedia.org'
wiki_api = u'/w/api.php'
wiki_index = u'/w/index.php'
action = u'action=query'
dat_format = u'format=json'
# eititle=Template:Infobox+company - embedded pages with Template {{Infobox Company}}
# einamespace=0 only articles
# eilimit=max - maximum number before continuing to minimize requests
properties = u'list=embeddedin&eititle=Template:Infobox+company&einamespace=0&eilimit=max'

# concatenate URL
infobox_url = '{0}{1}?&{2}&{3}&'.format(
    wiki_base, wiki_api, action, dat_format)

# init and update with recursive function
companies = dict()
get_comp_pages(infobox_url + properties)

print len(companies), "companies were extracted."
# Out:
# 56893 companies were extracted.

# %% [markdown]
# A small excerpt of gathered information.

# %%
company = 'AT&T'
print "Dictonary excerpt of", company, "after searching for Infobox company template:"
print companies[company]
# Out:
# Dictonary excerpt of AT&T after searching for Infobox company template:
# {'name_url_quoted': u'AT%26T', 'wiki_page_id': 17555269, 'wiki_url': u'https://en.wikipedia.org/w/index.php?title=AT%26T', 'wiki_name': u'AT&T'}

# %% [markdown]
# A lot of cleaning and proper parsing of the each individual field in the template has to be done. Since everyone is free to edit any wikipedia page there are certain problems on many pages. Individual cases are handled in the next functions. The module [mwparserfromhell](https://github.com/earwig/mwparserfromhell) is used to parse so called templates in the extracted wikitext.
#
# Here are some other modules that are used:
# * [dateparser](https://pypi.python.org/pypi/dateparser) for `defunct` and `founded` date fields
# * [nameparser](https://pypi.python.org/pypi/nameparser) for `key_people` field
#
# Also notice that even with this method there are problematic non-company subjects like: [Logo of the BBC](https://en.wikipedia.org/wiki/Logo_of_the_BBC) but then usually the name in infobox fits: British Broadcasting Corporation. However, it would be more problematic to create a link list according to the `name` in the company infobox. Multiple companies with the same name will be addressed later.

# %%
def get_temp_val(temp, k):
    """Check if the parameter exists in the infobox template"""

    try:
        param = temp.get(k)
        return param
    except ValueError:
        # try alternative keys (template not always consistent)
        if k == 'founded':
            return get_temp_val(temp, 'foundation')
        if k == 'founders':
            return get_temp_val(temp, 'founder')
        if 'location' in k and 'hq_' not in k:
            return get_temp_val(temp, 'hq_' + k)
    # key not found in template
    return None

# %%
def parse_employee_nr(input_val, c_name):
    """
    Parse a proper number out of the various inputs
    Case possibilities tested:
    
    s_list = [
        '15-50',
        '~300+',
        'circa 40',
        '9,985(Dec 2011)',
        'over 10,000 in 10 countries',
        'Five',
        'over 1 million',
        '10.000',
        'Part of Popular, Inc., which has 8,000 employees'
    ]

    for s in s_list:
        print parse_employee_nr(s, 'test')
    """
    
    # match the first number, dot or comma separation optional
    m = re.search(r'[0-9]+([,\.][0-9]+)?', unicode(input_val))
    if m:
        try:
            # replace , and conert to int
            return int(m.group().replace(',', '').replace('.', ''))
        except ValueError:
            print "WARN: Failed conversion of:{0} (company: {1})".format(
                input_val, c_name)
    return None

# %%
def parse_people_name(names):
    """
    Tim Cook (CEO) becomes 
    {u'last': u'Cook', u'suffix': u'', u'title': u'', u'middle': u'', u'nickname': u'CEO', u'first': u'Tim'}
    """

    if isinstance(names, list):
        # if n makes sure no empty list value
        return [HumanName(unicode(n)).as_dict() for n in names if n]
    elif names:
        # parse the single name and return as list
        return [HumanName(unicode(names)).as_dict()]
    return names

# %%
def parse_date(date):
    """
    Parse a date, also handles complicated cases and other languages like:
    Martes 21 de Octubre de 201 -> datetime.datetime(2014, 10, 21, 0, 0) [Spanish (Tuesday 21 October 2014)]
    """

    if date: 
        # if only the year is given returns todays date in that year
        date_parsed = dateparser.parse(date, settings={
            'PREFER_DATES_FROM': 'past',
            'DATE_ORDER': 'YMD'})
        # try to extract the first number with 4 digits from 18XX-20XX
        if not date_parsed:
            m = re.search(r'(18|19|20\d{2})', date)
            if m:
                return dateparser.parse(m.group())
        else:
            return date_parsed
    # return null time: 00:00:00
    return datetime.time()

# %%
def parse_wiki_raw(param, k, c_name):
    """Extract the information on the raw value without notable wiki markup"""

    # strip_code does not work properly for [[File:: https://github.com/earwig/mwparserfromhell/issues/136
    if k == 'logo':
        split_val = unicode(param.value).strip().split('|')
        # first value always image link
        if split_val[0]:
            # avoid bs4 warning
            val = split_val[0]
            if not re.match(r'http://.*', val):
                val = bs4.BeautifulSoup(val, 'lxml').text
            val = val.replace('[[', '').replace(' ', '_')
            if val:
                # can be written without [[File: or [[Image:
                if 'File:' in val or 'Image:' in val:
                    pass
                else:
                    val = 'File:' + val
                # submit raw version too, also links can differ
                return {
                    'wiki_commons_link': 'https://commons.wikimedia.org/wiki/' + val,
                    'wiki_file_link': wiki_base + '/wiki/' + val,
                    'wiki_raw_code': param.value.strip()}
    
    # fields can contain break separations, e.g. Microsoft: 
    # [[John W. Thompson]] <small> ([[Chairman]]) </small> <br /> [[Satya Nadella]]
    if '<br' in param.value:
        # replace the HTML breaks with real newline
        param.value = re.sub(r'<br>|<br ?/>', '\n', unicode(param.value))
        # get rid of media wiki markup and split into parts
        val = unicode(param.value.strip_code())
        # strip code does not always remove HTML tags
        val = bs4.BeautifulSoup(val, 'lxml').text
        items = val.split('\n')
        if k == 'key_people' or k == 'founders':
            return parse_people_name(items)
        if k == 'num_employees':
            return parse_employee_nr(items[-1], c_name)
        return items

    # only assuming one value when no breaks, too vague to use other seperators than <br>
    val = param.value.strip_code()

    # avoid bs4 warning when parsing HTML link
    if k != 'homepage':
        # properly remove HTML remains
        val = bs4.BeautifulSoup(val, 'lxml').text
    if k == 'homepage':
        # there are cases like: [http://www.absn.tv/ ABS] for homepage/website that don't match URL template
        match_link = re.search(r'\[(.+)\]', unicode(param.value))
        if match_link:
            val = match_link.group(1)
        # if whitespaces, then still no valid link
        if ' ' in val:
            # HTML needs to be ignored, e.g.: <!-- {{URL|www.example.com}} --> (also strips text)
            rem_html = bs4.BeautifulSoup(val, 'lxml').text
            if rem_html:
                return param.value.strip().split(' ')[0].replace('[', '')
            else:
                return None
    if k == 'num_employees':
        return parse_employee_nr(val, c_name)

    # make sure string didn't just contain whitespaces
    if val:
        return unicode(val).strip()
    # it can be that the field exists but is empty
    return None

# %%
def parse_wiki_template(param, k, c_name):
    """Extract further information if templates in key value"""

    for tem in param.value.filter_templates():
        # handle dates, URL and list
        if k == 'founded' or k == 'defunct':
            if tem.name.matches(('start date and age', 'start date', 'end date')):
                # valid date: {{Start date and age|2003|January|5|df=1}}
                date = [unicode(p) for p in tem.params if '=' not in unicode(p)]
                # concatenate the date and give to dateparser
                if not date:
                    return datetime.time()
                return parse_date("/".join(date))
            else:
                return datetime.time()
        elif k == 'homepage' and tem.name.matches(('url', 'URL')):
            if tem.params:
                try:
                    url = tem.get(1)
                except ValueError:
                    print "WARN: Could not get first element in params:", tem.params
                    return unicode(tem.params[0]).strip()
                return unicode(url).strip()
        elif tem.name.matches('unbulleted list'):
            # replace wiki link markup and remove extra citations etc.
            items = [unicode(p.value.strip_code().strip()) for p in tem.params]
            if k == 'key_people' or k == 'founders':
                return parse_people_name(items)
            if k == 'num_employees':
                # e.g.: {{unbulleted list|{{loss}}0 (7 February 2013)|850 (6 February 2013)}}
                # usually last value contains current number
                return parse_employee_nr(items[-1], c_name)
            return items
        elif tem.name.matches(('plainlist', 'flatlist')):
            if tem.params:
                items = unicode(tem.params[0].value.strip_code().strip()).split('\n')
                if k == 'key_people' or k == 'founders':
                    # use nameparse to exclude titles, etc.
                    return parse_people_name(items)
                return items
        elif 'formatnum' in tem.name and k == 'num_employees':
            # {{formatnum:1234}}, colon not detected by mwparser
            m = re.search(r'formatnum:(.*)', unicode(tem.name))
            if m:
                return parse_employee_nr(m.group(1), c_name)
        elif 'nowrap' in tem.name or 'nihongo' in tem.name or 'small' in tem.name:
            if k == 'name':
                return unicode(tem.params)

    # if the template didn't match anything parse raw text
    return parse_wiki_raw(param, k, c_name)

# %%
def parse_wiki_text(company):
    """Parse MediaWiki markup to extract detailed information"""

    # remove ref tags, bs4 adds unwanted body tags, thus regex better
    wiki_raw = re.sub(r'<ref.+?</ref>|<ref>.+?</ref>', '', company['wiki_raw'])
    
    # sometimes name can not be attached when parsing
    company['name'] = company['wiki_name']

    comp_infobox = dict()
    # parse the wikimedia syntax
    # style can be ignored: https://github.com/earwig/mwparserfromhell/issues/115
    code = mwparserfromhell.parse(wiki_raw, skip_style_tags=True)
    # filter for the infobox
    # If matches is a regex, the flags passed to re.search() are re.IGNORECASE ...
    c_template = code.filter_templates(
        matches=r'infobox company|infobox_company|company infobox|infobox dot-com company')
    if not c_template:
        # try regex approach for any infobox, if nothing found above
        match = re.search(r'({{infobox.*\n(?:\|.*\n|\*.*\n)+}})', wiki_raw, re.IGNORECASE)
        if match:
            infobox_temp = mwparserfromhell.parse(
                match.group(1), skip_style_tags=True).filter_templates()
            if infobox_temp:
                infobox_temp = infobox_temp[0]
            else:
                print "WARN: No parsable company infobox template for:", company['wiki_name']
                return comp_infobox
        else:
            print "WARN: No company infobox found for:", company['wiki_name']
            return comp_infobox
    else:
        infobox_temp = c_template[0]

    # find values for each key
    key_list = ['name', 'logo', 'type', 'founders', 'key_people', 'industry', 'founded', 'location', \
                'location_city', 'location_country', 'defunct', 'subsid', \
                'products', 'num_employees', 'parent', 'homepage']
    for k in key_list:
        param = get_temp_val(infobox_temp, k)
        if param:
            val = parse_wiki_template(param, k, company['wiki_name'])
            if val:
                comp_infobox[k] = val

    return comp_infobox

# %%
def get_c_info(company, repeat=None):
    """Get links and the wikitext which is used to extract key information about the company"""

    # reparse old text if text and links already there
    if repeat or 'wiki_raw' not in company or 'all_links' not in company:   
        # concatenate URL from previously set values
        link_url = '{0}{1}?&{2}&{3}&{4}&pageid={5}'.format(
            wiki_base, wiki_api, action, properties, dat_format, company['wiki_page_id'])

        # get JSON and check for validity
        c_content = get_json_from_url(link_url)
        if not c_content or 'parse' not in c_content:
            print 'WARN: No parsable content on: {0} under page {1} (id: {2})'.format(
                link_url, company['wiki_name'], company['wiki_page_id'])
            company['is_company'] = False
            return company

        # save new fields
        company['wiki_api_url'] = unicode(link_url)
        company['all_links'] = [x['*'] for x in c_content['parse']['links'] if x['ns'] == 0]

        # original wikitext to parse {{Infobox company
        company['wiki_raw'] = c_content['parse']['wikitext']['*']
    
    # extract company info from box, only on wiki text not HTML
    company_infobox = parse_wiki_text(company)
    company.update(company_infobox)
    company['is_company'] = True
    
    # keep non-company nodes but mark
    if not company_infobox:
        company['is_company'] = False
    return company

# %% [markdown]
# Here is an excerpt of the company infobox of the Google page:
# ```
# {{Infobox company
# | name          = Google Inc.
# | logo          = Google 2015 logo.svg
# | logo_size     = 225
# | logo_alt = The letters of "Google" are each purely colored (from left to right) with blue, red, yellow, blue, green, and red.
# | logo_caption  =
# | image         = Googleplex-Patio-Aug-2014.JPG
# | image_size    = 250
# | image_caption = The [[Googleplex]] headquarters in 2014
# | type          = [[Subsidiary]]
# | area_served      = Worldwide
# | key_people       = [[Sundar Pichai]] ([[CEO]])
# | industry      = {{plainlist|
# * [[Internet]]
# * [[Software|Computer software]]
# * [[Computer hardware]]
# }}
# | products         = [[List of Google products]]
# | num_employees    = 57,100 (Q2 2015)<ref>{{cite web|url=http://www.businessinsider.com/google-has-57000-employees-2015-7|title=Google's hiring may have slowed, but it's still adding thousands of new employees|publisher=[[Business Insider]]}}</ref>
# | parent           = [[Alphabet Inc.]]<br><small>(2015–present)</small>
# | subsid           = [[List of mergers and acquisitions by Alphabet|List of subsidiaries]]
# | footnotes        = <ref>{{cite web|url=http://investor.google.com/proxy.html|title=Google Inc. Annual Reports |date=July 28, 2014|publisher=Google Inc.|accessdate=August 29, 2014}}</ref>
# | homepage         = {{URL|https://www.google.com}}
# | foundation       = {{start date and age|1998|09|4}}<!-- Do not change this to September 27: every year they celebrate at a different date, but the company was founded on September 4. Also, do not add that it is x years old as Google is, obviously, not a human and therefore the age is not very relevant. --><br />[[Menlo Park, California]]<ref>{{cite web|title=Company|url=https://www.google.com/intl/en/about/company/|publisher=Google|accessdate=January 16, 2015}}</ref><ref>{{cite web|last=Claburn|first=Thomas|title=Google Founded By Sergey Brin, Larry Page... And Hubert Chang?!?|url=http://www.informationweek.com/news/internet/google/210603678|publisher=InformationWeek|accessdate=August 31, 2011}}</ref>
# | founders         = {{plainlist|
# * [[Larry Page]]
# * [[Sergey Brin]]
# }}
# | location_city    = [[Googleplex]], [[Mountain View, California|Mountain View]], [[California]]
# | location_country = U.S.<ref>{{cite web|url=https://www.google.com/about/jobs/locations/ |title=Locations&nbsp;— Google Jobs |publisher=Google.com |accessdate=September 27, 2013}}</ref>
# }}
# ```
#
# And the parsed result:
# ```
#  'founded': datetime.datetime(1998, 9, 4, 0, 0),
#  'homepage': u'https://www.google.com',
#  'industry': [u'Internet', u' Computer software', u' Computer hardware'],
#  'is_company': True,
#  'key_people': u'Sundar Pichai (CEO)',
#  'location_city': u'Googleplex, Mountain View, California',
#  'location_country': u'U.S.',
#  'logo': {'wiki_commons_link': u'https://commons.wikimedia.org/wiki/File:Google_2015_logo.svg',
#           'wiki_file_link': u'https://en.wikipedia.org/wiki/File:Google_2015_logo.svg',
#           'wiki_raw_code': u'Google 2015 logo.svg'},
#  'name': u'Google Inc.',
#  'name_url_quoted': 'Google',
#  'num_employees': 57100,
#  'parent': [u'Alphabet Inc.', u'(2015\u2013present)'],
#  'products': u'List of Google products',
#  'subsid': u'List of subsidiaries',
#  'type': u'Subsidiary',
# ```
#
# Unfortunately not all fields are always detected properly but that issue is adressed in the cleaning part.

# %% [markdown]
# For each page links and the wikitext is extracted and saved along with the data fields from the template. Example queries to extract the information from a Wikipedia page:
# * https://en.wikipedia.org/w/api.php?action=parse&page=Audi&prop=links|wikitext
# * https://en.wikipedia.org/w/api.php?action=parse&page=AT%26T&prop=links|wikitext
# * https://en.wikipedia.org/w/api.php?&action=parse&format=json&prop=links|wikitext&pageid=17555269

# %%
# change the main URL parameters
action = u'action=parse'
dat_format = u'format=json'
properties = u'prop=links|wikitext'

# other: 'Audi', 'Apple Inc.', 'Microsoft'
company = 'Candover Investments'

print "Excerpt of", company, "dict structure:"
pprint(
    get_c_info(merged_companies[company], repeat=True))
# Out:
# Excerpt of Candover Investments dict structure:
# {'all_links': [u'Candover',
#                u'3i',
#                u'ABN AMRO',
#                u'Advent International',
#                u'AlpInvest Partners',
#                u'American Capital Strategies',
#                u'Angel investor',
#                u'Apax Partners',
#                u'Apollo Global Management',
#                u'Ares Management',
#                u'Assets under management',
#                u'BC Partners',
#                u'Bain Capital',
#                u'Berkshire Partners',
#                u'Bridgepoint Capital',
#                u'Business Development Company',
#                u'Business incubator',
#                u'Buyout',
#                u'Buy\u2013sell agreement',
#                u'CCMP Capital',
#                u'CVC Capital Partners',
#                u'Capital call',
#                u'Capital commitment',
#                u'Capital structure',
#                u'Capitalization table',
#                u'Carlyle Group',
#                u'Carried interest',
#                u'Cerberus Capital Management',
#                u'Chair (official)',
#                u'Charterhouse Capital Partners',
#                u'Cinven',
#                u'Clayton, Dubilier & Rice',
#                u'Commercial bank',
#                u'Corporate venture capital',
#                u'Crowdfunding',
#                u'Distribution waterfall',
#                u'Dividend recapitalization',
#                u'Divisional buyout',
#                u'Doughty Hanson & Co',
#                u'EQT Partners',
#                u'Early history of private equity',
#                u'Earnings before interest, taxes, depreciation and amortization',
#                u'Earnings before interest and taxes',
#                u'EnCap Investments',
#                u'Envy ratio',
#                u'Equity co-investment',
#                u'Family office',
#                u'Financial endowment',
#                u'Financial sponsor',
#                u'First Reserve Corporation',
#                u'Fortress Investment Group',
#                u'Fund of funds',
#                u'GTCR',
#                u'General Atlantic',
#                u'Goldman Sachs Capital Partners',
#                u'Growth capital',
#                u'H.I.G. Capital',
#                u'Hellman & Friedman',
#                u'High-net-worth individual',
#                u'High-yield debt',
#                u'History of private equity and venture capital',
#                u'Initial public offering',
#                u'Institutional investor',
#                u'Insurance',
#                u'Internal rate of return',
#                u'Investment',
#                u'Investment banking',
#                u'JRK Property Holdings',
#                u'Kohlberg Kravis Roberts',
#                u'Leonard Green & Partners',
#                u'Leverage (finance)',
#                u'Leveraged buyout',
#                u'Leveraged recapitalization',
#                u'Limited liability company',
#                u'Limited partnership',
#                u'Liquidation preference',
#                u'List of private equity firms',
#                u'London',
#                u'Madison Dearborn Partners',
#                u'Madrid',
#                u'Management buyout',
#                u'Management fee',
#                u'Merchant bank',
#                u'Mergers and acquisitions',
#                u'Mezzanine capital',
#                u'Milan',
#                u'Net income',
#                u'Nordic Capital',
#                u'Oak Investment Partners',
#                u'Oaktree Capital Management',
#                u'Onex Corporation',
#                u"Ontario Teachers' Pension Plan",
#                u'PAI Partners',
#                u'Pacific Equity Partners',
#                u'Paris',
#                u'Pension fund',
#                u'Permira',
#                u'Pledge fund',
#                u'Post-money valuation',
#                u'Pound sterling',
#                u'Pre-money valuation',
#                u'Private equity',
#                u'Private equity fund',
#                u'Private equity in the 1980s',
#                u'Private equity in the 1990s',
#                u'Private equity in the 2000s',
#                u'Private equity secondary market',
#                u'Private foundation',
#                u'Private investment in public equity',
#                u'Providence Equity Partners',
#                u'Public Market Equivalent',
#                u'Publicly traded private equity',
#                u'Seed money',
#                u'Sentinel Capital Partners',
#                u'Silver Lake Partners',
#                u'Sovereign wealth fund',
#                u'Startup company',
#                u'Subsidiary',
#                u'Summit Partners',
#                u'Sun Capital Partners',
#                u'TA Associates',
#                u'TPG Capital',
#                u'Taxation of private equity and hedge funds',
#                u'Terra Firma Capital Partners',
#                u'The Blackstone Group',
#                u'Thomas H. Lee Partners',
#                u'Trilantic Capital Partners',
#                u'Trust law',
#                u'Types of business entity',
#                u'Undercapitalization',
#                u'United Kingdom',
#                u'Venture capital',
#                u'Venture capital financing',
#                u'Venture capital trust',
#                u'Venture debt',
#                u'Venture round',
#                u'Vintage year',
#                u'Warburg Pincus',
#                u'Welsh, Carson, Anderson & Stowe'],
#  'countries': None,
#  'defunct': None,
#  'founded': u'1980',
#  'founders': None,
#  'homepage': u'http://www.candover.com',
#  'industry': u'Private equity',
#  'is_company': True,
#  'key_people': u'Richard Stone, Chairman',
#  'links': set([u'3i',
#                u'ABN AMRO',
#                u'Advent International',
#                u'AlpInvest Partners',
#                u'Apax Partners',
#                u'Apollo Global Management',
#                u'Ares Management',
#                u'BC Partners',
#                u'Bain Capital',
#                u'Berkshire Partners',
#                u'Bridgepoint Capital',
#                u'CCMP Capital',
#                u'CVC Capital Partners',
#                u'Cerberus Capital Management',
#                u'Charterhouse Capital Partners',
#                u'Cinven',
#                u'Clayton, Dubilier & Rice',
#                u'Doughty Hanson & Co',
#                u'EQT Partners',
#                u'EnCap Investments',
#                u'First Reserve Corporation',
#                u'Fortress Investment Group',
#                u'GTCR',
#                u'General Atlantic',
#                u'Goldman Sachs Capital Partners',
#                u'H.I.G. Capital',
#                u'Hellman & Friedman',
#                u'JRK Property Holdings',
#                u'Kohlberg Kravis Roberts',
#                u'Leonard Green & Partners',
#                u'Madison Dearborn Partners',
#                u'Nordic Capital',
#                u'Oak Investment Partners',
#                u'Oaktree Capital Management',
#                u'Onex Corporation',
#                u"Ontario Teachers' Pension Plan",
#                u'PAI Partners',
#                u'Pacific Equity Partners',
#                u'Permira',
#                u'Providence Equity Partners',
#                u'Sentinel Capital Partners',
#                u'Silver Lake Partners',
#                u'Summit Partners',
#                u'Sun Capital Partners',
#                u'TA Associates',
#                u'TPG Capital',
#                u'Terra Firma Capital Partners',
#                u'The Blackstone Group',
#                u'Thomas H. Lee Partners',
#                u'Trilantic Capital Partners',
#                u'Warburg Pincus',
#                u'Welsh, Carson, Anderson & Stowe']),
#  'location': u'London, United Kingdom',
#  'location_city': None,
#  'location_country': None,
#  'location_geo': u'London, Greater London, England, UK',
#  'location_gps': (51.5073219, -0.1276473),
#  'logo': {'wiki_commons_link': u'https://commons.wikimedia.org/wiki/Image:Candover_logo.png]]',
#           'wiki_file_link': u'https://en.wikipedia.org/wiki/Image:Candover_logo.png]]',
#           'wiki_raw_code': u'[[Image:Candover logo.png]]'},
#  'name': u'Candover Investments plc.',
#  'name_url_quoted': u'Candover+Investments',
#  'num_employees': 40,
#  'parent': None,
#  'products': u'private equity funds',
#  'subsid': None,
#  'type': u'Subsidiary',
#  'wiki_api_url': u'https://en.wikipedia.org/w/api.php?&action=parse&prop=links|wikitext&format=json&pageid=1116643',
#  'wiki_name': u'Candover Investments',
#  'wiki_page_id': 1116643,
#  'wiki_raw': u"{{Infobox company\n| name   = Candover Investments plc.\n| logo   = [[Image:Candover logo.png]] \n| type   = [[Subsidiary]] \n| traded_as      = \n| foundation     = 1980 \n| location       = [[London]], [[United Kingdom]] \n| industry       = [[Private equity]] \n| products       = [[private equity fund]]s \n| key_people     = Richard Stone, [[Chair (official)|Chairman]]\n| assets         =  \n| revenue          = [[Pound sterling|$]]41.2 million (2008)\n| operating_income = [[Pound sterling|$]]8.0 million (2008)\n| net_income       = [[Pound sterling|$]](212.6) million (2008)\n| homepage       = {{URL|http://www.candover.com}}\n| num_employees  = circa 40\n}}\n\n'''Candover Investments plc.''' is a [[United Kingdom|British]]-based, [[private equity]] firm, specialising in arranging and leading large [[buyout]]s and buyins. Candover Investments is structured as an [[investment]] [[Trust law|trust]]. On 31 August 2010 Candover announced that it would unwind its assets and return money to shareholders and investors.<ref>[http://www.economist.com/node/16944046]</ref>\n\nAt its peak Candover had offices in [[London]], [[Paris]], [[Madrid]] and [[Milan]]. Since 1980, Candover raised nine funds with total capital commitments of more than $8.7 billion.<ref>[http://www.candover.com/english/about-candover/funds-perform Candover fund performance]</ref>\n\n==References==\n{{reflist}}\n\n==External links==\n* [http://www.candoverinvestments.com Official Website]\n\n{{Private equity and venture capital}}\n{{Largest private equity firms}}\n\n\n[[Category:Investment trusts of the United Kingdom]]\n[[Category:Companies established in 1980]]\n[[Category:Private equity firms of the United Kingdom]]",
#  'wiki_url': u'https://en.wikipedia.org/w/index.php?title=Candover+Investments'}

# %% [markdown]
# The function `get_c_info()` will now be apllied for each company in a loop.

# %%
def scrape_companies(companies, repeat=None):
    """Gets two dictionaries and parses those who don't have same content"""

    # scrape links and extra information of all companies, call with progress-bar
    for company in tqdm_notebook(companies, desc='Companies'):
        # don't repeat if pickle file already contains data
        if not repeat and 'is_company' in companies[company] and \
            companies[company]['is_company']:
                continue
        # extract any company information
        companies[company] = get_c_info(companies[company])
    return companies

# %% [markdown]
# A file containing previous scraped data is loaded. All companies that intersect with the previous data are updated to the old data. For complete reparsing that step can be skipped.

# %%
# get company file from extraction 1
com_dat_pickle = dict()
if os.path.isfile(ex1_fdat):
    with open(ex1_fdat, 'rb') as f:
        com_dat_pickle = pickle.load(f)
        # update previously fetched data to same keys
        companies.update(com_dat_pickle)

# %% [markdown]
# Each query and parsing with regular expressions takes some time for the approximately 57.000 companies. A rough estimate of 5 hours crawling time was made. There are sometimes warning when bare URL strings are parsed with the HTML parser [Beautiful Soup](https://www.crummy.com/software/BeautifulSoup/) but the warning can be ignored as it is just used to strip HTML tags, sometimes fields contain a bare URL for instance at the `logo` field.

# %%
# %%time
# 500 companies take about 2-3 mins
# for 64k that is approx. 128 cykles which should total maximum 5 hours crawl time
# ((64000 / 500) * 2) / 60

# crawl for all companies that were not prcoessed yet and cotain no or a false 'is_company' flag
companies = scrape_companies(companies)
# Out:
# WARN: No company infobox found for: McDonald's legal cases
# WARN: No company infobox found for: History of Burger King
# WARN: No company infobox found for: KFC advertising
# WARN: No company infobox found for: Burger King products
# WARN: No company infobox found for: Burger King legal issues
# WARN: No company infobox found for: History of McDonald's
# WARN: No company infobox found for: History of KFC
# WARN: No company infobox found for: McDonald's advertising
# WARN: No company infobox found for: Burger King advertising
# WARN: No company infobox found for: BEHR Group Holdings LLP
# WARN: No company infobox found for: Fondo Común
# WARN: No company infobox found for: List of Burger King ad programs
# WARN: No company infobox found for: List of McDonald's ad programs
# WARN: No parsable content on: https://en.wikipedia.org/w/api.php?&action=parse&prop=links|wikitext&format=json&pageid=52437332 under page ONMI audio (id: 52437332)
# WARN: No company infobox found for: List of McDonald's products
#
# CPU times: user 3.79 s, sys: 124 ms, total: 3.92 s
# Wall time: 24.1 s

# %%
# store company data in one binary file
with open(ex1_fdat, 'wb') as f:
    pickle.dump(companies, f)

# %% [markdown]
# ### 1.2. Additional Extraction
#
# Additional extraction was conducted in order to get more data. However, it is very hard to verify if page links are actual companies. Two alternate data sources where used:
#
# 1. [Companies portal](https://en.wikipedia.org/wiki/Portal:Companies) which aims to collect data and interesting facts about companies. They provide a [table](https://tools.wmflabs.org/enwp10/cgi-bin/list2.fcgi?run=yes&projecta=Company&limit=1000) with approximately 48.000 companies. Nevertheless, this table also contains [stubs](https://en.wikipedia.org/wiki/Wikipedia:Stub), many companies that actually have the "Infobox company" template and other irrelevant/non-companies.
# 2. Another approach was to use a [list of companies by country](https://en.wikipedia.org/wiki/Category:Lists_of_companies_by_country). But also this list had some shortcomings with regards to identify what is a company link. although many of the pages have either bullet lists or tables some sections contain non-companies in the enumerations. For example the [list of companies in Ireland](https://en.wikipedia.org/wiki/List_of_companies_of_Ireland) has a section about company types i.e. [private company](https://en.wikipedia.org/wiki/Private_company_limited_by_shares). These kind of subjects have a lot of links but a hard to detect.
#
# The answer to why additional data is even necessary is that some prominent companies like [Yahoo](https://en.wikipedia.org/wiki/Yahoo!) might be missing because it has another used template called "Infobox dot-com company". Obviously it is hard to keep track of all these different cases.
#
# With these shortcomings the idea was to verify a page title over a third party source called [OpenCorporates](https://opencorporates.com/) with over 115M verified companies from official company registers. However, their API has a very strict API restriction of 500 lookups per month. They also had the API possibility to retrieve [network data](https://opencorporates.com/info/networks) about subsidiaries of companies. Unfortunately a more sophisticated API access was denied although 2 mails have been exchanged.
#
# Instead the Copenhagen based company [WikiBusiness](http://wikibusiness.org/) was more interested in helping us realize our idea.
#
# The two approaches of extracting extra data have been documented in two separate notebooks:
# * [Data extration part 2](extraction2.ipynb)
# * [Data extration part 3](extraction3.ipynb)

# %% [markdown]
# ### 1.3. Data Merging
#
# In this part all the data will be merged into one dictionary. With this set of companies the links that a company has to all other companies can be collected in a link set.

# %%
# delete old objects to save some memory
del companies, com_dat_pickle
gc.collect()
# Out:
# 0

# %%
# load all pickle files that contain separate company dictionaries
extraction1, extraction2, extraction3 = dict(), dict(), dict()
if os.path.isfile(ex1_fdat):
    with open(ex1_fdat, 'rb') as f:
        extraction1 = pickle.load(f)
if os.path.isfile(ex2_fdat):
    with open(ex2_fdat, 'rb') as f:
        extraction2 = pickle.load(f)
if os.path.isfile(ex3_fdat):
    with open(ex3_fdat, 'rb') as f:
        extraction3 = pickle.load(f)

# %%
def create_link_set(extr_companies):
    """If valid company then add to set of all companies."""

    all_c = set()
    for c in extr_companies:
        if 'is_company' in extr_companies[c] and extr_companies[c]['is_company']:
            all_c.add(c)
    return all_c

# %%
# create unique set of all companies
ex1_links = create_link_set(extraction1)
ex2_links = create_link_set(extraction2)
ex3_links = create_link_set(extraction3)
# union of sets
all_companies = ex1_links | ex2_links | ex3_links

print "Number of all companies and valid companies from extraction 1:"
print len(extraction1), len(ex1_links)

print "Number of all companies and valid companies from extraction 2:"
print len(extraction2), len(ex2_links)

print "Number of all companies and valid companies from extraction 3:"
print len(extraction3), len(ex3_links)

print "\nTotal of valid companies from all extractions:"
print len(all_companies)
# Out:
# Number of all companies and valid companies from extraction 1:
# 56962 56898
# Number of all companies and valid companies from extraction 2:
# 0 0
# Number of all companies and valid companies from extraction 3:
# 0 0
#
# Total of valid companies from all extractions:
# 56898

# %% [markdown]
# Now each individual set will be merged.

# %%
# load the old data
merged_companies = dict()
if os.path.isfile(merged):
    with open(merged, 'rb') as f:
        merged_companies = pickle.load(f)

# iterate and merge each extracted data
dicts = [extraction1, extraction2, extraction3]
for d in dicts:
    for c_name, comp in d.iteritems():
        if comp['is_company']:
            # list of links intersected with list containing all companies
            comp['links'] = all_companies.intersection(comp['all_links'])
            # on first iteration set merged_companies
            if c_name not in merged_companies:
                merged_companies[c_name] = comp
                continue
            # valid values set in extraction 1 are eventually overwritten by extraction 2 or 3
            for k, v in comp.iteritems():
                # if value not None
                if v:
                    comp[k] = v
            # set additional keys and values to merged companies
            merged_companies[c_name].update(comp)

print "Final amount of companies with link lists:", len(merged_companies)
# Out:
# Final amount of companies with link lists: 56898

# %%
# free up some memory
del extraction1, extraction2, extraction3, all_companies
gc.collect()
# Out:
# 0

# %% [markdown]
# ### 1.4. Adding Geo Location
#
# Geo location is added in order to make some plots and illustrations according to the origin of the company. Mainly [OpenStreetMap Nominatim](https://wiki.openstreetmap.org/wiki/Nominatim) is used to resolve places strings to GPS coordinates. Alternatively the [Google Geocoding API (V3)](https://developers.google.com/maps/documentation/geocoding/start) can be used with an API key. An OpenSource alternative named [Photon](https://photon.komoot.de/) seems to be buggy in the current version of the Python library [geopy](https://pypi.python.org/pypi/geopy/1.11.0) that was used to crawl the data.

# %%
def get_location(comp, geolocators, fields_to_check=None):
    """Try to retrieve address and GPS using different geolocators."""
    
    # location variables
    loc_str = None
    loc_dict = {
        'location_geo': loc_str,
        'location_gps': (None, None)}
    if 'location_geo' in comp and 'location_gps' in comp:
        # if not None
        if comp['location_geo'] and comp['location_gps']:
            return {
                'location_geo': comp['location_geo'],
                'location_gps': comp['location_gps']}
    
    # check from first to last element for location, order important 
    # location_city usually headquarters
    if not fields_to_check:
        fields_to_check = ['location_city', 'location', 'location_country']
    for f in fields_to_check:
        # continue if field not in company
        if f not in comp:
            # delete from checkable fields
            continue
        # check if value unicode or list
        val = comp[f]
        if val:
            loc_str = val
            # join lists like [u'9th Floor, Equity Centre', u' Hospital Road, Upper Hill', u'Nairobi, Kenya']
            if isinstance(val, list):
                loc_str = " ".join(val)
        
        # fields are ordered, highest with value wins
        if loc_str:
            fields_to_check.remove(f)
            break
    # return if none of the fields set
    if not loc_str:
        return loc_dict

    # avoid request by looking into already processed
    if loc_str in all_locations:
        return all_locations[loc_str]

    # try to validate and get coordinates with geopy
    for g in geolocators:
        try:
            loc = g.geocode(loc_str, timeout=10, exactly_one=True)
            if 'nominatim' in g.domain:
                # max 1 request per second, http://wiki.openstreetmap.org/wiki/Nominatim_usage_policy
                time.sleep(1)
            if loc:
                loc_dict = {
                    'location_geo': loc.address,
                    'location_gps': (loc.latitude, loc.longitude)}
                all_locations[loc_str] = loc_dict
                return loc_dict            
        # IndexError seems when Photon returns no result
        except (GeocoderServiceError, IndexError):
            print "HTML, Python or API error on", comp['wiki_name'], "checking: ", loc_str

    # if more strings can be checked
    if fields_to_check:
        return get_location(comp, geolocators, fields_to_check)
    else:
        return loc_dict

# %% [markdown]
# Crawling geolocation will also take some time especially because there are [limitations](http://wiki.openstreetmap.org/wiki/Nominatim_usage_policy).

# %%
### initialize the different geolocator APIs
# https://photon.komoot.de/ - OpenSource
g_photon = geopy.geocoders.Photon()
# http://nominatim.openstreetmap.org/search.php?q=
g_osm = geopy.geocoders.Nominatim(
    user_agent='Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:50.0) Gecko/20100101 Firefox/50.0')
# should be only with API key otherwise GeocoderQuotaExceeded
g_google = geopy.geocoders.GoogleV3()
#geolocators = [g_google, g_photon, g_osm]
geolocators = [g_osm]

# save looked up locations to not make API request
all_locations = dict()
for c in tqdm_notebook(merged_companies, desc='Geolocation'):    
    processed_loc = get_location(merged_companies[c], geolocators)
    merged_companies[c].update(processed_loc)
# Out:
# HTML, Python or API error on Claro Americas checking:  Flagship headquarters  Brazil   Local headquarters   Argentina   Chile   Colombia   Costa Rica   Dominican Republic  Ecuador  El Salvador  Guatemala  Honduras    Nicaragua  Panama Paraguay  Peru   Uruguay
# HTML, Python or API error on Phreesia checking:  432 Park Ave South New York, New York, 10016 U.S.
# HTML, Python or API error on Ainol checking:  Lijincheng Industry Park, Shenzhen, Guangdong
# HTML, Python or API error on BINDER (company) checking:  Tuttlingen
# HTML, Python or API error on Holborn Assets LLC checking:  Dubaihttp://www.informazione.it/c/D3C67367-9506-403B-BC4C-EB3C3B5845F5/Holborn-Assets-International-Financial-Planner-to-Educate-South-Africans-on-Offshore-Trust-and-Tax-Planninghttp://www.indiainfoline.com/prnewswire?doc=201607280719PR_NEWS_EURO_ND__enUK201607281843_Public&dir=2http://goevnts.com/pr-landing?rkey=20160728enUK201607281843_Public&filter=4444http://globalnewsweek.com/prnewswire/index.html?doc=201607280719PR_NEWS_EURO_ND__enUK201607281843_Public&dir=2http://ezerin.com/pr-newswire/?doc=201607280719PR_NEWS_EURO_ND__enUK201607281843_Public&dir=2http://europeanbusinessexpress.com/business-newswire/?doc=201607280719PR_NEWS_EURO_ND__enUK201607281843_Public&dir=2http://www.emsf-lisboa.pt/news.php?news=PRNE_English/201607280719PR_NEWS_EURO_ND__enUK201607281843_Public.xml&ling=1http://www.emarketsdaily.com/newsroom/?doc=201607280719PR_NEWS_EURO_ND__enUK201607281843_Public&dir=2http://www.creditmarket.co.uk/latest-finance-news/?doc=201607280719PR_NEWS_EURO_ND__enUK201607281843_Public&dir=2Link
# HTML, Python or API error on BioTek checking:  Winooski, VT, U.S.Staff writer,
# Profile: BioTek Instruments ,
# ''Vermont Economic Development Authority'', Jan 1 2008, quote=The elder Alpert, a physiology professor at the University of Vermont, had started the business in a colleague's basement and had guided it to success as a manufacturer of biomedical instruments that test the safety and reliability of machinery used in hospitals...,
# Retrieved 2010-01-29

# %% [markdown]
# ### 1.5. Data Cleaning
#
# Each field should follow a specific layout and each company should contain all fields even though the might be `None`. As an example the main dictonary `companies` contains a key `Google` which is a dictonary itself and contains fields like `key_people`. Furthermore `key_people` should be a list of dictonaries where each dictonary contains the name split in fields like `first_name`, `last_name` and so on.

# %%
# specify the type for each field
types = {
    # when first link is crawled
    'wiki_name': unicode,
    'wiki_url': unicode,
    'name_url_quoted': unicode,

    # when WIKI API is crawled
    'wiki_page_id': int,
    'wiki_api_url': unicode,
    'all_links': list,
    'links': set,
    'is_company': bool,
    'wiki_raw': unicode,

    # added only when Infobox company exists or fields from OpenCorporates
    # not all fields always exist, they are NaN in the resulting DataFrame
    'name': unicode,
    'type': unicode,
    'founded': datetime.datetime,
    'defunct': datetime.datetime,
    'location': unicode,
    'location_city': unicode,
    'location_country': unicode,
    'location_geo': unicode,
    'location_gps': tuple,
    # following not in OC
    'countries': set, # multiple possible from extraction 3
    'logo': dict,
    'key_people': list, # additonally processed with nameparser.HumanName (dict)
    'founders': list, # same as key_people
    'industry': list,
    'subsid': list,
    'products': list,
    'num_employees': int,
    'parent': unicode,
    'homepage': unicode
}

# %% [markdown]
# Especially often lists occur where there is only supposed to be one value. These and certain other cases that also involve reparsing are done.

# %%
for c, comp in tqdm_notebook(merged_companies.iteritems(), desc='Cleaning'):
    for k, val in comp.iteritems():
        if not val:
            continue
        # list values that are not supposed to be lists, to single value
        if types[k] != list and isinstance(val, list):
            if k == 'num_employees':
                comp[k] = parse_employee_nr(val[0], c)
            elif types[k] == datetime.datetime:
                 comp[k] = parse_date(val[0])
            else:
                comp[k] = val[0]
        # string values to unicode
        elif types[k] == unicode and isinstance(val, str):
            comp[k] = unicode(val)
        # single values with one element to list
        elif types[k] == list and not isinstance(val, list):
            # only one dict, e.g. in key_people, to list
            if k == 'key_people' or k == 'founders':
                # if not a dict, reparse
                if not isinstance(val, dict):
                    comp[k] = parse_people_name(val)
            else:
                comp[k] = [val]
        # single unicode values to datetime obj
        elif types[k] == datetime.datetime and isinstance(val, unicode):
                comp[k] = parse_date(val)
    # fill in all keys with None if they don't exist
    comp.update(
        {key: None for key in types.keys() if key not in comp})

# %% [markdown]
# Check if all fields where converted successfully to their designated types.

# %%
# reiterate to check conversion result
failed_types = dict()
for c, comp in merged_companies.iteritems():
    for k, val in comp.iteritems():
        # show values that do not fit specified type
        if val and not isinstance(val, types[k]):
            # just delete non extracted logos
            if k == 'logo':
                comp[k] = dict()
            if k not in failed_types:
                failed_types.update({
                    k: {
                        'is_type': type(val),
                        'should_be_type': types[k]}})

print "Failed types:", failed_types
# Out:
# Failed types: {'logo': {'is_type': <type 'unicode'>, 'should_be_type': <type 'dict'>}}

# %% [markdown]
# Often the field `key_people` contains the full name under the `last` name. That happens on the common string: _Ulrich Hackenberg, Head of Technical Development_
#
# Another problem that occurs when a lot of names are just divided by a comma: _Alan Dukes (Chairman), Mike Aynsley (Group CEO)_ those cases are not handled.
#
# See the following example:

# %%
pprint(merged_companies['Irish Bank Resolution Corporation']['key_people'])
pprint(merged_companies['Audi']['key_people'])
# Out:
# [{u'first': u'Mike',
#   u'last': u'Alan Dukes',
#   u'middle': u'Aynsley',
#   u'nickname': u'Chairman Group CEO',
#   u'suffix': u'',
#   u'title': u''}]
# [{u'first': u'Chairman of the Board of Management',
#   u'last': u'Rupert Stadler',
#   u'middle': u'',
#   u'nickname': u'',
#   u'suffix': u'',
#   u'title': u''},
#  {u'first': u'Head of Design',
#   u'last': u'Marc Lichte',
#   u'middle': u'',
#   u'nickname': u'',
#   u'suffix': u'',
#   u'title': u''},
#  {u'first': u'Head of Technical',
#   u'last': u'Ulrich Hackenberg',
#   u'middle': u'Development',
#   u'nickname': u'',
#   u'suffix': u'',
#   u'title': u''}]

# %% [markdown]
# If the string is matched the element will be reparsed.

# %%
for c, comp in merged_companies.iteritems():
    if 'key_people' in comp and comp['key_people']:
        people = list()
        for person in comp['key_people']:
            # if a space seperates the name in last
            if 'last' in person and re.match(r'.+\ .+', person['last']):
                 people.append(parse_people_name(person['last']))
        if people:
            comp['key_people'] = people
    if 'founders' in comp and comp['founders']:
        founders = list()
        for person in comp['founders']:
            # if a space seperates the name in last
            if 'last' in person and re.match(r'.+\ .+', person['last']):
                 people.append(parse_people_name(person['last']))
        if founders:
            comp['founders'] = founders

# %%
pprint(merged_companies['Irish Bank Resolution Corporation']['key_people'])
pprint(merged_companies['Audi']['key_people'])
# Out:
# [[{u'first': u'Alan',
#    u'last': u'Dukes',
#    u'middle': u'',
#    u'nickname': u'',
#    u'suffix': u'',
#    u'title': u''}]]
# [[{u'first': u'Rupert',
#    u'last': u'Stadler',
#    u'middle': u'',
#    u'nickname': u'',
#    u'suffix': u'',
#    u'title': u''}],
#  [{u'first': u'Marc',
#    u'last': u'Lichte',
#    u'middle': u'',
#    u'nickname': u'',
#    u'suffix': u'',
#    u'title': u''}],
#  [{u'first': u'Ulrich',
#    u'last': u'Hackenberg',
#    u'middle': u'',
#    u'nickname': u'',
#    u'suffix': u'',
#    u'title': u''}]]

# %% [markdown]
# Print statistics and certain keys to show the conversion result.

# %%
loc = 0
for c in merged_companies:
    if 'location_gps' in merged_companies[c] and merged_companies[c]['location_gps']:
        if merged_companies[c]['location_gps'][0] and merged_companies[c]['location_gps'][1]:
            loc += 1

print loc, "companies of total", len(merged_companies), "have a resolved GPS location.\n"

test_excerpt = 'Google'
print "Excerpt of", test_excerpt, "dict structure:"
include = types.keys()
include.remove('all_links')
include.remove('wiki_raw')
pprint(
    {k: merged_companies[test_excerpt][k] for k in include})
# Out:
# 49646 companies of total 56898 have a resolved GPS location.
#
# Excerpt of Google dict structure:
# {'countries': None,
#  'defunct': None,
#  'founded': datetime.datetime(1998, 9, 4, 0, 0),
#  'founders': [{u'first': u'Larry',
#                u'last': u'Page',
#                u'middle': u'',
#                u'nickname': u'',
#                u'suffix': u'',
#                u'title': u''},
#               {u'first': u'Sergey',
#                u'last': u'Brin',
#                u'middle': u'',
#                u'nickname': u'',
#                u'suffix': u'',
#                u'title': u''}],
#  'homepage': u'https://www.google.com',
#  'industry': [u'Internet', u' Computer software', u' Computer hardware'],
#  'is_company': True,
#  'key_people': [{u'first': u'Sundar',
#                  u'last': u'Pichai',
#                  u'middle': u'',
#                  u'nickname': u'CEO',
#                  u'suffix': u'',
#                  u'title': u''}],
#  'links': set([u'ADATA',
#                u'AOL',
#                u'ARCA Space Corporation',
#                u'ARM Holdings',
#                u'AT&T',
#                u'Accenture',
#                u'Access (company)',
#                u'Acer Inc.',
#                u'Activision Blizzard',
#                u'AdMob',
#                u'Adobe Systems',
#                u'Adscape',
#                u'Advanced Micro Devices',
#                u'Alliance for Affordable Internet',
#                u'Alphabet Inc.',
#                u'Am\xe9rica M\xf3vil',
#                u'Apple Inc.',
#                u'Applied Materials',
#                u'Arris Group',
#                u'Associated Press',
#                u'Astrobotic Technology',
#                u'Asus',
#                u'Atos',
#                u'Audience (company)',
#                u'Avaya',
#                u'BBC',
#                u'BBK Electronics',
#                u'BT Global Services',
#                u'BT Group',
#                u'Bell Canada',
#                u'Bharat Sanchar Nigam Limited',
#                u'Bharti Airtel',
#                u'BlackBerry Limited',
#                u'Bloomberg L.P.',
#                u'Booz Allen Hamilton',
#                u'Borqs',
#                u'Bouygues Telecom',
#                u'CA Technologies',
#                u'CACI',
#                u'CBS Interactive',
#                u'CGI Group',
#                u'Calico (company)',
#                u'Canon Inc.',
#                u'Capgemini',
#                u'CapitalG',
#                u'Casio',
#                u'Celestica',
#                u'CenturyLink',
#                u'Chaudhary Group',
#                u'China Mobile',
#                u'China Telecom',
#                u'China Unicom',
#                u'Cisco Systems',
#                u'Cognizant',
#                u'ComScore',
#                u'Comcast',
#                u'Compal Electronics',
#                u'Computer Sciences Corporation',
#                u'Credit Suisse',
#                u'Cypress Semiconductor',
#                u'Dell',
#                u'Dell (subsidiary)',
#                u'Dell EMC',
#                u'Dell Technologies',
#                u'Deloitte',
#                u'Deutsche Telekom',
#                u'Dodgeball (service)',
#                u'DoubleClick',
#                u'Electronic Arts',
#                u'Ericsson',
#                u'Ericsson Mobile Platforms',
#                u'Flextronics',
#                u'Foxconn',
#                u'Freescale Semiconductor',
#                u'Fujifilm',
#                u'Fujitsu',
#                u'GV (company)',
#                u'Garmin',
#                u'Gemalto',
#                u'GeoEye',
#                u'Global IP Solutions',
#                u'GlobalFoundries',
#                u'Google Contributor',
#                u'Google Energy',
#                u'Goojje',
#                u'HCL Technologies',
#                u'HP Inc.',
#                u'HTC',
#                u'Hayneedle',
#                u'Hewlett Packard Enterprise',
#                u'Hewlett Packard Enterprise Services',
#                u'Hisense',
#                u'Hitachi Consulting',
#                u'Hitachi Data Systems',
#                u'Huawei',
#                u'I-Mobile',
#                u'IAC (company)',
#                u'IBM',
#                u'IBM Global Services',
#                u'Idea Cellular',
#                u'Indra Sistemas',
#                u'Infineon Technologies',
#                u'Infosys',
#                u'Inspur',
#                u'Integrated Micro-Electronics, Inc.',
#                u'Intel',
#                u'Interbrand',
#                u'Intuit',
#                u'Jabil Circuit',
#                u'Jaiku',
#                u'Jigsaw (company)',
#                u'Juniper Networks',
#                u'KDDI',
#                u'KPMG',
#                u'KPN',
#                u'KT Corporation',
#                u'Karbonn Mobiles',
#                u'Keyhole, Inc',
#                u'Kingston Technology',
#                u'Kleiner Perkins Caufield & Byers',
#                u'Kodak',
#                u'Konica Minolta',
#                u'Kyocera',
#                u'LG Electronics',
#                u'Lam Research',
#                u'Leidos',
#                u'Lenovo',
#                u'LenovoEMC',
#                u'Lexmark',
#                u'MIPS Technologies',
#                u'MTN Group',
#                u'MTS (network provider)',
#                u'Mahanagar Telephone Nigam',
#                u'Marvell Technology Group',
#                u'MediaTek',
#                u'Meizu',
#                u'Micron Technology',
#                u'Microsoft',
#                u'Microsoft Studios',
#                u'Morgan Stanley',
#                u'Motorola Mobility',
#                u'Motorola Solutions',
#                u'NCR Corporation',
#                u'NEC',
#                u'NTT DATA',
#                u'NTT DoCoMo',
#                u'NXP Semiconductors',
#                u'National Semiconductor',
#                u'Naver Corporation',
#                u'Nepal Telecom',
#                u'Nest Labs',
#                u'NetApp',
#                u'News Corporation',
#                u'NextEra Energy Resources',
#                u'Nikon',
#                u'Nintendo',
#                u'Nippon Telegraph and Telephone',
#                u'Nokia',
#                u'Nuance Communications',
#                u'Nvidia',
#                u'ON Semiconductor',
#                u'Oi (telecommunications)',
#                u'Olympus Corporation',
#                u'Omron',
#                u'On2 Technologies',
#                u'Oracle Corporation',
#                u'Orange Business Services',
#                u'Orange S.A.',
#                u'PacketVideo',
#                u'Panasonic',
#                u'Part-Time Scientists',
#                u'Pegatron',
#                u'Penn State Lunar Lion Team',
#                u'Plextor',
#                u'Puli Space Technologies',
#                u'Qualcomm',
#                u'Qualcomm Atheros',
#                u'Quanta Computer',
#                u'Quest Visual',
#                u'Rackspace',
#                u'Rakuten',
#                u'Reliance Communications',
#                u'Renesas Electronics',
#                u'Reuters',
#                u'Ricoh',
#                u'SAP SE',
#                u'SK Hynix',
#                u'SK Telecom',
#                u'ST-Ericsson',
#                u'STMicroelectronics',
#                u'SVOX',
#                u'Salesforce.com',
#                u'Samsung',
#                u'Samsung Electronics',
#                u'SanDisk',
#                u'Sanmina Corporation',
#                u'Sasken Communication Technologies',
#                u'Seagate Technology',
#                u'Seiko Epson',
#                u'Semiconductor Manufacturing International Corporation',
#                u'Sequoia Capital',
#                u'Sharp Corporation',
#                u'SiRF',
#                u'Sidewalk Labs',
#                u'Silicon Graphics',
#                u'Silicon Power',
#                u'Sony',
#                u'Sony Interactive Entertainment',
#                u'Sony Mobile',
#                u'Sprint Corporation',
#                u'Star Micronics',
#                u'Sun Microsystems',
#                u'Symantec',
#                u'Synaptics',
#                u'T-Mobile',
#                u'T-Systems',
#                u'TCL Corporation',
#                u'TPV Technology',
#                u'TSMC',
#                u'Take-Two Interactive',
#                u'Tata Consultancy Services',
#                u'Tata Teleservices',
#                u'Team Indus',
#                u'Tech Mahindra',
#                u'Telecom Italia',
#                u'Telef\xf3nica',
#                u'Telenor',
#                u'Telus',
#                u'Tencent',
#                u'Texas Instruments',
#                u'Tokyo Electron',
#                u'Toshiba',
#                u'Transcend Information',
#                u'True Corporation',
#                u'Unisys',
#                u'United Microelectronics Corporation',
#                u'VIA Technologies',
#                u'VMware',
#                u'Verily Life Sciences',
#                u'Verizon Communications',
#                u'Viettel',
#                u'VimpelCom Ltd.',
#                u'Vivendi',
#                u'Vodafone',
#                u'Western Digital',
#                u'Wincor Nixdorf',
#                u'Wind River Systems',
#                u'Wipro',
#                u'Wistron Corporation',
#                u'X (company)',
#                u'Xerox',
#                u'Xiaomi',
#                u'Yahoo! Search Marketing',
#                u'ZTE']),
#  'location': None,
#  'location_city': u'Googleplex, Mountain View, California',
#  'location_country': u'U.S.',
#  'location_geo': u'U.S., State Highway 55, Langlade, Wolf River, Langlade County, Wisconsin, 54462, United States of America',
#  'location_gps': (45.1895845, -88.73215835),
#  'logo': {'wiki_commons_link': u'https://commons.wikimedia.org/wiki/File:Google_2015_logo.svg',
#           'wiki_file_link': u'https://en.wikipedia.org/wiki/File:Google_2015_logo.svg',
#           'wiki_raw_code': u'Google 2015 logo.svg'},
#  'name': u'Google Inc.',
#  'name_url_quoted': u'Google',
#  'num_employees': 57100,
#  'parent': u'Alphabet Inc.',
#  'products': [u'List of Google products'],
#  'subsid': [u'List of subsidiaries'],
#  'type': u'Subsidiary',
#  'wiki_api_url': u'https://en.wikipedia.org/w/api.php?&action=parse&prop=links|wikitext&format=json&pageid=1092923',
#  'wiki_name': u'Google',
#  'wiki_page_id': 1092923,
#  'wiki_url': u'https://en.wikipedia.org/w/index.php?title=Google'}

# %% [markdown]
# All merged data is also saved to a file for convenience reasons.

# %%
with open(merged, 'wb') as f:
    pickle.dump(merged_companies, f)

# %% [markdown]
# ## 2. Preliminary Data Analysis
# ### 2.2. Company Analysis
#
# In order to gain some insights into the companies a analysis of the current data is done along with some additional cleaning. As data structure a DataFrame from the [pandas](http://pandas.pydata.org/) library is used.

# %%
# convert from dict into dataframe
comp_df = pd.DataFrame.from_dict(merged_companies, orient='index')
comp_df.index.name = 'wiki_title'
comp_df
# Out:
#                                                                                links  \
# wiki_title
# &pizza                                      {Ruby Tuesday (restaurant), City Sports}
# +Beryll                                {Henri Bendel, Fred Segal, Los Angeles Times}
# ...instore                         {Home Bargains, Heron Foods, Tesco, Poundstret...
# 01 Communique                                                                     {}
# 01 Distribution                                                                {RAI}
# 07th Expansion                                                 {Alchemist (company)}
# 0verflow                                                                          {}
# 1-2-3 (fuel station)                                         {Statoil Fuel & Retail}
# 1-800 Contacts                     {Johnson & Johnson, DITTO, CooperVision, AEA I...
# 1-800-FREE-411                     {Google, Liberty Media, Tellme Networks, March...
# 1-800-Flowers                      {CompuServe, AOL, Comtex, Harry & David, Marth...
# 1-800-GOT-JUNK?                    {HSBC Bank Canada, Teradici, The Pantry (resta...
# 1-Page                                             {Business Wire, Blumberg Capital}
# 1-UP Studio                        {Nintendo Network Service Database, Game Freak...
# 10 feet                                                                           {}
# 10,000ft                                                        {Artefact (company)}
# 100 Women in Hedge Funds           {DonorsChoose, Bridgewater Associates, The Tru...
# 100% Banco                                                                        {}
# 1000Bulbs.com                                                                     {}
# 1000Memories                       {Wieden+Kennedy, McKinsey & Company, Greylock ...
# 108 Shop                           {Tom's Convenience Store, Delhaize Group, Mini...
# 10Bet, LLC                                                                        {}
# 10th Legion Championship Fighting  {Battlecade Extreme Fighting, Shark Fights, Af...
# 10x (company)                                                                     {}
# 10x Genomics                                                    {Illumina (company)}
# 11 bit studios                                     {CD Projekt, Metropolis Software}
# 112dB                              {Apple Inc., Dolby Laboratories, Native Instru...
# 12 Yard                            {ITV Studios, Wireless Group, STV Group (Scotl...
# 12 bis                                                                            {}
# 123 Money                                                      {RSA Insurance Group}
# ...                                                                              ...
# Đuro Đaković (company)             {Tvornica Autobusa Zagreb, Atlantska plovidba,...
# Ērenpreiss Bicycles                                   {G. Ērenpreis Bicycle Factory}
# İDO                                                       {İDO, Damen Group, Austal}
# İZBAN A.Ş.                         {Hyundai Rotem, Turkish State Railways, Constr...
# İhlas Holding                      {Migros Türk, Akbank, Abank, Coca-Cola Içecek,...
# İlbank                                                                            {}
# İletişim Yayınları                                                                {}
# İnterbank                                                {Etibank, Çukurova Holding}
# İsdemir                                                                    {Erdemir}
# İstanbul Plak                                                                     {}
# İzocam                             {Migros Türk, Akbank, Abank, Coca-Cola Içecek,...
# İş Yatırım                         {DYO Boya Fabrikaları, Deutsche Bank, Renaissa...
# Łódzka Kolej Aglomeracyjna         {Arriva RP, PKP Polskie Linie Kolejowe, Lotos ...
# Ōigawa Railway                                                                    {}
# Şahinler Holding                                                                  {}
# Şekerbank                          {Migros Türk, Akbank, Abank, Coca-Cola Içecek,...
# Šipad                                                                             {}
# Škoda Auto                         {Hispano-Suiza, DKW, Lamborghini, Porsche, FAW...
# Škoda Auto India Private Limited   {DKW, Lamborghini, Honda, Ford Motor Company, ...
# Škoda Transportation               {Rīgas Satiksme, Transtech (Finnish company), ...
# Škoda Works                        {Ganz Works, České dráhy, Škoda Auto, Škoda Tr...
# Školska knjiga                                                                    {}
# Štark                                                                             {}
# Ūkio bankas                                        {Nasdaq Nordic, General Electric}
# ŽIA valda                                     {Agrowill Group, Avia Solutions Group}
# Železara Smederevo                                       {Hesteel Group, U.S. Steel}
# Železničná spoločnosť Slovensko             {RegioJet, Rail transport in Montenegro}
# Željeznički prevoz Crne Gore       {Deutsche Bahn, Calea Ferată din Moldova, Iarn...
# Živnostenská banka                                        {UniCredit, Dresdner Bank}
# Țiriac Holdings                                                            {Allianz}
#
#                                                                         location_geo  \
# wiki_title
# &pizza                                                                          None
# +Beryll                                                                         None
# ...instore                         Huddersfield, Yorkshire and the Humber, Englan...
# 01 Communique                                     Ont., Peel Region, Ontario, Canada
# 01 Distribution                                                           Lomé, Togo
# 07th Expansion                                                                    日本
# 0verflow                           神田, 神田ふれあい通り, 鍛冶町2, 鍛冶町, 東京, 千代田区, 東京都, 101-00...
# 1-2-3 (fuel station)                                                            None
# 1-800 Contacts                                Draper, Utah, United States of America
# 1-800-FREE-411                     U, 4200, Mary Gates Memorial Drive Northeast, ...
# 1-800-Flowers                        Carle Place, New York, United States of America
# 01 Distribution                                                      01+Distribution
# 07th Expansion                                                        07th+Expansion
# 0verflow                                                                    0verflow
# 1-2-3 (fuel station)                                        1-2-3+%28fuel+station%29
# 1-800 Contacts                                                        1-800+Contacts
# 1-800-FREE-411                                                        1-800-FREE-411
# 1-800-Flowers                                                          1-800-Flowers
# 1-800-GOT-JUNK?                                                    1-800-GOT-JUNK%3F
# 1-Page                                                                        1-Page
# 1-UP Studio                                                              1-UP+Studio
# 10 feet                                                                      10+feet
# 10,000ft                                                                  10%2C000ft
# 100 Women in Hedge Funds                                    100+Women+in+Hedge+Funds
# 100% Banco                                                              100%25+Banco
# 1000Bulbs.com                                                          1000Bulbs.com
# 1000Memories                                                            1000Memories
# 108 Shop                                                                    108+Shop
# 10Bet, LLC                                                              10Bet%2C+LLC
# 10th Legion Championship Fighting                  10th+Legion+Championship+Fighting
# 10x (company)                                                      10x+%28company%29
# 10x Genomics                                                            10x+Genomics
# 11 bit studios                                                        11+bit+studios
# 112dB                                                                          112dB
# 12 Yard                                                                      12+Yard
# 12 bis                                                                        12+bis
# 123 Money                                                                  123+Money
# ...                                                                              ...
# Đuro Đaković (company)                     %C4%90uro+%C4%90akovi%C4%87+%28company%29
# Ērenpreiss Bicycles                                         %C4%92renpreiss+Bicycles
# İDO                                                                         %C4%B0DO
# İZBAN A.Ş.                                                      %C4%B0ZBAN+A.%C5%9E.
# İhlas Holding                                                     %C4%B0hlas+Holding
# İlbank                                                                   %C4%B0lbank
# İletişim Yayınları                            %C4%B0leti%C5%9Fim+Yay%C4%B1nlar%C4%B1
# İnterbank                                                             %C4%B0nterbank
# İsdemir                                                                 %C4%B0sdemir
# İstanbul Plak                                                     %C4%B0stanbul+Plak
# İzocam                                                                   %C4%B0zocam
# İş Yatırım                                            %C4%B0%C5%9F+Yat%C4%B1r%C4%B1m
# Łódzka Kolej Aglomeracyjna                      %C5%81%C3%B3dzka+Kolej+Aglomeracyjna
# Ōigawa Railway                                                   %C5%8Cigawa+Railway
# Şahinler Holding                                               %C5%9Eahinler+Holding
# Şekerbank                                                             %C5%9Eekerbank
# Šipad                                                                     %C5%A0ipad
# Škoda Auto                                                           %C5%A0koda+Auto
# Škoda Auto India Private Limited               %C5%A0koda+Auto+India+Private+Limited
# Škoda Transportation                                       %C5%A0koda+Transportation
# Škoda Works                                                         %C5%A0koda+Works
# Školska knjiga                                                   %C5%A0kolska+knjiga
# Štark                                                                     %C5%A0tark
# Ūkio bankas                                                         %C5%AAkio+bankas
# ŽIA valda                                                             %C5%BDIA+valda
# Železara Smederevo                                           %C5%BDelezara+Smederevo
# Železničná spoločnosť Slovensko    %C5%BDelezni%C4%8Dn%C3%A1+spolo%C4%8Dnos%C5%A5...
# Željeznički prevoz Crne Gore                  %C5%BDeljezni%C4%8Dki+prevoz+Crne+Gore
# Živnostenská banka                                      %C5%BDivnostensk%C3%A1+banka
# Țiriac Holdings                                                 %C8%9Airiac+Holdings
#
#                                                                                 logo  \
# wiki_title
# &pizza                                                                          None
# +Beryll                            {u'wiki_raw_code': u'Beryll logo.jpg', u'wiki_...
# ...instore                         {u'wiki_raw_code': u'[[File:Instore-logo.png]]...
# 01 Communique                      {u'wiki_raw_code': u'01 Communique Logo.svg', ...
# 01 Distribution                                                                 None
# 07th Expansion                                                                  None
# 0verflow                           {u'wiki_raw_code': u'0verflowlogo.png', u'wiki...
# 1-2-3 (fuel station)                                                            None
# 1-800 Contacts                                                                  None
# 1-800-FREE-411                     {u'wiki_raw_code': u'800free411.gif', u'wiki_f...
# 1-800-Flowers                      {u'wiki_raw_code': u'1-800-flowers com.svg', u...
# 1-800-GOT-JUNK?                    {u'wiki_raw_code': u'1800GOTJUNK Logo.svg', u'...
# 1-Page                             {u'wiki_raw_code': u'1PAGE_LOGO.png', u'wiki_f...
# 1-UP Studio                                                                     None
# 10 feet                                                                         None
# 10,000ft                           {u'wiki_raw_code': u'10,000ft logo.png', u'wik...
# 100 Women in Hedge Funds                                                        None
# 100% Banco                         {u'wiki_raw_code': u'[[File:100% Banco logo.pn...
# 1000Bulbs.com                                                                   None
# 1000Memories                       {u'wiki_raw_code': u'[[Image:1000memories.png]...
# 108 Shop                                                                        None
# 10Bet, LLC                                                                      None
# 10th Legion Championship Fighting  {u'wiki_raw_code': u'[[File:10thLegionLogo.jpg...
# 10x (company)                                                                   None
# 10x Genomics                       {u'wiki_raw_code': u'File:10x_Genomics_Logo.pn...
# 11 bit studios                                                                  None
# 112dB                                                                           None
# 12 Yard                            {u'wiki_raw_code': u'File:12 Yard Productions ...
# 12 bis                                                                          None
# 123 Money                                                                       None
# ...                                                                              ...
# Đuro Đaković (company)                                                          None
# Ērenpreiss Bicycles                {u'wiki_raw_code': u'[[File:Erenpreiss logo.jp...
# İDO                                {u'wiki_raw_code': u'[[File:Istanbul Sea Buses...
# İZBAN A.Ş.                                                                      None
# İhlas Holding                                                                   None
# İlbank                                                                          None
# İletişim Yayınları                                                              None
# İnterbank                                                                       None
# İsdemir                            {u'wiki_raw_code': u'[[File:Isdemir logo.PNG|2...
# İstanbul Plak                                                                   None
# İzocam                                                                          None
# İş Yatırım                         {u'wiki_raw_code': u'Is Investment Logo.png', ...
# Łódzka Kolej Aglomeracyjna         {u'wiki_raw_code': u'[[File:Łódzka Kolej Aglom...
# Ōigawa Railway                                                                  None
# Şahinler Holding                                                                None
# Şekerbank                          {u'wiki_raw_code': u'[[File:Şekerbank Logo.jpg...
# Šipad                              {u'wiki_raw_code': u'[[File:Šipad d.d.jpg|155p...
# Škoda Auto                         {u'wiki_raw_code': u'[[File:Skoda Auto logo (2...
# Škoda Auto India Private Limited   {u'wiki_raw_code': u'[[File:Skoda Auto logo (2...
# Škoda Transportation               {u'wiki_raw_code': u'Škoda Transportation logo...
# Škoda Works                        {u'wiki_raw_code': u'Škoda Works logo.png', u'...
# Školska knjiga                     {u'wiki_raw_code': u'[[File:Skolskaknjigalogo....
# Štark                              {u'wiki_raw_code': u'Stark 02 800.png', u'wiki...
# Ūkio bankas                        {u'wiki_raw_code': u'[[File:Ukio bankas logo.j...
# ŽIA valda                                                                       None
# Železara Smederevo                                                              None
# Železničná spoločnosť Slovensko    {u'wiki_raw_code': u'Železničná spoločnosť Slo...
# Željeznički prevoz Crne Gore       {u'wiki_raw_code': u'[[File:ZCGlogo.png]]', u'...
# Živnostenská banka                 {u'wiki_raw_code': u'[[Image:ZIBA logo.gif|214...
# Țiriac Holdings                    {u'wiki_raw_code': u'[[Image:Tiriac-Holdings.p...
#
#                                                                               subsid  \
# wiki_title
# &pizza                                                                          None
# +Beryll                                                                         None
# ...instore                                                                      None
# 01 Communique                                                                   None
# 01 Distribution                                                                 None
# 07th Expansion                                                                  None
# 0verflow                                                                        None
# 1-2-3 (fuel station)                                                            None
# 1-800 Contacts                                                                  None
# 1-800-FREE-411                                                                  None
# 1-800-Flowers                                                                   None
# 1-800-GOT-JUNK?                                                                 None
# 1-Page                                                                          None
# 1-UP Studio                                                                     None
# 10 feet                                                                         None
# 10,000ft                                                                        None
# 100 Women in Hedge Funds                                                        None
# 100% Banco                                                                      None
# 1000Bulbs.com                                                                   None
# 1000Memories                                                                    None
# 108 Shop                                                                        None
# 10Bet, LLC                                                                      None
# 10th Legion Championship Fighting                                               None
# 10x (company)                                                                   None
# 10x Genomics                                                                    None
# 11 bit studios                                                                  None
# 112dB                                                                           None
# 12 Yard                                                                         None
# 12 bis                                                                          None
# 123 Money                                                                       None
# ...                                                                              ...
# Đuro Đaković (company)                                                          None
# Ērenpreiss Bicycles                                                             None
# İDO                                                                             None
# İZBAN A.Ş.                                                                      None
# İhlas Holding                                                                   None
# İlbank                                                                          None
# İletişim Yayınları                                                              None
# İnterbank                                                                       None
# İsdemir                                                                         None
# İstanbul Plak                                                                   None
# İzocam                                                                          None
# İş Yatırım                                                                      None
# Łódzka Kolej Aglomeracyjna                                                      None
# Ōigawa Railway                                                                  None
# Şahinler Holding                                                                None
# Şekerbank                                                                       None
# Šipad                                                                           None
# Škoda Auto                         [Škoda Auto Deutschland GmbH, Skoda Auto India...
# Škoda Auto India Private Limited                                                None
# Škoda Transportation                                                            None
# Škoda Works                                                                     None
# Školska knjiga                                                                  None
# Štark                                                                           None
# Ūkio bankas                                                                     None
# ŽIA valda                                                                       None
# Železara Smederevo                                                              None
# Železničná spoločnosť Slovensko                                                 None
# Željeznički prevoz Crne Gore                                                    None
# Živnostenská banka                                                              None
# Țiriac Holdings                                                                 None
#
#                                                                 location_city  \
# wiki_title
# &pizza                                                                   None
# +Beryll                                                                  None
# ...instore                                                               None
# 01 Communique                                                            None
# 01 Distribution                                                          Rome
# 07th Expansion                                                           None
# 0verflow                                               Kanda, Chiyoda , Tokyo
# 1-2-3 (fuel station)                                                     None
# 1-800 Contacts                                                           None
# 1-800-FREE-411                                                           None
# 1-800-Flowers                                                            None
# 1-800-GOT-JUNK?                                                          None
# 1-Page                                                                   None
# 1-UP Studio                                                             Tokyo
# 10 feet                                                                  None
# 10,000ft                                                  Seattle, Washington
# 100 Women in Hedge Funds                                                 None
# 100% Banco                                                               None
# 1-UP Studio                                              1-UP Studio
# 10 feet                                                      10 feet
# 10,000ft                                                    10,000ft
# 100 Women in Hedge Funds                    100 Women in Hedge Funds
# 100% Banco                                                100% Banco
# 1000Bulbs.com                                          1000Bulbs.com
# 1000Memories                                            1000Memories
# 108 Shop                                                    108 Shop
# 10Bet, LLC                                                10Bet, LLC
# 10th Legion Championship Fighting  10th Legion Championship Fighting
# 10x (company)                                          10x (company)
# 10x Genomics                                            10x Genomics
# 11 bit studios                                        11 bit studios
# 112dB                                                          112dB
# 12 Yard                                                      12 Yard
# 12 bis                                                        12 bis
# 123 Money                                                  123 Money
# ...                                                              ...
# Đuro Đaković (company)                        Đuro Đaković (company)
# Ērenpreiss Bicycles                              Ērenpreiss Bicycles
# İDO                                                              İDO
# İZBAN A.Ş.                                                İZBAN A.Ş.
# İhlas Holding                                          İhlas Holding
# İlbank                                                        İlbank
# İletişim Yayınları                                İletişim Yayınları
# İnterbank                                                  İnterbank
# İsdemir                                                      İsdemir
# İstanbul Plak                                          İstanbul Plak
# İzocam                                                        İzocam
# İş Yatırım                                                İş Yatırım
# Łódzka Kolej Aglomeracyjna                Łódzka Kolej Aglomeracyjna
# Ōigawa Railway                                        Ōigawa Railway
# Şahinler Holding                                    Şahinler Holding
# Şekerbank                                                  Şekerbank
# Šipad                                                          Šipad
# Škoda Auto                                                Škoda Auto
# Škoda Auto India Private Limited    Škoda Auto India Private Limited
# Škoda Transportation                            Škoda Transportation
# Škoda Works                                              Škoda Works
# Školska knjiga                                        Školska knjiga
# Štark                                                          Štark
# Ūkio bankas                                              Ūkio bankas
# ŽIA valda                                                  ŽIA valda
# Železara Smederevo                                Železara Smederevo
# Železničná spoločnosť Slovensko      Železničná spoločnosť Slovensko
# Željeznički prevoz Crne Gore            Željeznički prevoz Crne Gore
# Živnostenská banka                                Živnostenská banka
# Țiriac Holdings                                      Țiriac Holdings
#
#                                                                    location  \
# wiki_title
# &pizza                                                                 None
# +Beryll                                                                None
# ...instore                            Huddersfield, England, United Kingdom
# 01 Communique                                  Mississauga, Ontario, Canada
# 01 Distribution                                                        None
# 07th Expansion                                                        Japan
# 0verflow                                                               None
# 1-2-3 (fuel station)                                                   None
# 1-800 Contacts                                                 Draper, Utah
# 1-800-FREE-411                                            Seattle, WA, U.S.
# ...
# Škoda Auto                                                             [Automobiles]
# Škoda Auto India Private Limited                                       [Automobiles]
# Škoda Transportation               [electric locomotives, low-floor trams, underg...
# Škoda Works                                                                     None
# Školska knjiga                                         [Books, Magazines, Textbooks]
# Štark                                   [Branded food, candies, chocolate, biscuits]
# Ūkio bankas                        [Retail banking, mortgage loans, corporate ban...
# ŽIA valda                                                                       None
# Železara Smederevo                                               [Flat-rolled steel]
# Železničná spoločnosť Slovensko                                                 None
# Željeznički prevoz Crne Gore                                                    None
# Živnostenská banka                 [Banking, asset management, leasing and factor...
# Țiriac Holdings                                                                 None
#
#                                                                            all_links  \
# wiki_title
# &pizza                             [City Sports, DC Central Kitchen, Fast casual ...
# Ōigawa Railway                     [Alishan Forest Railway, Brienz Rothorn Bahn, ...
# Şahinler Holding                   [Austria, Bulgaria, Catering, France, Germany,...
# Şekerbank                          [Turkey, A&T Bank, ASELSAN, Abank, Acıbadem He...
# Šipad                              [Bosnia, Bosnia and Herzegovina, Bosnian war, ...
# Škoda Auto                         [Czech Republic, 1999 World Rally Championship...
# Škoda Auto India Private Limited   [India, Ashok Leyland STiLE, Audi, Aurangabad,...
# Škoda Transportation               [Akciová společnost, Artic (tram), Asset, Bile...
# Škoda Works                        [Aircraft, Asset stripping, Austria-Hungary, A...
# Školska knjiga                     [Book, Chairman, Croatia, Croatian kuna, Publi...
# Štark                              [Asset, Belgrade, Biscuit, Biscuits, Brand, Bu...
# Ūkio bankas                        [Commercial bank, Credit crunch, Delfi.lt, Eco...
# ŽIA valda                          [Agriculture, Agrowill Group, Aircraft, Airpor...
# Železara Smederevo                 [Aleksandar Vučić, Assassination of Zoran Đinđ...
# Železničná spoločnosť Slovensko    [Rail transport in Europe, Rail transport in V...
# Željeznički prevoz Crne Gore       [Austrian Federal Railways, Azerbaijan Railway...
# Živnostenská banka                 [Acronym, Austro-Hungarian Empire, Bankgesells...
# Țiriac Holdings                    [Allianz, Banking, Bucharest, Construction, Da...
#
#                                                     location_gps wiki_page_id  \
# wiki_title
# &pizza                                              (None, None)     47858476
# +Beryll                                             (None, None)     13860681
# ...instore                              (53.6467031, -1.7832076)      9291975
# 01 Communique                          (43.5892854, -79.6441645)     15244876
# 01 Distribution                             (6.130419, 1.215829)     46724099
# 07th Expansion                         (36.5748441, 139.2394179)      5936289
# 0verflow                                (35.6917842, 139.770917)     10387049
# 1-2-3 (fuel station)                                (None, None)     14018485
# 1-800 Contacts                        (40.5246711, -111.8638225)      4613366
# 1-800-FREE-411                     (47.66003045, -122.290454247)     18480351
# 1-800-Flowers                          (40.7526008, -73.6104057)      4048045
# 1-800-GOT-JUNK?                       (49.2608944, -123.1139382)      5579899
# 1-Page                                (37.7792808, -122.4192362)     44914210
# 1-UP Studio                          (34.2255804, 139.294774527)      1549290
# 10 feet                              (52.3745403, 4.89797550562)      7481455
# 10,000ft                              (47.6038321, -122.3300623)     37913068
# 100 Women in Hedge Funds               (40.7305991, -73.9865811)     33740186
# 100% Banco                              (10.506098, -66.9146016)     23958183
# 1000Bulbs.com                           (32.912624, -96.6388832)     48249798
# 1000Memories                          (37.7792808, -122.4192362)     28493016
# 108 Shop                                            (None, None)     23183503
# 10Bet, LLC                              (51.5073219, -0.1276473)     40634514
# 10th Legion Championship Fighting     (-37.6549863, 176.1939988)     29825173
# 10x (company)                                       (None, None)     51084325
# 10x Genomics                          (37.6624312, -121.8746788)     52236081
# 11 bit studios                          (52.2319237, 21.0067265)     38544394
# 112dB                                (52.08095165, 5.1276803155)     23239375
# 12 Yard                                 (51.5073219, -0.1276473)      3052956
# 12 bis                                    (46.603354, 1.8883335)     29163465
# 123 Money                               (53.3497645, -6.2602731)     35861728
# ...                                                          ...          ...
# Đuro Đaković (company)                    (45.1713519, 18.01354)     10072143
# Ērenpreiss Bicycles                     (56.9493977, 24.1051846)     49226907
# İDO                                     (41.0096334, 28.9651646)      6286396
# İZBAN A.Ş.                              (38.4390174, 27.1407071)     30483454
# İhlas Holding                           (41.0014887, 28.8229619)     39611864
# İlbank                              (39.92807995, 32.8732092664)     42266068
# İletişim Yayınları                      (41.0096334, 28.9651646)     39646855
# İnterbank                               (41.0096334, 28.9651646)     40034174
# İsdemir                                 (38.9597594, 34.9249653)      8722407
# İstanbul Plak                           (41.0096334, 28.9651646)     12807361
# İzocam                                  (38.9597594, 34.9249653)     43380582
# İş Yatırım                                          (None, None)     34538340
# Łódzka Kolej Aglomeracyjna               (51.768749, 19.4569817)     47269370
# Ōigawa Railway                           (34.879912, 138.146599)     10752196
# Şahinler Holding                        (41.0096334, 28.9651646)     18393229
# Şekerbank                               (38.9597594, 34.9249653)     27193229
# Šipad                                   (43.8519774, 18.3866868)     46874309
# Škoda Auto                              (50.4116187, 14.9031301)        26970
# Škoda Auto India Private Limited     (20.0328377, 75.1589513219)     22342461
# Škoda Transportation                    (49.7477415, 13.3775249)     42128619
# Škoda Works                             (49.7477415, 13.3775249)       672117
# Školska knjiga                          (45.8131545, 15.9770298)      3125604
# Štark                                   (44.8178787, 20.4568089)      5056670
# Ūkio bankas                             (54.8982139, 23.9044817)      7165143
# ŽIA valda                               (54.6870458, 25.2829111)     19022570
# Železara Smederevo                      (44.6636063, 20.9283896)     40327203
# Železničná spoločnosť Slovensko      (48.1359085, 17.1597440625)     17402318
# Željeznički prevoz Crne Gore            (42.4415238, 19.2621081)     39357175
# Živnostenská banka                      (50.0874654, 14.4212503)      7906982
# Țiriac Holdings                         (44.4361414, 26.1027202)     10868077
#
#                                   wb_api_url wb_api_search_url
# wiki_title
# &pizza                                   NaN               NaN
# +Beryll                                  NaN               NaN
# ...instore                               NaN               NaN
# 01 Communique                            NaN               NaN
# 01 Distribution                          NaN               NaN
# 07th Expansion                           NaN               NaN
# 0verflow                                 NaN               NaN
# 1-2-3 (fuel station)                     NaN               NaN
# 1-800 Contacts                           NaN               NaN
# 1-800-FREE-411                           NaN               NaN
# 1-800-Flowers                            NaN               NaN
# 1-800-GOT-JUNK?                          NaN               NaN
# 1-Page                                   NaN               NaN
# 1-UP Studio                              NaN               NaN
# 10 feet                                  NaN               NaN
# 10,000ft                                 NaN               NaN
# 100 Women in Hedge Funds                 NaN               NaN
# 100% Banco                               NaN               NaN
# 1000Bulbs.com                            NaN               NaN
# 1000Memories                             NaN               NaN
# 108 Shop                                 NaN               NaN
# 10Bet, LLC                               NaN               NaN
# 10th Legion Championship Fighting        NaN               NaN
# 10x (company)                            NaN               NaN
# 10x Genomics                             NaN               NaN
# 11 bit studios                           NaN               NaN
# 112dB                                    NaN               NaN
# 12 Yard                                  NaN               NaN
# 12 bis                                   NaN               NaN
# 123 Money                                NaN               NaN
# ...                                      ...               ...
# Đuro Đaković (company)                   NaN               NaN
# Ērenpreiss Bicycles                      NaN               NaN
# İDO                                      NaN               NaN
# İZBAN A.Ş.                               NaN               NaN
# İhlas Holding                            NaN               NaN
# İlbank                                   NaN               NaN
# İletişim Yayınları                       NaN               NaN
# İnterbank                                NaN               NaN
# İsdemir                                  NaN               NaN
# İstanbul Plak                            NaN               NaN
# İzocam                                   NaN               NaN
# İş Yatırım                               NaN               NaN
# Łódzka Kolej Aglomeracyjna               NaN               NaN
# Ōigawa Railway                           NaN               NaN
# Şahinler Holding                         NaN               NaN
# Şekerbank                                NaN               NaN
# Šipad                                    NaN               NaN
# Škoda Auto                               NaN               NaN
# Škoda Auto India Private Limited         NaN               NaN
# Škoda Transportation                     NaN               NaN
# Škoda Works                              NaN               NaN
# Školska knjiga                           NaN               NaN
# Štark                                    NaN               NaN
# Ūkio bankas                              NaN               NaN
# ŽIA valda                                NaN               NaN
# Železara Smederevo                       NaN               NaN
# Železničná spoločnosť Slovensko          NaN               NaN
# Željeznički prevoz Crne Gore             NaN               NaN
# Živnostenská banka                       NaN               NaN
# Țiriac Holdings                          NaN               NaN
#
# [56898 rows x 30 columns]

# %% [markdown]
# Companies with missing name are eliminated. Those name misses should not occur because the Wikipedia link name is taken if it is missing in the "Infobox company" but this is as insurance.

# %%
comp_df.dropna(subset=['name'], inplace=True)

# %% [markdown]
# Companies with duplicate names can occur if people put similar company templates on pages, e.g.:
# *
# *
# *

# %%
# find duplicate company names
c_dupl = pd.concat(g for _, g in comp_df.groupby('name') if len(g) > 1)
print "Found", len(c_dupl['name']), "duplicates:"
print c_dupl['name']
# Out:
# Found 426 duplicates:
# wiki_title
# Big Bazaar                                                      '''Big Bazaar'''
# Big Bazaar (Rourkela)                                           '''Big Bazaar'''
# Hanriot                                           ''Aéroplanes Hanriot et Cie.''
# Hanriot (aircraft company)                        ''Aéroplanes Hanriot et Cie.''
# Automobiles Darracq France                                      A Darracq et Cie
# Darracq and Company London                                      A Darracq et Cie
# ASICS                                                          ASICS Corporation
# Haglöfs                                                        ASICS Corporation
# Abrazo Scottsdale Campus                                Abrazo Scottsdale Campus
# Abrazo Scottsdale Campus Arizona                        Abrazo Scottsdale Campus
# Al Marjan Island                                                Al Marjan Island
# Al Marjan Island LLC                                            Al Marjan Island
# Alchemy (company)                                                        Alchemy
# Alchemy Boulders                                                         Alchemy
# Amiga, Inc.                                                          Amiga, Inc.
# Amiga, Inc. (South Dakota)                                           Amiga, Inc.
# Amplify (company)                                                        Amplify
# Amplify (distributor)                                                    Amplify
# Andersen Tax                                                    Andersen Tax LLC
# Andersen Tax LLC                                                Andersen Tax LLC
# Anki (Finnish company)                                                      Anki
# Anki (company)                                                              Anki
# Applause (digital testing company)                                Applause, Inc.
# Applause (software company)                                       Applause, Inc.
# Argex Mining                                                 Argex Titanium Inc.
# Argex Titanium Inc.                                          Argex Titanium Inc.
# Army and Air Force Exchange Service          Army and Air Force Exchange Service
# Army and Air Force Motion Picture Service    Army and Air Force Exchange Service
# Atari, Inc.                                                          Atari, Inc.
# Atari, Inc. (Atari, SA subsidiary)                                   Atari, Inc.
#                                                             ...
# Verizon Maryland                                            Verizon Maryland LLC
# Casas Bahia                                                      Via Varejo S.A.
# Via Varejo                                                       Via Varejo S.A.
# Vision Research (cameras)                                        Vision Research
# Vision Research Phantom                                          Vision Research
# VitrA (sanitaryware)                                                       Vitra
# Vitra (furniture)                                                          Vitra
# Vétra                                                                      Vétra
# Vétra (workwear)                                                           Vétra
# Walton (motorcycle)                            Walton Hi-Tech Industries Limited
# Walton Hi-Tech Industries Limited              Walton Hi-Tech Industries Limited
# WellAway                                                                WellAway
# WellAway Limited                                                        WellAway
# Wendy's                                                                  Wendy's
# Wendy's Supa Sundaes                                                     Wendy's
# Western Power (networks corporation)                               Western Power
# Western Power Corporation                                          Western Power
# World Wide Pictures                                          World Wide Pictures
# World Wide Pictures (UK)                                     World Wide Pictures
# List of Yamaha guitars                                        Yamaha Corporation
# Yamaha Corporation                                            Yamaha Corporation
# Yamaha electric guitar models                                 Yamaha Corporation
# Yates (company)                                                            Yates
# Yates's                                                                    Yates
# ZAP (motor company)                                                          ZAP
# ZAP (satellite television)                                                   ZAP
# Fukui Television Broadcasting                                     [u'Co., Ltd.']
# STX Offshore & Shipbuilding                                       [u'Co., Ltd.']
# Wagamama                                                                wagamama
# Wok to Walk                                                             wagamama
# Name: name, dtype: object

# %%
# add extra column adding the length of the link set
for i, row in c_dupl.iterrows():
  c_dupl.set_value(i, 'link_amount', len(row['links']))

# %%
s_list = [ 'List of Yamaha guitars',
          'Yamaha Corporation',
          'Yamaha electric guitar models']

for s in s_list:
    print s, c_dupl.loc[s, 'link_amount']
# Out:
# List of Yamaha guitars 1.0
# Yamaha Corporation 331.0
# Yamaha electric guitar models 5.0

# %%
# sort after multiple values, sorts the columns with least links and employees
sort_cols = ['name', 'link_amount', 'num_employees']
c_dupl_sort = c_dupl.sort_values(by=sort_cols, ascending=[True,True,True])
c_dupl_sort[['link_amount', 'name', 'num_employees']]
# Out:
#                                            link_amount  \
# wiki_title
# Big Bazaar (Rourkela)                              3.0
# Big Bazaar                                         4.0
# Hanriot                                           40.0
# Hanriot (aircraft company)                        40.0
# Darracq and Company London                         7.0
# Automobiles Darracq France                         9.0
# Haglöfs                                            1.0
# ASICS                                             19.0
# Abrazo Scottsdale Campus                           8.0
# Abrazo Scottsdale Campus Arizona                   8.0
# Al Marjan Island LLC                               0.0
# Al Marjan Island                                   1.0
# Alchemy Boulders                                   0.0
# Alchemy (company)                                  5.0
# Amiga, Inc. (South Dakota)                        10.0
# Amiga, Inc.                                       13.0
# Amplify (company)                                  2.0
# Amplify (distributor)                              2.0
# Andersen Tax                                       2.0
# Andersen Tax LLC                                   2.0
# Anki (Finnish company)                             0.0
# Anki (company)                                     2.0
# Applause (digital testing company)                 2.0
# Applause (software company)                        2.0
# Argex Titanium Inc.                                0.0
# Argex Mining                                       1.0
# Army and Air Force Motion Picture Service          1.0
# Army and Air Force Exchange Service                7.0
# Atari, Inc.                                       11.0
# Atari, Inc. (Atari, SA subsidiary)                25.0
# WellAway Limited                                                      WellAway
# Wendy's Supa Sundaes                                                   Wendy's
# Wendy's                                                                Wendy's
# Western Power (networks corporation)                             Western Power
# Western Power Corporation                                        Western Power
# World Wide Pictures                                        World Wide Pictures
# World Wide Pictures (UK)                                   World Wide Pictures
# List of Yamaha guitars                                      Yamaha Corporation
# Yamaha electric guitar models                               Yamaha Corporation
# Yamaha Corporation                                          Yamaha Corporation
# Yates (company)                                                          Yates
# Yates's                                                                  Yates
# ZAP (motor company)                                                        ZAP
# ZAP (satellite television)                                                 ZAP
# STX Offshore & Shipbuilding                                     [u'Co., Ltd.']
# Fukui Television Broadcasting                                   [u'Co., Ltd.']
# Wok to Walk                                                           wagamama
# Wagamama                                                              wagamama
#
#                                            num_employees
# wiki_title
# Big Bazaar (Rourkela)                                NaN
# Big Bazaar                                       36000.0
# Hanriot                                              NaN
# Hanriot (aircraft company)                           NaN
# Darracq and Company London                           NaN
# Automobiles Darracq France                           NaN
# Haglöfs                                            200.0
# ASICS                                             5937.0
# Abrazo Scottsdale Campus                           650.0
# Abrazo Scottsdale Campus Arizona                   650.0
# Al Marjan Island LLC                                 NaN
# Al Marjan Island                                     NaN
# Alchemy Boulders                                     NaN
# Alchemy (company)                                    NaN
# Amiga, Inc. (South Dakota)                           5.0
# Amiga, Inc.                                          NaN
# Amplify (company)                                    NaN
# Amplify (distributor)                                NaN
# Andersen Tax                                       500.0
# Andersen Tax LLC                                   800.0
# Anki (Finnish company)                               NaN
# Anki (company)                                       NaN
# Applause (digital testing company)                 301.0
# Applause (software company)                        301.0
# Argex Titanium Inc.                                 22.0
# Argex Mining                                        22.0
# Army and Air Force Motion Picture Service         2950.0
# Army and Air Force Exchange Service              35000.0
# Atari, Inc.                                          NaN
# Atari, Inc. (Atari, SA subsidiary)                  10.0
# ...                                                  ...
# C&P Telephone                                        NaN
# Casas Bahia                                      57500.0
# Via Varejo                                       65160.0
# Vision Research Phantom                              NaN
# Vision Research (cameras)                            NaN
# Vitra (furniture)                                    NaN
# VitrA (sanitaryware)                                 NaN
# Vétra (workwear)                                     NaN
# Vétra                                                NaN
# Walton Hi-Tech Industries Limited                10000.0
# Walton (motorcycle)                                  NaN
# WellAway                                             NaN
# WellAway Limited                                     NaN
# Wendy's Supa Sundaes                                 NaN
# Wendy's                                          21200.0
# Western Power (networks corporation)                 NaN
# Western Power Corporation                            NaN
# World Wide Pictures                                  NaN
# World Wide Pictures (UK)                             NaN
# List of Yamaha guitars                           26803.0
# Yamaha electric guitar models                    26803.0
# Yamaha Corporation                               19851.0
# Yates (company)                                      NaN
# Yates's                                              NaN
# ZAP (motor company)                                  NaN
# ZAP (satellite television)                           NaN
# STX Offshore & Shipbuilding                          NaN
# Fukui Television Broadcasting                        NaN
# Wok to Walk                                        300.0
# Wagamama                                             NaN
#
# [426 rows x 3 columns]

# %%
# now drop the one's with duplicate names, will take the second duplicate with less links
c_dupl_sort.drop_duplicates('name', inplace=True)
c_dupl_sort
# Out:
#                                                                                        links  \
# wiki_title
# Big Bazaar (Rourkela)                       {Future Group, Rourkela Steel Plant, Big Bazaar}
# Hanriot                                    {Air Sylphe, Gourdou-Leseurre, Loire Aviation,...
# Darracq and Company London                 {Heenan & Froude, Automobiles Talbot France, C...
# Haglöfs                                                                              {ASICS}
# Abrazo Scottsdale Campus                   {Abrazo Community Health Network, Tenet Health...
# Al Marjan Island LLC                                                                      {}
# Alchemy Boulders                                                                          {}
# Amiga, Inc. (South Dakota)                 {Commodore International, MetaComCo, Amiga, In...
# Amplify (company)                                                          {Asus, News Corp}
# Andersen Tax                                                         {HSBC, Arthur Andersen}
# Anki (Finnish company)                                                                    {}
# Applause (digital testing company)                             {Google, Concur Technologies}
# Argex Titanium Inc.                                                                       {}
# Army and Air Force Motion Picture Service              {Army and Air Force Exchange Service}
# Atari, Inc.                                {Commodore International, Warner Communication...
# Athena (company)                                                                          {}
# Babes.com                                                                         {MindGeek}
# Banco di Sardegna                          {Banca Popolare di Vicenza, Banca Generali, Ba...
# Bank of Melbourne (1989)                   {BT Financial Group, Bank of Melbourne (2011),...
# Intelligent Finance                        {Clerical Medical, Royal Bank of Scotland Grou...
# Bengal and North Western Railway           {Diesel Locomotive Works, Oudh and Tirhut Rail...
# Bevolo Luci a Gas ed Elettrici                                                            {}
# Big W                                      {Woolworths Limited, Caltex Woolworths, Georgi...
# Boundless (company)                        {Valore (company), Kno, Inkling, BenchPrep, Fl...
# Brihan Maharashtra Sugar Syndicate                {Brihans Natural Products, Bloomberg L.P.}
# Brihans Natural Products                   {Bath & Body Works, Bonne Bell, Brihan Maharas...
# Logo of the BBC                            {Freesat, BBC Sport, BBC Films, BBC, YouView, ...
# Jessop & Company                           {Butterley Company, Bharat Bhari Udyog Nigam, ...
# Central European Institute of Technology                                                  {}
# Cactus (camera equipment brand)                                                           {}
# ...                                                                                      ...
# Berkeley Cinemas                                            {Pacific Equity Partners, Hoyts}
# Farmville Basin                                                        {Farmville, Virginia}
# Child & Co.                                {Royal Bank of Scotland Group, Bank of Wales, ...
# The Vision Factory                                                                 {Philips}
# Pavilions (supermarket)                    {Jerry's Foods, Niemann Foods, Strack & Van Ti...
# Times Mirror Company                       {Tribune Broadcasting, Hearst Television, Nexs...
# Tip Top Bakeries                             {Associated British Foods, George Weston Foods}
# Tokyo Waterfront Area Rapid Transit        {Rinkai Line, East Japan Railway Company, Mizu...
# Video Gaming Technologies                                               {Aristocrat Leisure}
# Tupperware Brands                                                       {Rexall, Tupperware}
# Haseko                                                                                    {}
# Umbra (company)                                              {Umbra (3D technology company)}
# United Aircraft Corporation                {Komsomolsk-on-Amur Aircraft Production Associ...
# Viadyaratnam Treatment Centre – Franchise  {Steel Industries Kerala Limited, Dhanlaxmi Ba...
# Girish Jain                                                          {Venus Records & Tapes}
# Verizon Maryland                           {AT&T Corporation, Verizon New England, Terrem...
# Casas Bahia                                                     {Bloomberg L.P., Via Varejo}
# Vision Research Phantom                                                             {Ametek}
# Vitra (furniture)                                                  {Deutsche Bank, Novartis}
# Vétra (workwear)                                                                          {}
# ...                                                                                      ...
# Berkeley Cinemas                                                            Berkeley+Cinemas
# Farmville Basin                                                              Farmville+Basin
# Child & Co.                                                                    Child+%26+Co.
# The Vision Factory                                                        The+Vision+Factory
# Pavilions (supermarket)                                          Pavilions+%28supermarket%29
# Times Mirror Company                                                    Times+Mirror+Company
# Tip Top Bakeries                                                            Tip+Top+Bakeries
# Tokyo Waterfront Area Rapid Transit                      Tokyo+Waterfront+Area+Rapid+Transit
# Video Gaming Technologies                                          Video+Gaming+Technologies
# Tupperware Brands                                                          Tupperware+Brands
# Haseko                                                                                Haseko
# Umbra (company)                                                          Umbra+%28company%29
# United Aircraft Corporation                                      United+Aircraft+Corporation
# Viadyaratnam Treatment Centre – Franchise  Viadyaratnam+Treatment+Centre+%E2%80%93+Franchise
# Girish Jain                                                                      Girish+Jain
# Verizon Maryland                                                            Verizon+Maryland
# Casas Bahia                                                                      Casas+Bahia
# Vision Research Phantom                                              Vision+Research+Phantom
# Vitra (furniture)                                                      Vitra+%28furniture%29
# Vétra (workwear)                                                   V%C3%A9tra+%28workwear%29
# Walton Hi-Tech Industries Limited                          Walton+Hi-Tech+Industries+Limited
# WellAway                                                                            WellAway
# Wendy's Supa Sundaes                                                  Wendy%27s+Supa+Sundaes
# Western Power (networks corporation)                Western+Power+%28networks+corporation%29
# World Wide Pictures                                                      World+Wide+Pictures
# List of Yamaha guitars                                                List+of+Yamaha+guitars
# Yates (company)                                                          Yates+%28company%29
# ZAP (motor company)                                                  ZAP+%28motor+company%29
# STX Offshore & Shipbuilding                                    STX+Offshore+%26+Shipbuilding
# Wok to Walk                                                                      Wok+to+Walk
#
#                                                                                         logo  \
# wiki_title
# Big Bazaar (Rourkela)                      {u'wiki_raw_code': u'Big Bazaar Logo.jpg', u'w...
# Hanriot                                                                                 None
# Darracq and Company London                                                              None
# Haglöfs                                    {u'wiki_raw_code': u'Image:Logo Haglofs.png', ...
# Abrazo Scottsdale Campus                                                                None
# Al Marjan Island LLC                                                                    None
# Alchemy Boulders                           {u'wiki_raw_code': u'[[File:Alchemy Boulders l...
# Amiga, Inc. (South Dakota)                                                              None
# Amplify (company)                                                                       None
# Andersen Tax                                                                            None
# Anki (Finnish company)                                                                  None
# Applause (digital testing company)         {u'wiki_raw_code': u'[[File:Applause,_Inc.jpg|...
# Argex Titanium Inc.                                                                     None
# Army and Air Force Motion Picture Service                                               None
# Atari, Inc.                                {u'wiki_raw_code': u'Atari logo alt.svg', u'wi...
# Athena (company)                                                                        None
# Babes.com                                                                               None
# Banco di Sardegna                          {u'wiki_raw_code': u'[[File:Banco di Sardegna ...
# Bank of Melbourne (1989)                                                                None
# Intelligent Finance                        {u'wiki_raw_code': u'[[Image:Intelligent Finan...
# Bengal and North Western Railway                                                        None
# Bevolo Luci a Gas ed Elettrici                                                          None
# Big W                                      {u'wiki_raw_code': u'[[Image: BIGW Logo.png]]'...
# Boundless (company)                        {u'wiki_raw_code': u'[[File:boundless-logo-cen...
# Brihan Maharashtra Sugar Syndicate                                                      None
# Brihans Natural Products                                                                None
# Logo of the BBC                            {u'wiki_raw_code': u'[[File:BBC.svg|200px|BBC ...
# Jessop & Company                                                                        None
# Central European Institute of Technology   {u'wiki_raw_code': u'[[File:CEITEC logo.jpg|28...
# Cactus (camera equipment brand)            {u'wiki_raw_code': u'[[Image:CactusLogo.jpg|17...
# ...                                                                                      ...
# Berkeley Cinemas                                                                        None
# Farmville Basin                                                                         None
# Child & Co.                                {u'wiki_raw_code': u'Child & Co logo.png', u'w...
# The Vision Factory                         {u'wiki_raw_code': u'[[File:TheVisionFactoryLo...
# Pavilions (supermarket)                    {u'wiki_raw_code': u'[[File:Pavilions (superma...
# Times Mirror Company                                                                    None
# Tip Top Bakeries                           {u'wiki_raw_code': u'[[File:Logo TipTop.jpg|26...
# Tokyo Waterfront Area Rapid Transit                                                     None
# Video Gaming Technologies                                                               None
# Tupperware Brands                          {u'wiki_raw_code': u'[[Image:Tupperware Brands...
# Haseko                                                                                  None
# Umbra (company)                            {u'wiki_raw_code': u'[[File:Umbra logo.png|100...
# United Aircraft Corporation                {u'wiki_raw_code': u'[[File:Logo United Aircra...
# Viadyaratnam Treatment Centre – Franchise                                               None
# Girish Jain                                                                             None
# Verizon Maryland                           {u'wiki_raw_code': u'<!-- Do NOT place non-fre...
# Casas Bahia                                {u'wiki_raw_code': u'Casas Bahia logo.svg', u'...
# Vision Research Phantom                    {u'wiki_raw_code': u'File:Vision Research Logo...
# Vitra (furniture)                          {u'wiki_raw_code': u'[[Image:Image-Vitra Logo....
# Vétra (workwear)                           {u'wiki_raw_code': u'Logo Vétra.jpg', u'wiki_f...
# Walton Hi-Tech Industries Limited                                                       None
# WellAway                                   {u'wiki_raw_code': u'Wellaway logo.png', u'wik...
# Wendy's Supa Sundaes                       {u'wiki_raw_code': u'Wendy's_Supa_Sundaes.jpg'...
# Western Power (networks corporation)       {u'wiki_raw_code': u'[[Image:Western Power New...
# World Wide Pictures                                                                     None
# List of Yamaha guitars                                                                  None
# Yates (company)                            {u'wiki_raw_code': u'[[File:Yates logo.JPG|180...
# ZAP (motor company)                                                                     None
# STX Offshore & Shipbuilding                {u'wiki_raw_code': u'[[File:조선해양.png|250px]]',...
# Wok to Walk                                                                             None
#
#                                                                                       subsid  \
# wiki_title
# Big Bazaar (Rourkela)                                                                   None
# Hanriot                                                                                 None
# Darracq and Company London                                                              None
# Haglöfs                                                                                 None
# Abrazo Scottsdale Campus                                                                None
# Al Marjan Island LLC                                                                    None
# Alchemy Boulders                                                                        None
# Amiga, Inc. (South Dakota)                                                              None
# Amplify (company)                                                                       None
# Andersen Tax                                                                            None
# Anki (Finnish company)                                                                  None
# Applause (digital testing company)                                                      None
# Argex Titanium Inc.                                                                     None
# Army and Air Force Motion Picture Service                                               None
# Atari, Inc.                                                                             None
# Athena (company)                                                                        None
# Babes.com                                                                               None
# Banco di Sardegna                                                                       None
# Bank of Melbourne (1989)                                                                None
# Intelligent Finance                                                                     None
# Bengal and North Western Railway                                                        None
# Bevolo Luci a Gas ed Elettrici                                                          None
# Big W                                                                                   None
# Boundless (company)                                                                     None
# Brihan Maharashtra Sugar Syndicate                                                      None
# Brihans Natural Products                                                                None
# Logo of the BBC                                                                         None
# Jessop & Company                                                                        None
# Central European Institute of Technology                                                None
# Cactus (camera equipment brand)                                                         None
# ...                                                                                      ...
# Berkeley Cinemas                                                        [Hoyts Distribution]
# Farmville Basin                                                                         None
# Child & Co.                                                                             None
# The Vision Factory                                                                      None
# Pavilions (supermarket)                                                                 None
# Times Mirror Company                                                                    None
# Tip Top Bakeries                                                                        None
# Tokyo Waterfront Area Rapid Transit                                                     None
# Video Gaming Technologies                                                               None
# Tupperware Brands                                                                       None
# Haseko                                                                                  None
# Umbra (company)                                                                         None
# United Aircraft Corporation                [Voronezh Aircraft Production Association, Ber...
# Viadyaratnam Treatment Centre – Franchise                                               None
# Girish Jain                                                                             None
# Verizon Maryland                                                                        None
# Casas Bahia                                                                             None
# Vision Research Phantom                                                                 None
# Vitra (furniture)                                                                       None
# Vétra (workwear)                                                                        None
# Walton Hi-Tech Industries Limited                                                       None
# WellAway                                                                                None
# Wendy's Supa Sundaes                                                                    None
# Western Power (networks corporation)                                                    None
# World Wide Pictures                                                                     None
# List of Yamaha guitars                                                                  None
# Yates (company)                                                                         None
# ZAP (motor company)                                                  [Zhejiang Jonway (51%)]
# STX Offshore & Shipbuilding                                                             None
# Wok to Walk                                                                             None
#
#                                                                                location_city  \
# wiki_title
# Big Bazaar (Rourkela)                                                                   None
# Hanriot                                    Bétheny, Boulogne-Billancourt, Carrières-sur-S...
# Darracq and Company London                                                              None
# Haglöfs                                                                                 None
# Abrazo Scottsdale Campus                                                                None
# Al Marjan Island LLC                                                          Ras Al Khaimah
# Alchemy Boulders                                                                        None
# Amiga, Inc. (South Dakota)                                                              None
# Amplify (company)                                                                       None
# Andersen Tax                                                                            None
# Anki (Finnish company)                                                                  None
# Applause (digital testing company)                                 Framingham, Massachusetts
# Argex Titanium Inc.                                                                 Montreal
# Army and Air Force Motion Picture Service                                               None
# Atari, Inc.                                                                             None
# Athena (company)                                                                        None
# Babes.com                                                                   Montreal, Quebec
# Banco di Sardegna                                                                       None
# Bank of Melbourne (1989)                                                                None
# Intelligent Finance                                                                     None
# Bengal and North Western Railway                                                        None
# Bevolo Luci a Gas ed Elettrici                                                          None
# Big W                                                           Bella Vista, New South Wales
# Boundless (company)                                                                     None
# Brihan Maharashtra Sugar Syndicate                                                      Pune
# Brihans Natural Products                                                 Shaniwar Peth, Pune
# Logo of the BBC                                                                       London
# Jessop & Company                                                                     Kolkata
# Central European Institute of Technology                                                Brno
# Cactus (camera equipment brand)                                                         None
# ...                                                                                      ...
# Berkeley Cinemas                                                                        None
# Farmville Basin                                                                         None
# Child & Co.                                                                             None
# The Vision Factory                                                                      None
# Pavilions (supermarket)                                                                 None
# Times Mirror Company                                                                    None
# Tip Top Bakeries                                                                        None
# Tokyo Waterfront Area Rapid Transit                                              Kōtō, Tokyo
# Video Gaming Technologies                                                Franklin, Tennessee
# Army and Air Force Motion Picture Service  Army and Air Force Motion Picture Service
# Atari, Inc.                                                              Atari, Inc.
# ...
# Tupperware Brands                          [Asset, Brownie Wise, Cosmetics, Direct sales,...
# Haseko                                                             [Condominium, Nikkei 225]
# Umbra (company)                            [Canada, Hlynur Atlason, Housewares, Karim Ras...
# United Aircraft Corporation                [Aeroflot, Aerospace, Aircraft industry of Rus...
# Viadyaratnam Treatment Centre – Franchise  [Aanayoottu, Academy of climate change educati...
# Girish Jain                                [Akele Hum Akele Tum, Baadshah (1999 film), Ba...
# Verizon Maryland                           [AOL, AOL Desktop, AOL Explorer, AOL Hometown,...
# Casas Bahia                                [Bahia, Bloomberg L.P., Brasilia, Brazil, Braz...
# Vision Research Phantom                    [Academy Scientific and Technical Award, Amete...
# Vitra (furniture)                          [Alberto Meda, Allentown, Pennsylvania, Alvaro...
# Vétra (workwear)                                                 [Kanban, Le Lude, Workwear]
# Walton Hi-Tech Industries Limited          [Bangladesh, Automobile, Automotive industry, ...
# WellAway                                   [American Medical Association, Barack Obama, B...
# Wendy's Supa Sundaes                       [Adelaide, Ali Baba (franchise), Australia, Ba...
# Western Power (networks corporation)       [ATCO, Albany Wind Farm, Alinta, Bluewaters Po...
# World Wide Pictures                        [1951 in film, 1965 in film, 1973 in film, 197...
# List of Yamaha guitars                     [Automobile, Conglomerate (company), Earnings ...
# Yates (company)                            [Auckland, Australia, Dulux, New Zealand, Pare...
# ZAP (motor company)                        [21st Century Insurance, AB Volvo USA, AGCO, A...
# STX Offshore & Shipbuilding                [Asset, Busan, Chairman, FPSO, Jinhae, Korean ...
# Wok to Walk                                [Amsterdam, Asian cuisine, Barcelona, Berlin, ...
#
#                                                               location_gps  \
# wiki_title
# Big Bazaar (Rourkela)                                         (None, None)
# Hanriot                                             (46.603354, 1.8883335)
# Darracq and Company London                         (48.8710147, 2.2252883)
# Haglöfs                                           (59.6749712, 14.5208584)
# Abrazo Scottsdale Campus                        (33.4485866, -112.0773455)
# Al Marjan Island LLC                               (25.7737705, 55.938232)
# Alchemy Boulders                                   (7.2930922, 80.6350768)
# Amiga, Inc. (South Dakota)                 (42.5252972785, -96.4960886743)
# Amplify (company)                                             (None, None)
# Andersen Tax                                    (37.7792808, -122.4192362)
# Anki (Finnish company)                            (60.1674086, 24.9425683)
# Applause (digital testing company)               (42.2792625, -71.4161719)
# Argex Titanium Inc.                               (45.497684, -73.6125179)
# Army and Air Force Motion Picture Service        (32.7762719, -96.7968558)
# Atari, Inc.                                     (37.3688301, -122.0363495)
# Athena (company)                                              (None, None)
# Babes.com                                         (45.497684, -73.6125179)
# Banco di Sardegna                                  (40.7232643, 8.5610074)
# Bank of Melbourne (1989)                        (-37.8142175, 144.9631608)
# Intelligent Finance                                           (None, None)
# Bengal and North Western Railway                  (22.3511148, 78.6677428)
# Bevolo Luci a Gas ed Elettrici                                (None, None)
# Big W                                          (-32.8956668, 151.74238135)
# Boundless (company)                          (42.36136175, -71.0691552263)
# Brihan Maharashtra Sugar Syndicate            (18.64395815, 73.9325681901)
# Brihans Natural Products                          (18.5192839, 73.8524863)
# Logo of the BBC                                   (51.5073219, -0.1276473)
# Jessop & Company                                  (22.5677459, 88.3476023)
# Central European Institute of Technology          (49.1922443, 16.6113382)
# Cactus (camera equipment brand)                  (22.2793278, 114.1628131)
# ...                                                                    ...
# Berkeley Cinemas                                 (-33.8679573, 151.210047)
# Farmville Basin                                  (37.3024713, -78.3923812)
# Child & Co.                                       (51.5073219, -0.1276473)
# The Vision Factory                                 (51.2684164, 5.5949186)
# Pavilions (supermarket)                                       (None, None)
# Times Mirror Company                            (34.0543942, -118.2439408)
# Tip Top Bakeries                                 (-33.8679573, 151.210047)
# Tokyo Waterfront Area Rapid Transit                 (35.649154, 139.81279)
# Video Gaming Technologies                         (35.925193, -86.8689364)
# Tupperware Brands                                (28.5421175, -81.3790461)
# Haseko                                                        (None, None)
# Umbra (company)                                  (43.6529206, -79.3849007)
# United Aircraft Corporation                       (55.7506828, 37.6174976)
# Viadyaratnam Treatment Centre – Franchise          (10.485326, 76.2350095)
# Girish Jain                                                   (None, None)
# Verizon Maryland                                 (39.2908816, -76.6107589)
# Casas Bahia                                     (-23.6195922, -46.5688322)
# Vision Research Phantom                          (40.9491723, -74.2376801)
# Vitra (furniture)                                  (47.5542152, 7.6304739)
# Vétra (workwear)                                   (47.6463281, 0.1576725)
# Walton Hi-Tech Industries Limited                 (23.7593572, 90.3788136)
# WellAway                                          (43.255205, -79.8682019)
# Wendy's Supa Sundaes                                          (None, None)
# Western Power (networks corporation)             (-31.952712, 115.8604796)
# World Wide Pictures                              (44.9772995, -93.2654691)
# List of Yamaha guitars                           (36.5748441, 139.2394179)
# Yates (company)                                               (None, None)
# ZAP (motor company)                             (38.4404675, -122.7144313)
# STX Offshore & Shipbuilding                     (35.147838, 128.619167382)
# Wok to Walk                                    (52.3745403, 4.89797550562)
#
#                                           wiki_page_id wb_api_url  \
# wiki_title
# Big Bazaar (Rourkela)                         46454193        NaN
# Hanriot                                       12681181        NaN
# Darracq and Company London                    30862570        NaN
# Haglöfs                                        4446963        NaN
# Abrazo Scottsdale Campus                      48338967        NaN
# Al Marjan Island LLC                          47113267        NaN
# Alchemy Boulders                              13352678        NaN
# Amiga, Inc. (South Dakota)                    14893446        NaN
# Amplify (company)                             38755162        NaN
# Andersen Tax                                  29840306        NaN
# Anki (Finnish company)                        48954654        NaN
# Applause (digital testing company)            42843977        NaN
# Argex Titanium Inc.                           40615891        NaN
# Army and Air Force Motion Picture Service     38587842        NaN
# Atari, Inc.                                   16462490        NaN
# Athena (company)                               5445173        NaN
# Babes.com                                     52218049        NaN
# Banco di Sardegna                             24986296        NaN
# Bank of Melbourne (1989)                      31281789        NaN
# Intelligent Finance                            2996633        NaN
# Bengal and North Western Railway              39813363        NaN
# Bevolo Luci a Gas ed Elettrici                28653054        NaN
# Big W                                          3428007        NaN
# Boundless (company)                           39971610        NaN
# Brihan Maharashtra Sugar Syndicate            52266477        NaN
# Brihans Natural Products                      52234177        NaN
# Logo of the BBC                               29164513        NaN
# Jessop & Company                              34122519        NaN
# Central European Institute of Technology      29661407        NaN
# Cactus (camera equipment brand)               46887767        NaN
# ...                                                ...        ...
# Berkeley Cinemas                              13056950        NaN
# Farmville Basin                               51314266        NaN
# Child & Co.                                    7019464        NaN
# The Vision Factory                            37721061        NaN
# Pavilions (supermarket)                        2925358        NaN
# Times Mirror Company                          17507201        NaN
# Tip Top Bakeries                               6183092        NaN
# Tokyo Waterfront Area Rapid Transit             390226        NaN
# Video Gaming Technologies                     49320965        NaN
# Tupperware Brands                              3592515        NaN
# Haseko                                        51179389        NaN
# Umbra (company)                               27759612        NaN
# United Aircraft Corporation                    7058125        NaN
# Viadyaratnam Treatment Centre – Franchise     34446200        NaN
# Girish Jain                                   49501219        NaN
# Verizon Maryland                              27616232        NaN
# Casas Bahia                                    7432666        NaN
# Vision Research Phantom                       35564703        NaN
# Vitra (furniture)                              7289517        NaN
# Vétra (workwear)                              47392430        NaN
# Walton Hi-Tech Industries Limited             41911636        NaN
# WellAway                                      52119497        NaN
# Wendy's Supa Sundaes                           3873418        NaN
# Western Power (networks corporation)           5960886        NaN
# World Wide Pictures                            2120549        NaN
# List of Yamaha guitars                        30700900        NaN
# Yates (company)                               23486373        NaN
# ZAP (motor company)                            9010381        NaN
# STX Offshore & Shipbuilding                   15430110        NaN
# Wok to Walk                                   51517808        NaN
#
#                                           wb_api_search_url link_amount
# wiki_title
# Big Bazaar (Rourkela)                                   NaN         3.0
# Hanriot                                                 NaN        40.0
# Darracq and Company London                              NaN         7.0
# Haglöfs                                                 NaN         1.0
# Abrazo Scottsdale Campus                                NaN         8.0
# Al Marjan Island LLC                                    NaN         0.0
# Alchemy Boulders                                        NaN         0.0
# Amiga, Inc. (South Dakota)                              NaN        10.0
# Amplify (company)                                       NaN         2.0
# Andersen Tax                                            NaN         2.0
# Anki (Finnish company)                                  NaN         0.0
# Applause (digital testing company)                      NaN         2.0
# Argex Titanium Inc.                                     NaN         0.0
# Army and Air Force Motion Picture Service               NaN         1.0
# Atari, Inc.                                             NaN        11.0
# Athena (company)                                        NaN         0.0
# Babes.com                                               NaN         1.0
# Banco di Sardegna                                       NaN       122.0
# Bank of Melbourne (1989)                                NaN         4.0
# Intelligent Finance                                     NaN        91.0
# Bengal and North Western Railway                        NaN        16.0
# Bevolo Luci a Gas ed Elettrici                          NaN         0.0
# Big W                                                   NaN        16.0
# Boundless (company)                                     NaN         5.0
# Brihan Maharashtra Sugar Syndicate                      NaN         2.0
# Brihans Natural Products                                NaN        46.0
# Logo of the BBC                                         NaN        11.0
# Jessop & Company                                        NaN         5.0
# Central European Institute of Technology                NaN         0.0
# Cactus (camera equipment brand)                         NaN         0.0
# ...                                                     ...         ...
# Berkeley Cinemas                                        NaN         2.0
# Farmville Basin                                         NaN         1.0
# Child & Co.                                             NaN        86.0
# The Vision Factory                                      NaN         1.0
# Pavilions (supermarket)                                 NaN       251.0
# Times Mirror Company                                    NaN         9.0
# Tip Top Bakeries                                        NaN         2.0
# Tokyo Waterfront Area Rapid Transit                     NaN         3.0
# Video Gaming Technologies                               NaN         1.0
# Tupperware Brands                                       NaN         2.0
# Haseko                                                  NaN         0.0
# Umbra (company)                                         NaN         1.0
# United Aircraft Corporation                             NaN        11.0
# Viadyaratnam Treatment Centre – Franchise               NaN        13.0
# Girish Jain                                             NaN         1.0
# Verizon Maryland                                        NaN        49.0
# Casas Bahia                                             NaN         2.0
# Vision Research Phantom                                 NaN         1.0
# Vitra (furniture)                                       NaN         2.0
# Vétra (workwear)                                        NaN         0.0
# Walton Hi-Tech Industries Limited                       NaN         7.0
# WellAway                                                NaN         0.0
# Wendy's Supa Sundaes                                    NaN        49.0
# Western Power (networks corporation)                    NaN         8.0
# World Wide Pictures                                     NaN         1.0
# List of Yamaha guitars                                  NaN         1.0
# Yates (company)                                         NaN         0.0
# ZAP (motor company)                                     NaN       190.0
# STX Offshore & Shipbuilding                             NaN         2.0
# Wok to Walk                                             NaN         0.0
#
# [207 rows x 31 columns]

# %%
# now drop the rows of our main dataframe which are in the dataframe with the unwanted duplicates
dupl_companies = list(c_dupl_sort.index.values)
comp_df.drop(dupl_companies, inplace=True)

# %% [markdown]
# A good export format is a CSV file the properties of lists and dictionaries are lost but that is actually an advantage exporting to `gexf` for visualization in gephi.

# %%
comp_df.to_csv(extraction_csv, encoding='utf-8')

# %% [markdown]
# ### 2.2. Company Statistics
#
# This section is about revealing some things that would not be visible by simply studying the table. To achieve this there is always a simple iteration over all values and the top 10 are generated using the `Counter` object from the [collections](https://docs.python.org/2/library/collections.html) library.

# %% [markdown]
# #### Most Links per Company
#
# In below cell the number of links for each company is counted.

# %%
cnt = Counter()
# iterate every row that represents a company
for index, row in comp_df.iterrows():
    # empty link list
    if isinstance(row['links'], float):
        continue
    cnt[row['name']] = len(row['links'])

print "Top 10 companies with most links:"
pprint(cnt.most_common(10))
# Out:
# Top 10 companies with most links:
# [(u'Telia Company AB', 529),
#  (u'Hitachi, Ltd.', 524),
#  (u'Vodafone Group', 519),
#  (u'Sony Corporation', 511),
#  (u'Panasonic Corporation', 489),
#  (u'Toshiba Corporation', 488),
#  (u'Kyocera Corporation', 487),
#  (u'Mitsubishi Electric Corporation', 466),
#  (u'Comcast Corporation', 461),
#  (u'Fujitsu Ltd.', 460)]

# %% [markdown]
# Technology companies seem to have a lot of references to other companies.

# %% [markdown]
# #### Most Employees per Company
#
# Next the companies are sorted according to number of employees.

# %%
cnt = Counter()
for index, row in comp_df.iterrows():
    if pd.isnull(row['num_employees']):
        continue
    cnt[row['name']] = row['num_employees']

print "Highest number of employees by company:"
pprint(cnt.most_common(10))
# Out:
# Highest number of employees by company:
# [(u'UMW Holdings Berhad', 1100000.0),
#  (u'JSC Russian Railways', 942808.0),
#  (u'Rostec', 900000.0),
#  (u'China Post Group Corporation', 860200.0),
#  (u'Tata Group', 660800.0),
#  (u'G4S plc', 618000.0),
#  (u'Volkswagen AG', 610076.0),
#  (u'Volkswagen', 610000.0),
#  (u'People Ready', 600000.0),
#  (u'Tesco PLC', 597784.0)]

# %% [markdown]
# The companies with most employees are unsurprisingly in area's where many people live.

# %% [markdown]
# #### Names of People over all Companies
# The next cells are used to find most influential people's names. Regardless of the data cleaning efforts some entries are just to different from each other so some things need to be cleared.

# %%
def check_if_real(p):
    """The human parser is not as accurate, so we need to sort out some false names"""
    if p and p.isalpha() and \
        not re.search(r'President|Chairman|Manag|Founder|VP|Officer|CTO|CEO|CFO|COO|Director', p, re.IGNORECASE):
            return True
    return False

# %%
females = set(names.words('female.txt'))

def count_people(key):
    cnt_first, cnt_last, cnt_female = Counter(), Counter(), Counter()
    for index, comp in merged_companies.iteritems():
        if not comp[key]:
            continue
        for person in comp[key]:
            if isinstance(person, dict):
                if check_if_real(person['first']):
                    cnt_first[person['first']] += 1
                    if person['first'] in females:
                        cnt_female[person['first']] += 1
                if check_if_real(person['last']):
                    cnt_last[person['last']] += 1

    print "Most common male first names by company key people:"
    pprint(cnt_first.most_common(10))

    print "Most common female first names by company key people:"
    pprint(cnt_female.most_common(10))

    print "Most common last names by company key people:"
    pprint(cnt_last.most_common(10))

# %%
count_people('key_people')
# Out:
# Most common male first names by company key people:
# [(u'John', 690),
#  (u'David', 571),
#  (u'Michael', 420),
#  (u'Robert', 314),
#  (u'Mark', 307),
#  (u'Peter', 295),
#  (u'Paul', 267),
#  (u'Richard', 264),
#  (u'James', 254),
#  (u'William', 206)]
# Most common female first names by company key people:
# [(u'Chris', 174),
#  (u'George', 146),
#  (u'Daniel', 116),
#  (u'Tim', 102),
#  (u'Frank', 99),
#  (u'Bill', 97),
#  (u'Tony', 82),
#  (u'Andy', 80),
#  (u'Alex', 73),
#  (u'Lee', 66)]
# Most common last names by company key people:
# [(u'Smith', 118),
#  (u'Lee', 72),
#  (u'Jones', 62),
#  (u'Brown', 59),
#  (u'Taylor', 55),
#  (u'Williams', 53),
#  (u'Miller', 50),
#  (u'Johnson', 47),
#  (u'Wilson', 45),
#  (u'Singh', 45)]

# %%
count_people('founders')
# Out:
# Most common male first names by company key people:
# [(u'John', 491),
#  (u'David', 324),
#  (u'William', 311),
#  (u'Robert', 246),
#  (u'Michael', 245),
#  (u'James', 197),
#  (u'Peter', 197),
#  (u'Charles', 192),
#  (u'George', 189),
#  (u'Paul', 186)]
# Most common female first names by company key people:
# [(u'George', 189),
#  (u'Chris', 129),
#  (u'Frank', 105),
#  (u'Bill', 105),
#  (u'Daniel', 100),
#  (u'Alex', 68),
#  (u'Tony', 54),
#  (u'Fred', 49),
#  (u'Tim', 48),
#  (u'Sam', 45)]
# Most common last names by company key people:
# [(u'Smith', 82),
#  (u'Johnson', 46),
#  (u'Williams', 41),
#  (u'Miller', 41),
#  (u'Brown', 39),
#  (u'Group', 39),
#  (u'Anderson', 38),
#  (u'Lee', 37),
#  (u'Cohen', 37),
#  (u'Gupta', 33)]

# %%
for index, comp in merged_companies.iteritems():
    if not comp['key_people']:
        continue
    for person in comp['key_people']:
        if isinstance(person, dict):
            if person['first'] == 'John' and  person['last'] == 'Smith':
                print "Actual people called John Smith in company:", comp['wiki_name']
# Out:
# Actual people called John Smith in company: GB Railfreight

# %% [markdown]
# As you can see John Smith is not only a very common name but also a very successful businessman. At least one could argue that if your first name is John or your last name is Smith not necessarily both. Also we are shocked by the female names which are probably all males.

# %% [markdown]
# ### 2.3. Company Graphs
#
# In this part there are some basics graphs revealing how the distribution of crawled companies is.
#
# In the following cells the geodata of companies is gathered for specific areas. These points will be accumulated in a kernel density map (also heatmap) with the [geoplotlib](https://github.com/andrea-cuttone/geoplotlib) module.

# %%
def get_all_geodata(dataset, bounds=None):
    """Get geodata for specific latitude and longitude input bounds."""

    # filter bad rows
    dataset = dataset[dataset.location_gps.notnull()]
    
    # ignore the warning about chained assignments
    pd.options.mode.chained_assignment = None 
    # make 2 extra columns for split longitude and latitude
    dataset['lat'], dataset['lon'] = zip(*dataset.location_gps)    
    
    # only activity in the boundaries
    if not bounds:
        include = dataset.location_gps.notnull()
    else:
        include = (dataset.lat > bounds[0]) & \
        (dataset.lat < bounds[1]) & \
        (dataset.lon > bounds[2]) & \
        (dataset.lon < bounds[3])
        
    # get data in the format geoplotlib requires. We put the geodata in a dictionary structured as follows
    geo_coords = dataset.loc[include].location_gps.tolist()
    geo_data = {
        "lat": [x[0] for x in geo_coords if x[0]], 
        "lon": [x[1] for x in geo_coords if x[1]]
    }
    return geo_data

# %% [markdown]
# 4 plots will be created one for all points, the USA, Europe and Asia (including China, Japan, South Korea, India). The plots are inline in the notebook.

# %%
# create the dictionary with lat and lon
geodat_all_comp = get_all_geodata(comp_df)
geodat_us_comp = get_all_geodata(
    comp_df,
    # [min lat, max lat, min lon, max lon)]
    [24.9493, 49.5904, -125.0011, -66.9326]
)
geodat_eu_comp = get_all_geodata(
    comp_df,
    # [min lat, max lat, min lon, max lon)]
    [27.6363, 70, -25, 40]
)
geodat_asia_comp = get_all_geodata(
    comp_df,
    # [min lat, max lat, min lon, max lon)]
    [0, 43, 70, 160]
)

# %%
def geo_plot(geodata):
    """Plot given coordinate input."""

    # bounding box on the minima and maxima of the data
    geoplotlib.set_bbox(
        BoundingBox(
            max(geodata['lat']), 
            max(geodata['lon']), 
            min(geodata['lat']), 
            min(geodata['lon'])
        ));
    
    # kernel density estimation visualization
    geoplotlib.kde(geodata, bw=5, cut_below=1e-3, cmap='hot', alpha=170)
    # google tiles with lyrs=y ... hybrid
    geoplotlib.tiles_provider({
        #'url': lambda zoom, xtile, ytile: 'https://mt1.google.com/vt/lyrs=y&hl=en&x=%d&y=%d&z=%d' % (xtile, ytile, zoom),
        'url': lambda zoom, xtile, ytile: 'https://maps.wikimedia.org/osm-intl/%d/%d/%d.png' % (zoom, xtile, ytile),
        'tiles_dir': 'DTU-social_graphs',
        'attribution': 'DTU - 02805 Social graphs and interactions'
    })
    
    geoplotlib.inline();

# %%
print 'all companies'
geo_plot(geodat_all_comp)
# Out:
# all companies
# ('smallest non-zero count', 1.4329573088768091e-09)
# ('max count:', 21.740096339281834)
# <img style='width: 900px; margin: 0px; float: left; border: 1px solid black;' src='...
# #### General Histogram Distribution Analysis in accordance with Found and Defunct year

# %%
com_founded_years=list()
com_defounded_years=list()
acient=0
for com, com_detail in comp_df.iteritems():
    if com_detail['founded']: 
        found_year=int(com_detail['founded'].year)
        if found_year>=1800 and found_year<=int(datetime.date.today().year):
            com_founded_years.append(int(found_year))
        elif found_year<1800: 
            acient=acient+1 #count of com eariler than 1800
    if com_detail['defunct']:
        defound_year=int(com_detail['defunct'].year)
        if defound_year>=1800 and defound_year<=int(datetime.date.today().year):
            com_defounded_years.append(int(defound_year))     

            
#compute defunct rate
com_founded_dict= dict()
com_founded_cum=dict()
com_founded_count=Counter(com_founded_years)

for key in sorted(com_founded_count.iterkeys()):
    com_founded_dict[key]= com_founded_count[key]
    
    acient=acient+com_founded_count[key]
    com_founded_cum[key]= acient

defunt_cum=0
com_defounded_dict= dict()

com_defounded_count=Counter(com_defounded_years)
for key in sorted(com_defounded_count.iterkeys()):
    com_defounded_dict[key]= com_defounded_count[key]
    
    defunt_cum=defunt_cum+com_defounded_count[key]
    com_founded_cum[key]=com_founded_cum[key]-defunt_cum
#patching defunct dict
years_no_defunct=set(com_defounded_dict.keys()).symmetric_difference(com_founded_dict.keys())
for year_no_defunct in years_no_defunct:
    com_defounded_dict[year_no_defunct]=0
    
defunct_rates=list()
for cum, defunct in zip(com_founded_cum.values(),com_defounded_dict.values()):
    defunct_rates.append((defunct/cum)*100)


#plot histogram
fig = plt.figure(num=None, figsize=(20, 20), dpi=1200)
ax = fig.add_subplot(211)
count, bins, ignored = ax.hist(com_founded_years, bins=50,alpha=0.5, range=(min(com_founded_years), max(com_founded_years)),label="Found")
count, bins, ignored = ax.hist(com_defounded_years, bins=50,alpha=0.5, range=(min(com_defounded_years), max(com_defounded_years)),label="Defunct")

ax.legend(loc=2,fontsize=15)
ax.set_title("Number of companies founded/defunct after 1800",fontsize=20)
ax.set_xlabel('Timeline',fontsize=15)
ax.set_ylabel('Count',fontsize=15)
plt.xticks(list(plt.xticks()[0]) + [2008]) #add special tick for 2008, possible financial crisis influence

ax = fig.add_subplot(212)
ax.bar(com_founded_dict.keys(),defunct_rates,color='y')
ax.set_title("Defunct rate since 1800",fontsize=20)
ax.set_xlabel('Timeline',fontsize=15)
ax.set_ylabel('Rate',fontsize=15)


plt.xticks(list(plt.xticks()[0]) + [2008]) #add special tick for 2008, possible financial crisis influence
plt.show()
# Out:
# wiki_title
# &pizza                                        {Ruby Tuesday (restaurant), City Sports}
# +Beryll                                  {Henri Bendel, Fred Segal, Los Angeles Times}
# ...instore                           {Home Bargains, Heron Foods, Tesco, Shoprite (...
# 01 Communique                                                                       {}
# 01 Distribution                                                                  {RAI}
# 07th Expansion                                                   {Alchemist (company)}
# 0verflow                                                                            {}
# 1-2-3 (fuel station)                                           {Statoil Fuel & Retail}
# 1-800 Contacts                       {Johnson & Johnson, DITTO, CooperVision, AEA I...
# 1-800-FREE-411                       {Google, Liberty Media, Tellme Networks, March...
# 1-800-Flowers                        {CompuServe, AOL, Comtex, Martha Stewart Livin...
# 1-800-GOT-JUNK?                      {HSBC Bank Canada, Teradici, The Pantry (resta...
# 1-Page                                               {Business Wire, Blumberg Capital}
# 1-UP Studio                          {Nintendo Software Planning & Development, Nin...
# 10 feet                                                                             {}
# 10,000ft                                                          {Artefact (company)}
# 100 Women in Hedge Funds             {The Trump Organization, PAAMCO, DonorsChoose,...
# 100% Banco                                                                          {}
# 1000Bulbs.com                                                                       {}
# 1000Memories                         {Wieden+Kennedy, McKinsey & Company, Greylock ...
# 108 Shop                             {Tom's Convenience Store, Delhaize Group, Mini...
# 10Bet, LLC                                                                          {}
# 10th Legion Championship Fighting    {Battlecade Extreme Fighting, Super Fight Leag...
# 10x (company)                                                                       {}
# 10x Genomics                                                      {Illumina (company)}
# 11 bit studios                                       {CD Projekt, Metropolis Software}
# 112dB                                {Apple Inc., Dolby Laboratories, Native Instru...
# 12 Yard                              {ITV Studios, Wireless Group, STV Group (Scotl...
# 12 bis                                                                              {}
# 123 Money                                                        {RSA Insurance Group}
#                                                            ...
# Đuro Đaković (company)               {Tvornica Autobusa Zagreb, Atlantska plovidba,...
# Ērenpreiss Bicycles                                     {G. Ērenpreis Bicycle Factory}
# İDO                                                         {İDO, Damen Group, Austal}
# İZBAN A.Ş.                           {Hyundai Rotem, Turkish State Railways, Constr...
# İhlas Holding                        {Migros Türk, Akbank, Petrol Ofisi, Ülker, Coc...
# İlbank                                                                              {}
# İletişim Yayınları                                                                  {}
# İnterbank                                                  {Etibank, Çukurova Holding}
# İsdemir                                                                      {Erdemir}
# İstanbul Plak                                                                       {}
# İzocam                               {Migros Türk, Akbank, Petrol Ofisi, Ülker, Coc...
# İş Yatırım                           {DYO Boya Fabrikaları, Renaissance Capital (Ru...
# Łódzka Kolej Aglomeracyjna           {Arriva RP, PKP Polskie Linie Kolejowe, Lotos ...
# Ōigawa Railway                                                                      {}
# Şahinler Holding                                                                    {}
# Şekerbank                            {Migros Türk, Akbank, Petrol Ofisi, Ülker, Coc...
# Šipad                                                                               {}
# Škoda Auto                           {Hispano-Suiza, DKW, Škoda Auto India Private ...
# Škoda Auto India Private Limited     {DKW, Capital Group Companies, Ford Motor Comp...
# Škoda Transportation                 {Rīgas Satiksme, Helsinki Regional Transport A...
# Škoda Works                          {Ganz Works, České dráhy, Škoda Auto, Škoda Tr...
# Školska knjiga                                                                      {}
# Štark                                                                               {}
# Ūkio bankas                                          {Nasdaq Nordic, General Electric}
# ŽIA valda                                       {Avia Solutions Group, Agrowill Group}
# Železara Smederevo                                         {Hesteel Group, U.S. Steel}
# Železničná spoločnosť Slovensko               {RegioJet, Rail transport in Montenegro}
# Željeznički prevoz Crne Gore         {Deutsche Bahn, Calea Ferată din Moldova, Iarn...
# Živnostenská banka                                          {UniCredit, Dresdner Bank}
# Țiriac Holdings                                                              {Allianz}
# Name: links, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-de50d72836b6> in <module>()
#       4 for com, com_detail in comp_df.iteritems():
#       5     print com_detail
# ----> 6     if com_detail['founded']:
#       7         found_year=int(com_detail['founded'].year)
#       8         if found_year>=1800 and found_year<=int(datetime.date.today().year):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# /usr/local/lib/python2.7/dist-packages/pandas/indexes/base.pyc in get_value(self, series, key)
#    2151                     raise InvalidIndexError(key)
#    2152                 else:
# -> 2153                     raise e1
#    2154             except Exception:  # pragma: no cover
#    2155                 raise e1
#
# KeyError: 'founded'

# %% [markdown]
# Companies by age of foundation.

# %% [markdown]
# ## 3. Network Construction

# %% [markdown]
# ### 3.1. Alternative Construction

# %% [markdown]
# ## 4. Network Analysis
#
# Below analysis

# %% [markdown]
# ### 4.1. Degree Distribution

# %% [markdown]
# ### 4.2. Power-laws and Friendship Paradox
#
# Next step is to prove the [Friendship paradox](https://en.wikipedia.org/wiki/Friendship_paradox). This paradox states that _almost everyone_ have fewer friends than their friends have, on average.
# A consequence of having a network with a power-law degree distribution. The explanation is that almost everyone is friends with a hub, that drives up the average degree of the friends.

# %% [markdown]
# Pick a node $i$ at random (e.g. use `random.choice`). [Find its degree](http://networkx.lanl.gov/reference/generated/networkx.Graph.degree.html) and [neighbors](http://networkx.lanl.gov/reference/generated/networkx.Graph.neighbors.html).

# %%
# pick random node
i = rand.choice(G.nodes())
# find its degree
i_deg = G.degree(i)
# find neighbours
i_neighs = G.neighbors(i)

# %%
def get_average_degree(graph, nodes=None, print_edges=False):
    if not nodes:
        nodes = graph.nodes()
    deg_graph = graph.degree(nbunch=nodes)
    sum_of_edges = sum(deg_graph.values())
    deg = sum_of_edges/len(nodes)
    if print_edges:
        return deg, deg_graph.values()
    return deg

# %% [markdown]
# Now we find the neighbors average degree and compare the averages to check if it's true that $i$'s friends (on average) have more friends than $i$.

# %%
# calculate average degree of neighbors
i_neighs_avg_deg = get_average_degree(G, i_neighs, print_edges=False)

# show details
print 'Random node i {0} with degree of {1} has neighbour(s) {2}'.format(i, i_deg, i_neighs)
print 'Neighbour(s) {0} of random node i {1} has/have average degree of {2}'.format(i_neighs, i, i_neighs_avg_deg)

# %% [markdown]
# This will be done a 1000 times to see the percantage of cases how often the paradoxon is true.

# %%
# try 1000 times how often paradoxon true
paradoxon_true = 0
trials = 1000
for x in xrange(0, trials):
    i = rand.choice(G.nodes())
    i_deg = G.degree(i)
    i_neighs = G.neighbors(i)
    i_neighs_avg_deg = get_average_degree(G, i_neighs, print_edges=False)
    if i_neighs_avg_deg > i_deg:
        paradoxon_true += 1
print "Out of {0} trials the friendship paradoxon was true {1} time(s).".format(trials, paradoxon_true)

# %% [markdown]
# ### 4.3. Centrality

# %% [markdown]
# ### 4.4. Assortativity

# %% [markdown]
# ### 4.5. Modularity

# %% [markdown]
# ### 4.6. Communities

# %% [markdown]
# ### 4.7. Network Visualizations and Statistics

# %% [markdown]
# ##  5. Sentiment Analysis of Twitter Data

# %% [markdown]
# ###  5.1. API Data Gathering

# %% [markdown]
# ###  5.2. Happiness Averages of Companies

# %% [markdown]
# ###  5.3. Wordclouds

# %% [markdown]
# ## 6. Discussion.
#
# Think critically about your creation:
# * What went well?,
# * What is still missing? What could be improved?, Why?
