# %% [markdown]
# # Overview
#
# This week is all about working with data. I'm not going to lie to you. This part might be frustrating - but frustration is an integral part of learning. Real data is almost always messy & difficult ... and learning to deal with that fact, is a key part of being a data scientist.
# >
# > **_Video Lecture_**: Since you guys will be struggling with real data today, the first lecture today is just a short, silly pep-talk to cheer you up in the midst of the tedium of working with messy wikipedia data.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("VlVvyWliQU8",width=800, height=450)

# %% [markdown]
# Enough about the process, let's get to the content. My plan for the next few lectures is to use network science and Wikipedia to learn about philosophy. We're going to download all the Wikipedia pages about philosophers from Wikipedia - and then create the network of the pages that link to each other. Next time, we'll use our network skills (as well as new ones) to understand that network. Further down the line, we'll use natural language processing to understand the text displayed on those pages.
#
# But for today, the tasks are
#
# * Learn about _regular expressions_
# * Find the names of all the philosopher-pages on Wikipedia
# * Download and store (for later use) all the philosopher-pages from Wikipedia
# * Extract all the internal wikipedia-links that connect the philosopher-pages on wikipedia
# * Generate the network of philosophers on wikipedia. We'll also do a little bit of initial analysis of the network.

# %% [markdown]
# # Part 0: Regular expressions
#
# Before we get started, we have to get a little head start on the _Natural Language Processing_ part of the class. This is a new direction for us, up to now, we've mostly been doing math-y stuff with Python, but today, we're going to be using Python to work through a text. The central thing we need to be able to do today, is to extract internal wikipedia links. And for that we need regular expressions.
#
# > _Exercises_: Regular expressions round 1\.
# >
# > * Read [**this tutorial**](https://developers.google.com/edu/python/regular-expressions) to form an overview of regular expressions. This is important to understand the content of the tutorial (also very useful later), so you may actually want to work through the examples.
# > * Now, explain in your own words: what are regular expressions?
#
# Regular expressions can be used to extract, match or substitute text to be able to get useful information or handle certain strings differently.
#
# > * Provide an example of a regex to match 4 digits numbers (by this, I mean precisely 4 digits, you should not match any part of numbers with e.g. 5 digits). In your notebook, use `findall` to show that your regex works on this [test-text](https://raw.githubusercontent.com/suneman/socialgraphs2016/master/files/test.txt). **Hint**: a great place to test out regular expressions is: https://regex101.com.

# %%
import requests
import re

r = requests.get('https://raw.githubusercontent.com/suneman/socialgraphs2016/master/files/test.txt')
print re.findall(r'\s([0-9]{4})\s', r.text)
# Out:
# [u'1234', u'9999']

# %% [markdown]
# > * Provide an example of a regex to match words starting with "super". Show that it works on the [test-text](https://raw.githubusercontent.com/suneman/socialgraphs2016/master/files/test.txt).
# >

# %%
print re.findall(r'super\w+', r.text)
# Out:
# [u'superpolaroid', u'supertaxidermy', u'superbeer']

# %% [markdown]
# Finally, we need to figure out how how to match internal wiki links. Wiki links come in two flavors. They're always enclosed in double square brackets, e.g. `[[wiki-link]]` and can either occur like this:
#
#     ... some text [[Aristotle]] some more text ...
#
# which links to the page [`https://en.wikipedia.org/wiki/Aristotle`](https://en.wikipedia.org/wiki/Aristotle).
#
# The second flavor has two parts, so that links can handle spaces and other more fancy forms of references, here's an example:
#
#     ... some text [[Eudemus_of_Rhodes|Eudemus of Rhodos]] some more text ...
#
# which links to the page [`https://en.wikipedia.org/wiki/Eudemus_of_Rhodes`](https://en.wikipedia.org/wiki/Eudemus_of_Rhodes). Now it's your turn.

# %% [markdown]
# > _Exercise_: Regular expressions round 2\. Show that you can extract the wiki-links from the [test-text](https://raw.githubusercontent.com/suneman/socialgraphs2016/master/files/test.txt). Perhaps you can find inspiration on stack overflow or similar. **Hint**: Try to solve this exercise on your own (that's what you will get the most out of - learning wise), but if you get stuck ... take a look at the video lecture below.
# >

# %%
wiki_part = 'https://en.wikipedia.org/wiki/'
matches = re.findall(r'\[\[(.+?)\]\]', r.text) # ? is non-greedy
final_links = list()
for m in matches:
    final_links.append('{0}{1}'.format(wiki_part, m.split('|')[0].replace(' ', '_')))
print final_links
# Out:
# ['https://en.wikipedia.org/wiki/drinking_vinegar', 'https://en.wikipedia.org/wiki/gentrify', 'https://en.wikipedia.org/wiki/hashtag', 'https://en.wikipedia.org/wiki/Bicycle', 'https://en.wikipedia.org/wiki/Pitchfork']

# %% [markdown]
# # Part A: Download Philosopher-pages from Wikipedia
#
# Armed with some knowledge of regular expressions, we're going to start extracting all the names of philosophers on Wikipedia. These will be the nodes of our network.
#
# > **_Video Lecture_**: A barebones strategy for getting philosopher page names.
# >

# %%
YouTubeVideo("91gknsVGHls",width=800, height=450)

# %% [markdown]
# > _Exercise_: Find the names of all the philosopher-pages, download and analyze them.
# >
# > * [This wiki-page](https://en.wikipedia.org/wiki/Lists_of_philosophers) contains list of philosophers from various branches of philosophy:
# >   1. [aestheticians](https://en.wikipedia.org/wiki/List_of_aestheticians)
# >   2. [epistemologists](https://en.wikipedia.org/wiki/List_of_epistemologists)
# >   3. [ethicists](https://en.wikipedia.org/wiki/List_of_ethicists)
# >   4. [logicians](https://en.wikipedia.org/wiki/List_of_logicians)
# >   5. [metaphysicians](https://en.wikipedia.org/wiki/List_of_metaphysicians)
# >   6. [social and political philosophers](https://en.wikipedia.org/wiki/List_of_social_and_political_philosophers)

# %%
from bs4 import BeautifulSoup
import pprint

phil_links = [
    ('https://en.wikipedia.org/w/index.php?title=List_of_aestheticians&action=edit', 'aestheticians'),
    ('https://en.wikipedia.org/w/index.php?title=List_of_epistemologists&action=edit', 'epistemologists'),
    ('https://en.wikipedia.org/w/index.php?title=List_of_ethicists&action=edit', 'ethicists'),
    ('https://en.wikipedia.org/w/index.php?title=List_of_logicians&action=edit', 'logicians'),
    ('https://en.wikipedia.org/w/index.php?title=List_of_metaphysicians&action=edit', 'metaphysicians'),
    ('https://en.wikipedia.org/w/index.php?title=List_of_social_and_political_philosophers&action=edit', 'social_and_political_philosophers')
]

# get all philosopher pages wiki text
all_matches = {
    'all': set()
}
for l in phil_links:
    r = requests.get(l[0])
    soup = BeautifulSoup(r.text, 'html.parser')
    wiki_text = soup.find('textarea').get_text()
    # lines of philosophers start with "*" or "*St."
    # this link in logicians '[[Categoriae decem]]'' wasn't counted
    matches = re.findall(r'(\*\s?|\*\s?St\.\s?)\[\[(.+?)\]\]', wiki_text)
    # only 2nd group with philosopher name
    # remove any lists that can occur in the == See also == section
    m = [x[1].split('|')[0].replace(' ', '_') for x in matches if not re.match(r'list of.*', x[1], re.IGNORECASE)]
    # put in dictonary
    all_matches[l[1]] = m
    all_matches['all'] |= set(m)

pprint.pprint(all_matches)
# Out:
# {'aestheticians': [u'Andreas_Linder',
#                    u'Virgil_Aldrich',
#                    u'Anandavardhana',
#                    u'Sri_Aurobindo',
#                    u'John_Anderson_(philosopher)',
#                    u'Yves_Marie_Andr\xe9',
#                    u'Thomas_Aquinas',
#                    u'Aristotle',
#                    u'Rudolf_Arnheim',
#                    u'Mazen_Asfour',
#                    u'Georg_Anton_Friedrich_Ast',
#                    u'Augustine_of_Hippo',
#                    u'Jody_Azzouni',
#                    u'Victor_Basch',
#                    u'Yusuf_Balasagun',
#                    u'Roland_Barthes',
#                    u'Georges_Bataille',
#                    u'Alexander_Gottlieb_Baumgarten',
#                    u'Monroe_Beardsley',
#                    u'Vissarion_Belinsky',
#                    u'Clive_Bell',
#                    u'Walter_Benjamin',
#                    u'Arnold_Berleant',
#                    u'George_Birkhoff',
#                    u'Max_Black',
#                    u'Maurice_Blanchot',
#                    u'Harold_Bloom',
#                    u'Georg_Brandes',
#                    u'Cameron_Breen',
#                    u'Jean_Anthelme_Brillat-Savarin',
#                    u'Ferruccio_Busoni',
#                    u'John_Cage',
#                    u'Cesare_Brandi',
#                    u'Stanley_Cavell',
#                    u'R._G._Collingwood',
#                    u'Victor_Cousin',
#                    u'Benedetto_Croce',
#                    u'Gregory_Currie',
#                    u'Arthur_Danto',
#                    u'William_C._Dowling',
#                    u'John_Dewey',
#                    u'Umberto_Eco',
#                    u'Jonathan_Edwards_(theologian)',
#                    u'Ralph_Waldo_Emerson',
#                    u'Jerry_Farber',
#                    u'Valentin_Feldman',
#                    u'Henri_Focillon',
#                    u'Michel_Foucault',
#                    u'Hans-Georg_Gadamer',
#                    u'Alexander_Gerard',
#                    u'Nelson_Goodman',
#                    u'Edmund_Gurney',
#                    u'Etienne_Gilson',
#                    u'Paul_H\xe4berlin',
#                    u'Garry_Hagberg',
#                    u'Ferdinand_Gotthelf_Hand',
#                    u'Eduard_Hanslick',
#                    u'Georg_Wilhelm_Friedrich_Hegel',
#                    u'Fran\xe7ois_Hemsterhuis',
#                    u'Johann_Friedrich_Herbart',
#                    u'Johann_Gottfried_Herder',
#                    u'Hermann_Theodor_Hettner',
#                    u'John_Hospers',
#                    u'Heinrich_Gustav_Hotho',
#                    u'David_Hume',
#                    u'Francis_Hutcheson_(philosopher)',
#                    u'Francis_Ernest_Jackson',
#                    u'Christopher_Janaway',
#                    u'James_Joyce',
#                    u'Immanuel_Kant',
#                    u'Mani_Kaul',
#                    u'S\xf8ren_Kierkegaard',
#                    u'Peter_Kivy',
#                    u'Andrzej_Tadeusz_Kijowski',
#                    u'Joseph_Kosuth',
#                    u'Susanne_Langer',
#                    u'Vernon_Lee',
#                    u'Gotthold_Ephraim_Lessing',
#                    u'Jerrold_Levinson',
#                    u'Liu_Xie',
#                    u'Longinus_(literature)',
#                    u'Peter_Lunenfeld',
#                    u'Jean-Fran\xe7ois_Lyotard',
#                    u'Gy\xf6rgy_Luk\xe1cs',
#                    u'John_Maeda',
#                    u'Andr\xe9_Malraux',
#                    u'Jacques_Maritain',
#                    u'Georg_Mehlis',
#                    u'Richard_Meltzer',
#                    u'Theodor_Mundt',
#                    u'Sam_Murgatroyd',
#                    u'Friedrich_Nietzsche',
#                    u'Michael_Oakeshott',
#                    u'Lalita_Pandit',
#                    u'Walter_Pater',
#                    u'Ronald_Paulson',
#                    u'Hans_Pfitzner',
#                    u'Plato',
#                    u'Edgar_Allan_Poe',
#                    u'Steven_Poole',
#                    u'Ayn_Rand',
#                    u'Thomas_Reid',
#                    u'John_Ruskin',
#                    u'George_Santayana',
#                    u'Friedrich_Wilhelm_Joseph_von_Schelling',
#                    u'Friedrich_Schiller',
#                    u'August_Wilhelm_Schlegel',
#                    u'Karl_Wilhelm_Friedrich_von_Schlegel',
#                    u'Arthur_Schopenhauer',
#                    u'Roger_Scruton',
#                    u'Calvin_Seerveld',
#                    u'Richard_Shusterman',
#                    u'Frank_Sibley_(philosopher)',
#                    u'Eli_Siegel',
#                    u'Guy_Sircello',
#                    u'Karl_Wilhelm_Ferdinand_Solger',
#                    u'Michael_Sprinker',
#                    u'Algernon_Charles_Swinburne',
#                    u'Socrates',
#                    u'Luca_Vercelloni',
#                    u'Tudor_Vianu',
#                    u'Kendall_Walton',
#                    u'Morris_Weitz',
#                    u'Oscar_Wilde',
#                    u'W.K._Wimsatt',
#                    u'Richard_Wollheim'],
#  'all': set([u':nl:Martinus_Dorpius',
#              u'A._J._Ayer',
#              u'Abraham_Fraenkel',
#              u'Abraham_Joshua_Heschel',
#              u'Abraham_Robinson',
#              u'Abraham_ibn_Daud',
#              u'Abul_Kalam_Azad',
#              u'Adam_M\xfcller',
#              u'Adam_Smith',
#              u'Adolf_Lindenbaum',
#              u'Adrian_Johnston_(philosopher)',
#              u'Ahmed_Raza_Khan',
#              u'Alain_Badiou',
#              u'Alan_Bundy',
#              u'Alan_Carter_(philosopher)',
#              u'Alan_Gewirth',
#              u'Alan_Ross_Anderson',
#              u'Alan_Ryan',
#              u'Alan_Turing',
#              u'Alasdair_MacIntyre',
#              u'Alasdair_Urquhart',
#              u'Alastair_Norcross',
#              u'Albert_Camus',
#              u'Albert_Schweitzer',
#              u'Albert_of_Saxony_(philosopher)',
#              u'Alcuin',
#              u'Aldo_Leopold',
#              u'Alexander_Bain',
#              u'Alexander_Campbell_Fraser',
#              u'Alexander_Esenin-Volpin',
#              u'Alexander_Gerard',
#              u'Alexander_Gottlieb_Baumgarten',
#              u'Alexander_S._Kechris',
#              u'Alexander_Zinoviev',
#              u'Alexis_de_Tocqueville',
#              u'Alfred_Horn',
#              u'Alfred_North_Whitehead',
#              u'Alfred_Rosenberg',
#              u'Alfred_Tarski',
#              u'Algernon_Charles_Swinburne',
#              u'Ali_Shariati',
#              u'Alice_Crary',
#              u'Alija_Izetbegovi\u0107',
#              u'Allan_Gibbard',
#              u'Alon_Ben-Meir',
#              u'Alonzo_Church',
#              u'Alvin_Goldman',
#              u'Alvin_Plantinga',
#              u'Amartya_Sen',
#              u'Ambrose',
#              u'Anandavardhana',
#              u'Anaximander',
#              u'Andrea_Bonom\xec',
#              u'Andreas_Linder',
#              u'Andrei_Marga',
#              u'Andronicus_of_Rhodes',
#              u'Andrzej_Mostowski',
#              u'Andrzej_Tadeusz_Kijowski',
#              u'Andr\xe9_Malraux',
#              u'Anne_Conway_(philosopher)',
#              u'Anne_Sjerp_Troelstra',
#              u'Anthony_de_Jasay',
#              u'Antoine_Garaby_de_La_Luzerne',
#              u'Antonio_Negri',
#              u'Ant\xf3nio_Castanheira_Neves',
#              u'Archon',
#              u'Arda_Denkel',
#              u'Arend_Heyting',
#              u'Aristotle',
#              u'Aristoxenus',
#              u'Armin_Mohler',
#              u'Arnold_Berleant',
#              u'Arthur_Caplan',
#              u'Arthur_Danto',
#              u'Arthur_Linton_Corbin',
#              u'Arthur_Moeller_van_den_Bruck',
#              u'Arthur_Prior',
#              u'Arthur_Schopenhauer',
#              u'Ashoka',
#              u'Auberon_Herbert',
#              u'August_Wilhelm_Schlegel',
#              u'Augustine_of_Hippo',
#              u'Augustus_De_Morgan',
#              u'Austin_Osman_Spare',
#              u'Averroes',
#              u'Avicenna',
#              u'Axel_Honneth',
#              u'Ayn_Rand',
#              u'B._F._Skinner',
#              u'B._R._Ambedkar',
#              u'Bahmany\u0101r',
#              u'Bahya_ibn_Paquda',
#              u"Bah\xe1'u'll\xe1h",
#              u'Barron_H._Lerner',
#              u'Barry_Stroud',
#              u'Baruch_Spinoza',
#              u'Benedetto_Croce',
#              u'Benjamin_Tucker',
#              u'Benjamin_Wiker',
#              u'Berit_Brogaard',
#              u'Bernard_Bolzano',
#              u'Bernard_Williams',
#              u'Bertrand_Russell',
#              u'Bertrand_de_Jouvenel',
#              u'Bjarni_J\xf3nsson',
#              u'Blaise_Pascal',
#              u'Bob_Meyer_(logician)',
#              u'Boethius',
#              u'Boris_Furlan',
#              u'Brian_Leftow',
#              u'Bruce_Lee',
#              u'Bruno_Leoni',
#              u'Bryan_Caplan',
#              u'C._D._Broad',
#              u'Calvin_Seerveld',
#              u'Cameron_Breen',
#              u'Carew_Arthur_Meredith',
#              u'Carl_Joachim_Friedrich',
#              u'Carl_Schmitt',
#              u'Carlo_Lottieri',
#              u'Carlos_Santiago_Nino',
#              u'Carol_Gilligan',
#              u'Carrie_Ichikawa_Jenkins',
#              u'Carveth_Read',
#              u'Catherine_Elgin',
#              u'Cesare_Brandi',
#              u'Chanakya',
#              u'Charles_Blattberg',
#              u'Charles_Parsons_(philosopher)',
#              u'Charles_Sanders_Peirce',
#              u'Charles_Stevenson',
#              u'Charles_Taylor_(philosopher)',
#              u'Cha\xefm_Perelman',
#              u'Cheng_Hao',
#              u'Cheng_Yi_(philosopher)',
#              u'Christian_Wolff_(philosopher)',
#              u'Christine_Korsgaard',
#              u'Christine_Ladd-Franklin',
#              u'Christopher_Janaway',
#              u'Chrysippus',
#              u'Clarence_Irving_Lewis',
#              u'Claude_Adrien_Helv\xe9tius',
#              u'Claude_Lefort',
#              u'Claude_L\xe9vi-Strauss',
#              u'Claudio_Canaparo',
#              u'Clive_Bell',
#              u'Colin_Wilson',
#              u'Confucius',
#              u'Conimbricenses',
#              u'Constantin_R\u0103dulescu-Motru',
#              u'Cora_Diamond',
#              u'Cornel_West',
#              u'Cornelius_Castoriadis',
#              u'Costas_Douzinas',
#              u'Craig_Paterson',
#              u'Dag_Prawitz',
#              u'Damon_Young',
#              u'Dana_Scott',
#              u'Dana_Ward',
#              u'Daniel_Brock',
#              u'Daniel_Gu\xe9rin',
#              u'Daniel_Wikler',
#              u'David_Bohm',
#              u'David_Chalmers',
#              u'David_Crocker',
#              u'David_D._Friedman',
#              u'David_Friedrich_Strauss',
#              u'David_Gauthier',
#              u'David_Hilbert',
#              u'David_Hume',
#              u'David_K._Lewis',
#              u'David_Kaplan_(philosopher)',
#              u'David_Kellogg_Lewis',
#              u'David_Kolb',
#              u'David_Korten',
#              u'David_L._Norton',
#              u'David_Lewis_(philosopher)',
#              u'David_Makinson',
#              u'David_Malet_Armstrong',
#              u'David_Miller_(political_theorist)',
#              u'David_Pearce_(philosopher)',
#              u'David_Prychitko',
#              u'David_Schmidtz',
#              u'David_Sosa',
#              u'David_Wiggins',
#              u'Dean_Zimmerman',
#              u'Democritus',
#              u'Derek_Parfit',
#              u'Dharmakirti',
#              u'Dick_de_Jongh',
#              u'Dietrich_Bonhoeffer',
#              u'Dign\u0101ga',
#              u'Dimiter_Skordev',
#              u'Dimitris_Dimitrakos',
#              u'Diodorus_Cronus',
#              u'Dirk_van_Dalen',
#              u'Disciples_of_Confucius',
#              u'Donald_A._Martin',
#              u'Donella_Meadows',
#              u'Dong_Zhongshu',
#              u'Donna_Haraway',
#              u'Dov_Gabbay',
#              u'Dugald_Macpherson',
#              u'Dugald_Stewart',
#              u'Duncan_Kennedy_(legal_philosopher)',
#              u'Duns_Scotus',
#              u'Edgar_Allan_Poe',
#              u'Edgar_Morin',
#              u'Edmund_Gettier',
#              u'Edmund_Gurney',
#              u'Eduard_Hanslick',
#              u'Edward_Hundert',
#              u'Edward_Nelson',
#              u'Edward_Said',
#              u'Ehud_Hrushovski',
#              u'Eli_Siegel',
#              u'Elizabeth_Harman_(disambiguation)',
#              u'Elliot_N._Dorff',
#              u'Emil_Leon_Post',
#              u'Emma_Goldman',
#              u'Emma_Rush',
#              u'Emmanuel_Levinas',
#              u'Enrique_Dussel',
#              u'Epicurus',
#              u'Eric_Voegelin',
#              u'Erich_Fromm',
#              u'Erich_Heller',
#              u'Ernest_Sosa',
#              u'Ernest_Wamba_dia_Wamba',
#              u'Ernst_Bloch',
#              u'Ernst_Schr\xf6der',
#              u'Ernst_Zermelo',
#              u'Ernst_von_Glasersfeld',
#              u'Etienne_Gilson',
#              u'Eugen_Rosenstock-Huessy',
#              u'Evert_Willem_Beth',
#              u'Fatema_Mernissi',
#              u'Fazlur_Rahman',
#              u'Felix_Kaufmann',
#              u'Ferdinand_Gotthelf_Hand',
#              u'Ferruccio_Busoni',
#              u"Francesco_D'Andrea",
#              u'Francis_Bacon',
#              u'Francis_Ernest_Jackson',
#              u'Francis_Fukuyama',
#              u'Francis_Hutcheson_(philosopher)',
#              u'Francis_Jeffrey',
#              u'Francis_Parker_Yockey',
#              u'Francisco_de_Vitoria',
#              u'Franco_Burgersdijk',
#              u'Frank_Herbert',
#              u'Frank_Meyer_(political_philosopher)',
#              u'Frank_Plumpton_Ramsey',
#              u'Frank_Schmalleger',
#              u'Frank_Sibley_(philosopher)',
#              u'Franz_Xaver_von_Baader',
#              u'Fran\xe7ois_Hemsterhuis',
#              u'Fred_Dretske',
#              u'Fred_Poch\xe9',
#              u'Frederick_Rowbottom',
#              u'Friedrich_A._Hayek',
#              u'Friedrich_Adolf_Trendelenburg',
#              u'Friedrich_Daniel_Ernst_Schleiermacher',
#              u'Friedrich_Eduard_Beneke',
#              u'Friedrich_Hayek',
#              u'Friedrich_Nietzsche',
#              u'Friedrich_Schiller',
#              u'Friedrich_Wilhelm_Joseph_von_Schelling',
#              u'Frithjof_Schuon',
#              u'Fujiwara_Seika',
#              u'Fyodor_Shcherbatskoy',
#              u'F\xe9lix_Guattari',
#              u'G.W.F._Hegel',
#              u'G._E._M._Anscombe',
#              u'G._E._Moore',
#              u'Gabriele_Taylor',
#              u'Gaisi_Takeuti',
#              u'Galileo_Galilei',
#              u'Garlandus_Compotista',
#              u'Garry_Hagberg',
#              u'Gary_Chartier',
#              u'Gary_R._Mar',
#              u'Gautama_Buddha',
#              u'Gene_Callahan_(economist)',
#              u'Geoffrey_Sayre-McCord',
#              u'Georg_Anton_Friedrich_Ast',
#              u'Georg_Brandes',
#              u'Georg_Cantor',
#              u'Georg_Henrik_von_Wright',
#              u'Georg_Jellinek',
#              u'Georg_Kreisel',
#              u'Georg_Mehlis',
#              u'Georg_Simmel',
#              u'Georg_W._F._Hegel',
#              u'Georg_Wilhelm_Friedrich_Hegel',
#              u'George_Berkeley',
#              u'George_Birkhoff',
#              u'George_Boole',
#              u'George_Boolos',
#              u'George_Croom_Robertson',
#              u'George_Edward_Moore',
#              u'George_Holmes_Howison',
#              u'George_Kateb',
#              u'George_Ohsawa',
#              u'George_Pappas',
#              u'George_Santayana',
#              u'Georges_Bataille',
#              u'Gerald_Cohen',
#              u'Gerald_Dworkin',
#              u'Gerald_Sacks',
#              u'Gerhard_Gentzen',
#              u'Gerhard_Vollmer',
#              u'Gerrard_Winstanley',
#              u'Ghazali',
#              u'Giacomo_Marramao',
#              u'Giambattista_Vico',
#              u'Gianfranco_Sanguinetti',
#              u'Giannina_Braschi',
#              u'Gilbert_Harman',
#              u'Gilbert_Simondon',
#              u'Gilbert_de_la_Porr\xe9e',
#              u'Gilles_Deleuze',
#              u'Giorgi_Japaridze',
#              u'Giorgio_Agamben',
#              u'Giorgio_Del_Vecchio',
#              u'Giovanni_Battista_Scaramelli',
#              u'Giovanni_Girolamo_Saccheri',
#              u'Giuseppe_Peano',
#              u'Glenn_McGee',
#              u'Gottfried_Leibniz',
#              u'Gotthold_Ephraim_Lessing',
#              u'Gottlob_Frege',
#              u'Graeme_Forbes',
#              u'Graham_Priest',
#              u'Gregory_Chaitin',
#              u'Gregory_Currie',
#              u'Grigori_Mints',
#              u'Gualtiero_Piccinini',
#              u'Gustave_de_Molinari',
#              u'Guy_Aldred',
#              u'Guy_Debord',
#              u'Guy_Sircello',
#              u'Gy\xf6rgy_Luk\xe1cs',
#              u'H._B._Acton',
#              u'H._L._A._Hart',
#              u'H._Richard_Niebuhr',
#              u'Hammurabi',
#              u'Han_Fei',
#              u'Han_Ryner',
#              u'Hannah_Arendt',
#              u'Hans-Georg_Gadamer',
#              u'Hans-Hermann_Hoppe',
#              u'Hans_Achterhuis',
#              u'Hans_Kelsen',
#              u'Hans_K\xf6chler',
#              u'Hans_K\xfcng',
#              u'Hans_Pfitzner',
#              u'Hao_Wang_(academic)',
#              u'Har_Dayal',
#              u'Harold_Bloom',
#              u'Harriet_Taylor_Mill',
#              u'Harry_Binswanger',
#              u'Hartry_Field',
#              u'Harvey_Friedman',
#              u'Haskell_Curry',
#              u'Hayashi_Razan',
#              u'Heinrich_Gustav_Hotho',
#              u'Heinz_von_Foerster',
#              u'Heiric_of_Auxerre',
#              u'Helena_Rasiowa',
#              u'Henk_Barendregt',
#              u'Henri_Bergson',
#              u'Henri_Focillon',
#              u'Henri_Lefebvre',
#              u'Henry_Babcock_Veatch',
#              u'Henry_David_Thoreau',
#              u'Henry_George',
#              u'Henry_Hazlitt',
#              u'Henry_Home,_Lord_Kames',
#              u'Henry_Pachter',
#              u'Henry_Sidgwick',
#              u'Heraclitus',
#              u'Herbert_Spencer',
#              u'Herman_Oliphant',
#              u'Hermann_Lotze',
#              u'Hermann_Theodor_Hettner',
#              u'Hierocles_of_Alexandria',
#              u'Hilary_Kornblith',
#              u'Hilary_Putnam',
#              u'Hirata_Atsutane',
#              u'Holly_Martin_Smith',
#              u'Horace_Romano_Harr\xe9',
#              u'Houston_Stewart_Chamberlain',
#              u'Howard_Zinn',
#              u'Hsun_Tzu',
#              u'Hugh_MacColl',
#              u'Hugo_Grotius',
#              u'Hui_Shi',
#              u'Ian_Rumfitt',
#              u'Ibn_Taymiyyah',
#              u'Igor_Pribac',
#              u'Immanuel_Kant',
#              u'Inayatullah_Khan_Mashriqi',
#              u'Iris_Marion_Young',
#              u'Isaac_Levi',
#              u'Isaac_Malitz',
#              u'Isaac_Watts',
#              u'Isabel_Paterson',
#              u'Isaiah_Berlin',
#              u"Ismail_Raji'_al-Faruqi",
#              u'Israel_Kirzner',
#              u'Israr_Ahmed',
#              u'It\u014d_Jinsai',
#              u'Ivan_Orlov_(philosopher)',
#              u'Ivan_Svit\xe1k',
#              u'J._Barkley_Rosser',
#              u'J._J._C._Smart',
#              u'J._L._Mackie',
#              u'J._M._E._McTaggart',
#              u'Jaakko_Hintikka',
#              u'Jack_Copeland',
#              u'Jack_Russell_Weinstein',
#              u'Jacob_M._Appel',
#              u'Jacopo_Zabarella',
#              u'Jacques_Herbrand',
#              u'Jacques_Maritain',
#              u'Jacques_Ranci\xe8re',
#              u'James_Brusseau',
#              u'James_Childress',
#              u'James_Earl_Baumgartner',
#              u'James_Frederick_Ferrier',
#              u'James_Hinton',
#              u'James_Joyce',
#              u'James_Martineau',
#              u'James_Mill',
#              u'James_Tully_(philosopher)',
#              u'James_VI_and_I',
#              u'Jamie_Whyte',
#              u'Jan_\u0141ukasiewicz',
#              u'Jane_Jacobs',
#              u'Janet_Biehl',
#              u'Janet_Coleman',
#              u'Jaoudat_Khouri',
#              u'Jawaharlal_Nehru',
#              u'Jay_Rosenberg',
#              u'Jean-Fran\xe7ois_Lyotard',
#              u'Jean-Jacques_Rousseau',
#              u'Jean-Louis_Le_Moigne',
#              u'Jean-Paul_Sartre',
#              u'Jean-Yves_B\xe9ziau',
#              u'Jean-Yves_Girard',
#              u'Jean_Anthelme_Brillat-Savarin',
#              u'Jean_Bodin',
#              u'Jean_Buridan',
#              u'Jean_Grondin',
#              u'Jean_Nicod',
#              u'Jean_Piaget',
#              u'Jean_Van_Heijenoort',
#              u'Jeff_Paris',
#              u'Jeffrey_Friedman_(political_scientist)',
#              u'Jeffrey_Stout',
#              u'Jennifer_Lackey',
#              u'Jenny_Teichman',
#              u'Jeremy_Bentham',
#              u'Jeroen_Groenendijk',
#              u'Jerrold_Levinson',
#              u'Jerry_Farber',
#              u'Jerzy_\u0141o\u015b',
#              u'Jessica_Wilson',
#              u'Jesus',
#              u'Jin_Yuelin',
#              u'Joachim_Jungius',
#              u'Joachim_Lambek',
#              u'Joan_Tronto',
#              u'Jody_Azzouni',
#              u'Johan_van_Benthem_(logician)',
#              u'Johann_Albert_Fabricius',
#              u'Johann_Friedrich_Herbart',
#              u'Johann_Georg_Walch',
#              u'Johann_Gottfried_Herder',
#              u'Johann_Heinrich_Lambert',
#              u'John_Anderson_(philosopher)',
#              u'John_Arthur_(philosopher)',
#              u'John_Austin_(legal_philosopher)',
#              u'John_Burnheim',
#              u'John_Cage',
#              u'John_Corcoran_(logician)',
#              u'John_Dewey',
#              u'John_Dumbleton',
#              u'John_Duns_Scotus',
#              u'John_Etchemendy',
#              u'John_Finnis',
#              u'John_Greco_(philosopher)',
#              u'John_Harsanyi',
#              u'John_Hawthorne',
#              u'John_Hospers',
#              u'John_Howard_Yoder',
#              u"John_Joseph_O'Connor",
#              u'John_Lane_Bell',
#              u'John_Locke',
#              u'John_M._Cooper',
#              u'John_Maeda',
#              u'John_Major_(philosopher)',
#              u'John_McDowell',
#              u'John_Oswald_(activist)',
#              u'John_Pagus',
#              u'John_Peters_Humphrey',
#              u'John_R._Steel',
#              u'John_Ralston_Saul',
#              u'John_Rawls',
#              u'John_Ruskin',
#              u'John_Searle',
#              u'John_Shelby_Spong',
#              u'John_Stevens_Cabot_Abbott',
#              u'John_Stuart_Mill',
#              u'John_Venn',
#              u'John_William_Miller',
#              u'John_Woods_(logician)',
#              u'John_Zerzan',
#              u'John_of_St._Thomas',
#              u'John_von_Neumann',
#              u'Jon_Barwise',
#              u'Jonathan_Dancy',
#              u'Jonathan_Edwards_(theologian)',
#              u'Jonathan_Wolff_(philosopher)',
#              u'Joseph_Diaz_Gergonne',
#              u'Joseph_Fins',
#              u'Joseph_Fletcher',
#              u'Joseph_Kosuth',
#              u'Joseph_Priestley',
#              u'Joseph_Priestley_and_Dissent',
#              u'Joseph_Raz',
#              u'Joseph_de_Torre',
#              u'Joshua_Cohen_(philosopher)',
#              u'Joxe_Azurmendi',
#              u'Juan_Luis_Vives',
#              u'Judith_Butler',
#              u'Judith_Jarvis_Thomson',
#              u'Jules_Vuillemin',
#              u'Julia_Annas',
#              u'Julia_Driver',
#              u'Julian_Gumperz',
#              u'Julian_Savulescu',
#              u'Julien_Offray_de_La_Mettrie',
#              u'Julius_Binder',
#              u'J\xf3zef_Maria_Boche\u0144ski',
#              u'J\xfcrgen_Habermas',
#              u'Kaibara_Ekken',
#              u'Karel_Lambert',
#              u'Karl-Otto_Apel',
#              u'Karl_Immanuel_Nitzsch',
#              u'Karl_Loewenstein',
#              u'Karl_Marx',
#              u'Karl_Popper',
#              u'Karl_Wilhelm_Ferdinand_Solger',
#              u'Karl_Wilhelm_Friedrich_von_Schlegel',
#              u'Karla_Jessen_Williamson',
#              u'Kazimierz_Ajdukiewicz',
#              u'Kazimierz_Twardowski',
#              u'Keith_Lehrer',
#              u'Kendall_Walton',
#              u'Kevin_Carson',
#              u'Kit_Fine',
#              u'Kurt_G\xf6del',
#              u'Kurt_Sch\xfctte',
#              u'L.A._Paul',
#              u'L._T._F._Gamut',
#              u'Lalita_Pandit',
#              u'Langdon_Winner',
#              u'Laurence_Bonjour',
#              u'Lauri_Ingman',
#              u'Lawrence_Kohlberg',
#              u'Lennart_\xc5qvist',
#              u'Leo_Harrington',
#              u'Leo_Tolstoy',
#              u'Leon_Chwistek',
#              u'Leon_Henkin',
#              u'Leonard_Borgzinner',
#              u'Leonard_Peikoff',
#              u'Leonard_Read',
#              u'Leonidas_Donskis',
#              u'Leopold_Kronecker',
#              u'Leopold_L\xf6wenheim',
#              u'Leslie_Stephen',
#              u'Lewis_Call',
#              u'Lewis_Carroll',
#              u'Linda_Trinkaus_Zagzebski',
#              u'Liu_Xie',
#              u'Lon_L._Fuller',
#              u'Longinus_(literature)',
#              u'Loren_Lomasky',
#              u'Lorenzo_Pe\xf1a',
#              u'Lorenzo_Valla',
#              u'Lotfi_A._Zadeh',
#              u'Louis_Althusser',
#              u'Louis_Pojman',
#              u'Luca_Vercelloni',
#              u'Lucius_Annaeus_Seneca',
#              u'Lucretius',
#              u'Ludwig_Wittgenstein',
#              u'Ludwig_von_Mises',
#              u'Luitzen_Egbertus_Jan_Brouwer',
#              u'Lynne_Rudder_Baker',
#              u'Lysander_Spooner',
#              u'Maimonides',
#              u'Mani_Kaul',
#              u'Manuel_De_Landa',
#              u'Mao_Zedong',
#              u'Marcion_of_Sinope',
#              u'Margaret_Canovan',
#              u'Margaret_Elizabeth_Egan',
#              u'Margaret_Somerville',
#              u'Marilyn_McCord_Adams',
#              u'Mario_Bunge',
#              u'Mario_Kopi\u0107',
#              u'Mario_Tronti',
#              u'Marquis_de_Sade',
#              u'Marsilius_of_Inghen',
#              u'Martha_Nussbaum',
#              u'Martin_Buber',
#              u'Martin_Davis',
#              u'Martin_Heidegger',
#              u'Martin_Luther_King,_Jr.',
#              u'Martin_L\xf6b',
#              u'Martin_Rees',
#              u'Martin_Stokhof',
#              u'Mary_Daly',
#              u'Matthew_Foreman',
#              u'Maurice_Blanchot',
#              u'Maurice_Brinton',
#              u'Maurice_Cranston',
#              u'Max_Baginski',
#              u'Max_Black',
#              u'Max_Horkheimer',
#              u'Max_Scheler',
#              u'Max_Stirner',
#              u'Mazdak',
#              u'Mazen_Asfour',
#              u'Melvin_Fitting',
#              u'Mencius',
#              u'Menedemus',
#              u'Michael_A._E._Dummett',
#              u'Michael_A._Smith',
#              u'Michael_Davis_(philosopher)',
#              u'Michael_Devitt',
#              u'Michael_Fourman',
#              u'Michael_J._Sandel',
#              u'Michael_Novak',
#              u'Michael_O._Rabin',
#              u'Michael_Oakeshott',
#              u'Michael_Otsuka',
#              u'Michael_Sprinker',
#              u'Michel_Foucault',
#              u'Michel_Onfray',
#              u'Miguel_A._De_La_Torre',
#              u'Mihailo_Markovi\u0107',
#              u'Mikelis_Avlichos',
#              u'Mikhail_Bakunin',
#              u'Milan_Kangrga',
#              u'Mioara_Mugur-Sch\xe4chter',
#              u'Mohandas_Gandhi',
#              u'Mohandas_Karamchand_Gandhi',
#              u'Moj\u017cesz_Presburger',
#              u'Monarchomachs',
#              u'Monroe_Beardsley',
#              u'Montesquieu',
#              u'Moritz_Schlick',
#              u'Morris_Weitz',
#              u'Mortimer_Adler',
#              u'Moses',
#              u'Moses_Sch\xf6nfinkel',
#              u'Moshe_Chaim_Luzzatto',
#              u'Moshe_Y._Vardi',
#              u'Mozi',
#              u'Muhammad',
#              u'Muhammad_Asad',
#              u'Muhammad_Iqbal',
#              u'Murray_Bookchin',
#              u'Murray_Rothbard',
#              u'Nader_El-Bizri',
#              u'Nancy_Cartwright_(philosopher)',
#              u'Nassim_Nicholas_Taleb',
#              u'Nathan_Salmon',
#              u'Nayef_Al-Rodhan',
#              u'Nelson_Goodman',
#              u'Nestor_Makhno',
#              u'Newton_da_Costa',
#              u'Niccol\xf2_Machiavelli',
#              u'Nick_Bostrom',
#              u'Nicolai_A._Vasiliev',
#              u'Nicolai_Hartmann',
#              u'Nicolas_Bourbaki',
#              u'Nicolas_Malebranche',
#              u'Nigel_Warburton',
#              u'Niklas_Luhmann',
#              u'Noam_Chomsky',
#              u'Nomy_Arpaly',
#              u'Norbert_Bolz',
#              u'Norbert_Leser',
#              u'Norman_Daniels',
#              u'Norman_Malcolm',
#              u'Nosson_Tzvi_Finkel_(Slabodka)',
#              u'Nuel_Belnap',
#              u'Ny\u0101ya_S\u016btras',
#              u'Octave_Mirbeau',
#              u'Ogy\u016b_Sorai',
#              u'Oliver_Wendell_Holmes,_Jr.',
#              u"Onora_O'Neill,_Baroness_O'Neill_of_Bengarve",
#              u'Oscar_Wilde',
#              u'Oskar_Negt',
#              u'Oswald_von_Nell-Breuning',
#              u'Otto_Weininger',
#              u'Owen_Flanagan',
#              u'P._F._Strawson',
#              u'Paolo_Virno',
#              u'Paolo_da_Pergola',
#              u'Parmenides',
#              u'Partha_Dasgupta',
#              u'Paul_Benacerraf',
#              u'Paul_Bernays',
#              u'Paul_Cohen_(mathematician)',
#              u'Paul_Grice',
#              u'Paul_Hawken',
#              u'Paul_H\xe4berlin',
#              u'Paul_Janet',
#              u'Paul_Lorenzen',
#              u'Paul_R._Patton',
#              u'Paul_Tillich',
#              u'Paul_Virilio',
#              u'Paul_of_Venice',
#              u'Pavel_Tich\xfd',
#              u'Pekka_Himanen',
#              u'Penelope_Maddy',
#              u'Per_Bauhn',
#              u'Per_Martin-L\xf6f',
#              u'Peter_Abelard',
#              u'Peter_B._Andrews_(mathematician)',
#              u'Peter_D._Klein',
#              u'Peter_Geach',
#              u'Peter_Glassen',
#              u'Peter_Goldie',
#              u'Peter_Kivy',
#              u'Peter_Kropotkin',
#              u'Peter_Lamborn_Wilson',
#              u'Peter_Lipton',
#              u'Peter_Ludlow',
#              u'Peter_Lunenfeld',
#              u'Peter_Medawar',
#              u'Peter_Railton',
#              u'Peter_Singer',
#              u'Peter_Sloterdijk',
#              u'Peter_Unger',
#              u'Peter_of_Spain_(author)',
#              u'Peter_van_Inwagen',
#              u'Petr_H\xe1jek',
#              u'Petrus_Ramus',
#              u'Phaleas_of_Chalcedon',
#              u'Philip_Doddridge',
#              u'Philip_Jourdain',
#              u'Philip_Mazzei',
#              u'Philip_Pettit',
#              u'Philip_Wicksteed',
#              u'Philippa_Foot',
#              u'Philippe_Van_Parijs',
#              u'Phillip_H._Wiebe',
#              u'Philo',
#              u'Philo_the_Dialectician',
#              u'Piergiorgio_Odifreddi',
#              u'Pierre-Andr\xe9_Taguieff',
#              u'Pierre_Ab\xe9lard',
#              u'Pierre_Bourdieu',
#              u'Pierre_Teilhard_de_Chardin',
#              u'Plato',
#              u'Plotinus',
#              u'Porphyry_(philosopher)',
#              u'Proclus_Lycaeus',
#              u'Prodicus',
#              u'Protagoras',
#              u'Pyotr_Novikov',
#              u'Pythagoras',
#              u'Quintilian',
#              u'R._Edward_Freeman',
#              u'R._G._Collingwood',
#              u'R._M._Hare',
#              u'Rada_Ivekovi\u0107',
#              u'Radhakamal_Mukerjee',
#              u'Raghunatha_Siromani',
#              u'Raimond_Gaita',
#              u'Rainer_Forst',
#              u'Ralph_Strode',
#              u'Ralph_Waldo_Emerson',
#              u'Ramon_Llull',
#              u'Randy_Cohen',
#              u'Raphael_M._Robinson',
#              u'Raya_Dunayevskaya',
#              u'Raymond_Frey',
#              u'Raymond_Smullyan',
#              u'Reinhold_Niebuhr',
#              u'Ren\xe9_Descartes',
#              u'Reuben_Louis_Goodstein',
#              u'Richard_Brinkley',
#              u'Richard_Ferrybridge',
#              u'Richard_Jeffrey',
#              u'Richard_Kilvington',
#              u'Richard_M._Weaver',
#              u'Richard_Meltzer',
#              u'Richard_Milton_Martin',
#              u'Richard_Montague',
#              u'Richard_Price',
#              u'Richard_Rorty',
#              u'Richard_Routley',
#              u'Richard_Shusterman',
#              u'Richard_Swineshead',
#              u'Richard_Sylvan',
#              u'Richard_Whately',
#              u'Richard_Wollheim',
#              u'Richard_the_Sophister',
#              u'Right_Hegelians',
#              u'Robert_Audi',
#              u'Robert_Kilwardby',
#              u'Robert_Kowalski',
#              u'Robert_Lawson_Vaught',
#              u'Robert_M._Solovay',
#              u'Robert_Merrihew_Adams',
#              u'Robert_Nozick',
#              u'Robert_P._George',
#              u'Robert_Paul_Wolff',
#              u'Robert_S._Hartman',
#              u'Robert_Stalnaker',
#              u'Roberto_Esposito',
#              u'Roberto_Mangabeira_Unger',
#              u'Robin_Gandy',
#              u'Roderick_Long',
#              u'Rodolphus_Agricola',
#              u'Roger_Chao',
#              u'Roger_Crisp',
#              u'Roger_Scruton',
#              u'Roland_Barthes',
#              u'Roland_Fra\xefss\xe9',
#              u'Rolf_Schock',
#              u'Ronald_Dworkin',
#              u'Ronald_Jensen',
#              u'Ronald_Paulson',
#              u'Ronald_Reagan',
#              u'Rosalind_Hursthouse',
#              u'Rudolf_Arnheim',
#              u'Rudolf_Carnap',
#              u'Rudolf_Christoph_Eucken',
#              u'Rudolf_Steiner',
#              u'Rushworth_Kidder',
#              u'Russ_Shafer-Landau',
#              u'Russell_Kirk',
#              u'Ruth_Barcan_Marcus',
#              u'S._Barry_Cooper',
#              u'Saharon_Shelah',
#              u'Sally_Haslanger',
#              u'Sam_Murgatroyd',
#              u'Samuel_Bailey',
#              u'Samuel_Scheffler',
#              u'Sandra_Harding',
#              u'Saul_Kripke',
#              u'Saunders_MacLane',
#              u'Sedulius_Scottus',
#              u'Serge_Moscovici',
#              u'Sergei_Adian',
#              u'Seyyed_Hossein_Nasr',
#              u'Shadworth_Hodgson',
#              u'Shelly_Kagan',
#              u'Sherrilyn_Roush',
#              u'Shmuel_Alexandrov',
#              u'Siegfried_Gottwald',
#              u'Simon_Critchley',
#              u'Simone_Weil',
#              u'Simone_de_Beauvoir',
#              u'Simplicius_of_Cilicia',
#              u'Slavoj_\u017di\u017eek',
#              u'Socrates',
#              u'Sol_Garfunkel',
#              u'Solomon_Feferman',
#              u'Solomon_Passy',
#              u'Spencer_Heath',
#              u'Sri_Aurobindo',
#              u'Stanis\u0142aw_Ja\u015bkowski',
#              u'Stanis\u0142aw_Le\u015bniewski',
#              u'Stanley_Cavell',
#              u'Stanley_Grenz',
#              u'Stanley_Hauerwas',
#              u'Stephen_Bronner',
#              u'Stephen_Cole_Kleene',
#              u'Steven_Poole',
#              u'Stewart_Shapiro',
#              u'Stobaeus',
#              u'Stuart_Wilde',
#              u'Sun_Yat-sen',
#              u'Susan_Haack',
#              u'Susan_Wolf',
#              u'Susanna_Schellenberg',
#              u'Susanna_Siegel',
#              u'Susanne_Langer',
#              u'Suzy_Kassem',
#              u'Swami_Vivekananda',
#              u'S\xf8ren_Kierkegaard',
#              u'T._H._Irwin',
#              u'T._M._Scanlon',
#              u'Tadeusz_Cze\u017cowski',
#              u'Tadeusz_Kotarbi\u0144ski',
#              u'Takis_Fotopoulos',
#              u'Tan_Sitong',
#              u'Tara_Smith_(philosopher)',
#              u'Tenzin_Gyatso',
#              u'Terence_McKenna',
#              u'Terence_Parsons',
#              u'Theodor_Mundt',
#              u'Theodor_Sternberg',
#              u'Theodor_W._Adorno',
#              u'Theodor_Zwinger',
#              u'Theodore_Sider',
#              u'Theodore_Slaman',
#              u'Theophrastus',
#              u'Thiruvalluvar',
#              u'Thomas_Aquinas',
#              u'Thomas_Berry',
#              u'Thomas_Bradwardine',
#              u'Thomas_Henry_Huxley',
#              u'Thomas_Hill_Green',
#              u'Thomas_Hobbes',
#              u'Thomas_Nagel',
#              u'Thomas_Reid',
#              u'Thoralf_Skolem',
#              u'Thucydides',
#              u'Th\xe9odore_Simon_Jouffroy',
#              u'Todd_May',
#              u'Toju_Nakae',
#              u'Tom_Beauchamp',
#              u'Tom_Regan',
#              u'Tomek_Pietkiewicz',
#              u'Tony_Honor\xe9',
#              u'Trenton_Merricks',
#              u'Tripp_York',
#              u'Tudor_Vianu',
#              u'Udayana',
#              u'Umar_bin_al-Khattab',
#              u'Umberto_Eco',
#              u'Valentin_Feldman',
#              u'Vernon_Lee',
#              u'Victor_Basch',
#              u'Victor_Cousin',
#              u'Victor_Gollancz',
#              u'Virgil_Aldrich',
#              u'Vissarion_Belinsky',
#              u'Vladimir_Andreyevich_Uspensky',
#              u'Voltaire',
#              u'Voltairine_de_Cleyre',
#              u'W.K._Wimsatt',
#              u'W.V.O._Quine',
#              u'W._D._Ross',
#              u'W._Hugh_Woodin',
#              u'Walter_Benjamin',
#              u'Walter_Burley',
#              u'Walter_Pater',
#              u'Walter_Pitts',
#              u'Walter_Terence_Stace',
#              u'Warren_Buffett',
#              u'Wau_Holland',
#              u'Wesley_J._Smith',
#              u'Wesley_Newcomb_Hohfeld',
#              u'Wilhelm_Ackermann',
#              u'Wilhelm_Dilthey',
#              u'Willard_V._O._Quine',
#              u'Willard_Van_Orman_Quine',
#              u'William_Alston',
#              u'William_Alvin_Howard',
#              u'William_C._Dowling',
#              u'William_Craig_(logician)',
#              u'William_Ernest_Johnson',
#              u'William_Fontaine',
#              u'William_George_Ward',
#              u'William_James',
#              u'William_K._Frankena',
#              u'William_Lycan',
#              u'William_Paley',
#              u'William_Stanley_Jevons',
#              u'William_Sweet',
#              u'William_Whewell',
#              u'William_Wollaston',
#              u'William_of_Ockham',
#              u'William_of_Sherwood',
#              u'Wolfgang_Smith',
#              u'Wu_Enyu',
#              u'Xavier_Zubiri',
#              u'Xenocrates',
#              u'Xenophanes',
#              u'Xun_Kuang',
#              u'Xun_Zi',
#              u'Yamaga_Sok\u014d',
#              u'Yamazaki_Ansai',
#              u'Yehoshua_Bar-Hillel',
#              u'Yi_I',
#              u'Yiannis_N._Moschovakis',
#              u'Young_Hegelians',
#              u'Yuri_Matiyasevich',
#              u'Yusuf_Balasagun',
#              u'Yves_Marie_Andr\xe9',
#              u'Zalman_Schachter-Shalomi',
#              u'Zeno_of_Elea',
#              u'Zhuang_Zhou',
#              u'Ziauddin_Sardar',
#              u'\xc9tienne_de_La_Bo\xe9tie',
#              u'\xdeorsteinn_Gylfason',
#              u'\u0130oanna_Ku\xe7uradi']),
#  'epistemologists': [u'William_Alston',
#                      u'Thomas_Aquinas',
#                      u'Aristotle',
#                      u'Robert_Audi',
#                      u'A._J._Ayer',
#                      u'Francis_Bacon',
#                      u'George_Berkeley',
#                      u'Harry_Binswanger',
#                      u'David_Bohm',
#                      u'Laurence_Bonjour',
#                      u'Berit_Brogaard',
#                      u'Mario_Bunge',
#                      u'Judith_Butler',
#                      u'David_Chalmers',
#                      u'Noam_Chomsky',
#                      u'Jonathan_Dancy',
#                      u'Simone_de_Beauvoir',
#                      u'Ren\xe9_Descartes',
#                      u'Fred_Dretske',
#                      u'Nader_El-Bizri',
#                      u'Margaret_Elizabeth_Egan',
#                      u'Catherine_Elgin',
#                      u'Heinz_von_Foerster',
#                      u'Edmund_Gettier',
#                      u'Ernst_von_Glasersfeld',
#                      u'Alvin_Goldman',
#                      u'Emma_Goldman',
#                      u'Nelson_Goodman',
#                      u'John_Greco_(philosopher)',
#                      u'Paul_Grice',
#                      u'Susan_Haack',
#                      u'Donna_Haraway',
#                      u'Sandra_Harding',
#                      u'Gilbert_Harman',
#                      u'Sally_Haslanger',
#                      u'Friedrich_A._Hayek',
#                      u'G.W.F._Hegel',
#                      u'John_Hawthorne',
#                      u'Thomas_Hobbes',
#                      u'David_Hume',
#                      u'James_VI_and_I',
#                      u'Carrie_Ichikawa_Jenkins',
#                      u'Immanuel_Kant',
#                      u'S\xf8ren_Kierkegaard',
#                      u'Peter_D._Klein',
#                      u'Hilary_Kornblith',
#                      u'Jennifer_Lackey',
#                      u'Keith_Lehrer',
#                      u'Isaac_Levi',
#                      u'David_Lewis_(philosopher)',
#                      u'Peter_Lipton',
#                      u'John_Locke',
#                      u'Niklas_Luhmann',
#                      u'Norman_Malcolm',
#                      u'Terence_McKenna',
#                      u'Trenton_Merricks',
#                      u'Ludwig_von_Mises',
#                      u'Jean-Louis_Le_Moigne',
#                      u'George_Edward_Moore',
#                      u'Edgar_Morin',
#                      u'Mioara_Mugur-Sch\xe4chter',
#                      u'Robert_Nozick',
#                      u'William_of_Ockham',
#                      u'George_Pappas',
#                      u'L.A._Paul',
#                      u'Leonard_Peikoff',
#                      u'Jean_Piaget',
#                      u'Tomek_Pietkiewicz',
#                      u'Gualtiero_Piccinini',
#                      u'Alvin_Plantinga',
#                      u'Plato',
#                      u'Louis_Pojman',
#                      u'Karl_Popper',
#                      u'W.V.O._Quine',
#                      u'Ayn_Rand',
#                      u'Sherrilyn_Roush',
#                      u'Bertrand_Russell',
#                      u'John_Searle',
#                      u'Susanna_Schellenberg',
#                      u'Susanna_Siegel',
#                      u'Socrates',
#                      u'David_Sosa',
#                      u'Ernest_Sosa',
#                      u'Walter_Terence_Stace',
#                      u'Rudolf_Steiner',
#                      u'P._F._Strawson',
#                      u'Barry_Stroud',
#                      u'Nassim_Nicholas_Taleb',
#                      u'Peter_Unger',
#                      u'Jules_Vuillemin',
#                      u'Giambattista_Vico',
#                      u'Gerhard_Vollmer',
#                      u'Phillip_H._Wiebe',
#                      u'Karla_Jessen_Williamson',
#                      u'Jessica_Wilson',
#                      u'Ludwig_Wittgenstein',
#                      u'Xenophanes',
#                      u'Linda_Trinkaus_Zagzebski',
#                      u'James_Frederick_Ferrier'],
#  'ethicists': [u'Pierre_Ab\xe9lard',
#                u'B._R._Ambedkar',
#                u'John_Stevens_Cabot_Abbott',
#                u'Mortimer_Adler',
#                u'Nayef_Al-Rodhan',
#                u'Thomas_Aquinas',
#                u'Nomy_Arpaly',
#                u'Ambrose',
#                u'Andronicus_of_Rhodes',
#                u'Julia_Annas',
#                u'G._E._M._Anscombe',
#                u'Karl-Otto_Apel',
#                u'Jacob_M._Appel',
#                u'Aristotle',
#                u'Aristoxenus',
#                u'John_Arthur_(philosopher)',
#                u'Ashoka',
#                u'Augustine_of_Hippo',
#                u'Avicenna',
#                u'Joxe_Azurmendi',
#                u"Bah\xe1'u'll\xe1h",
#                u'Franz_Xaver_von_Baader',
#                u'Francis_Bacon',
#                u'Alain_Badiou',
#                u'Samuel_Bailey',
#                u'Tom_Beauchamp',
#                u'Friedrich_Eduard_Beneke',
#                u'Jeremy_Bentham',
#                u'Thomas_Berry',
#                u'Maurice_Blanchot',
#                u'Dietrich_Bonhoeffer',
#                u'Murray_Bookchin',
#                u'George_Boole',
#                u'Nick_Bostrom',
#                u'Daniel_Brock',
#                u'Martin_Buber',
#                u'Gautama_Buddha',
#                u'Mario_Bunge',
#                u'Judith_Butler',
#                u'Albert_Camus',
#                u'Arthur_Caplan',
#                u'Roger_Chao',
#                u'James_Childress',
#                u'Randy_Cohen',
#                u'Confucius',
#                u'John_M._Cooper',
#                u'Alice_Crary',
#                u'Roger_Crisp',
#                u'Simon_Critchley',
#                u'David_Crocker',
#                u'Mary_Daly',
#                u'Norman_Daniels',
#                u'Partha_Dasgupta',
#                u'Abraham_ibn_Daud',
#                u'Miguel_A._De_La_Torre',
#                u'Cora_Diamond',
#                u'Philip_Doddridge',
#                u'Elliot_N._Dorff',
#                u'Julia_Driver',
#                u'Ronald_Dworkin',
#                u'Epicurus',
#                u'Rudolf_Christoph_Eucken',
#                u'Johann_Albert_Fabricius',
#                u"Ismail_Raji'_al-Faruqi",
#                u'Nosson_Tzvi_Finkel_(Slabodka)',
#                u'John_Finnis',
#                u'Joseph_Fins',
#                u'Owen_Flanagan',
#                u'Joseph_Fletcher',
#                u'Philippa_Foot',
#                u'William_K._Frankena',
#                u'Alexander_Campbell_Fraser',
#                u'R._Edward_Freeman',
#                u'Raymond_Frey',
#                u'Erich_Fromm',
#                u'Raimond_Gaita',
#                u'Mohandas_Gandhi',
#                u'David_Gauthier',
#                u'Alan_Gewirth',
#                u'Ghazali',
#                u'Allan_Gibbard',
#                u'Carol_Gilligan',
#                u'Peter_Goldie',
#                u'Victor_Gollancz',
#                u'Thomas_Hill_Green',
#                u'Stanley_Grenz',
#                u'Hugo_Grotius',
#                u'Tenzin_Gyatso',
#                u'J\xfcrgen_Habermas',
#                u'Hammurabi',
#                u'R._M._Hare',
#                u'Elizabeth_Harman_(disambiguation)',
#                u'Gilbert_Harman',
#                u'John_Harsanyi',
#                u'Robert_S._Hartman',
#                u'Stanley_Hauerwas',
#                u'Henry_Hazlitt',
#                u'Paul_Hawken',
#                u'Martin_Heidegger',
#                u'Erich_Heller',
#                u'Claude_Adrien_Helv\xe9tius',
#                u'Frank_Herbert',
#                u'Abraham_Joshua_Heschel',
#                u'Hierocles_of_Alexandria',
#                u'James_Hinton',
#                u'Wau_Holland',
#                u'Hans-Hermann_Hoppe',
#                u'David_Hume',
#                u'John_Peters_Humphrey',
#                u'Edward_Hundert',
#                u'Rosalind_Hursthouse',
#                u'Francis_Hutcheson_(philosopher)',
#                u'Thomas_Henry_Huxley',
#                u'Lauri_Ingman',
#                u'T._H._Irwin',
#                u'Alija_Izetbegovi\u0107',
#                u'Jane_Jacobs',
#                u'Paul_Janet',
#                u'Francis_Jeffrey',
#                u'Th\xe9odore_Simon_Jouffroy',
#                u'Jesus',
#                u'Shelly_Kagan',
#                u'Immanuel_Kant',
#                u'Rushworth_Kidder',
#                u'S\xf8ren_Kierkegaard',
#                u'Martin_Luther_King,_Jr.',
#                u'\u0130oanna_Ku\xe7uradi',
#                u'Israel_Kirzner',
#                u'Lawrence_Kohlberg',
#                u'Mario_Kopi\u0107',
#                u'Christine_Korsgaard',
#                u'David_Korten',
#                u'Peter_Kropotkin',
#                u'Hans_K\xfcng',
#                u'Aldo_Leopold',
#                u'Barron_H._Lerner',
#                u'Emmanuel_Levinas',
#                u'John_Locke',
#                u'Antoine_Garaby_de_La_Luzerne',
#                u'Moshe_Chaim_Luzzatto',
# ...
#                                        u'Bertrand_Russell',
#                                        u'B._R._Ambedkar',
#                                        u'Boris_Furlan',
#                                        u'Bruce_Lee',
#                                        u'Bruno_Leoni',
#                                        u'Bryan_Caplan',
#                                        u'Carl_Joachim_Friedrich',
#                                        u'Carl_Schmitt',
#                                        u'Carlo_Lottieri',
#                                        u'Chanakya',
#                                        u'Charles_Blattberg',
#                                        u'Montesquieu',
#                                        u'Charles_Taylor_(philosopher)',
#                                        u'Cheng_Hao',
#                                        u'Cheng_Yi_(philosopher)',
#                                        u'Claude_Lefort',
#                                        u'Claude_L\xe9vi-Strauss',
#                                        u'Claudio_Canaparo',
#                                        u'Confucius',
#                                        u'Constantin_R\u0103dulescu-Motru',
#                                        u'Cornel_West',
#                                        u'Cornelius_Castoriadis',
#                                        u'Costas_Douzinas',
#                                        u'Dana_Ward',
#                                        u'Daniel_Gu\xe9rin',
#                                        u'David_D._Friedman',
#                                        u'David_Kolb',
#                                        u'David_Miller_(political_theorist)',
#                                        u'David_Prychitko',
#                                        u'Dimitris_Dimitrakos',
#                                        u'Disciples_of_Confucius',
#                                        u'Dong_Zhongshu',
#                                        u'Duncan_Kennedy_(legal_philosopher)',
#                                        u'Edward_Said',
#                                        u'Emma_Goldman',
#                                        u'Enrique_Dussel',
#                                        u'Eric_Voegelin',
#                                        u'Ernest_Wamba_dia_Wamba',
#                                        u'Ernst_Bloch',
#                                        u'\xc9tienne_de_La_Bo\xe9tie',
#                                        u'Eugen_Rosenstock-Huessy',
#                                        u'F\xe9lix_Guattari',
#                                        u'Felix_Kaufmann',
#                                        u"Francesco_D'Andrea",
#                                        u'Francis_Fukuyama',
#                                        u'Francis_Parker_Yockey',
#                                        u'Frank_Meyer_(political_philosopher)',
#                                        u'Friedrich_Hayek',
#                                        u'Fujiwara_Seika',
#                                        u'Gary_Chartier',
#                                        u'Gene_Callahan_(economist)',
#                                        u'Georg_Jellinek',
#                                        u'Georg_Wilhelm_Friedrich_Hegel',
#                                        u'George_Kateb',
#                                        u'George_Ohsawa',
#                                        u'Georges_Bataille',
#                                        u'Gerald_Cohen',
#                                        u'Gerald_Dworkin',
#                                        u'Gerrard_Winstanley',
#                                        u'Giacomo_Marramao',
#                                        u'Giambattista_Vico',
#                                        u'Gianfranco_Sanguinetti',
#                                        u'Giannina_Braschi',
#                                        u'Giorgio_Agamben',
#                                        u'Giorgio_Del_Vecchio',
#                                        u'Gottfried_Leibniz',
#                                        u'Gustave_de_Molinari',
#                                        u'Guy_Aldred',
#                                        u'Guy_Debord',
#                                        u'H._B._Acton',
#                                        u'H._L._A._Hart',
#                                        u'Han_Fei',
#                                        u'Han_Ryner',
#                                        u'Hannah_Arendt',
#                                        u'Hans_Achterhuis',
#                                        u'Hans_Kelsen',
#                                        u'Hans_K\xf6chler',
#                                        u'Har_Dayal',
#                                        u'Harriet_Taylor_Mill',
#                                        u'Hayashi_Razan',
#                                        u'Henri_Lefebvre',
#                                        u'Henry_David_Thoreau',
#                                        u'Henry_George',
#                                        u'Henry_Home,_Lord_Kames',
#                                        u'Henry_Pachter',
#                                        u'Henry_Sidgwick',
#                                        u'Herbert_Spencer',
#                                        u'Herman_Oliphant',
#                                        u'Hirata_Atsutane',
#                                        u'Horace_Romano_Harr\xe9',
#                                        u'Houston_Stewart_Chamberlain',
#                                        u'Howard_Zinn',
#                                        u'Hugo_Grotius',
#                                        u'Igor_Pribac',
#                                        u'Immanuel_Kant',
#                                        u'Inayatullah_Khan_Mashriqi',
#                                        u'Iris_Marion_Young',
#                                        u'Isabel_Paterson',
#                                        u'Isaiah_Berlin',
#                                        u'Israr_Ahmed',
#                                        u'It\u014d_Jinsai',
#                                        u'Ivan_Svit\xe1k',
#                                        u'J._J._C._Smart',
#                                        u'Jacques_Ranci\xe8re',
#                                        u'Jack_Russell_Weinstein',
#                                        u'James_Brusseau',
#                                        u'James_Tully_(philosopher)',
#                                        u'Jamie_Whyte',
#                                        u'Janet_Biehl',
#                                        u'Janet_Coleman',
#                                        u'Jawaharlal_Nehru',
#                                        u'Jean_Bodin',
#                                        u'Jean-Fran\xe7ois_Lyotard',
#                                        u'Jean-Jacques_Rousseau',
#                                        u'Jeffrey_Friedman_(political_scientist)',
#                                        u'Jeremy_Bentham',
#                                        u'John_Austin_(legal_philosopher)',
#                                        u'John_Burnheim',
#                                        u'John_Finnis',
#                                        u'John_Hospers',
#                                        u'John_Locke',
#                                        u'John_Oswald_(activist)',
#                                        u'John_Rawls',
#                                        u'John_Searle',
#                                        u'John_Stuart_Mill',
#                                        u'John_William_Miller',
#                                        u'John_Zerzan',
#                                        u'Jonathan_Wolff_(philosopher)',
#                                        u'Joseph_de_Torre',
#                                        u'Joseph_Priestley_and_Dissent',
#                                        u'Joseph_Priestley',
#                                        u'Joseph_Raz',
#                                        u'Joshua_Cohen_(philosopher)',
#                                        u'Joxe_Azurmendi',
#                                        u'Judith_Butler',
#                                        u'Julian_Gumperz',
#                                        u'Julien_Offray_de_La_Mettrie',
#                                        u'Julius_Binder',
#                                        u'J\xfcrgen_Habermas',
#                                        u'Kaibara_Ekken',
#                                        u'Karl_Loewenstein',
#                                        u'Karl_Marx',
#                                        u'Karl_Popper',
#                                        u'Karl-Otto_Apel',
#                                        u'Kevin_Carson',
#                                        u'Langdon_Winner',
#                                        u'Leonard_Borgzinner',
#                                        u'Leonard_Read',
#                                        u'Leonidas_Donskis',
#                                        u'Lewis_Call',
#                                        u'Lon_L._Fuller',
#                                        u'Loren_Lomasky',
#                                        u'Lorenzo_Pe\xf1a',
#                                        u'Louis_Althusser',
#                                        u'Ludwig_von_Mises',
#                                        u'Lysander_Spooner',
#                                        u'Manuel_De_Landa',
#                                        u'Mao_Zedong',
#                                        u'Margaret_Canovan',
#                                        u'Mario_Bunge',
#                                        u'Mario_Tronti',
#                                        u'Martha_Nussbaum',
#                                        u'Martin_Luther_King,_Jr.',
#                                        u'Maurice_Brinton',
#                                        u'Maurice_Cranston',
#                                        u'Max_Baginski',
#                                        u'Max_Horkheimer',
#                                        u'Max_Stirner',
#                                        u'Mazdak',
#                                        u'Mencius',
#                                        u'Michael_Davis_(philosopher)',
#                                        u'Michael_Novak',
#                                        u'Michael_Oakeshott',
#                                        u'Michael_Otsuka',
#                                        u'Michel_Foucault',
#                                        u'Michel_Onfray',
#                                        u'Mihailo_Markovi\u0107',
#                                        u'Mikelis_Avlichos',
#                                        u'Mikhail_Bakunin',
#                                        u'Milan_Kangrga',
#                                        u'Mohandas_Karamchand_Gandhi',
#                                        u'Monarchomachs',
#                                        u'Mortimer_Adler',
#                                        u'Mozi',
#                                        u'Muhammad',
#                                        u'Muhammad_Asad',
#                                        u'Muhammad_Iqbal',
#                                        u'Murray_Bookchin',
#                                        u'Murray_Rothbard',
#                                        u'Nancy_Cartwright_(philosopher)',
#                                        u'Nestor_Makhno',
#                                        u'Niccol\xf2_Machiavelli',
#                                        u'Nigel_Warburton',
#                                        u'Noam_Chomsky',
#                                        u'Norbert_Bolz',
#                                        u'Norbert_Leser',
#                                        u'Octave_Mirbeau',
#                                        u'Ogy\u016b_Sorai',
#                                        u'Oliver_Wendell_Holmes,_Jr.',
#                                        u'Oskar_Negt',
#                                        u'Paolo_Virno',
#                                        u'Paul_R._Patton',
#                                        u'Paul_Virilio',
#                                        u'Pekka_Himanen',
#                                        u'Per_Bauhn',
#                                        u'Peter_Kropotkin',
#                                        u'Peter_Lamborn_Wilson',
#                                        u'Peter_Sloterdijk',
#                                        u'Phaleas_of_Chalcedon',
#                                        u'Philip_Mazzei',
#                                        u'Philip_Pettit',
#                                        u'Philippe_Van_Parijs',
#                                        u'Pierre_Bourdieu',
#                                        u'Pierre-Andr\xe9_Taguieff',
#                                        u'Plato',
#                                        u'Fred_Poch\xe9',
#                                        u'Rada_Ivekovi\u0107',
#                                        u'Rainer_Forst',
#                                        u'Raya_Dunayevskaya',
#                                        u'Richard_M._Weaver',
#                                        u'Right_Hegelians',
#                                        u'Roberto_Esposito',
#                                        u'Robert_P._George',
#                                        u'Robert_Paul_Wolff',
#                                        u'Roberto_Mangabeira_Unger',
#                                        u'Roderick_Long',
#                                        u'Ronald_Dworkin',
#                                        u'Russell_Kirk',
#                                        u'Serge_Moscovici',
#                                        u'Shmuel_Alexandrov',
#                                        u'Simone_Weil',
#                                        u'Slavoj_\u017di\u017eek',
#                                        u'Spencer_Heath',
#                                        u'Stephen_Bronner',
#                                        u'Sun_Yat-sen',
#                                        u'T._M._Scanlon',
#                                        u'Takis_Fotopoulos',
#                                        u'Tan_Sitong',
#                                        u'Tara_Smith_(philosopher)',
#                                        u'Theodor_Sternberg',
#                                        u'Theodor_W._Adorno',
#                                        u'Thomas_Aquinas',
#                                        u'Thomas_Hill_Green',
#                                        u'Thomas_Hobbes',
#                                        u'Thomas_Nagel',
#                                        u'\xdeorsteinn_Gylfason',
#                                        u'Thucydides',
#                                        u'Todd_May',
#                                        u'Toju_Nakae',
#                                        u'Tony_Honor\xe9',
#                                        u'Tripp_York',
#                                        u'Umar_bin_al-Khattab',
#                                        u'Voltaire',
#                                        u'Voltairine_de_Cleyre',
#                                        u'Walter_Benjamin',
#                                        u'Warren_Buffett',
#                                        u'Wesley_Newcomb_Hohfeld',
#                                        u'Wilhelm_Dilthey',
#                                        u'William_Fontaine',
#                                        u'William_James',
#                                        u'William_Paley',
#                                        u'William_Sweet',
#                                        u'Wu_Enyu',
#                                        u'Xun_Zi',
#                                        u'Yamaga_Sok\u014d',
#                                        u'Yamazaki_Ansai',
#                                        u'Yi_I',
#                                        u'Young_Hegelians',
#                                        u'Zhuang_Zhou']}

# %% [markdown]
# >
# > We're going to have to go and extract the page names for all six groups of philosophers. Unfortunately wikipedia does not have a uniform way of setting such pages up, so you'll have to do each page differently. And I'd like you to maintain **seven** (7) separate lists of philosophers. One for each branch of philosophy - and one combined list of all philosophers.
# >
# > * Let's put together some descriptive statistics:
# >   * How many philosophers in each list? How many total?

# %%
for x in all_matches:
    if x == 'all':
        print 'All (unique) philosophers together are:', len(all_matches[x])
    else:
        print 'Philosophers in list "{0}" are all together {1}'.format(x, len(all_matches[x]))
# Out:
# All (unique) philosophers together are: 1010
# Philosophers in list "aestheticians" are all together 126
# Philosophers in list "logicians" are all together 271
# Philosophers in list "epistemologists" are all together 99
# Philosophers in list "social_and_political_philosophers" are all together 295
# Philosophers in list "metaphysicians" are all together 96
# Philosophers in list "ethicists" are all together 272

# %% [markdown]
# >   * Which is the largest branch of philosophy?

# %%
largest_branch = (0, None)
for x in all_matches:
    if x == 'all':
        continue
    if len(all_matches[x]) > largest_branch[0]:
        largest_branch = (len(all_matches[x]), x)
print 'The largest branch is "{0}" with {1} members'.format(largest_branch[1], largest_branch[0])
# Out:
# The largest branch is "social_and_political_philosophers" with 295 members

# %%
from collections import Counter

cnt = Counter()
for x in all_matches:
    if x == 'all':
        continue
    cnt[x] = len(all_matches[x])

maximum = max(list(cnt.values()))
# there might be more than one maximum, thus iterate
for x in cnt:
    if cnt[x] == maximum:
        print 'The largest branch is "{0}" with {1} members.'.format(x, maximum)
# Out:
# The largest branch is "social_and_political_philosophers" with 295 members.

# %% [markdown]
# >   * Are some philosophers in more than one list?

# %%
cnt = Counter()
for x in all_matches:
    if x == 'all':
        continue
    for i in all_matches[x]:
        cnt[i] += 1
print 'There are {0} philosophers in more than one list.'.format(len([x for x in cnt if cnt[x] > 1]))
# Out:
# There are 117 philosophers in more than one list.

# %% [markdown]
# >   * Which philosopher is in most lists & and how many?

# %%
cnt = Counter()
for x in all_matches:
    if x == 'all':
        continue
    for i in all_matches[x]:
        cnt[i] += 1
        
maximum = max(list(cnt.values()))
# there might be more than one maximum, thus iterate
for x in cnt:
    if cnt[x] == maximum:
        print 'The philosopher {0} is in {1} lists.'.format(x, maximum)
# Out:
# The philosopher Thomas_Aquinas is in 6 lists.
# The philosopher Aristotle is in 6 lists.

# %% [markdown]
# >   * Let's investigate philosophers active in multiple sub-fields. Create a list of every philosopher that occurs in more than one list. Use Python to sort the list according to how many lists each philosopher belongs to (so the guy you found in the previous question is first in that list).
# >

# %%
cnt = Counter()
for x in all_matches:
    if x == 'all':
        continue
    for i in all_matches[x]:
        cnt[i] += 1
print sorted([(x, cnt[x]) for x in cnt if cnt[x] > 1], key=lambda x: x[1], reverse=True)
# Out:
# [(u'Thomas_Aquinas', 6), (u'Aristotle', 6), (u'Plato', 5), (u'Bertrand_Russell', 5), (u'Immanuel_Kant', 5), (u'Ayn_Rand', 4), (u'Georg_Wilhelm_Friedrich_Hegel', 3), (u'S\xf8ren_Kierkegaard', 3), (u'Ludwig_Wittgenstein', 3), (u'Judith_Butler', 3), (u'Nelson_Goodman', 3), (u'David_Hume', 3), (u'John_Stuart_Mill', 3), (u'Ruth_Barcan_Marcus', 3), (u'Mario_Bunge', 3), (u'Susan_Haack', 3), (u'John_Locke', 3), (u'Arthur_Schopenhauer', 3), (u'Gottfried_Leibniz', 3), (u'Mortimer_Adler', 2), (u'Peter_Unger', 2), (u'Friedrich_Nietzsche', 2), (u'Socrates', 2), (u'Peter_Geach', 2), (u'Gottlob_Frege', 2), (u'Mozi', 2), (u'Robert_Nozick', 2), (u'Martin_Heidegger', 2), (u'Baruch_Spinoza', 2), (u'Kit_Fine', 2), (u'Maurice_Blanchot', 2), (u'John_Finnis', 2), (u'Augustine_of_Hippo', 2), (u'J._J._C._Smart', 2), (u'Martin_Luther_King,_Jr.', 2), (u'Jean-Jacques_Rousseau', 2), (u'Georges_Bataille', 2), (u'Michel_Foucault', 2), (u'Giambattista_Vico', 2), (u'Paul_Benacerraf', 2), (u'Nader_El-Bizri', 2), (u'Alain_Badiou', 2), (u'John_Hospers', 2), (u'Philip_Pettit', 2), (u'J\xfcrgen_Habermas', 2), (u'Walter_Benjamin', 2), (u'Hugo_Grotius', 2), (u'John_Hawthorne', 2), (u'B._R._Ambedkar', 2), (u'Karl_Wilhelm_Friedrich_von_Schlegel', 2), (u'Herbert_Spencer', 2), (u'Catherine_Elgin', 2), (u'Sally_Haslanger', 2), (u'Robert_S._Hartman', 2), (u'John_Searle', 2), (u'Jean-Fran\xe7ois_Lyotard', 2), (u'Mao_Zedong', 2), (u'P._F._Strawson', 2), (u'Murray_Rothbard', 2), (u'Murray_Bookchin', 2), (u'Alfred_North_Whitehead', 2), (u'Trenton_Merricks', 2), (u'Jeremy_Bentham', 2), (u'Walter_Terence_Stace', 2), (u'George_Berkeley', 2), (u'Emma_Goldman', 2), (u'Francis_Bacon', 2), (u'Abraham_Joshua_Heschel', 2), (u'Ren\xe9_Descartes', 2), (u'Peter_of_Spain_(author)', 2), (u'Ludwig_von_Mises', 2), (u'Paul_of_Venice', 2), (u'Saul_Kripke', 2), (u'Noam_Chomsky', 2), (u'Thomas_Nagel', 2), (u'John_Ruskin', 2), (u'Gualtiero_Piccinini', 2), (u'Jessica_Wilson', 2), (u'Gilbert_Harman', 2), (u'G._E._Moore', 2), (u'Sun_Yat-sen', 2), (u'Mencius', 2), (u'Alvin_Plantinga', 2), (u'Karl_Popper', 2), (u'Niccol\xf2_Machiavelli', 2), (u'T._M._Scanlon', 2), (u'William_Alston', 2), (u'Christian_Wolff_(philosopher)', 2), (u'Lorenzo_Pe\xf1a', 2), (u'Ronald_Dworkin', 2), (u'Peter_Kropotkin', 2), (u'Henry_Sidgwick', 2), (u'David_Chalmers', 2), (u'Hilary_Putnam', 2), (u'Max_Stirner', 2), (u'Graham_Priest', 2), (u'Michel_Onfray', 2), (u'L.A._Paul', 2), (u'Constantin_R\u0103dulescu-Motru', 2), (u'William_of_Ockham', 2), (u'David_Kolb', 2), (u'Karl-Otto_Apel', 2), (u'Joseph_Raz', 2), (u'Berit_Brogaard', 2), (u'Martha_Nussbaum', 2), (u'Thomas_Hill_Green', 2), (u'Confucius', 2), (u'Judith_Jarvis_Thomson', 2), (u'Edward_Said', 2), (u'Friedrich_Schiller', 2), (u'Penelope_Maddy', 2), (u'Thomas_Hobbes', 2), (u'Michael_Oakeshott', 2), (u'John_Rawls', 2), (u'Francis_Hutcheson_(philosopher)', 2), (u'Joxe_Azurmendi', 2), (u'George_Boole', 2)]

# %% [markdown]
# Now that we have the names, it's time to download all of the pages. Use your experience with APIs from Week 1\. To get started, I **strongly** recommend that you re-watch the **APIs video lecture** from that week - it contains lots of useful tips on this specific activity (yes, I had planned this all along!). I've included it below for your covenience.

# %%
YouTubeVideo("9l5zOfh0CRo",width=800, height=450)

# %% [markdown]
# > _Exercise_: Download wikipages and save them to your own computer. For each of the philosophers in the _combined list_ obtained in the previous exercise, use Wikipedia's API to download the full page content (using python) and save it (get it in `json` format, _AND **don't** get the `html` version of the page which is much more difficult to parse_).
# >
# > This is an important point, so I will repeat it: **Don't** get the `html` version of the page (which is much more difficult to parse_), get the standard [wiki markup](https://en.wikipedia.org/wiki/Help:Wiki_markup) which is what you see when you press "edit" on a wikipedia page.
# >
# > A couple of extra tips below:
# >
# > * Some pages contain unicode characters, so we recommend you save the files using the [`io.open`](http://stackoverflow.com/questions/5250744/difference-between-open-and-codecs-open-in-python) method with `utf-8` encoding
# > * Some philosopher names have spaces. As a first stab, try to simply substitute spaces with underscores. (E.g. `https://en.wikipedia.org/wiki/Thomas_Aquinas` from `Thomas Aquinas`. If that doesn't work, you can construct the api-url using `urllib.quote` (or similar). This is another way of handling spaces using and other non-ascii characters in `url`s using [url encoding](http://www.w3schools.com/tags/ref_urlencode.asp).
# > * Store the content of all pages. It's up to you how to do this. One strategy is to use Python's built in `pickle` format. Or you can simply write the content of wiki-pages to text files and store those in a folder on your computer. I'm sure there are other ways. It's crucial that you store them in a way that's easy to access, since we'll use these pages a lot throughout the remainder of the course (so you don't want to retrieve them from wikipedia every time).
# >

# %%
import urllib
import pickle
import os

# wikipedia API parameters
baseurl = "https://en.wikipedia.org/w/api.php"
action = "action=query"
content = "prop=revisions&rvprop=content"
dataformat = "format=json"

# create dir if not exists
directory = 'philosophers'
if not os.path.exists(directory):
    os.makedirs(directory)

# get content key: philosopher name, value: json
data = dict()
for p_name in all_matches['all']:
    # replace special cahrs in philosopher name with URL encoded
    title = 'titles={0}'.format(urllib.quote(p_name.encode('utf-8')))
    # concatenate wikipedia query
    url = '{0}?{1}&{2}&{3}&{4}'.format(baseurl, action, title, content, dataformat)
    r = requests.get(url)
    data.update({p_name:r.text})

# store philosopher data in one small binary file
with open('{0}/dat.pkl'.format(directory), 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# # Part B: Building the networks
#
# Now, we're going to build a NetworkX directed graph of the links between pages. For each philosopher page, we'll find all the links to other characters, and for each link add an edge in the graph.
# >
# > _Exercise_: Build the philosopher network. The **combined list** from above provides the network nodes. We will use info from the pages to define links. Every time philosopher A's page links to philosopher B's page, we create a directed link from A to B. There are many ways to do this, but below, I've tried to break it down into natural steps.
# >
# > * Use a regular expression to extract all outgoing links from each of the pages you downloaded above. There are many ways to iterate over pages - feel free to choose the one that matches the way you've chosen to store the pages.
# > * For each link you extract, check if the target is in the list you generated above. If yes, keep it. If no, discard it.
# > * Use a NetworkX [`DiGraph`](http://networkx.lanl.gov/reference/classes.digraph.html) to store the network.
# >

# %%
import re
import networkx as nx

# get data dictionary
with open('{0}/dat.pkl'.format(directory), 'rb') as f:
    dat = pickle.load(f)

# create one node per philosopher name (keys of data)
p_graph = nx.DiGraph()
p_graph.add_nodes_from(dat.keys())

# %%
# create node links
for p in dat:
    p_content = dat[p]
    # find all wiki links in the content
    p_links = re.findall(r'\[\[(.+?)\]\]', p_content)
    # list with all outgoing links for edges
    # decode unicode chars and clean the link for matching
    out_links = [l.decode('unicode-escape').split('|')[0].replace(' ', '_') for l in p_links]

    # intersection between all philosophers and found links in article
    all_edges = set(dat.keys()).intersection(out_links)
    # show example of related philosophers
    if p == 'Immanuel_Kant':
        print all_edges

    # add an edge for the philosopher
    for e in all_edges:
        p_graph.add_edge(p, e)
# Out:
# set([u'Jean_Piaget', u'Johann_Gottfried_Herder', u'Friedrich_Wilhelm_Joseph_von_Schelling', u'August_Wilhelm_Schlegel', u'Baruch_Spinoza', u'Roger_Scruton', u'John_Locke', u'Ren\xe9_Descartes', u'Gotthold_Ephraim_Lessing', u'Robert_Nozick', u'Plato', u'John_McDowell', u'Arthur_Schopenhauer', u'Jean-Jacques_Rousseau', u'Houston_Stewart_Chamberlain', u'Nicolai_Hartmann', u'Gottfried_Leibniz', u'David_Hilbert', u'Christian_Wolff_(philosopher)', u'P._F._Strawson', u'Epicurus', u'Gilles_Deleuze', u'Bertrand_Russell', u'Georg_Simmel', u'Friedrich_Nietzsche', u'Michel_Foucault', u'Alexander_Gottlieb_Baumgarten', u'Thomas_Henry_Huxley', u'Wilhelm_Dilthey', u'Charles_Sanders_Peirce', u'David_Hume', u'John_Rawls', u'S\xf8ren_Kierkegaard', u'Christine_Korsgaard', u'C._D._Broad', u'Georg_Wilhelm_Friedrich_Hegel', u'Martin_Heidegger', u'Derek_Parfit', u'Noam_Chomsky', u'Aristotle', u'Adam_Smith', u'J\xfcrgen_Habermas', u'Joxe_Azurmendi'])

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

pos = nx.spring_layout(p_graph)
nx.draw(p_graph, pos,node_size=2, edge_color='r', node_color='m', width=0.5)
plt.figure(num=None, figsize=(8, 8), dpi=1200)
plt.show()

# %% [markdown]
# # Part C: Analyzing the networks
#
# Now that we have the network, it's time to do a preliminary analysis of it (we'll go more in depth next time).
#
# > _Exercise_: Begin to analyze the philosopher network.
# >
# > * Why do you think we want to use a directed graph? Could have we used an undirected graph instead?

# %% [markdown]
# No we couldn't use an undirected graph that would imply that one philosopher is linked with another one although there is only a link on one philosophers page.

# %% [markdown]
# > * What is the total number of nodes in the network? What is the total number of links? What's the average degree? What's the median degree?

# %%
import numpy as np

print 'Philosopher network has {0} nodes.'.format(p_graph.number_of_nodes())
print 'Philosopher network has {0} links.'.format(p_graph.number_of_edges())

deg_sequence = sorted(nx.degree(p_graph).values(), reverse=True)

dmean = np.mean(deg_sequence)
dmedian = np.median(np.array(deg_sequence))

print 'The average degree in the philosopher network is', dmean
print 'The median degree in the philosopher network is', dmedian
# Out:
# Philosopher network has 1010 nodes.
# Philosopher network has 4453 links.
# The average degree in the philosopher network is 8.81782178218
# The median degree in the philosopher network is 4.0

# %% [markdown]
# > * List the top 10 philosophers by in-degree and out-degree. What is the interpretation of in-degree and out-degree in this case?

# %%
import operator

print 'Top 10 philosophers by in-degree\n', sorted(p_graph.in_degree_iter(), key=operator.itemgetter(1), reverse=True)[0:10]
print '\n\nTop 10 philosophers by out-degree\n', sorted(p_graph.out_degree_iter(), key=operator.itemgetter(1), reverse=True)[0:10]
# Out:
# Top 10 philosophers by in-degree
# [(u'Immanuel_Kant', 128), (u'Aristotle', 121), (u'Plato', 89), (u'Bertrand_Russell', 85), (u'Karl_Marx', 81), (u'Friedrich_Nietzsche', 65), (u'David_Hume', 65), (u'Ludwig_Wittgenstein', 63), (u'Georg_Wilhelm_Friedrich_Hegel', 57), (u'John_Stuart_Mill', 57)]
#
#
# Top 10 philosophers by out-degree
# [(u'Georg_Wilhelm_Friedrich_Hegel', 49), (u'Friedrich_Nietzsche', 44), (u'Immanuel_Kant', 43), (u'Bertrand_Russell', 40), (u'Martin_Heidegger', 40), (u'David_Hume', 38), (u'S\xf8ren_Kierkegaard', 33), (u'John_Stuart_Mill', 32), (u'Plato', 31), (u'Jean-Jacques_Rousseau', 31)]

# %% [markdown]
# The in-degree relates to how many edges link to the philosopher from other philosophers which could indicate how many built on top of his work or are in some way related or refer to him. According to that Kant was most refered to by other philosophers.
#
# The out degree shows how one particular philosopher is in some connection with others. Hegel has the most connections with other philosophers.

# %% [markdown]
# > Have you heard about these philosophers before?

# %% [markdown]
# Yes these philosophers are all known to us. No matter if Denmark, China or Germany we all talked about them in school. The one's out of the top 10 are, however, less known.

# %% [markdown]
# > * Plot the distribution of in-degrees and out-degrees, binned using `numpy.histogram`. What is the most common degree?

# %%
deg_sequence_in = sorted(p_graph.in_degree().values(), reverse=True)
dmax_in = max(deg_sequence_in)
dmin_in = min(deg_sequence_in)

deg_sequence_out = sorted(p_graph.out_degree().values(), reverse=True)
dmax_out = max(deg_sequence_out)
dmin_out = min(deg_sequence_out)

# set figure
fig = plt.figure(num=None, figsize=(14, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Distribution of in-degrees and out-degrees philosopher network (linear)', fontsize=28)

# generate histograms
p_bin_in = xrange(dmin_in, dmax_in+1)
hist_in, bin_edg_in = np.histogram(deg_sequence_in, bins=p_bin_in)

p_bin_out = xrange(dmin_out, dmax_out+1)
hist_out, bin_edg_out = np.histogram(deg_sequence_out, bins=p_bin_out)

# set histogram data and dimension
plt.subplot('211')
plt.plot(bin_edg_in[:-1], hist_in, 'ro', color='blue', markersize=4, clip_on=False)
plt.axis([min(bin_edg_in), max(bin_edg_in), min(hist_in), max(hist_in)])

plt.ylabel("count")
plt.title("in-degree")

plt.subplot('212')
plt.plot(bin_edg_out[:-1], hist_out, 'ro', color='blue', markersize=4, clip_on=False)
plt.axis([min(bin_edg_out), max(bin_edg_out), min(hist_out), max(hist_out)])
plt.xlabel('k')
plt.ylabel('count')
plt.title("out-degree")
plt.show()

print "Most common in-degree:", np.median(np.array(deg_sequence_in))
print "Most common out-degree:", np.median(np.array(deg_sequence_out))
# Out:
# Most common in-degree: 1.0
# Most common out-degree: 2.0

# %% [markdown]
# The most common out and in-degree relate to the median degree.

# %% [markdown]
# > * Plot the distribution of in-degrees and out-degrees one more time, this time plotted loglog scale.

# %%
fig = plt.figure(num=None, figsize=(14, 10), dpi=80, facecolor='w', edgecolor='k')
fig.suptitle('Distribution of in-degrees and out-degrees philosopher network (loglog)', fontsize=28)

plt.subplot('211')
plt.loglog(bin_edg_in[:-1], hist_in, 'ro', color='blue', markersize=4, clip_on=False)
plt.ylabel("count")
plt.title("in-degree")

plt.subplot('212')
plt.loglog(bin_edg_out[:-1], hist_out, 'ro', color='blue', markersize=4, clip_on=False)
plt.axis([min(bin_edg_out), max(bin_edg_out), min(hist_out), max(hist_out)])
plt.xlabel('k')
plt.ylabel('count')
plt.title("out-degree")
plt.show()

# %% [markdown]
# > * Describe the distributions (as you would in a well written figure caption). Do they look Poissonian? Power-law? Something in between?

# %% [markdown]
# * The in-degree distribution in the philosophers network follows the power-law. A popular philosopher gets much more attention. The incoming links follow preferential attachment.
# * The out-degree distribution follows something between power-law and poisson, because a document cannot be infinitely long and thus have innumerable out-degree links.

# %% [markdown]
# > * Plot a scatter plot of the the in- versus out- degree for all philosophers using a loglog scale. Comment on the relation between the two.

# %%
in_deg_val = p_graph.in_degree().values()
out_deg_val = p_graph.out_degree().values()

fig, ax = plt.subplots()

ax.set_title("Philosopher network in-degree vs. out-degree", fontsize=14)
ax.set_xlabel("out-degree", fontsize=12)
ax.set_ylabel("in-degree", fontsize=12)

ax.grid(True, linestyle='-', color='0.75')
ax.set_xlim([1, max(in_deg_val) * 2])
ax.set_ylim([1, max(out_deg_val) * 2])
ax.set_xscale('log')
ax.set_yscale('log')

plt.scatter(in_deg_val, out_deg_val, alpha=0.5)

plt.show()

print 'Correlation coefficient is: {0}'.format(np.corrcoef(x=out_deg_val, y=in_deg_val)[0,1])
# Out:
# Correlation coefficient is: 0.792641674077

# %% [markdown]
# The relation between the two plots is positive correlation. (Correlation coefficient between in and out-degree is around 0.79)
